# %% [markdown]
# # Creating genes mapping table

# %% [markdown]
# **General steps to build the genes mapping table:**
#
# > I / Install missing modules and

# %% [markdown]
# # I / Install missing modules & load modules

# %%
import pandas as pd
import numpy as np
import cobra
import requests # requests module allows us to send HTTP requests
import sys

# %%
from urllib.error import HTTPError

# %%
#If this doesn't run install pandarallel in your conda enviroment using conda or pip
#https://github.com/nalepae/pandarallel 

# => Problem to install pandarallel => seems to work with Python version 3.{5, 6, 7, 8}, not 3.9
# => Create a new environment containing the same packages, but changing the version of Python : Python 3.8
# Then, try to install pandarallel

# => For this gene mapping, use the environment named env_aracore_update_gene_mapping => same problem
# same problem for all the versions of python...

from pandarallel import pandarallel 

pandarallel.initialize(progress_bar=True)

from pandarallel.utils import progress_bars
progress_bars.is_notebook_lab = lambda : True
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# # II / Load AraCore model

# %%
#Get file from github
fileName = 'https://raw.githubusercontent.com/ma-blaetke/CBM_C3_C4_Metabolism/master/data/2018-23-05-mb-genC3.sbml'
r = requests.get(fileName)

# %%
#Create model
model = cobra.io.read_sbml_model(r.text)

# %%
model
# Out:
# <Model c3_model at 0x7f4f44f781c0>

# %% [markdown]
# # III / Create Gene Table for AraCore Model

# %%
#Create mapping table
df_genes_aracore = pd.DataFrame(
    {
        "aracore_ids" : [gene_id.id for gene_id in model.genes],
        "aracore_name" : [gene_id.name for gene_id in model.genes],
        "aracore_annotations" : [gene_id.annotation for gene_id in model.genes]
    })

df_genes_aracore.head(25)
# Out:
#    aracore_ids aracore_name aracore_annotations
# 0    AT4G05180    AT4G05180                  {}
# 1    AT2G30570    AT2G30570                  {}
# 2    ATCG00560    ATCG00560                  {}
# 3    AT4G21280    AT4G21280                  {}
# 4    ATCG00300    ATCG00300                  {}
# 5    AT1G06680    AT1G06680                  {}
# 6    ATCG00080    ATCG00080                  {}
# 7    AT2G06520    AT2G06520                  {}
# 8    AT1G79040    AT1G79040                  {}
# 9    AT5G66570    AT5G66570                  {}
# 10   AT3G21055    AT3G21055                  {}
# 11   ATCG00020    ATCG00020                  {}
# 12   ATCG00270    ATCG00270                  {}
# 13   ATCG00690    ATCG00690                  {}
# 14   ATCG00710    ATCG00710                  {}
# 15   ATCG00550    ATCG00550                  {}
# 16   ATCG00570    ATCG00570                  {}
# 17   AT1G67740    AT1G67740                  {}
# 18   ATCG00580    ATCG00580                  {}
# 19   AT3G50820    AT3G50820                  {}
# 20   ATCG00680    ATCG00680                  {}
# 21   ATCG00280    ATCG00280                  {}
# 22   AT1G44575    AT1G44575                  {}
# 23   ATCG00220    ATCG00220                  {}
# 24   ATCG00700    ATCG00700                  {}

# %%
df_genes_aracore['aracore_ids'].shape[0] #804 genes
# Out:
# 804

# %% [markdown]
# # IV / Retrieve additional information on genes using the ENSEMBL API

# %%
#EXAMPLE REQUEST:

#Retrieve Information on gene symbol, location (chromosome, start and end), uniprot id/descriptive name using the ENSEMBL REST API
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/lookup

gene_id = 'AT4G05180'

#ENSEMBL Server Url
server = "https://rest.ensembl.org"

#URL specification to get meta-information of a gene by its id
ext = f"/lookup/id/{gene_id}?expand=1"
  
#Request information from URL in json format
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})

#Check if request wad successful
if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

else:

    json_anno = None

json_anno
# Out:
# {'logic_name': 'araport11',
#  'source': 'araport11',
#  'end': 2673243,
#  'description': 'Oxygen-evolving enhancer protein 3-2, chloroplastic [Source:UniProtKB/Swiss-Prot;Acc:Q41932]',
#  'id': 'AT4G05180',
#  'object_type': 'Gene',
#  'start': 2671523,
#  'db_type': 'core',
#  'strand': -1,
#  'display_name': 'PSBQ2',
#  'seq_region_name': '4',
#  'Transcript': [{'source': 'araport11',
#    'Parent': 'AT4G05180',
#    'biotype': 'protein_coding',
#    'assembly_name': 'TAIR10',
#    'seq_region_name': '4',
#    'strand': -1,
#    'object_type': 'Transcript',
#    'id': 'AT4G05180.1',
#    'Exon': [{'id': 'AT4G05180.1.exon1',
#      'end': 2673243,
#      'start': 2672873,
#      'db_type': 'core',
#      'object_type': 'Exon',
#      'assembly_name': 'TAIR10',
#      'strand': -1,
#      'seq_region_name': '4',
#      'species': 'arabidopsis_thaliana'},
#     {'species': 'arabidopsis_thaliana',
#      'seq_region_name': '4',
#      'strand': -1,
#      'assembly_name': 'TAIR10',
#      'object_type': 'Exon',
#      'db_type': 'core',
#      'start': 2672340,
#      'end': 2672635,
#      'id': 'AT4G05180.1.exon2'},
#     {'assembly_name': 'TAIR10',
#      'strand': -1,
#      'seq_region_name': '4',
#      'species': 'arabidopsis_thaliana',
#      'id': 'AT4G05180.1.exon3',
#      'end': 2672191,
#      'db_type': 'core',
#      'start': 2671900,
#      'object_type': 'Exon'},
#     {'strand': -1,
#      'seq_region_name': '4',
#      'assembly_name': 'TAIR10',
#      'species': 'arabidopsis_thaliana',
#      'end': 2671718,
#      'id': 'AT4G05180.1.exon4',
#      'object_type': 'Exon',
#      'db_type': 'core',
#      'start': 2671523}],
#    'logic_name': 'araport11',
#    'is_canonical': 1,
#    'species': 'arabidopsis_thaliana',
#    'Translation': {'Parent': 'AT4G05180.1',
#     'length': 230,
#     'species': 'arabidopsis_thaliana',
#     'id': 'AT4G05180.1',
#     'end': 2673170,
#     'db_type': 'core',
#     'start': 2672093,
#     'object_type': 'Translation'},
#    'db_type': 'core',
#    'start': 2671523,
#    'end': 2673243},
#   {'logic_name': 'araport11',
#    'Exon': [{'id': 'AT4G05180.1.exon1',
#      'end': 2673243,
#      'start': 2672873,
#      'db_type': 'core',
#      'object_type': 'Exon',
#      'assembly_name': 'TAIR10',
#      'seq_region_name': '4',
#      'strand': -1,
#      'species': 'arabidopsis_thaliana'},
#     {'species': 'arabidopsis_thaliana',
#      'assembly_name': 'TAIR10',
#      'strand': -1,
#      'seq_region_name': '4',
#      'db_type': 'core',
#      'start': 2672340,
#      'object_type': 'Exon',
#      'id': 'AT4G05180.1.exon2',
#      'end': 2672635},
#     {'start': 2671784,
#      'db_type': 'core',
#      'object_type': 'Exon',
#      'id': 'AT4G05180.2.exon3',
#      'end': 2672191,
#      'species': 'arabidopsis_thaliana',
#      'assembly_name': 'TAIR10',
#      'strand': -1,
#      'seq_region_name': '4'}],
#    'is_canonical': 0,
#    'Translation': {'Parent': 'AT4G05180.2',
#     'length': 230,
#     'species': 'arabidopsis_thaliana',
#     'end': 2673170,
#     'id': 'AT4G05180.2',
#     'object_type': 'Translation',
#     'start': 2672093,
#     'db_type': 'core'},
#    'species': 'arabidopsis_thaliana',
#    'end': 2673243,
#    'db_type': 'core',
#    'start': 2671784,
#    'Parent': 'AT4G05180',
#    'source': 'araport11',
#    'seq_region_name': '4',
#    'strand': -1,
#    'assembly_name': 'TAIR10',
#    'biotype': 'protein_coding',
#    'id': 'AT4G05180.2',
#    'object_type': 'Transcript'}],
#  'assembly_name': 'TAIR10',
#  'biotype': 'protein_coding',
#  'species': 'arabidopsis_thaliana'}

# %%
#Retrieve Information on gene symbol, location (chromosome, start and end), uniprot id/descriptive name using the ENSEMBL REST API
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/lookup

def lookup_ensembl_id(gene_id):

    #pandas series to hold information
    ds_anno = pd.Series(index=['symbol','chr','start', 'end', 'description'])
  
    #ENSEMBL Server Url
    server = "https://rest.ensembl.org"
  
    #URL specification to get meta-information of a gene by its id
    ext = f"/lookup/id/{gene_id}?expand=1"
  
    #Request information from URL in json format
    r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
  
    #Check if request wad successful
    if r.ok:
    
        #Get json (dictionary-like structure) from request
        json_anno = r.json()

        #Save relevant information in pandas series
        ds_anno['symbol'] = json_anno.get('display_name', None)
        ds_anno['chr'] = json_anno.get('seq_region_name', None)
        ds_anno['start'] = json_anno.get('start', None)
        ds_anno['end'] = json_anno.get('end', None)
        ds_anno['description'] = json_anno.get('description', None)
    else:
        #Save set pandas series to None if request was not successfull
        ds_anno['symbol'] = None
        ds_anno['chr'] = None
        ds_anno['start'] = None
        ds_anno['end'] = None
        ds_anno['description'] = None
    
    #return pandas series
    return ds_anno
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-fe451201a2d1> in <module>
#      40     return ds_anno
#      41
# ---> 42 ds_anno
#
# NameError: name 'ds_anno' is not defined

# %%
#EXAMPLE REQUEST

#Retrieve Information on cross references for each gene symbol (NCBI gene id)
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/xref_id

gene_id = 'AT4G05180'

#ENSEMBL Server Url
server = "https://rest.ensembl.org"

#URL specification to get meta-information of a gene by its id
ext = f"/xrefs/id/{gene_id}?"
  
#Request information from URL in json format
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
# headers is used to add specific headers on the HTTP request

#Check if request was successful
if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json() # json format file for annotations containing r variable content

    #Convert json to pandas dataframe format to easily retrieve information
    df_anno = pd.DataFrame(json_anno) # dataframe containing annotations
    df_anno.set_index('dbname', inplace=True) # delete the index on the left of the dataframe
else:
     df_anno = None

df_anno
# Out:
#               primary_id info_text        display_id       info_type  \
# dbname
# NASC_GENE_ID   AT4G05180            AT4G05180-TAIR-G          DIRECT
# ArrayExpress   AT4G05180                   AT4G05180          DIRECT
# TAIR_LOCUS     AT4G05180                   AT4G05180          DIRECT
# TAIR_SYMBOL         PSBQ                        PSBQ          DIRECT
# UniGene         At.21853                    At.21853  SEQUENCE_MATCH
# EntrezGene        825866                      825866       DEPENDENT
# KNETMINER_ARA  AT4G05180                   AT4G05180       DEPENDENT
#
#                                         description  \
# dbname
# NASC_GENE_ID             photosystem II subunit Q-2
# ArrayExpress
# TAIR_LOCUS               photosystem II subunit Q-2
# TAIR_SYMBOL
# UniGene        Oxygen-evolving enhancer protein 3-2
# EntrezGene                                     None
# KNETMINER_ARA                                  None
#
#                                db_display_name  \
# dbname
# NASC_GENE_ID                      NASC Gene ID
# ArrayExpress                  Expression Atlas
# TAIR_LOCUS                                TAIR
# TAIR_SYMBOL                     TAIR Gene Name
# UniGene                                UniGene
# EntrezGene     NCBI gene (formerly Entrezgene)
# KNETMINER_ARA                    KNETMINER_ARA
#
#                                       synonyms version  evalue  xref_start  \
# dbname
# NASC_GENE_ID                                []       0     NaN         NaN
# ArrayExpress                                []       0     NaN         NaN
# TAIR_LOCUS                                  []       0     NaN         NaN
# TAIR_SYMBOL    [PSBQ-1, PSBQ-2, PSBQA, PSII-Q]       0     NaN         NaN
# UniGene                                     []       0     NaN         1.0
# EntrezGene                                  []       0     NaN         NaN
# KNETMINER_ARA                               []       0     NaN         NaN
#
#                ensembl_start cigar_line  xref_identity  xref_end   score  \
# dbname
# NASC_GENE_ID             NaN        NaN            NaN       NaN     NaN
# ArrayExpress             NaN        NaN            NaN       NaN     NaN
# TAIR_LOCUS               NaN        NaN            NaN       NaN     NaN
# TAIR_SYMBOL              NaN        NaN            NaN       NaN     NaN
# UniGene                  1.0      1037M          100.0    1037.0  5185.0
# EntrezGene               NaN        NaN            NaN       NaN     NaN
# KNETMINER_ARA            NaN        NaN            NaN       NaN     NaN
#
#                ensembl_end  ensembl_identity
# dbname
# NASC_GENE_ID           NaN               NaN
# ArrayExpress           NaN               NaN
# TAIR_LOCUS             NaN               NaN
# TAIR_SYMBOL            NaN               NaN
# UniGene             1037.0              96.0
# EntrezGene             NaN               NaN
# KNETMINER_ARA          NaN               NaN

# %%
#Retrieve Information on cross references for each gene symbol (NCBI gene id)
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/xref_id

def xrefs_ensembl_id(gene_id):
  
    #pandas series to hold information
    ds_anno = pd.Series(index=['ncbigene'])
  
    #ENSEMBL Server Url
    server = "https://rest.ensembl.org"
    #URL specification to get meta-information of a gene by its id
    ext = f"/xrefs/id/{gene_id}?"
  
    #Request information from URL in json format
    r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
  
    #Check if request wad successful
    if r.ok:
    
    #Get json (dictionary-like structure) from request
        json_anno = r.json()

        #Convert json to pandas dataframe format
        df_anno = pd.DataFrame(json_anno)
        df_anno.set_index('dbname', inplace=True)

        #Save relevant information in pandas series
        if 'EntrezGene' in df_anno.index:
              if 'primary_id' in df_anno.columns:
                    ds_anno['ncbigene'] = str(df_anno.loc['EntrezGene','primary_id'])

    else:
        ds_anno['ncbigene'] = None
 
    return ds_anno
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-7b64edb02533> in <module>
#      36     return ds_anno
#      37
# ---> 38 ds_anno
#
# NameError: name 'ds_anno' is not defined

# %%
#Request information for each gene using xrefs_ensembl_id() function
df_genes_xref = df_genes_aracore['aracore_ids'].apply(lambda x: xrefs_ensembl_id(x))
# Out:
# <ipython-input-11-60b70e0fb5fa>:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   ds_anno = pd.Series(index=['ncbigene'])

# %%
df_genes_xref
# Out:
#      ncbigene
# 0    825866.0
# 1    817606.0
# 2    844751.0
# 3    827877.0
# 4    844774.0
# ..        ...
# 799  822384.0
# 800  836542.0
# 801  840127.0
# 802  821805.0
# 803  828321.0
#
# [804 rows x 1 columns]

# %% [markdown]
# **Concerning the cell below**:
#
# We write a REQUEST, which contains the URL of the ENSEMBL gene ID, and the Output format, under the following form :
# REQUEST(URL, Output format)
#
# This URL is constituted into 2 parts:
# - the base of the URL, which refers to the database ENSEMBL
# - the keywords, which will be translated into MySQL
#
# These 2 parts of the REQUEST are together converted into the Output format.
#
# This Output format is JSON, similar to a dictionary in Python.

# %%
#Request information for each gene using lookup_ensembl_id() function
df_genes_lookup = df_genes_aracore['aracore_ids'].apply(lambda x: lookup_ensembl_id(x)) #This may take a few minutes
# Out:
# <ipython-input-9-125c4ee2cac2>:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   ds_anno = pd.Series(index=['symbol','chr','start', 'end', 'description'])

# %%
df_genes_lookup
# Out:
#     symbol chr       start         end  \
# 0    PSBQ2   4   2671523.0   2673243.0
# 1     PSBW   2  13019028.0  13020311.0
# 2     PSBL  Pt     63804.0     63920.0
# 3    PSBQ1   4  11334352.0  11335815.0
# 4     PSBZ  Pt     35751.0     35939.0
# ..     ...  ..         ...         ...
# 799  AOX1C   3  10229045.0  10230707.0
# 800   AOX2   5  25683770.0  25685731.0
# 801   AOX3   1  11666886.0  11668690.0
# 802  AOX1B   3   7904097.0   7905576.0
# 803   AOX4   4  11769668.0  11772599.0
#
#                                            description
# 0    Oxygen-evolving enhancer protein 3-2, chloropl...
# 1        PSBW [Source:UniProtKB/TrEMBL;Acc:A0A178VQ32]
# 2    Photosystem II reaction center protein L [Sour...
# 3    Oxygen-evolving enhancer protein 3-1, chloropl...
# 4    Photosystem II reaction center protein Z [Sour...
# ..                                                 ...
# 799  Ubiquinol oxidase 1c, mitochondrial [Source:Un...
# 800  Ubiquinol oxidase 2, mitochondrial [Source:Uni...
# 801     AOX1D [Source:UniProtKB/TrEMBL;Acc:A0A384LFI3]
# 802  Ubiquinol oxidase 1b, mitochondrial [Source:Un...
# 803  Ubiquinol oxidase 4, chloroplastic/chromoplast...
#
# [804 rows x 5 columns]

# %% [markdown]
# # V / Merge information into a single mapping table

# %%
#Concat dataframe df_genes_aracore, df_genes_lookup, df_genes_xref
df_genes_aracore = pd.concat([df_genes_aracore, df_genes_lookup, df_genes_xref], axis=1) 
df_genes_aracore
# Out:
#     aracore_ids aracore_name aracore_annotations symbol chr       start  \
# 0     AT4G05180    AT4G05180                  {}  PSBQ2   4   2671523.0
# 1     AT2G30570    AT2G30570                  {}   PSBW   2  13019028.0
# 2     ATCG00560    ATCG00560                  {}   PSBL  Pt     63804.0
# 3     AT4G21280    AT4G21280                  {}  PSBQ1   4  11334352.0
# 4     ATCG00300    ATCG00300                  {}   PSBZ  Pt     35751.0
# ..          ...          ...                 ...    ...  ..         ...
# 799   AT3G27620    AT3G27620                  {}  AOX1C   3  10229045.0
# 800   AT5G64210    AT5G64210                  {}   AOX2   5  25683770.0
# 801   AT1G32350    AT1G32350                  {}   AOX3   1  11666886.0
# 802   AT3G22360    AT3G22360                  {}  AOX1B   3   7904097.0
# 803   AT4G22260    AT4G22260                  {}   AOX4   4  11769668.0
#
#             end                                        description  ncbigene
# 0     2673243.0  Oxygen-evolving enhancer protein 3-2, chloropl...  825866.0
# 1    13020311.0      PSBW [Source:UniProtKB/TrEMBL;Acc:A0A178VQ32]  817606.0
# 2       63920.0  Photosystem II reaction center protein L [Sour...  844751.0
# 3    11335815.0  Oxygen-evolving enhancer protein 3-1, chloropl...  827877.0
# 4       35939.0  Photosystem II reaction center protein Z [Sour...  844774.0
# ..          ...                                                ...       ...
# 799  10230707.0  Ubiquinol oxidase 1c, mitochondrial [Source:Un...  822384.0
# 800  25685731.0  Ubiquinol oxidase 2, mitochondrial [Source:Uni...  836542.0
# 801  11668690.0     AOX1D [Source:UniProtKB/TrEMBL;Acc:A0A384LFI3]  840127.0
# 802   7905576.0  Ubiquinol oxidase 1b, mitochondrial [Source:Un...  821805.0
# 803  11772599.0  Ubiquinol oxidase 4, chloroplastic/chromoplast...  828321.0
#
# [804 rows x 9 columns]

# %%
#Seperate descriptive name from uniprot symbol by first appearance of "[", expand in to two columns
#e.g. "Oxygen-evolving enhancer protein 3-2, chloroplastic [Source:UniProtKB/Swiss-Prot;Acc:Q41932]" -> "Oxygen-evolving enhancer protein 3-2, chloroplastic" & Source:UniProtKB/Swiss-Prot;Acc:Q41932]

df_name_uniprot = df_genes_aracore['description'].str.split('[', 1, expand=True) 
df_name_uniprot
# Out:
#                                                      0  \
# 0    Oxygen-evolving enhancer protein 3-2, chloropl...
# 1                                                PSBW
# 2            Photosystem II reaction center protein L
# 3    Oxygen-evolving enhancer protein 3-1, chloropl...
# 4            Photosystem II reaction center protein Z
# ..                                                 ...
# 799               Ubiquinol oxidase 1c, mitochondrial
# 800                Ubiquinol oxidase 2, mitochondrial
# 801                                             AOX1D
# 802               Ubiquinol oxidase 1b, mitochondrial
# 803  Ubiquinol oxidase 4, chloroplastic/chromoplastic
#
#                                            1
# 0    Source:UniProtKB/Swiss-Prot;Acc:Q41932]
# 1    Source:UniProtKB/TrEMBL;Acc:A0A178VQ32]
# 2    Source:UniProtKB/Swiss-Prot;Acc:P60129]
# 3    Source:UniProtKB/Swiss-Prot;Acc:Q9XFT3]
# 4    Source:UniProtKB/TrEMBL;Acc:A0A1B1W4U3]
# ..                                       ...
# 799  Source:UniProtKB/Swiss-Prot;Acc:O22048]
# 800  Source:UniProtKB/Swiss-Prot;Acc:O22049]
# 801  Source:UniProtKB/TrEMBL;Acc:A0A384LFI3]
# 802  Source:UniProtKB/Swiss-Prot;Acc:O23913]
# 803  Source:UniProtKB/Swiss-Prot;Acc:Q56X52]
#
# [804 rows x 2 columns]

# %%
#Merge with df_genes_aracore
df_genes_aracore = pd.concat([df_genes_aracore, df_name_uniprot], axis=1) 

#rename columns
df_genes_aracore.rename(columns={0: 'gene_name', 1: 'uniprot_id'}, inplace=True)
df_genes_aracore
# Out:
#     aracore_ids aracore_name aracore_annotations symbol chr       start  \
# 0     AT4G05180    AT4G05180                  {}  PSBQ2   4   2671523.0
# 1     AT2G30570    AT2G30570                  {}   PSBW   2  13019028.0
# 2     ATCG00560    ATCG00560                  {}   PSBL  Pt     63804.0
# 3     AT4G21280    AT4G21280                  {}  PSBQ1   4  11334352.0
# 4     ATCG00300    ATCG00300                  {}   PSBZ  Pt     35751.0
# ..          ...          ...                 ...    ...  ..         ...
# 799   AT3G27620    AT3G27620                  {}  AOX1C   3  10229045.0
# 800   AT5G64210    AT5G64210                  {}   AOX2   5  25683770.0
# 801   AT1G32350    AT1G32350                  {}   AOX3   1  11666886.0
# 802   AT3G22360    AT3G22360                  {}  AOX1B   3   7904097.0
# 803   AT4G22260    AT4G22260                  {}   AOX4   4  11769668.0
#
#             end                                        description  ncbigene  \
# 0     2673243.0  Oxygen-evolving enhancer protein 3-2, chloropl...  825866.0
# 1    13020311.0      PSBW [Source:UniProtKB/TrEMBL;Acc:A0A178VQ32]  817606.0
# 2       63920.0  Photosystem II reaction center protein L [Sour...  844751.0
# 3    11335815.0  Oxygen-evolving enhancer protein 3-1, chloropl...  827877.0
# 4       35939.0  Photosystem II reaction center protein Z [Sour...  844774.0
# ..          ...                                                ...       ...
# 799  10230707.0  Ubiquinol oxidase 1c, mitochondrial [Source:Un...  822384.0
# 800  25685731.0  Ubiquinol oxidase 2, mitochondrial [Source:Uni...  836542.0
# 801  11668690.0     AOX1D [Source:UniProtKB/TrEMBL;Acc:A0A384LFI3]  840127.0
# 802   7905576.0  Ubiquinol oxidase 1b, mitochondrial [Source:Un...  821805.0
# 803  11772599.0  Ubiquinol oxidase 4, chloroplastic/chromoplast...  828321.0
#
#                                              gene_name  \
# 0    Oxygen-evolving enhancer protein 3-2, chloropl...
# 1                                                PSBW
# 2            Photosystem II reaction center protein L
# 3    Oxygen-evolving enhancer protein 3-1, chloropl...
# 4            Photosystem II reaction center protein Z
# ..                                                 ...
# 799               Ubiquinol oxidase 1c, mitochondrial
# 800                Ubiquinol oxidase 2, mitochondrial
# 801                                             AOX1D
# 802               Ubiquinol oxidase 1b, mitochondrial
# 803  Ubiquinol oxidase 4, chloroplastic/chromoplastic
#
#                                   uniprot_id
# 0    Source:UniProtKB/Swiss-Prot;Acc:Q41932]
# 1    Source:UniProtKB/TrEMBL;Acc:A0A178VQ32]
# 2    Source:UniProtKB/Swiss-Prot;Acc:P60129]
# 3    Source:UniProtKB/Swiss-Prot;Acc:Q9XFT3]
# 4    Source:UniProtKB/TrEMBL;Acc:A0A1B1W4U3]
# ..                                       ...
# 799  Source:UniProtKB/Swiss-Prot;Acc:O22048]
# 800  Source:UniProtKB/Swiss-Prot;Acc:O22049]
# 801  Source:UniProtKB/TrEMBL;Acc:A0A384LFI3]
# 802  Source:UniProtKB/Swiss-Prot;Acc:O23913]
# 803  Source:UniProtKB/Swiss-Prot;Acc:Q56X52]
#
# [804 rows x 11 columns]

# %%
#Extract Uniprot id by splitting on last appearance of ':', expand columns, but only keep the last column for the uniprot id, the rest is trash
#e.g. Source:UniProtKB/Swiss-Prot;Acc:Q41932] -> "Source:UniProtKB/Swiss-Prot;Acc" & "Q41932]"
df_genes_aracore['uniprot_id'] = df_genes_aracore['uniprot_id'].str.rsplit(':',1,expand=True).iloc[:,-1]

#Remove closing "]" from uniprot id 
#e.g. "Q41932]" -> "Q41932"
df_genes_aracore['uniprot_id'] = df_genes_aracore['uniprot_id'].apply(lambda x: x[:-1] if isinstance(x,str) else None)
df_genes_aracore
# Out:
#     aracore_ids aracore_name aracore_annotations symbol chr       start  \
# 0     AT4G05180    AT4G05180                  {}  PSBQ2   4   2671523.0
# 1     AT2G30570    AT2G30570                  {}   PSBW   2  13019028.0
# 2     ATCG00560    ATCG00560                  {}   PSBL  Pt     63804.0
# 3     AT4G21280    AT4G21280                  {}  PSBQ1   4  11334352.0
# 4     ATCG00300    ATCG00300                  {}   PSBZ  Pt     35751.0
# ..          ...          ...                 ...    ...  ..         ...
# 799   AT3G27620    AT3G27620                  {}  AOX1C   3  10229045.0
# 800   AT5G64210    AT5G64210                  {}   AOX2   5  25683770.0
# 801   AT1G32350    AT1G32350                  {}   AOX3   1  11666886.0
# 802   AT3G22360    AT3G22360                  {}  AOX1B   3   7904097.0
# 803   AT4G22260    AT4G22260                  {}   AOX4   4  11769668.0
#
#             end                                        description  ncbigene  \
# 0     2673243.0  Oxygen-evolving enhancer protein 3-2, chloropl...  825866.0
# 1    13020311.0      PSBW [Source:UniProtKB/TrEMBL;Acc:A0A178VQ32]  817606.0
# 2       63920.0  Photosystem II reaction center protein L [Sour...  844751.0
# 3    11335815.0  Oxygen-evolving enhancer protein 3-1, chloropl...  827877.0
# 4       35939.0  Photosystem II reaction center protein Z [Sour...  844774.0
# ..          ...                                                ...       ...
# 799  10230707.0  Ubiquinol oxidase 1c, mitochondrial [Source:Un...  822384.0
# 800  25685731.0  Ubiquinol oxidase 2, mitochondrial [Source:Uni...  836542.0
# 801  11668690.0     AOX1D [Source:UniProtKB/TrEMBL;Acc:A0A384LFI3]  840127.0
# 802   7905576.0  Ubiquinol oxidase 1b, mitochondrial [Source:Un...  821805.0
# 803  11772599.0  Ubiquinol oxidase 4, chloroplastic/chromoplast...  828321.0
#
#                                              gene_name  uniprot_id
# 0    Oxygen-evolving enhancer protein 3-2, chloropl...      Q41932
# 1                                                PSBW   A0A178VQ32
# 2            Photosystem II reaction center protein L       P60129
# 3    Oxygen-evolving enhancer protein 3-1, chloropl...      Q9XFT3
# 4            Photosystem II reaction center protein Z   A0A1B1W4U3
# ..                                                 ...         ...
# 799               Ubiquinol oxidase 1c, mitochondrial       O22048
# 800                Ubiquinol oxidase 2, mitochondrial       O22049
# 801                                             AOX1D   A0A384LFI3
# 802               Ubiquinol oxidase 1b, mitochondrial       O23913
# 803  Ubiquinol oxidase 4, chloroplastic/chromoplastic       Q56X52
#
# [804 rows x 11 columns]

# %%
df_genes_aracore[df_genes_aracore.isna().sum(axis=1) == 8] #2 Genes have no annotations at all -> Look-up those genes, maybe the Gene ids are wrong!?!
# Out:
#     aracore_ids aracore_name aracore_annotations symbol  chr  start  end  \
# 683   AT5G34920    AT5G34920                  {}    NaN  NaN    NaN  NaN
# 721  AT3G600180   AT3G600180                  {}    NaN  NaN    NaN  NaN
#
#     description ncbigene gene_name uniprot_id
# 683         NaN      NaN       NaN       None
# 721         NaN      NaN       NaN       None

# %%
df_genes_aracore[df_genes_aracore['ncbigene'].isna()] # ~28 genes without NCBI Symbol
# Out:
#     aracore_ids aracore_name aracore_annotations  symbol  chr       start  \
# 43    ATCG00890    ATCG00890                  {}  NDHB.1   Pt     94941.0
# 58    ATCG01050    ATCG01050                  {}    NDHD   Pt    115665.0
# 181   AT1G17000    AT1G17000                  {}  ATTPS3    1   5812728.0
# 306   ATMG00510    ATMG00510                  {}    NAD7   Mt    132071.0
# 307   ATMG00580    ATMG00580                  {}    NAD4   Mt    161693.0
# 308   ATMG00060    ATMG00060                  {}   NAD5C   Mt     20571.0
# 309   ATMG00070    ATMG00070                  {}    NAD9   Mt     23663.0
# 310   ATMG01275    ATMG01275                  {}   NAD1A   Mt    318004.0
# 311   ATMG00285    ATMG00285                  {}   NAD2A   Mt     79740.0
# 314   ATMG00270    ATMG00270                  {}    NAD6   Mt     76642.0
# 315   ATMG00665    ATMG00665                  {}   NAD5B   Mt    190740.0
# 318   ATMG01120    ATMG01120                  {}   NAD1B   Mt    287917.0
# 319   ATMG00513    ATMG00513                  {}   NAD5A   Mt    140724.0
# 320   ATMG01320    ATMG01320                  {}   NAD2B   Mt    327890.0
# 322   ATMG00516    ATMG00516                  {}   NAD1C   Mt    143219.0
# 323   ATMG00650    ATMG00650                  {}   NAD4L   Mt    188929.0
# 324   ATMG00990    ATMG00990                  {}    NAD3   Mt    260647.0
# 343   ATMG00730    ATMG00730                  {}    COX3   Mt    217631.0
# 346   ATMG00160    ATMG00160                  {}    COX2   Mt     40502.0
# 347   ATMG01360    ATMG01360                  {}    COX1   Mt    349830.0
# 355   AT5G08670    AT5G08670                  {}     NaN  5.0   2818091.0
# 356   ATMG01170    ATMG01170                  {}  ATP6-2   Mt    296820.0
# 364   ATMG01190    ATMG01190                  {}    ATP1   Mt    302166.0
# 367   ATMG00640    ATMG00640                  {}   ORF25   Mt    188084.0
# 426   AT1G32480    AT1G32480                  {}  IDH-IV    1  11741083.0
# 683   AT5G34920    AT5G34920                  {}     NaN  NaN         NaN
# 721  AT3G600180   AT3G600180                  {}     NaN  NaN         NaN
# 794   AT5G08740    AT5G08740                  {}    NDC1    5   2848352.0
#
#             end                                        description ncbigene  \
# 43      96795.0  NADH-Ubiquinone/plastoquinone (complex I) prot...      NaN
# 58     117185.0  NADH-Ubiquinone/plastoquinone (complex I) prot...      NaN
# 181   5816662.0  trehalose-phosphatase/synthase 3 [Source:TAIR;...      NaN
# 306    138153.0  NADH dehydrogenase subunit 7 [Source:UniProtKB...      NaN
# 307    169674.0  NADH-ubiquinone oxidoreductase chain 4 [Source...      NaN
# 308     22086.0  NADH dehydrogenase subunit 5C [Source:TAIR;Acc...      NaN
# 309     24235.0  NADH dehydrogenase subunit 9 [Source:TAIR;Acc:...      NaN
# 310    318390.0  NADH dehydrogenase 1A [Source:TAIR;Acc:ATMG01275]      NaN
# 311     81297.0  NADH dehydrogenase 2A [Source:TAIR;Acc:ATMG00285]      NaN
# 314     77259.0  NADH-ubiquinone oxidoreductase chain 6 [Source...      NaN
# 315    190761.0  NADH dehydrogenase 5B [Source:TAIR;Acc:ATMG00665]      NaN
# 318    289083.0  NADH dehydrogenase 1B [Source:TAIR;Acc:ATMG01120]      NaN
# 319    142998.0  NADH dehydrogenase 5A [Source:TAIR;Acc:ATMG00513]      NaN
# 320    333105.0  NADH dehydrogenase 2B [Source:TAIR;Acc:ATMG01320]      NaN
# 322    147048.0  NADH dehydrogenase 1C [Source:TAIR;Acc:ATMG00516]      NaN
# 323    189231.0  NADH dehydrogenase subunit 4L [Source:UniProtK...      NaN
# 324    261006.0  NADH-ubiquinone oxidoreductase chain 3 [Source...      NaN
# 343    219077.0  cytochrome c oxidase subunit 3 [Source:TAIR;Ac...      NaN
# 346     42628.0  Cytochrome c oxidase subunit 2 [Source:UniProt...      NaN
# 347    351413.0  Cytochrome c oxidase subunit 1 [Source:UniProt...      NaN
# 355   2821251.0  ATP synthase alpha/beta family protein [Source...      NaN
# 356    298204.0  ATP synthase subunit a [Source:UniProtKB/TrEMB...      NaN
# 364    303689.0  ATP synthase subunit alpha [Source:UniProtKB/T...      NaN
# 367    188662.0  hydrogen ion transporting ATP synthases, rotat...      NaN
# 426  11741990.0  isocitrate dehydrogenase IV [Source:TAIR;Acc:A...      NaN
# 683         NaN                                                NaN      NaN
# 721         NaN                                                NaN      NaN
# 794   2851534.0  NAD(P)H dehydrogenase C1 [Source:TAIR;Acc:AT5G...      NaN
#
#                                              gene_name uniprot_id
# 43   NADH-Ubiquinone/plastoquinone (complex I) prot...  ATCG00890
# 58   NADH-Ubiquinone/plastoquinone (complex I) prot...  ATCG01050
# 181                  trehalose-phosphatase/synthase 3   AT1G17000
# 306                      NADH dehydrogenase subunit 7      G1C2X4
# 307            NADH-ubiquinone oxidoreductase chain 4      G1C2U9
# 308                     NADH dehydrogenase subunit 5C   ATMG00060
# 309                      NADH dehydrogenase subunit 9   ATMG00070
# 310                             NADH dehydrogenase 1A   ATMG01275
# 311                             NADH dehydrogenase 2A   ATMG00285
# 314            NADH-ubiquinone oxidoreductase chain 6      G1C2Y0
# 315                             NADH dehydrogenase 5B   ATMG00665
# 318                             NADH dehydrogenase 1B   ATMG01120
# 319                             NADH dehydrogenase 5A   ATMG00513
# 320                             NADH dehydrogenase 2B   ATMG01320
# 322                             NADH dehydrogenase 1C   ATMG00516
# 323                     NADH dehydrogenase subunit 4L      G1C2W6
# 324            NADH-ubiquinone oxidoreductase chain 3      G1C2Y6
# 343                    cytochrome c oxidase subunit 3   ATMG00730
# 346                    Cytochrome c oxidase subunit 2      G1C2Q7
# 347                    Cytochrome c oxidase subunit 1      P60620
# 355            ATP synthase alpha/beta family protein   AT5G08670
# 356                            ATP synthase subunit a      G1C2S8
# 364                        ATP synthase subunit alpha      G1C2Z0
# 367  hydrogen ion transporting ATP synthases, rotat...  ATMG00640
# 426                       isocitrate dehydrogenase IV   AT1G32480
# 683                                                NaN       None
# 721                                                NaN       None
# 794                          NAD(P)H dehydrogenase C1   AT5G08740

# %%
df_genes_aracore[df_genes_aracore['symbol'].isna()].head(100) # 97 genes have no official gene #symbol
# Out:
#     aracore_ids aracore_name aracore_annotations symbol  chr       start  \
# 30    AT2G26500    AT2G26500                  {}    NaN  2.0  11270082.0
# 94    AT5G38410    AT5G38410                  {}    NaN  5.0  15376988.0
# 98    AT1G56190    AT1G56190                  {}    NaN  1.0  21028137.0
# 116   AT5G44520    AT5G44520                  {}    NaN  5.0  17934287.0
# 143   AT4G26520    AT4G26520                  {}    NaN  4.0  13388290.0
# ..          ...          ...                 ...    ...  ...         ...
# 721  AT3G600180   AT3G600180                  {}    NaN  NaN         NaN
# 732   AT4G13720    AT4G13720                  {}    NaN  4.0   7966805.0
# 735   AT4G23895    AT4G23895                  {}    NaN  4.0  12422036.0
# 774   AT4G05590    AT4G05590                  {}    NaN  4.0   2907012.0
# 784   AT2G32040    AT2G32040                  {}    NaN  2.0  13635094.0
#
#             end                                        description   ncbigene  \
# 30   11271074.0  At2g26500/T9J22.17 [Source:UniProtKB/TrEMBL;Ac...   817191.0
# 94   15378642.0  Ribulose bisphosphate carboxylase small chain ...   833828.0
# 98   21030684.0  Phosphoglycerate kinase [Source:UniProtKB/TrEM...   842072.0
# 116  17936554.0  NagB/RpiA/CoA transferase-like superfamily pro...   834479.0
# 143  13390862.0  Aldolase superfamily protein [Source:TAIR;Acc:...   828758.0
# ..          ...                                                ...        ...
# 721         NaN                                                NaN        NaN
# 732   7968965.0  Inosine triphosphate pyrophosphatase family pr...   827006.0
# 735  12426475.0  Nucleoside diphosphate kinase [Source:UniProtK...  2745723.0
# 774   2908631.0  CONTAINS InterPro DOMAIN/s: Uncharacterised pr...   825927.0
# 784  13638081.0  Folate-biopterin transporter 1, chloroplastic ...   817764.0
#
#                                              gene_name  uniprot_id
# 30                                 At2g26500/T9J22.17       O48717
# 94      Ribulose bisphosphate carboxylase small chain       B3H5S2
# 98                            Phosphoglycerate kinase   A0A178W4Q1
# 116  NagB/RpiA/CoA transferase-like superfamily pro...   AT5G44520
# 143                      Aldolase superfamily protein    AT4G26520
# ..                                                 ...         ...
# 721                                                NaN        None
# 732  Inosine triphosphate pyrophosphatase family pr...   AT4G13720
# 735                     Nucleoside diphosphate kinase       F4JPD8
# 774  CONTAINS InterPro DOMAIN/s: Uncharacterised pr...   AT4G05590
# 784     Folate-biopterin transporter 1, chloroplastic       Q9SKZ5
#
# [97 rows x 11 columns]

# %%
df_genes_aracore[df_genes_aracore['uniprot_id'].isna()] #2 genes have no uniprot id (same as above)
# Out:
#     aracore_ids aracore_name aracore_annotations symbol  chr  start  end  \
# 683   AT5G34920    AT5G34920                  {}    NaN  NaN    NaN  NaN
# 721  AT3G600180   AT3G600180                  {}    NaN  NaN    NaN  NaN
#
#     description ncbigene gene_name uniprot_id
# 683         NaN      NaN       NaN       None
# 721         NaN      NaN       NaN       None

# %%
#Export final mapping table for manual mapping
df_genes_aracore.to_csv('../data/processed/2021-06-19-genes-mapping-table.csv')
