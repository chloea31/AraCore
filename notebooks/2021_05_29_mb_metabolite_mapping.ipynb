# %% [markdown]
# # Install missing modules & load modules

# %%
# !pip install cobra #install cobra only required for google colab
# Out:
# Requirement already satisfied: cobra in /usr/local/lib/python3.7/dist-packages (0.22.0)
# Requirement already satisfied: appdirs~=1.4 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.4.4)
# Requirement already satisfied: diskcache~=5.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (5.2.1)
# Requirement already satisfied: swiglpk in /usr/local/lib/python3.7/dist-packages (from cobra) (5.0.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from cobra) (5.1.3)
# Requirement already satisfied: depinfo in /usr/local/lib/python3.7/dist-packages (from cobra) (1.7.0)
# Requirement already satisfied: rich>=8.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (10.2.2)
# Requirement already satisfied: pydantic~=1.6 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.8.2)
# Requirement already satisfied: ruamel.yaml~=0.16 in /usr/local/lib/python3.7/dist-packages (from cobra) (0.17.7)
# Requirement already satisfied: httpx~=0.14 in /usr/local/lib/python3.7/dist-packages (from cobra) (0.18.1)
# Requirement already satisfied: python-libsbml==5.19.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (5.19.0)
# Requirement already satisfied: optlang~=1.5 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.5.2)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from cobra) (0.16.0)
# Requirement already satisfied: pandas~=1.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.1.5)
# Requirement already satisfied: numpy~=1.13 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.19.5)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-resources->cobra) (3.4.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from depinfo->cobra) (4.0.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (0.4.4)
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (3.7.4.3)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (2.6.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (0.9.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml~=0.16->cobra) (0.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (2020.12.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (1.2.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (1.5.0)
# Requirement already satisfied: httpcore<0.14.0,>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (0.13.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from optlang~=1.5->cobra) (1.15.0)
# Requirement already satisfied: sympy>=1.0 in /usr/local/lib/python3.7/dist-packages (from optlang~=1.5->cobra) (1.7.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.0->cobra) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.0->cobra) (2.8.1)
# Requirement already satisfied: idna; extra == "idna2008" in /usr/local/lib/python3.7/dist-packages (from rfc3986[idna2008]<2,>=1.3->httpx~=0.14->cobra) (2.10)
# Requirement already satisfied: h11<0.13,>=0.11 in /usr/local/lib/python3.7/dist-packages (from httpcore<0.14.0,>=0.13.0->httpx~=0.14->cobra) (0.12.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.0->optlang~=1.5->cobra) (1.2.1)

# %%
import pandas as pd
import numpy as np
import cobra
import requests

# %% [markdown]
# # Load AraCore Model

# %%
#Get file from github
fileName = 'https://raw.githubusercontent.com/ma-blaetke/CBM_C3_C4_Metabolism/master/data/2018-23-05-mb-genC3.sbml'
r = requests.get(fileName)

# %%
#Create model
model = cobra.io.read_sbml_model(r.text)

# %%
model
# Out:
# <Model c3_model at 0x7f7d34e54350>

# %% [markdown]
# # Correct Compartment Naming in AraCore Model according to BiGG naming conventions

# %%
model.compartments
# Out:
# {'c': 'Cytosol',
#  'h': 'Chloroplast',
#  'i': 'IntermembraneSpace',
#  'l': 'Lumen',
#  'm': 'Mitochondrion',
#  'p': 'Peroxisome'}

# %%
bigg_compartments = {'c':	'cytosol',
'e':	'extracellular space',
'p':	'periplasm',
'm':	'mitochondria',
'x':	'peroxisome/glyoxysome',
'r':	'endoplasmic reticulum',
'v':	'vacuole',
'n':	'nucleus',
'g':	'golgi apparatus',
'u':	'thylakoid',
'l':	'lysosome',
'h':	'chloroplast',
'f':	'flagellum',
's':	'eyespot',
'im':	'intermembrane space of mitochondria',
'cx':	'carboxyzome',
'um':	'thylakoid membrane',
'cm':	'cytosolic membrane',
'i':	'inner mitochondrial compartment',
'mm':	'mitochondrial intermembrane',
'w':	'wildtype staph aureus',
'y':	'cytochrome complex'}

# %%
#http://bigg.ucsd.edu/compartments

#c	cytosol
#h	chloroplast
#m	mitochondria
#x	peroxisome/glyoxysome
#im	intermembrane space of mitochondria
#h	chloroplast
#ul thylakoid lumen <<< NEW


df_compartment_mapping = pd.Series(
  { 'c': 'c', #cytosol
  'h': 'h', #chloroplast
  'm': 'm', #mitochondria
  'p': 'x', #peroxisome/glyoxysome
  'i': 'im', #intermembrane space of mitochondria
  'l': 'ul', #thylakoid lumen <<< NEW, not in BiGG compartment list
   'e':'e', #extracellular space << NEW, not yet in model
  }
 )

# %% [markdown]
# # Create Metabolite Table for AraCore Model

# %%
#Create mapping table
df_metabolites_aracore = pd.DataFrame(
    {
        "aracore_ids" : [met_obj.id for met_obj in model.metabolites],
        "aracore_name" : [met_obj.name for met_obj in model.metabolites],
        "aracore_formula": [met_obj.formula for met_obj in model.metabolites],
        "aracore_annotations" : [met_obj.annotation for met_obj in model.metabolites]
    })

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ... aracore_annotations
# 0        hnu_h  ...                  {}
# 1         PQ_h  ...                  {}
# 2        H2O_h  ...                  {}
# 3          H_h  ...                  {}
# 4       PQH2_h  ...                  {}
# 5         O2_h  ...                  {}
# 6          H_l  ...                  {}
# 7       PCox_h  ...                  {}
# 8       PCrd_h  ...                  {}
# 9       Fdox_h  ...                  {}
# 10      Fdrd_h  ...                  {}
# 11      NADP_h  ...                  {}
# 12     NADPH_h  ...                  {}
# 13       ADP_h  ...                  {}
# 14        Pi_h  ...                  {}
# 15       ATP_h  ...                  {}
# 16      RuBP_h  ...                  {}
# 17       CO2_h  ...                  {}
# 18       PGA_h  ...                  {}
# 19      DPGA_h  ...                  {}
# 20       GAP_h  ...                  {}
# 21      DHAP_h  ...                  {}
# 22       FBP_h  ...                  {}
# 23       F6P_h  ...                  {}
# 24       E4P_h  ...                  {}
#
# [25 rows x 4 columns]

# %%
df_metabolites_aracore['aracore_formula'].nunique()
# Out:
# 213

# %%
#Update compartment symbols in metabolite ids and make metabolite ids lower case
df_metabolites_aracore['aracore_updated_ids'] = df_metabolites_aracore['aracore_ids'].apply(lambda x: f"{x.rsplit('_',1)[0]}_{df_compartment_mapping[x.rsplit('_',1)[-1]]}").str.lower()

#Create universal metabolite ids by removing compartment symbols
df_metabolites_aracore['aracore_updated_universal_ids'] = df_metabolites_aracore['aracore_updated_ids'].apply(lambda x: x.rsplit('_',1)[0])

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ... aracore_updated_universal_ids
# 0        hnu_h  ...                           hnu
# 1         PQ_h  ...                            pq
# 2        H2O_h  ...                           h2o
# 3          H_h  ...                             h
# 4       PQH2_h  ...                          pqh2
# 5         O2_h  ...                            o2
# 6          H_l  ...                             h
# 7       PCox_h  ...                          pcox
# 8       PCrd_h  ...                          pcrd
# 9       Fdox_h  ...                          fdox
# 10      Fdrd_h  ...                          fdrd
# 11      NADP_h  ...                          nadp
# 12     NADPH_h  ...                         nadph
# 13       ADP_h  ...                           adp
# 14        Pi_h  ...                            pi
# 15       ATP_h  ...                           atp
# 16      RuBP_h  ...                          rubp
# 17       CO2_h  ...                           co2
# 18       PGA_h  ...                           pga
# 19      DPGA_h  ...                          dpga
# 20       GAP_h  ...                           gap
# 21      DHAP_h  ...                          dhap
# 22       FBP_h  ...                           fbp
# 23       F6P_h  ...                           f6p
# 24       E4P_h  ...                           e4p
#
# [25 rows x 6 columns]

# %% [markdown]
# # BIGG Metabolites
#
# ---

# %%
# Load BIGG Reaction Table
bigg_metabolites_url = 'http://bigg.ucsd.edu/static/namespace/bigg_models_metabolites.txt'
df_metabolites_bigg = pd.read_csv(bigg_metabolites_url, sep='\t')

df_metabolites_bigg.head(25)
# Out:
#          bigg_id  ...                                       old_bigg_ids
# 0     12dgr120_c  ...     12dgr120; 12dgr120[c]; 12dgr120_c; _12dgr120_c
# 1     12dgr140_c  ...     12dgr140; 12dgr140[c]; 12dgr140_c; _12dgr140_c
# 2     12dgr180_c  ...     12dgr180; 12dgr180[c]; 12dgr180_c; _12dgr180_c
# 3     14glucan_c  ...                               14glucan; 14glucan_c
# 4        15dap_c  ...                           15dap; 15dap[c]; 15dap_c
# 5       23ddhb_c  ...                                   23ddhb; 23ddhb_c
# 6       23dhba_c  ...                                   23dhba; 23dhba_c
# 7      23dhbzs_c  ...                                 23dhbzs; 23dhbzs_c
# 8     26dap_LL_c  ...  26dap-LL[c]; 26dap_DASH_LL_c; 26dap_LL; 26dap_...
# 9     2agpe141_c  ...                  2agpe141; 2agpe141_c; _2agpe141_c
# 10    2agpe160_c  ...                  2agpe160; 2agpe160_c; _2agpe160_c
# 11    2agpg120_c  ...                  2agpg120; 2agpg120_c; _2agpg120_c
# 12    2agpg140_c  ...                  2agpg140; 2agpg140_c; _2agpg140_c
# 13      2aobut_c  ...                        2aobut; 2aobut[c]; 2aobut_c
# 14  2dh3dgal6p_c  ...                           2dh3dgal6p; 2dh3dgal6p_c
# 15        2dhp_c  ...                     2dhp; 2dhp[c]; 2dhp_c; _2dhp_c
# 16     2dmmql8_c  ...         2dmmql8; 2dmmql8[c]; 2dmmql8_c; _2dmmql8_c
# 17    2h3oppan_c  ...                  2h3oppan; 2h3oppan[c]; 2h3oppan_c
# 18    2hdecg3p_c  ...                               2hdecg3p; 2hdecg3p_c
# 19    2odecg3p_c  ...                               2odecg3p; 2odecg3p_c
# 20       2ohph_c  ...                                     2ohph; 2ohph_c
# 21      2ombzl_c  ...                                   2ombzl; 2ombzl_c
# 22       2omph_c  ...                                     2omph; 2omph_c
# 23        2oph_c  ...                                       2oph; 2oph_c
# 24      2pglyc_c  ...                        2pglyc; 2pglyc[c]; 2pglyc_c
#
# [25 rows x 6 columns]

# %%
#Convert universal bigg id for metabolites to lower case
df_metabolites_bigg['universal_bigg_id_lower'] = df_metabolites_bigg['universal_bigg_id'].str.lower()

# %%
#Convert string of database links into dictionaries of database identifier/symbol (key) and database-specific metabolite/annotation id (value)
df_metabolites_bigg['database_links'] = df_metabolites_bigg['database_links'].apply(lambda str_links: {db_link.split(':',1)[-1].split('/')[-2]: db_link.split(':',1)[-1].split('/')[-1] for db_link in str_links.split(';')} if isinstance(str_links,str) else {})

# %%
#All database keys in database_links
np.unique(df_metabolites_bigg['database_links'].apply(lambda x: list(x.keys())).sum())
# Out:
# array(['biocyc', 'chebi', 'hmdb', 'inchikey', 'kegg.compound',
#        'kegg.drug', 'kegg.glycan', 'lipidmaps', 'metanetx.chemical',
#        'reactome', 'seed.compound'], dtype='<U17')

# %%
#Get ModelSEED compound ids (metabolite ids)
df_metabolites_bigg['seed.compound'] = df_metabolites_bigg['database_links'].apply(lambda dict_db_link:  dict_db_link['seed.compound'] if 'seed.compound' in dict_db_link.keys() else None)
df_metabolites_bigg.head(25)
# Out:
#          bigg_id universal_bigg_id  ... universal_bigg_id_lower seed.compound
# 0     12dgr120_c          12dgr120  ...                12dgr120          None
# 1     12dgr140_c          12dgr140  ...                12dgr140          None
# 2     12dgr180_c          12dgr180  ...                12dgr180          None
# 3     14glucan_c          14glucan  ...                14glucan      cpd21754
# 4        15dap_c             15dap  ...                   15dap      cpd01155
# 5       23ddhb_c            23ddhb  ...                  23ddhb      cpd29666
# 6       23dhba_c            23dhba  ...                  23dhba      cpd02494
# 7      23dhbzs_c           23dhbzs  ...                 23dhbzs      cpd15332
# 8     26dap_LL_c          26dap_LL  ...                26dap_ll      cpd00504
# 9     2agpe141_c          2agpe141  ...                2agpe141          None
# 10    2agpe160_c          2agpe160  ...                2agpe160      cpd26438
# 11    2agpg120_c          2agpg120  ...                2agpg120          None
# 12    2agpg140_c          2agpg140  ...                2agpg140      cpd26437
# 13      2aobut_c            2aobut  ...                  2aobut      cpd02211
# 14  2dh3dgal6p_c        2dh3dgal6p  ...              2dh3dgal6p      cpd00945
# 15        2dhp_c              2dhp  ...                    2dhp      cpd00712
# 16     2dmmql8_c           2dmmql8  ...                 2dmmql8      cpd15353
# 17    2h3oppan_c          2h3oppan  ...                2h3oppan      cpd00843
# 18    2hdecg3p_c          2hdecg3p  ...                2hdecg3p      cpd15355
# 19    2odecg3p_c          2odecg3p  ...                2odecg3p      cpd15358
# 20       2ohph_c             2ohph  ...                   2ohph      cpd03445
# 21      2ombzl_c            2ombzl  ...                  2ombzl      cpd15359
# 22       2omph_c             2omph  ...                   2omph      cpd03446
# 23        2oph_c              2oph  ...                    2oph      cpd03444
# 24      2pglyc_c            2pglyc  ...                  2pglyc      cpd00727
#
# [25 rows x 8 columns]

# %% [markdown]
# # ModelSeed Metabolites

# %%
# Load ModelSeed Reaction Table

seed_metabolites_url = 'https://raw.githubusercontent.com/ModelSEED/ModelSEEDDatabase/master/Biochemistry/compounds.tsv'
df_metabolites_seed = pd.read_csv(seed_metabolites_url, sep='\t')

df_metabolites_seed.head(25)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           id  ...      notes
# 0   cpd00001  ...  GC|EQ|EQU
# 1   cpd00002  ...  GC|EQ|EQU
# 2   cpd00003  ...  GC|EQ|EQU
# 3   cpd00004  ...  GC|EQ|EQU
# 4   cpd00005  ...  GC|EQ|EQU
# 5   cpd00006  ...  GC|EQ|EQU
# 6   cpd00007  ...  GC|EQ|EQU
# 7   cpd00008  ...  GC|EQ|EQU
# 8   cpd00009  ...  GC|EQ|EQU
# 9   cpd00010  ...  GC|EQ|EQU
# 10  cpd00011  ...  GC|EQ|EQU
# 11  cpd00012  ...  GC|EQ|EQU
# 12  cpd00013  ...  GC|EQ|EQU
# 13  cpd00014  ...  GC|EQ|EQU
# 14  cpd00015  ...  GC|EQ|EQU
# 15  cpd00016  ...  GC|EQ|EQU
# 16  cpd00017  ...      GC|EQ
# 17  cpd00018  ...  GC|EQ|EQU
# 18  cpd00019  ...  GC|EQ|EQU
# 19  cpd00020  ...  GC|EQ|EQU
# 20  cpd00021  ...  GC|EQ|EQU
# 21  cpd00022  ...  GC|EQ|EQU
# 22  cpd00023  ...  GC|EQ|EQU
# 23  cpd00024  ...  GC|EQ|EQU
# 24  cpd00025  ...  GC|EQ|EQU
#
# [25 rows x 21 columns]

# %%
df_metabolites_seed['abbreviation_lower'] = df_metabolites_seed['abbreviation'].str.lower()

# %%
#Convert string of alias pairs into dictionaries of keys and value - 
# 1) split by "|" to sepertae the different key - value pairs
# 2) split by ":" to seperate keys and values
df_metabolites_seed['aliases'] = df_metabolites_seed['aliases'].apply(lambda aliases_str: 
                                                                      {alias.split(':',1)[0]: alias.split(':',1)[-1] 
                                                                       for alias in aliases_str.split('|')} if isinstance(aliases_str, str) else {} )

#Some of the keys have values that are again a strings with multiple items that need to be splitted
# 3) split those  string by ';' and also remove leading and tailing white spaces 
df_metabolites_seed['aliases'] = df_metabolites_seed['aliases'].apply(lambda aliases_dict: 
                                                                      {alias_key:
                                                                       [alias_value.strip() for alias_value in alias_values.split(';')]
                                                                       for alias_key, alias_values in aliases_dict.items()}
                                                                      )

df_metabolites_seed.head(25)
# Out:
#           id abbreviation  ...      notes abbreviation_lower
# 0   cpd00001          h2o  ...  GC|EQ|EQU                h2o
# 1   cpd00002          atp  ...  GC|EQ|EQU                atp
# 2   cpd00003          nad  ...  GC|EQ|EQU                nad
# 3   cpd00004         nadh  ...  GC|EQ|EQU               nadh
# 4   cpd00005        nadph  ...  GC|EQ|EQU              nadph
# 5   cpd00006         nadp  ...  GC|EQ|EQU               nadp
# 6   cpd00007           o2  ...  GC|EQ|EQU                 o2
# 7   cpd00008          adp  ...  GC|EQ|EQU                adp
# 8   cpd00009           pi  ...  GC|EQ|EQU                 pi
# 9   cpd00010          coa  ...  GC|EQ|EQU                coa
# 10  cpd00011          co2  ...  GC|EQ|EQU                co2
# 11  cpd00012          ppi  ...  GC|EQ|EQU                ppi
# 12  cpd00013          nh4  ...  GC|EQ|EQU                nh4
# 13  cpd00014          udp  ...  GC|EQ|EQU                udp
# 14  cpd00015          fad  ...  GC|EQ|EQU                fad
# 15  cpd00016       pydx5p  ...  GC|EQ|EQU             pydx5p
# 16  cpd00017         amet  ...      GC|EQ               amet
# 17  cpd00018          amp  ...  GC|EQ|EQU                amp
# 18  cpd00019        ahcys  ...  GC|EQ|EQU              ahcys
# 19  cpd00020          pyr  ...  GC|EQ|EQU                pyr
# 20  cpd00021         Iron  ...  GC|EQ|EQU               iron
# 21  cpd00022        accoa  ...  GC|EQ|EQU              accoa
# 22  cpd00023        glu-L  ...  GC|EQ|EQU              glu-l
# 23  cpd00024          akg  ...  GC|EQ|EQU                akg
# 24  cpd00025         h2o2  ...  GC|EQ|EQU               h2o2
#
# [25 rows x 22 columns]

# %%
#All database keys in aliases
np.unique(df_metabolites_seed['aliases'].apply(lambda x: list(x.keys())).sum())
# Out:
# array(['AlgaGEM', 'AraCyc', 'AraGEM', 'BiGG', 'BrachyCyc', 'ChlamyCyc',
#        'CornCyc', 'DF_Athaliana', 'EcoCyc', 'JM_Creinhardtii',
#        'JP_Creinhardtii_MSB', 'JP_Creinhardtii_NMeth', 'KEGG', 'MaizeCyc',
#        'Maize_C4GEM', 'MetaCyc', 'Name', 'PlantCyc', 'PoplarCyc',
#        'RiceCyc', 'SorghumCyc', 'SoyCyc', 'TS_Athaliana', 'iAF1260',
#        'iAF692', 'iAG612', 'iAO358', 'iAbaylyiv4', 'iGT196', 'iIN800',
#        'iIT341', 'iJN746', 'iJR904', 'iMA945', 'iMEO21', 'iMM904',
#        'iMO1053-PAO1', 'iMO1056', 'iND750', 'iNJ661', 'iPS189', 'iRR1083',
#        'iRS1563', 'iRS1597', 'iSB619', 'iSO783', 'iYO844'], dtype='<U21')

# %%
#Get BiGG metabolite ids
df_metabolites_seed['BiGG'] = df_metabolites_seed['aliases'].apply(lambda dict_aliases:  dict_aliases['BiGG'] if 'BiGG' in dict_aliases.keys() else None)
df_metabolites_seed.head(25)
# Out:
#           id abbreviation  ... abbreviation_lower        BiGG
# 0   cpd00001          h2o  ...                h2o  [h2o, oh1]
# 1   cpd00002          atp  ...                atp       [atp]
# 2   cpd00003          nad  ...                nad       [nad]
# 3   cpd00004         nadh  ...               nadh      [nadh]
# 4   cpd00005        nadph  ...              nadph     [nadph]
# 5   cpd00006         nadp  ...               nadp      [nadp]
# 6   cpd00007           o2  ...                 o2        [o2]
# 7   cpd00008          adp  ...                adp       [adp]
# 8   cpd00009           pi  ...                 pi        [pi]
# 9   cpd00010          coa  ...                coa       [coa]
# 10  cpd00011          co2  ...                co2       [co2]
# 11  cpd00012          ppi  ...                ppi       [ppi]
# 12  cpd00013          nh4  ...                nh4  [nh3, nh4]
# 13  cpd00014          udp  ...                udp       [udp]
# 14  cpd00015          fad  ...                fad       [fad]
# 15  cpd00016       pydx5p  ...             pydx5p    [pydx5p]
# 16  cpd00017         amet  ...               amet      [amet]
# 17  cpd00018          amp  ...                amp       [amp]
# 18  cpd00019        ahcys  ...              ahcys     [ahcys]
# 19  cpd00020          pyr  ...                pyr       [pyr]
# 20  cpd00021         Iron  ...               iron        None
# 21  cpd00022        accoa  ...              accoa     [accoa]
# 22  cpd00023        glu-L  ...              glu-l    [glu__L]
# 23  cpd00024          akg  ...                akg       [akg]
# 24  cpd00025         h2o2  ...               h2o2      [h2o2]
#
# [25 rows x 23 columns]

# %%
df_metabolites_seed['BiGG'].notna().value_counts() # => ModelSeed seems to have only 2729 compounds mapped with BiGG Ids
# Out:
# False    31263
# True      2729
# Name: BiGG, dtype: int64

# %%
df_metabolites_seed['formula'].nunique()
# Out:
# 16762

# %% [markdown]
# # Mapping AraCore - BIGG

# %% [markdown]
# ## Based on BiGG and AraCore Metabolite Ids

# %%
#Check if universal metabolite ids of aracore model have an equivalent metabolite ids in BIGG based on same namimg
df_metabolites_aracore['is_bigg_id'] = df_metabolites_aracore['aracore_updated_universal_ids'].apply(lambda met_id: ((df_metabolites_bigg['universal_bigg_id_lower'] == met_id).sum() > 0))

#Fill column for universal bigg ids for which above is the case
df_metabolites_aracore['universal_bigg_id'] = df_metabolites_aracore[['aracore_updated_universal_ids','is_bigg_id']].apply(lambda x: x[0] if x[1] else None,axis=1)

#Add ModelSEED compound ids from BiGG metabolite table => df_metabolites_bigg['seed.compound']
df_metabolites_aracore['bigg_seed_id'] = df_metabolites_aracore[['aracore_updated_universal_ids','is_bigg_id']].apply(lambda x: df_metabolites_bigg[df_metabolites_bigg['universal_bigg_id_lower'] == x[0]]['seed.compound'].unique()[0] if x[1] else None,axis=1)

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ... bigg_seed_id
# 0        hnu_h  ...         None
# 1         PQ_h  ...         None
# 2        H2O_h  ...     cpd27222
# 3          H_h  ...     cpd00067
# 4       PQH2_h  ...         None
# 5         O2_h  ...     cpd00007
# 6          H_l  ...     cpd00067
# 7       PCox_h  ...     cpd30035
# 8       PCrd_h  ...     cpd30034
# 9       Fdox_h  ...     cpd15876
# 10      Fdrd_h  ...         None
# 11      NADP_h  ...     cpd00006
# 12     NADPH_h  ...     cpd00005
# 13       ADP_h  ...     cpd00008
# 14        Pi_h  ...     cpd27787
# 15       ATP_h  ...     cpd00002
# 16      RuBP_h  ...         None
# 17       CO2_h  ...     cpd00011
# 18       PGA_h  ...         None
# 19      DPGA_h  ...         None
# 20       GAP_h  ...         None
# 21      DHAP_h  ...     cpd00095
# 22       FBP_h  ...         None
# 23       F6P_h  ...     cpd19035
# 24       E4P_h  ...     cpd00236
#
# [25 rows x 9 columns]

# %%
df_metabolites_aracore['is_bigg_id'].value_counts() # => 165 mapping between aracore_updated_universal_ids and universal_bigg_id_lower
# Out:
# False    248
# True     165
# Name: is_bigg_id, dtype: int64

# %%
df_metabolites_aracore['bigg_seed_id'].isna().value_counts() # => 156 additional ModelSeed compound id found by mapped BiGG
# Out:
# True     257
# False    156
# Name: bigg_seed_id, dtype: int64

# %% [markdown]
# # Mapping AraCore - ModelSeed

# %% [markdown]
# ## Based on ModelSEED and AraCore Metabolite Ids

# %%
#Check if universal metabolite ids of aracore model have an equivalent metabolite ids in BIGG based on same namimg
df_metabolites_aracore['is_seed_id'] = df_metabolites_aracore['aracore_updated_universal_ids'].apply(lambda met_id: ((df_metabolites_seed['abbreviation_lower'] == met_id).sum() > 0))

#Fill column for universal bigg ids for which above is the case
df_metabolites_aracore['seed_id'] = df_metabolites_aracore[['aracore_updated_universal_ids','is_seed_id']].apply(lambda x: df_metabolites_seed[df_metabolites_seed['abbreviation_lower'] == x[0]]['id'].tolist()[0] if x[1] else None,axis=1)

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ...   seed_id
# 0        hnu_h  ...      None
# 1         PQ_h  ...      None
# 2        H2O_h  ...  cpd00001
# 3          H_h  ...  cpd00067
# 4       PQH2_h  ...      None
# 5         O2_h  ...  cpd00007
# 6          H_l  ...  cpd00067
# 7       PCox_h  ...      None
# 8       PCrd_h  ...      None
# 9       Fdox_h  ...  cpd15876
# 10      Fdrd_h  ...      None
# 11      NADP_h  ...  cpd00006
# 12     NADPH_h  ...  cpd00005
# 13       ADP_h  ...  cpd00008
# 14        Pi_h  ...  cpd00009
# 15       ATP_h  ...  cpd00002
# 16      RuBP_h  ...      None
# 17       CO2_h  ...  cpd00011
# 18       PGA_h  ...  cpd29254
# 19      DPGA_h  ...      None
# 20       GAP_h  ...      None
# 21      DHAP_h  ...  cpd00095
# 22       FBP_h  ...      None
# 23       F6P_h  ...  cpd00072
# 24       E4P_h  ...  cpd00236
#
# [25 rows x 11 columns]

# %% [markdown]
# ## Based on unique chemical formulas

# %%
#Map chemical formulas 
df_metabolites_aracore['formula_seed_id'] = df_metabolites_aracore['aracore_formula'].apply(lambda formula: 
                                                df_metabolites_seed[df_metabolites_seed['formula'] == formula]['id'].tolist() 
                                                if formula != 'X' else [] )

#Only keep mapping where a single seed_id has been mapped, since chemical formulas are not unique identifiers - different metabolites may have the same chemical formula
df_metabolites_aracore['formula_seed_id']  = df_metabolites_aracore['formula_seed_id'].apply(lambda formula_seed_id: formula_seed_id[0] if len(formula_seed_id) == 1 else None)                     
df_metabolites_aracore.head(50)
# Out:
#    aracore_ids  ... formula_seed_id
# 0        hnu_h  ...            None
# 1         PQ_h  ...            None
# 2        H2O_h  ...            None
# 3          H_h  ...        cpd00067
# 4       PQH2_h  ...            None
# 5         O2_h  ...            None
# 6          H_l  ...        cpd00067
# 7       PCox_h  ...            None
# 8       PCrd_h  ...            None
# 9       Fdox_h  ...            None
# 10      Fdrd_h  ...            None
# 11      NADP_h  ...            None
# 12     NADPH_h  ...            None
# 13       ADP_h  ...        cpd22244
# 14        Pi_h  ...            None
# 15       ATP_h  ...            None
# 16      RuBP_h  ...            None
# 17       CO2_h  ...        cpd00011
# 18       PGA_h  ...            None
# 19      DPGA_h  ...        cpd00203
# 20       GAP_h  ...            None
# 21      DHAP_h  ...            None
# 22       FBP_h  ...            None
# 23       F6P_h  ...            None
# 24       E4P_h  ...            None
# 25       X5P_h  ...            None
# 26       SBP_h  ...            None
# 27       S7P_h  ...            None
# 28       R5P_h  ...            None
# 29      Ru5P_h  ...            None
# 30       G6P_h  ...            None
# 31       G1P_h  ...            None
# 32      ADPG_h  ...            None
# 33       PPi_h  ...            None
# 34   starch1_h  ...            None
# 35   starch2_h  ...            None
# 36   starch3_h  ...            None
# 37   starch5_h  ...            None
# 38       Mas_h  ...            None
# 39       Glc_h  ...            None
# 40   starch1_c  ...            None
# 41       Mas_c  ...            None
# 42   starch2_c  ...            None
# 43       Glc_c  ...            None
# 44       ATP_c  ...            None
# 45       G6P_c  ...            None
# 46       ADP_c  ...        cpd22244
# 47         H_c  ...        cpd00067
# 48        Na_c  ...            None
# 49        Na_h  ...            None
#
# [50 rows x 12 columns]

# %% [markdown]
# ## Aggregate ModelSeed Ids mapped based on shared Ids and Chemical Formulas

# %%
#Fuse the to colums seed_id and formula_seed_id
df_metabolites_aracore['seed_id'] = df_metabolites_aracore[['seed_id','formula_seed_id']].apply(lambda x: list(np.unique(list(filter(None,[x[0], x[1]])))),axis=1) #.apply(len) > 1]

# %%
#Check if there are metabolites that have more than one ModelSEED id after fusing
df_metabolites_aracore[df_metabolites_aracore['seed_id'].apply(len) > 1]
# Out:
#     aracore_ids           aracore_name  ...               seed_id formula_seed_id
# 13        ADP_h  Adenosine diphosphate  ...  [cpd00008, cpd22244]        cpd22244
# 46        ADP_c  Adenosine diphosphate  ...  [cpd00008, cpd22244]        cpd22244
# 108       ADP_m  Adenosine diphosphate  ...  [cpd00008, cpd22244]        cpd22244
# 112         Q_m             Ubiquinone  ...  [cpd11669, cpd15560]        cpd15560
# 196       NO2_c                Nitrite  ...  [cpd00075, cpd27655]        cpd27655
# 197       NO2_h                Nitrite  ...  [cpd00075, cpd27655]        cpd27655
#
# [6 rows x 12 columns]

# %%
#Resolve conflicts check back with ModelSEED database https://modelseed.org/biochem/compounds

#ADP_h, ADP_c, ADP_m => #cpd00008
df_metabolites_aracore.loc[13, 'seed_id'] = [['cpd00008']]
df_metabolites_aracore.loc[46, 'seed_id'] = [['cpd00008']]
df_metabolites_aracore.loc[108, 'seed_id'] = [['cpd00008']]


#Q_m => cpd15560
df_metabolites_aracore.loc[112, 'seed_id'] = [['cpd15560']]

#NO2_c, NO2_h => cpd00075
df_metabolites_aracore.loc[196, 'seed_id'] = [['cpd00075']]
df_metabolites_aracore.loc[197, 'seed_id'] = [['cpd00075']]

# %%
#Convert ModelSeed id list of len 1 to simple string
df_metabolites_aracore['seed_id'] = df_metabolites_aracore['seed_id'].apply(lambda seed_id_list: seed_id_list[0] if len(seed_id_list) == 1 else None)

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ... formula_seed_id
# 0        hnu_h  ...            None
# 1         PQ_h  ...            None
# 2        H2O_h  ...            None
# 3          H_h  ...        cpd00067
# 4       PQH2_h  ...            None
# 5         O2_h  ...            None
# 6          H_l  ...        cpd00067
# 7       PCox_h  ...            None
# 8       PCrd_h  ...            None
# 9       Fdox_h  ...            None
# 10      Fdrd_h  ...            None
# 11      NADP_h  ...            None
# 12     NADPH_h  ...            None
# 13       ADP_h  ...        cpd22244
# 14        Pi_h  ...            None
# 15       ATP_h  ...            None
# 16      RuBP_h  ...            None
# 17       CO2_h  ...        cpd00011
# 18       PGA_h  ...            None
# 19      DPGA_h  ...        cpd00203
# 20       GAP_h  ...            None
# 21      DHAP_h  ...            None
# 22       FBP_h  ...            None
# 23       F6P_h  ...            None
# 24       E4P_h  ...            None
#
# [25 rows x 12 columns]

# %%
df_metabolites_aracore['seed_id'].notna().value_counts() # => 197 mapping with ModelSeed Ids
# Out:
# False    216
# True     197
# Name: seed_id, dtype: int64

# %% [markdown]
# ## Add BiGG ids that are avialble from the ModelSeed Table

# %%
#Add BiGG ids (BiGG) from ModelSEED table => df_metabolites_seed['BiGG]
df_metabolites_aracore['seed_BiGG_id'] = df_metabolites_aracore['seed_id'].apply(lambda seed_id: df_metabolites_seed[df_metabolites_seed['id'] == seed_id]['BiGG']  if not isinstance(seed_id, type(None)) else None)
df_metabolites_aracore['seed_BiGG_id'] = df_metabolites_aracore['seed_BiGG_id'].apply(lambda x: x.values.tolist()[0] if isinstance(x, pd.core.series.Series) else None)

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ...  seed_BiGG_id
# 0        hnu_h  ...          None
# 1         PQ_h  ...          None
# 2        H2O_h  ...    [h2o, oh1]
# 3          H_h  ...           [h]
# 4       PQH2_h  ...          None
# 5         O2_h  ...          [o2]
# 6          H_l  ...           [h]
# 7       PCox_h  ...          None
# 8       PCrd_h  ...          None
# 9       Fdox_h  ...        [fdox]
# 10      Fdrd_h  ...          None
# 11      NADP_h  ...        [nadp]
# 12     NADPH_h  ...       [nadph]
# 13       ADP_h  ...         [adp]
# 14        Pi_h  ...          [pi]
# 15       ATP_h  ...         [atp]
# 16      RuBP_h  ...          None
# 17       CO2_h  ...         [co2]
# 18       PGA_h  ...          None
# 19      DPGA_h  ...       [13dpg]
# 20       GAP_h  ...          None
# 21      DHAP_h  ...        [dhap]
# 22       FBP_h  ...          None
# 23       F6P_h  ...  [f6p, f6p_B]
# 24       E4P_h  ...         [e4p]
#
# [25 rows x 13 columns]

# %%
df_metabolites_aracore['seed_BiGG_id'].notna().value_counts() # => 187 additional BiGG Ids found by mapped ModelSeed compound id
# Out:
# False    226
# True     187
# Name: seed_BiGG_id, dtype: int64

# %% [markdown]
# #Aggregate ModelSEED compound ids in column 'bigg_seed_id' and 'seed_id'
#
#
# ---

# %%
#Aggregate model seed compound ids from columns 'bigg_seed_id' and 'seed_id' into a list and extract unique values of this list
df_metabolites_aracore['seed_id_aggr'] = df_metabolites_aracore[['bigg_seed_id', 'seed_id']].apply(lambda x: list(np.unique(list(filter(None,[x[0],x[1]])))) , axis=1)
df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ...          seed_id_aggr
# 0        hnu_h  ...                    []
# 1         PQ_h  ...                    []
# 2        H2O_h  ...  [cpd00001, cpd27222]
# 3          H_h  ...            [cpd00067]
# 4       PQH2_h  ...                    []
# 5         O2_h  ...            [cpd00007]
# 6          H_l  ...            [cpd00067]
# 7       PCox_h  ...            [cpd30035]
# 8       PCrd_h  ...            [cpd30034]
# 9       Fdox_h  ...            [cpd15876]
# 10      Fdrd_h  ...                    []
# 11      NADP_h  ...            [cpd00006]
# 12     NADPH_h  ...            [cpd00005]
# 13       ADP_h  ...            [cpd00008]
# 14        Pi_h  ...  [cpd00009, cpd27787]
# 15       ATP_h  ...            [cpd00002]
# 16      RuBP_h  ...                    []
# 17       CO2_h  ...            [cpd00011]
# 18       PGA_h  ...            [cpd29254]
# 19      DPGA_h  ...            [cpd00203]
# 20       GAP_h  ...                    []
# 21      DHAP_h  ...            [cpd00095]
# 22       FBP_h  ...                    []
# 23       F6P_h  ...  [cpd00072, cpd19035]
# 24       E4P_h  ...            [cpd00236]
#
# [25 rows x 14 columns]

# %%
df_metabolites_aracore['seed_id_aggr'].apply(len).value_counts() # => 127  + 37 = 164 metabolites have ModelSeed Ids -> 37 metabolites have 2 ModelSeed Ids -> potential conflicts !?!
# Out:
# 0    214
# 1    162
# 2     37
# Name: seed_id_aggr, dtype: int64

# %%
#Extract those metabolites that have more than one ModelSeed compound ids mmapped
df_metabolites_aracore_seed_conflicted = df_metabolites_aracore[df_metabolites_aracore['seed_id_aggr'].apply(len) > 1].copy()
df_metabolites_aracore_seed_conflicted
# Out:
#     aracore_ids  ...          seed_id_aggr
# 2         H2O_h  ...  [cpd00001, cpd27222]
# 14         Pi_h  ...  [cpd00009, cpd27787]
# 23        F6P_h  ...  [cpd00072, cpd19035]
# 28        R5P_h  ...  [cpd00101, cpd19028]
# 30        G6P_h  ...  [cpd00079, cpd26836]
# 31        G1P_h  ...  [cpd00089, cpd28817]
# 33        PPi_h  ...  [cpd00012, cpd27828]
# 45        G6P_c  ...  [cpd00079, cpd26836]
# 50         Pi_c  ...  [cpd00009, cpd27787]
# 51        G1P_c  ...  [cpd00089, cpd28817]
# 55        H2O_c  ...  [cpd00001, cpd27222]
# 56        F6P_c  ...  [cpd00072, cpd19035]
# 59       UDPG_c  ...  [cpd00026, cpd28293]
# 60        PPi_c  ...  [cpd00012, cpd27828]
# 95        CoA_m  ...  [cpd00010, cpd22528]
# 101       H2O_m  ...  [cpd00001, cpd27222]
# 109        Pi_m  ...  [cpd00009, cpd27787]
# 126       H2O_p  ...  [cpd00001, cpd27222]
# 133       THF_m  ...  [cpd00087, cpd29254]
# 136       NH4_m  ...  [cpd00013, cpd19013]
# 157       AMP_h  ...  [cpd00018, cpd22272]
# 164       CoA_c  ...  [cpd00010, cpd22528]
# 167       CoA_h  ...  [cpd00010, cpd22528]
# 182       For_h  ...  [cpd00047, cpd22511]
# 183       THF_h  ...  [cpd00087, cpd29254]
# 186       THF_c  ...  [cpd00087, cpd29254]
# 190       AMP_c  ...  [cpd00018, cpd22272]
# 198       NH4_h  ...  [cpd00013, cpd19013]
# 199       SO4_h  ...  [cpd00048, cpd29301]
# 200       SO4_m  ...  [cpd00048, cpd29301]
# 205       H2S_h  ...  [cpd00239, cpd24697]
# 216       Orn_h  ...  [cpd00064, cpd19016]
# 231       NH4_c  ...  [cpd00013, cpd19013]
# 237       H2S_c  ...  [cpd00239, cpd24697]
# 241       H2S_m  ...  [cpd00239, cpd24697]
# 303       Orn_m  ...  [cpd00064, cpd19016]
# 364       SO4_c  ...  [cpd00048, cpd29301]
#
# [37 rows x 14 columns]

# %%
#Add abbreviations and formulas of the df_metabolites_seed to compare by eye and make notes to solve potential conflicts for later
df_metabolites_aracore_seed_conflicted['seed_id_aggr_abbr'] = df_metabolites_aracore_seed_conflicted['seed_id_aggr'].apply(lambda x: [df_metabolites_seed[df_metabolites_seed['id'] == compound_id]['abbreviation'].tolist()[0] for compound_id in x])
df_metabolites_aracore_seed_conflicted['seed_id_aggr_formula'] = df_metabolites_aracore_seed_conflicted['seed_id_aggr'].apply(lambda x: [df_metabolites_seed[df_metabolites_seed['id'] == compound_id]['formula'].tolist()[0] for compound_id in x])
df_metabolites_aracore_seed_conflicted[['aracore_ids','aracore_name','aracore_formula','seed_id_aggr','seed_id_aggr_abbr','seed_id_aggr_formula']]
# Out:
#     aracore_ids  ...              seed_id_aggr_formula
# 2         H2O_h  ...                         [H2O, HO]
# 14         Pi_h  ...                      [HO4P, HO4P]
# 23        F6P_h  ...              [C6H11O9P, C6H11O9P]
# 28        R5P_h  ...                [C5H9O8P, C5H9O8P]
# 30        G6P_h  ...              [C6H11O9P, C6H11O9P]
# 31        G1P_h  ...              [C6H11O9P, C6H11O9P]
# 33        PPi_h  ...                    [HO7P2, HO7P2]
# 45        G6P_c  ...              [C6H11O9P, C6H11O9P]
# 50         Pi_c  ...                      [HO4P, HO4P]
# 51        G1P_c  ...              [C6H11O9P, C6H11O9P]
# 55        H2O_c  ...                         [H2O, HO]
# 56        F6P_c  ...              [C6H11O9P, C6H11O9P]
# 59       UDPG_c  ...    [C15H22N2O17P2, C15H22N2O17P2]
# 60        PPi_c  ...                    [HO7P2, HO7P2]
# 95        CoA_m  ...  [C21H32N7O16P3S, C21H32N7O16P3S]
# 101       H2O_m  ...                         [H2O, HO]
# 109        Pi_m  ...                      [HO4P, HO4P]
# 126       H2O_p  ...                         [H2O, HO]
# 133       THF_m  ...          [C19H21N7O6, C19H19N7O6]
# 136       NH4_m  ...                        [H4N, H4N]
# 157       AMP_h  ...        [C10H12N5O7P, C10H12N5O7P]
# 164       CoA_c  ...  [C21H32N7O16P3S, C21H32N7O16P3S]
# 167       CoA_h  ...  [C21H32N7O16P3S, C21H32N7O16P3S]
# 182       For_h  ...                      [CHO2, CHO2]
# 183       THF_h  ...          [C19H21N7O6, C19H19N7O6]
# 186       THF_c  ...          [C19H21N7O6, C19H19N7O6]
# 190       AMP_c  ...        [C10H12N5O7P, C10H12N5O7P]
# 198       NH4_h  ...                        [H4N, H4N]
# 199       SO4_h  ...                      [O4S, H2O4S]
# 200       SO4_m  ...                      [O4S, H2O4S]
# 205       H2S_h  ...                          [HS, HS]
# 216       Orn_h  ...            [C5H13N2O2, C5H13N2O2]
# 231       NH4_c  ...                        [H4N, H4N]
# 237       H2S_c  ...                          [HS, HS]
# 241       H2S_m  ...                          [HS, HS]
# 303       Orn_m  ...            [C5H13N2O2, C5H13N2O2]
# 364       SO4_c  ...                      [O4S, H2O4S]
#
# [37 rows x 6 columns]

# %%
#Resolve conflict in original table df_metabolites_aracore
df_metabolites_aracore.set_index("aracore_ids",inplace=True) #Set index to acacore_ids to make editing easiers

#H2O_c, H2O_h, H2O_p, H2O_m == cpd00001
df_metabolites_aracore.loc['H2O_c','seed_id_aggr'] = [['cpd00001']]
df_metabolites_aracore.loc['H2O_h','seed_id_aggr'] = [['cpd00001']]
df_metabolites_aracore.loc['H2O_p','seed_id_aggr'] = [['cpd00001']]
df_metabolites_aracore.loc['H2O_m','seed_id_aggr'] = [['cpd00001']]

#Pi_h,_c,_m => cpd00009
df_metabolites_aracore.loc['Pi_c','seed_id_aggr'] = [['cpd00009']]
df_metabolites_aracore.loc['Pi_h','seed_id_aggr'] = [['cpd00009']]
df_metabolites_aracore.loc['Pi_m','seed_id_aggr'] = [['cpd00009']]

#F6P_c,h => cpd00072
df_metabolites_aracore.loc['F6P_c','seed_id_aggr'] = [['cpd00072']]
df_metabolites_aracore.loc['F6P_h','seed_id_aggr'] = [['cpd00072']]

#R5P_h => cpd00101
df_metabolites_aracore.loc['R5P_h','seed_id_aggr'] = [['cpd00101']]

#G6P_h,c => cpd00079
df_metabolites_aracore.loc['G6P_c','seed_id_aggr'] = [['cpd00079']]
df_metabolites_aracore.loc['G6P_h','seed_id_aggr'] = [['cpd00079']]

#G1P_h,c => cpd00089
df_metabolites_aracore.loc['G1P_c','seed_id_aggr'] = [['cpd00089']]
df_metabolites_aracore.loc['G1P_h','seed_id_aggr'] = [['cpd00089']]


#UDPG_c => cpd00026
df_metabolites_aracore.loc['UDPG_c','seed_id_aggr'] = [['cpd00026']]

#PPi_h,_c => cpd00012
df_metabolites_aracore.loc['PPi_c','seed_id_aggr'] = [['cpd00012']]
df_metabolites_aracore.loc['PPi_h','seed_id_aggr'] = [['cpd00012']]


#CoA_m,_c,_h => cpd00010
df_metabolites_aracore.loc['CoA_c','seed_id_aggr'] = [['cpd00010']]
df_metabolites_aracore.loc['CoA_h','seed_id_aggr'] = [['cpd00010']]
df_metabolites_aracore.loc['CoA_m','seed_id_aggr'] = [['cpd00010']]

#NH4_m,_h,_c => cpd00013
df_metabolites_aracore.loc['NH4_c','seed_id_aggr'] = [['cpd00013']]
df_metabolites_aracore.loc['NH4_h','seed_id_aggr'] = [['cpd00013']]
df_metabolites_aracore.loc['NH4_m','seed_id_aggr'] = [['cpd00013']]

#AMP_h,_c => cpd00018
df_metabolites_aracore.loc['AMP_c','seed_id_aggr'] = [['cpd00018']]
df_metabolites_aracore.loc['AMP_h','seed_id_aggr'] = [['cpd00018']]

#H2S_h,_c,_m => cpd00239
df_metabolites_aracore.loc['H2S_c','seed_id_aggr'] = [['cpd00239']]
df_metabolites_aracore.loc['H2S_h','seed_id_aggr'] = [['cpd00239']]
df_metabolites_aracore.loc['H2S_m','seed_id_aggr'] = [['cpd00239']]

#Orn_h,_m => cpd00064
df_metabolites_aracore.loc['Orn_h','seed_id_aggr'] = [['cpd00064']]
df_metabolites_aracore.loc['Orn_m','seed_id_aggr'] = [['cpd00064']]

#For_h => cpd00047
df_metabolites_aracore.loc['For_h','seed_id_aggr'] = [['cpd00047']]

#THF_m, THF_c, THF_h	5,6,7,8-Tetrahydrofolate == cpd00087 -> 186 has one more H in sum formula
df_metabolites_aracore.loc['THF_m','seed_id_aggr'] = [['cpd00087']]
df_metabolites_aracore.loc['THF_c','seed_id_aggr'] = [['cpd00087']]
df_metabolites_aracore.loc['THF_h','seed_id_aggr'] = [['cpd00087']]

#SO4_h, SO4_m, SO4_c Sulfate O4S == cpd00048
df_metabolites_aracore.loc['SO4_h','seed_id_aggr'] = [['cpd00048']]
df_metabolites_aracore.loc['SO4_m','seed_id_aggr'] = [['cpd00048']]
df_metabolites_aracore.loc['SO4_c','seed_id_aggr'] = [['cpd00048']]

#ppi has different sum formulas in the Aracore model?!?
#Coenzyme A has different sum formulas in the Aracore model?!?
#5,6,7,8-Tetrahydrofolate has different sum formulas in the Aracore model?!?

df_metabolites_aracore.reset_index(inplace=True)

# %%
#Check if all bigg conflicts resolved 
(df_metabolites_aracore['seed_id_aggr'].apply(len) > 1).value_counts() #all conflicts resolved
# Out:
# False    413
# Name: seed_id_aggr, dtype: int64

# %%
#convert list of len 1 into string of BiGG id
df_metabolites_aracore['seed_id_aggr'] = df_metabolites_aracore['seed_id_aggr'].apply(lambda x: x[0] if x else None)

#clean dataframe and drop cols
df_metabolites_aracore.drop(['is_seed_id','seed_id','bigg_seed_id', 'formula_seed_id'], axis=1, inplace=True)

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ... seed_id_aggr
# 0        hnu_h  ...         None
# 1         PQ_h  ...         None
# 2        H2O_h  ...     cpd00001
# 3          H_h  ...     cpd00067
# 4       PQH2_h  ...         None
# 5         O2_h  ...     cpd00007
# 6          H_l  ...     cpd00067
# 7       PCox_h  ...     cpd30035
# 8       PCrd_h  ...     cpd30034
# 9       Fdox_h  ...     cpd15876
# 10      Fdrd_h  ...         None
# 11      NADP_h  ...     cpd00006
# 12     NADPH_h  ...     cpd00005
# 13       ADP_h  ...     cpd00008
# 14        Pi_h  ...     cpd00009
# 15       ATP_h  ...     cpd00002
# 16      RuBP_h  ...         None
# 17       CO2_h  ...     cpd00011
# 18       PGA_h  ...     cpd29254
# 19      DPGA_h  ...     cpd00203
# 20       GAP_h  ...         None
# 21      DHAP_h  ...     cpd00095
# 22       FBP_h  ...         None
# 23       F6P_h  ...     cpd00072
# 24       E4P_h  ...     cpd00236
#
# [25 rows x 10 columns]

# %% [markdown]
# #Aggregate BiGG ids  in column 'universal_bigg_id' and 'seed_BiGG_id'

# %%
#Aggregate model seed compound ids from columns 'bigg_seed_id' and 'seed_id' into a list and extract unique values of this list

df_metabolites_aracore['bigg_id_aggr'] = df_metabolites_aracore[['universal_bigg_id', 'seed_BiGG_id']].apply(lambda x: list(filter(None,[x[0]]+x[1])) if x[1] else  list(filter(None,[x[0]]+[x[1]])), axis=1) #.apply(len).value_counts()
df_metabolites_aracore['bigg_id_aggr'] = df_metabolites_aracore['bigg_id_aggr'].apply(lambda x: list(np.unique(x)))

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ...  bigg_id_aggr
# 0        hnu_h  ...            []
# 1         PQ_h  ...          [pq]
# 2        H2O_h  ...    [h2o, oh1]
# 3          H_h  ...           [h]
# 4       PQH2_h  ...        [pqh2]
# 5         O2_h  ...          [o2]
# 6          H_l  ...           [h]
# 7       PCox_h  ...        [pcox]
# 8       PCrd_h  ...        [pcrd]
# 9       Fdox_h  ...        [fdox]
# 10      Fdrd_h  ...            []
# 11      NADP_h  ...        [nadp]
# 12     NADPH_h  ...       [nadph]
# 13       ADP_h  ...         [adp]
# 14        Pi_h  ...          [pi]
# 15       ATP_h  ...         [atp]
# 16      RuBP_h  ...            []
# 17       CO2_h  ...         [co2]
# 18       PGA_h  ...            []
# 19      DPGA_h  ...       [13dpg]
# 20       GAP_h  ...            []
# 21      DHAP_h  ...        [dhap]
# 22       FBP_h  ...            []
# 23       F6P_h  ...  [f6p, f6p_B]
# 24       E4P_h  ...         [e4p]
#
# [25 rows x 11 columns]

# %%
#Extract those metabolites that have more than one ModelSeed compound ids mmapped
df_metabolites_aracore_bigg_conflicted = df_metabolites_aracore[df_metabolites_aracore['bigg_id_aggr'].apply(len) > 1].copy()
df_metabolites_aracore_bigg_conflicted
# Out:
#     aracore_ids          aracore_name  ... seed_id_aggr   bigg_id_aggr
# 2         H2O_h            H2O, water  ...     cpd00001     [h2o, oh1]
# 23        F6P_h  Fructose 6-phosphate  ...     cpd00072   [f6p, f6p_B]
# 55        H2O_c            H2O, water  ...     cpd00001     [h2o, oh1]
# 56        F6P_c  Fructose 6-phosphate  ...     cpd00072   [f6p, f6p_B]
# 76       HCO3_c           Bicarbonate  ...     cpd00242  [h2co3, hco3]
# 101       H2O_m            H2O, water  ...     cpd00001     [h2o, oh1]
# 112         Q_m            Ubiquinone  ...     cpd15560  [q, q8, q8h2]
# 126       H2O_p            H2O, water  ...     cpd00001     [h2o, oh1]
# 136       NH4_m               Ammonia  ...     cpd00013     [nh3, nh4]
# 178      HCO3_h           Bicarbonate  ...     cpd00242  [h2co3, hco3]
# 180       ACP_h  Acyl-carrier protein  ...     cpd11493     [ACP, acp]
# 198       NH4_h               Ammonia  ...     cpd00013     [nh3, nh4]
# 216       Orn_h             Ornithine  ...     cpd00064  [orn, orn__L]
# 231       NH4_c               Ammonia  ...     cpd00013     [nh3, nh4]
# 303       Orn_m             Ornithine  ...     cpd00064  [orn, orn__L]
#
# [15 rows x 11 columns]

# %%
# Access above table and compare by eye and make notes to solve potential conflicts for later
# H2O_h, H2O_m, H2O_p, H2O_c  => h2O
# F6P_h, F6P_c => f6p
# HCO3_c, HCO3_h => hco3
# NH4_m, NH4_h, NH4_c => nh4
# ACP_h => acp
# Orn_h, Orn_m => orn

#Resolve conflict in original table df_metabolites_aracore

df_metabolites_aracore.set_index("aracore_ids",inplace=True) #Set index to acacore_ids to make editing easiers

# H2O_h, H2O_m, H2O_p, H2O_c  => h2O
df_metabolites_aracore.loc['H2O_c','bigg_id_aggr'] = [['h2o']]
df_metabolites_aracore.loc['H2O_h','bigg_id_aggr'] = [['h2o']]
df_metabolites_aracore.loc['H2O_p','bigg_id_aggr'] = [['h2o']]
df_metabolites_aracore.loc['H2O_m','bigg_id_aggr'] = [['h2o']]

# F6P_h, F6P_c => f6p
df_metabolites_aracore.loc['F6P_h','bigg_id_aggr'] = [['f6p']]
df_metabolites_aracore.loc['F6P_c','bigg_id_aggr'] = [['f6p']]

# HCO3_c, HCO3_h => hco3
df_metabolites_aracore.loc['HCO3_c','bigg_id_aggr'] = [['hco3']]
df_metabolites_aracore.loc['HCO3_h','bigg_id_aggr'] = [['hco3']]

# NH4_m, NH4_h, NH4_c => nh4
df_metabolites_aracore.loc['NH4_m','bigg_id_aggr'] = [['nh4']]
df_metabolites_aracore.loc['NH4_h','bigg_id_aggr'] =[ ['nh4']]
df_metabolites_aracore.loc['NH4_c','bigg_id_aggr'] = [['nh4']]

# ACP_h => acp
df_metabolites_aracore.loc['ACP_h','bigg_id_aggr'] = [['acp']]

# Orn_h, Orn_m => orn
df_metabolites_aracore.loc['Orn_h','bigg_id_aggr'] = [['orn']]
df_metabolites_aracore.loc['Orn_m','bigg_id_aggr'] = [['orn']]

# Q_m => q8
df_metabolites_aracore.loc['Q_m','bigg_id_aggr'] = [['q8']]



#ppi has different sum formulas in the Aracore model?!?
#Coenzyme A has different sum formulas in the Aracore model?!?
#5,6,7,8-Tetrahydrofolate has different sum formulas in the Aracore model?!?

df_metabolites_aracore.reset_index(inplace=True)

# %%
#Check if all bigg conflicts resolved 
(df_metabolites_aracore['bigg_id_aggr'].apply(len) > 1).value_counts() #all conflicts resolved
# Out:
# False    413
# Name: bigg_id_aggr, dtype: int64

# %%
#convert list of len 1 into string of BiGG id
df_metabolites_aracore['bigg_id_aggr'] = df_metabolites_aracore['bigg_id_aggr'].apply(lambda x: x[0] if x else None)

#clean dataframe and drop cols
df_metabolites_aracore.drop(['is_bigg_id','seed_BiGG_id', 'universal_bigg_id'], axis=1, inplace=True)

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids  ... bigg_id_aggr
# 0        hnu_h  ...         None
# 1         PQ_h  ...           pq
# 2        H2O_h  ...          h2o
# 3          H_h  ...            h
# 4       PQH2_h  ...         pqh2
# 5         O2_h  ...           o2
# 6          H_l  ...            h
# 7       PCox_h  ...         pcox
# 8       PCrd_h  ...         pcrd
# 9       Fdox_h  ...         fdox
# 10      Fdrd_h  ...         None
# 11      NADP_h  ...         nadp
# 12     NADPH_h  ...        nadph
# 13       ADP_h  ...          adp
# 14        Pi_h  ...           pi
# 15       ATP_h  ...          atp
# 16      RuBP_h  ...         None
# 17       CO2_h  ...          co2
# 18       PGA_h  ...         None
# 19      DPGA_h  ...        13dpg
# 20       GAP_h  ...         None
# 21      DHAP_h  ...         dhap
# 22       FBP_h  ...         None
# 23       F6P_h  ...          f6p
# 24       E4P_h  ...          e4p
#
# [25 rows x 8 columns]

# %%
df_metabolites_aracore['bigg_id_aggr'].notna().value_counts() #165 BiGG Ids mapped to aracore id
# Out:
# False    218
# True     195
# Name: bigg_id_aggr, dtype: int64

# %%
#Export final mapping table for manual mapping
df_metabolites_aracore.to_csv('drive/MyDrive/2021-05-27-metabolite-mapping-table.csv')
