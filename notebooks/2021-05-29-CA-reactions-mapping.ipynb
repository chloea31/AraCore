# %%
################################################################################################################################
################################################################################################################################
############                                -*-  RAPESEED METABOLIC NETWORK -*-                                    #############
################################################################################################################################
################################################################################################################################



################################################################################################################################
############                       -*- Apply Community standards for AraCore Model-*-                              #############
################################################################################################################################



################################################################################################################################
############                                  -*- Parameters of the pipeline -*-                                   #############
################################################################################################################################


datadir = "../models/2018-23-05-mb-genC3.sbml"

# %%
################################################################################################################################
############                                         -*- Pipeline -*-                                              #############
################################################################################################################################



####################################################################
################## I/ Parsing the file
####################################################################


##################
########### Goal : Etract the information we need to annotate the model : metabolites, reactions and genes
##################


import cobra
import pandas as pd


def parsing(fileName):
    model = cobra.io.read_sbml_model(fileName)
    print("Reactions")
    print("---------")
    for x in model.reactions:
        print("%s : %s" % (x.id, x.reaction))

    print("Metabolites")
    print("-----------")
    for x in model.metabolites:
        print("%9s : %s" % (x.id, x.formula))

    print("Genes")
    print("-----")
    for x in model.genes:
        associated_ids = (i.id for i in x.reactions)
        print("%s is associated with reactions: %s" %
        (x.id, "{" + ", ".join(associated_ids) + "}"))

parsing(datadir)
# Out:
# Reactions
# ---------
# PSII_h : 2.0 H2O_h + 4.0 H_h + 2.0 PQ_h + 4.0 hnu_h --> 4.0 H_l + O2_h + 2.0 PQH2_h
# Cytb6f1_h : PCox_h + PQH2_h --> 2.0 H_l + PCrd_h + PQstar_h
# Cytb6f2_h : 2.0 H_h + PCox_h + PQstar_h --> 2.0 H_l + PCrd_h + PQ_h
# PGR5PGRL11_h : Fdrd_h + PGR5_PGRL1ox_h --> Fdox_h + PGR5_PGRL1rd_h
# PGR5PGRL12_h : 4.0 H_h + 2.0 PGR5_PGRL1rd_h + PQ_h --> 2.0 PGR5_PGRL1ox_h + PQH2_h
# NDH1_h : Fdrd_h + 2.0 H_h + NDHox_h --> Fdox_h + 2.0 H_l + NDHrd_h
# NDH2_h : 4.0 H_h + 2.0 NDHrd_h + PQ_h --> 2.0 NDHox_h + PQH2_h
# PSI_h : Fdox_h + PCrd_h + hnu_h --> Fdrd_h + PCox_h
# Fd_DASH_NADPR_h : 2.0 Fdrd_h + H_h + NADP_h --> 2.0 Fdox_h + NADPH_h
# ATPase_h : ADP_h + 4.0 H_l + Pi_h <=> ATP_h + H2O_h + 3.0 H_h
# RBC_h : CO2_h + H2O_h + RuBP_h --> 2.0 H_h + 2.0 PGA_h
# PGAK_h : ATP_h + PGA_h <=> ADP_h + DPGA_h
# GAPDH1_h : DPGA_h + H_h + NADPH_h --> GAP_h + NADP_h + Pi_h
# TPI_h : GAP_h <=> DHAP_h
# FBPA_h : DHAP_h + GAP_h <=> FBP_h
# FBPase_h : FBP_h + H2O_h --> F6P_h + Pi_h
# FTK_h : F6P_h + GAP_h <=> E4P_h + X5P_h
# SBPA_h : DHAP_h + E4P_h <=> SBP_h
# SBPase_h : H2O_h + SBP_h --> Pi_h + S7P_h
# STK_h : GAP_h + S7P_h <=> R5P_h + X5P_h
# Ru5PE_h : X5P_h <=> Ru5P_h
# R5PI_h : R5P_h <=> Ru5P_h
# Ru5PK_h : ATP_h + Ru5P_h --> ADP_h + H_h + RuBP_h
# PGI_h : F6P_h <=> G6P_h
# PGM_h : G6P_h <=> G1P_h
# AGPase_h : ATP_h + G1P_h --> ADPG_h + PPi_h
# StS_h1 : ADPG_h + H2O_h --> ADP_h + H_h + starch1_h
# StS_h2 : ADPG_h + starch1_h --> ADP_h + H_h + starch2_h
# StS_h3 : ADPG_h + starch2_h --> ADP_h + H_h + starch3_h
# bAMY1_h : H2O_h + starch5_h --> Mas_h + starch3_h
# bAMY2_h : H2O_h + starch3_h --> Mas_h + starch1_h
# DPE11_h : 2.0 starch3_h --> Glc_h + starch5_h
# DPE12_h : Mas_h + starch1_h --> Glc_h + starch2_h
# DPE13_h : Mas_h + starch2_h --> Glc_h + starch3_h
# DPE2_c : Mas_c + starch1_c --> Glc_c + starch2_c
# HEXK_c : ATP_c + Glc_c --> ADP_c + G6P_c + H_c
# StP1_h : Pi_h + starch2_h --> G1P_h + starch1_h
# StP21_c : Pi_c + starch2_c --> G1P_c + starch1_c
# TPI_c : GAP_c <=> DHAP_c
# FBPA_c : DHAP_c + GAP_c <=> FBP_c
# FBPase_c : FBP_c + H2O_c --> F6P_c + Pi_c
# F6PK2_c : ATP_c + F6P_c --> ADP_c + F26BP_c + H_c
# F26BPPh_c : F26BP_c + H2O_c <=> F6P_c + Pi_c
# PGI_c : F6P_c <=> G6P_c
# PGM_c : G6P_c <=> G1P_c
# UGPase_c : G1P_c + H_c + UTP_c <=> PPi_c + UDPG_c
# S6PS_c : F6P_c + UDPG_c --> S6P_c + UDP_c
# S6PPh_c : H2O_c + S6P_c --> Pi_c + Suc_c
# SucS_c : Suc_c + UDP_c <=> Frc_c + UDPG_c
# FrcFD_c : H2O_c + Suc_c --> Frc_c + Glc_c
# FrcK_c : ATP_c + Frc_c --> ADP_c + F6P_c + H_c
# TPS_c : G6P_c + UDPG_c --> T6P_c + UDP_c
# TPP_c : H2O_c + T6P_c --> Pi_c + Tre_c
# CeS_c1 : H2O_c + UDPG_c --> UDP_c + cellulose1_c
# CeS_c2 : UDPG_c + cellulose1_c --> UDP_c + cellulose2_c
# CeS_c3 : UDPG_c + cellulose2_c --> UDP_c + cellulose3_c
# MalDH1_c : Mal_c + NAD_c <=> H_c + NADH_c + OAA_c
# PEPC1_c : ATP_c + OAA_c --> ADP_c + CO2_c + PEP_c
# PEPC2_c : OAA_c + Pi_c <=> HCO3_c + PEP_c
# Enol_c : H2O_c + PEP_c <=> 2PGA_c
# PGAM_c : 2PGA_c <=> PGA_c
# PGAK_c : ATP_c + PGA_c <=> ADP_c + DPGA_c
# GAPDH2_c : GAP_c + NAD_c + Pi_c <=> DPGA_c + H_c + NADH_c
# GAPDH3_c : GAP_c + H2O_c + NADP_c --> 2.0 H_c + NADPH_c + PGA_c
# F6PK1_c : ATP_c + F6P_c --> ADP_c + FBP_c + H_c
# F6PK1_h : ATP_h + F6P_h --> ADP_h + FBP_h + H_h
# GAPDH2_h : GAP_h + NAD_h + Pi_h <=> DPGA_h + H_h + NADH_h
# PGAM_h : PGA_h <=> 2PGA_h
# Enol_h : 2PGA_h <=> H2O_h + PEP_h
# PyrK_c : ADP_c + H_c + PEP_c --> ATP_c + Pyr_c
# PyrK_h : ADP_h + H_h + PEP_h --> ATP_h + Pyr_h
# PyrDH1_m : H_m + Pyr_m + ThPP_m --> CO2_m + H_DASH_Eth_DASH_ThPP_m
# PyrDH2_m : H_DASH_Eth_DASH_ThPP_m + LPA_m --> A_DASH_DHL_m + ThPP_m
# DHLAcT_m : A_DASH_DHL_m + CoA_m --> A_DASH_CoA_m + DHL_m
# DHLDH2_m : DHL_m + NAD_m --> H_m + LPA_m + NADH_m
# CitS_m : A_DASH_CoA_m + H2O_m + OAA_m --> Cit_m + CoA_m + H_m
# cACNDHA_m : Cit_m --> H2O_m + cACN_m
# cACNHA_m : H2O_m + cACN_m --> iCit_m
# iCitDHNAD_m : NAD_m + iCit_m --> CO2_m + KG_m + NADH_m
# KGDH_m : H_m + KG_m + LPA_m --> CO2_m + S_DASH_DHL_m
# DHLST_m : CoA_m + S_DASH_DHL_m --> DHL_m + S_DASH_CoA_m
# SCACoAL_m : ADP_m + Pi_m + S_DASH_CoA_m <=> ATP_m + CoA_m + SCA_m
# cplx2_m : Q_m + SCA_m --> Fum_m + QH2_m
# FumHA_m : Fum_m + H2O_m --> Mal_m
# MalDH1_m : Mal_m + NAD_m <=> H_m + NADH_m + OAA_m
# MalDH2_m : Mal_m + NAD_m --> CO2_m + NADH_m + Pyr_m
# cplx1_m : 5.0 H_m + NADH_m + Q_m --> 4.0 H_i + NAD_m + QH2_m
# cplx3_m : 2.0 Cytcox_m + 2.0 H_m + QH2_m --> 2.0 Cytcrd_m + 4.0 H_i + Q_m
# cplx4_m : 4.0 Cytcrd_m + 8.0 H_m + O2_m --> 4.0 Cytcox_m + 2.0 H2O_m + 4.0 H_i
# cplx5_m : ADP_m + 3.0 H_i + Pi_m <=> ATP_m + H2O_m + 2.0 H_m
# RBO_h : O2_h + RuBP_h --> 2.0 H_h + PGA_h + PGCA_h
# PGP_h : H2O_h + PGCA_h --> GCA_h + Pi_h
# GCAO_p : GCA_p + O2_p --> GLX_p + H2O2_p
# CAT_p : 2.0 H2O2_p --> 2.0 H2O_p + O2_p
# GGAT_p : GLX_p + Glu_p --> Gly_p + KG_p
# GlyDH_m : Gly_m + H_m + LPL_m --> CO2_m + amDHP_m
# AMT_m : THF_m + amDHP_m --> DHP_m + M_DASH_THF_m + NH4_m
# DHLDH1_m : DHP_m + NAD_m --> H_m + LPL_m + NADH_m
# GlyHMT_m : Gly_m + H2O_m + M_DASH_THF_m <=> Ser_m + THF_m
# SGAT_p : GLX_p + Ser_p --> Gly_p + HPR_p
# GCEADH_p : HPR_p + H_p + NADH_p --> GCEA_p + NAD_p
# MalDH1_p : Mal_p + NAD_p <=> H_p + NADH_p + OAA_p
# GCEAK_h : ATP_h + GCEA_h --> ADP_h + H_h + PGA_h
# G6PDH_h : G6P_h + NADP_h --> GLP_h + H_h + NADPH_h
# 6PGL_h : GLP_h + H2O_h --> 6PG_h + H_h
# 6PGDHNAD_h : 6PG_h + NAD_h --> CO2_h + NADH_h + Ru5P_h
# 6PGDHNADP_h : 6PG_h + NADP_h --> CO2_h + NADPH_h + Ru5P_h
# TA_h : GAP_h + S7P_h <=> E4P_h + F6P_h
# DAHPS_h : E4P_h + H2O_h + PEP_h --> DAHP_h + Pi_h
# DHQS_h : DAHP_h --> DHQ_h + Pi_h
# DHQDH_h : DHQ_h --> DHS_h + H2O_h
# SADH_h : DHS_h + H_h + NADPH_h --> NADP_h + SA_h
# SAK_h : ATP_h + SA_h --> ADP_h + H_h + S3P_h
# EPSPS_h : PEP_h + S3P_h --> EPSP_h + Pi_h
# CHRS_h : EPSP_h --> CHR_h + Pi_h
# R5PDPK_h : ATP_h + R5P_h --> AMP_h + H_h + PRPP_h
# PyrPiDK_h : ATP_h + Pi_h + Pyr_h <=> AMP_h + 2.0 H_h + PEP_h + PPi_h
# MalDH1_h : Mal_h + NAD_h <=> H_h + NADH_h + OAA_h
# MalDH3_h : H_h + NADPH_h + OAA_h <=> Mal_h + NADP_h
# MalDH4_h : Mal_h + NADP_h --> CO2_h + NADPH_h + Pyr_h
# CitS_c : A_DASH_CoA_c + H2O_c + OAA_c --> Cit_c + CoA_c + H_c
# CitS_h : A_DASH_CoA_h + H2O_h + OAA_h --> Cit_h + CoA_h + H_h
# cACNDHA_c : Cit_c --> H2O_c + cACN_c
# cACNDHA_h : Cit_h --> H2O_h + cACN_h
# cACNHA_c : H2O_c + cACN_c --> iCit_c
# cACNHA_h : H2O_h + cACN_h --> iCit_h
# iCitDHNAD_c : NAD_c + iCit_c --> CO2_c + KG_c + NADH_c
# iCitDHNADP_c : NADP_c + iCit_c --> CO2_c + KG_c + NADPH_c
# iCitDHNADP_h : NADP_h + iCit_h --> CO2_h + KG_h + NADPH_h
# iCitDHNADP_m : NADP_m + iCit_m --> CO2_m + KG_m + NADPH_m
# iCitL_p : iCit_p --> GLX_p + SCA_p
# ATPCitL_c : ATP_c + Cit_c + CoA_c --> ADP_c + A_DASH_CoA_c + OAA_c + Pi_c
# ACoAS_h : AC_h + ATP_h + CoA_h --> AMP_h + A_DASH_CoA_h + H_h + PPi_h
# ACoAC_h : ATP_h + A_DASH_CoA_h + HCO3_h --> ADP_h + H_h + M_DASH_CoA_h + Pi_h
# ACPM_h : ACP_h + M_DASH_CoA_h --> CoA_h + M_DASH_ACP_h
# PPiase_h : H2O_h + PPi_h --> 2.0 Pi_h
# PPIase_c : H2O_c + PPi_c --> H_c + 2.0 Pi_c
# PPIF6PK_c : F6P_c + PPi_c --> FBP_c + H_c + Pi_c
# ForDH_h : CO2_h + NADH_h --> For_h + NAD_h
# ForTHFL_h : ATP_h + For_h + H_h + THF_h --> ADP_h + F_DASH_THF_h + Pi_h
# DHFR_c : DHF_c + H_c + NADPH_c --> NADP_c + THF_c
# TRXR_c : H_c + NADPH_c + TRXox_c --> NADP_c + TRXrd_c
# ADNK_c : ADN_c + ATP_c --> ADP_c + AMP_c + H_c
# ADNN_c : ADN_c + H2O_c --> AD_c + H_c + Rib_c
# ADPRPPT_c : AD_c + PRPP_c --> AMP_c + PPi_c
# RibK_h : ATP_h + Rib_h --> ADP_h + H_h + R5P_h
# NO3R1_c : H_c + NADH_c + NO3_c --> H2O_c + NAD_c + NO2_c
# NO3R2_c : H_c + NADPH_c + NO3_c <=> H2O_c + NADP_c + NO2_c
# NO2R_h : 6.0 Fdrd_h + 8.0 H_h + NO2_h --> 6.0 Fdox_h + 2.0 H2O_h + NH4_h
# ATPSL_h : ATP_h + SO4_h --> APS_h + PPi_h
# APSR_h : APS_h + 2.0 GSH_h --> AMP_h + GSSG_h + H_h + SO3_h
# GSSGR_h : GSSG_h + H_h + NADPH_h --> 2.0 GSH_h + NADP_h
# SO3R_h : 3.0 Fdrd_h + 7.0 H_h + SO3_h --> 3.0 Fdox_h + 3.0 H2O_h + H2S_h
# HCO3DHA_c : CO2_c + H2O_c --> HCO3_c + H_c
# HCO3DHA_h : CO2_h + H2O_h --> HCO3_h + H_h
# AlaTA_h : Glu_h + Pyr_h <=> Ala_h + KG_h
# AlaTA_m : Glu_m + Pyr_m <=> Ala_m + KG_m
# AlaTA_p : Glu_p + Pyr_p <=> Ala_p + KG_p
# AGluK : ATP_h + A_DASH_Glu_h --> ADP_h + A_DASH_GluP_h
# AGluPR_h : A_DASH_GluP_h + H_h + NADPH_h --> A_DASH_Glu_DASH_SeA_h + NADP_h + Pi_h
# AOrnTA_h : A_DASH_Glu_DASH_SeA_h + Glu_h --> A_DASH_Orn_h + KG_h
# AOrnAGluAcT_h : A_DASH_Orn_h + Glu_h --> A_DASH_Glu_h + Orn_h
# CBPS_h : 2.0 ATP_h + Gln_h + H2O_h + HCO3_h --> 2.0 ADP_h + CBP_h + Glu_h + 3.0 H_h + Pi_h
# OrnCMT_h : CBP_h + H_h + Orn_h <=> CTL_h + Pi_h
# ArgSCAS_h : ATP_h + Asp_h + CTL_h --> AMP_h + Arg_DASH_SCA_h + 3.0 H_h + PPi_h
# ArgSCAL_h : Arg_DASH_SCA_h --> Arg_h + Fum_h
# FumHA_c : Fum_c + H2O_c --> Mal_c
# AsnS_c : ATP_c + Asp_c + Gln_c + H2O_c --> AMP_c + Asn_c + Glu_c + H_c + PPi_c
# AspAT_c : Glu_c + OAA_c <=> Asp_c + KG_c
# AspAT_h : Glu_h + OAA_h <=> Asp_h + KG_h
# AspAT_m : Glu_m + OAA_m <=> Asp_m + KG_m
# AspAT_p : Glu_p + OAA_p <=> Asp_p + KG_p
# AspAT2_c : Ala_c + OAA_c <=> Asp_c + Pyr_c
# AspAT2_h : Ala_h + OAA_h <=> Asp_h + Pyr_h
# AspAT2_m : Ala_m + OAA_m <=> Asp_m + Pyr_m
# AspAT2_p : Ala_p + OAA_p <=> Asp_p + Pyr_p
# Asnase_c : Asn_c + H2O_c --> Asp_c + NH4_c
# SerAcT_c : A_DASH_CoA_c + Ser_c --> A_DASH_Ser_c + CoA_c
# SerAcT_h : A_DASH_CoA_h + Ser_h --> A_DASH_Ser_h + CoA_h
# SerAcT_m : A_DASH_CoA_m + Ser_m --> A_DASH_Ser_m + CoA_m
# CysS_c : A_DASH_Ser_c + H2S_c --> AC_c + Cys_c + H_c
# CysS_h : A_DASH_Ser_h + H2S_h --> AC_h + Cys_h + H_h
# CysS_m : A_DASH_Ser_m + H2S_m --> AC_m + Cys_m + H_m
# GluDH3NADP_c : Glu_c + H2O_c + NADP_c <=> H_c + KG_c + NADPH_c + NH4_c
# Glnase_c : Gln_c + H2O_c --> Glu_c + NH4_c
# GluSNAD_h : Gln_h + H_h + KG_h + NADH_h --> 2.0 Glu_h + NAD_h
# GluSFd_h : 2.0 Fdrd_h + Gln_h + 2.0 H_h + KG_h --> 2.0 Fdox_h + 2.0 Glu_h
# GluDH1NAD_m : H_m + KG_m + NADH_m + NH4_m <=> Glu_m + H2O_m + NAD_m
# GluDH1NADP_m : H_m + KG_m + NADPH_m + NH4_m <=> Glu_m + H2O_m + NADP_m
# GluDC_c : Glu_c + H_c --> CO2_c + GABA_c
# GABATA1_m : GABA_m + Pyr_m <=> Ala_m + SCA_DASH_SeA_m
# GABATA2_m : GABA_m + KG_m --> Glu_m + SCA_DASH_SeA_m
# SCASeADH_m : H2O_m + NAD_m + SCA_DASH_SeA_m --> 2.0 H_m + NADH_m + SCA_m
# GlnS_c : ATP_c + Glu_c + NH4_c --> ADP_c + Gln_c + H_c + Pi_c
# GlnS_h : ATP_h + Glu_h + NH4_h --> ADP_h + Gln_h + H_h + Pi_h
# GlnS_m : ATP_m + Glu_m + NH4_m --> ADP_m + Gln_m + H_m + Pi_m
# ThrA_c : Thr_c --> ACD_c + Gly_c
# ACDOxRed_c : ACD_c + H2O_c + NAD_c --> AC_c + 2.0 H_c + NADH_c
# GCAO_h : GCA_h + O2_h --> GLX_h + H2O2_h
# CAT_h : 2.0 H2O2_h --> 2.0 H2O_h + O2_h
# GGAT_h : GLX_h + Glu_h --> Gly_h + KG_h
# ATPPRT_h : ATP_h + PRPP_h --> H_h + PPi_h + PR_DASH_ATP_h
# PrATPDP_h : H2O_h + PR_DASH_ATP_h --> 2.0 H_h + PPi_h + PR_DASH_AMP_h
# PrAMPCy_h : H2O_h + PR_DASH_AMP_h --> P_DASH_AICAR_DASH_P_h
# PAICARPI_h : P_DASH_AICAR_DASH_P_h --> Pu_DASH_AICAR_DASH_P_h
# IGPS_h : Gln_h + Pu_DASH_AICAR_DASH_P_h --> AICAR_h + EIGP_h + Glu_h
# IGPDA_h : EIGP_h --> H2O_h + IA_DASH_P_h
# HisolPTA_h : Glu_h + IA_DASH_P_h --> Hisol_DASH_P_h + KG_h
# HisolPP_h : H2O_h + Hisol_DASH_P_h --> Hisol_h + Pi_h
# HisolPDH_h : Hisol_h + NAD_h --> 2.0 H_h + Hisal_h + NADH_h
# HisalPDH_h : H2O_h + Hisal_h + NAD_h --> H_h + His_h + NADH_h
# ThrDA_h : Thr_h --> NH4_h + OB_h
# ALS1_h : H_h + Pyr_h + ThPP_h --> CO2_h + H_DASH_Eth_DASH_ThPP_h
# ALS2_h : H_DASH_Eth_DASH_ThPP_h + OB_h --> AHB_h + ThPP_h
# KARI12_h : AHB_h + H_h + NADPH_h --> DHMP_h + NADP_h
# DHADA1_h : DHMP_h --> H2O_h + MOP_h
# BAATA1_h : Glu_h + MOP_h <=> Ile_h + KG_h
# ALS3_h : H_DASH_Eth_DASH_ThPP_h + Pyr_h --> AL_h + ThPP_h
# KARI34_h : AL_h + H_h + NADPH_h --> DHMB_h + NADP_h
# DHADA2_h : DHMB_h --> H2O_h + MOB_h
# 2IPMS_h : A_DASH_CoA_h + H2O_h + MOB_h --> 2IPM_h + CoA_h + H_h
# 3IPMDA1_h : 2IPM_h --> H2O_h + IPM_h
# 3IPMDA2_h : H2O_h + IPM_h --> 3IPM_h
# 3IPMDH_h : 3IPM_h + NAD_h --> H_h + IPO_h + NADH_h
# IPODC_h : H_h + IPO_h --> 4MOP_h + CO2_h
# BAATA2_h : 4MOP_h + Glu_h <=> KG_h + Leu_h
# AspK_h : ATP_h + Asp_h --> ADP_h + AspP_h
# Asp_DASH_SeADH_h : AspP_h + H_h + NADPH_h --> Asp_DASH_SeA_h + NADP_h + Pi_h
# DHDS_h : Asp_DASH_SeA_h + Pyr_h --> DHD_h + 2.0 H2O_h + H_h
# DHDRNAD_h : DHD_h + H_h + NADH_h --> NAD_h + THD_h
# DHDRNADP_h : DHD_h + H_h + NADPH_h --> NADP_h + THD_h
# DAPAT_h : Glu_h + H2O_h + H_h + THD_h --> DAP_h + KG_h
# DAPE_h : DAP_h --> mDAP_h
# DAPDC_h : H_h + mDAP_h --> CO2_h + Lys_h
# HSerDHNADP_h : Asp_DASH_SeA_h + H_h + NADPH_h --> H_DASH_Ser_h + NADP_h
# HSerDHNAD_h : Asp_DASH_SeA_h + H_h + NADH_h --> H_DASH_Ser_h + NAD_h
# HSerK_h : ATP_h + H_DASH_Ser_h --> ADP_h + H_h + PH_DASH_Ser_h
# CTHS_h : Cys_h + PH_DASH_Ser_h --> CTH_h + Pi_h
# CTHL_h : CTH_h + H2O_h --> H_DASH_Cys_h + NH4_h + Pyr_h
# 5M_DASH_THFOR_c : H_c + M_DASH_THF_c + NADH_c --> 5M_DASH_THF_c + NAD_c
# MetS_c : 5M_DASH_THF_c + H_DASH_Cys_c --> Met_c + THF_c
# GlyHMT_c : Gly_c + H2O_c + M_DASH_THF_c <=> Ser_c + THF_c
# MetAdT_c : ATP_c + H2O_c + Met_c --> H_c + PPi_c + Pi_c + aMet_c
# HCysMT_c : H_DASH_Cys_c + aMet_c --> Met_c + aH_DASH_Cys_c
# Cysase_c : H2O_c + aH_DASH_Cys_c <=> ADN_c + H_DASH_Cys_c
# CHRM_h : CHR_h --> PRE_h
# GPAT_h : Glu_h + PRE_h <=> AGN_h + KG_h
# AGNDA_h : AGN_h + H_h --> CO2_h + H2O_h + Phe_h
# Arginase_m : Arg_m + H2O_m + H_m --> Orn_m + urea_m
# Urease_m : H2O_m + H_m + urea_m --> CO2_m + 2.0 NH4_m
# OrnAT_m : KG_m + Orn_m <=> Glu_DASH_SeA_m + Glu_m
# GluK_c : ATP_c + Glu_c --> ADP_c + GluP_c
# GluK_h : ATP_h + Glu_h --> ADP_h + GluP_h
# GluK_m : ATP_m + Glu_m --> ADP_m + GluP_m
# GluSeADH_c : GluP_c + H_c + NADPH_c --> Glu_DASH_SeA_c + NADP_c + Pi_c
# GluSeADH_h : GluP_h + H_h + NADPH_h --> Glu_DASH_SeA_h + NADP_h + Pi_h
# GluSeADH_m : GluP_m + H_m + NADPH_m <=> Glu_DASH_SeA_m + NADP_m + Pi_m
# GluSeADA_c : Glu_DASH_SeA_c <=> H2O_c + H_c + P5C_c
# GluSeADA_h : Glu_DASH_SeA_h <=> H2O_h + H_h + P5C_h
# GluSeADA_m : Glu_DASH_SeA_m <=> H2O_m + H_m + P5C_m
# P5CRNAD_c : 2.0 H_c + NADH_c + P5C_c --> NAD_c + Pro_c
# ProDHNAD_m : NAD_m + Pro_m --> 2.0 H_m + NADH_m + P5C_m
# ProDHNADP_m : NADP_m + Pro_m --> 2.0 H_m + NADPH_m + P5C_m
# P5CDHNAD_h : 2.0 H2O_h + NAD_h + P5C_h --> Glu_h + H_h + NADH_h
# P5CDHNADP_h : 2.0 H2O_h + NADP_h + P5C_h --> Glu_h + H_h + NADPH_h
# P5CDHNAD_m : 2.0 H2O_m + NAD_m + P5C_m --> Glu_m + H_m + NADH_m
# P5CDHNADP_m : 2.0 H2O_m + NADP_m + P5C_m --> Glu_m + H_m + NADPH_m
# PGADH_h : NAD_h + PGA_h <=> H_h + NADH_h + P_DASH_HPR_h
# PSerAT_h : Glu_h + P_DASH_HPR_h --> KG_h + PSer_h
# PSerP_h : H2O_h + PSer_h --> Pi_h + Ser_h
# SerRM_c : Ser_c --> NH4_c + Pyr_c
# ThrS_h : H2O_h + PH_DASH_Ser_h --> Pi_h + Thr_h
# ANTS_h : CHR_h + Gln_h --> ANT_h + Glu_h + H_h + Pyr_h
# ANTPRT_h : ANT_h + PRPP_h --> H_h + PPi_h + PR_DASH_ANT_h
# PRANTI_h : PR_DASH_ANT_h --> CPD_DASH_Ru5P_h
# IndGPS_h : CPD_DASH_Ru5P_h + H_h --> CO2_h + H2O_h + Ind_DASH_GP_h
# IndGPL_h : Ind_DASH_GP_h --> GAP_h + Ind_h
# TrpS_h : Ind_h + Ser_h --> H2O_h + Trp_h
# AGNDH_h : AGN_h + NADP_h --> CO2_h + NADPH_h + Tyr_h
# BAATA3_h : Glu_h + MOB_h <=> KG_h + Val_h
# ATase_h : Gln_h + H2O_h + PRPP_h --> Glu_h + H_h + PPi_h + PRA_h
# PRAGlyL_h : ATP_h + Gly_h + PRA_h --> ADP_h + GAR_h + H_h + Pi_h
# GARFT_h : F_DASH_THF_h + GAR_h --> FGAR_h + 2.0 H_h + THF_h
# FGAMS_h : ATP_h + FGAR_h + Gln_h + H2O_h --> ADP_h + FGAM_h + Glu_h + 2.0 H_h + Pi_h
# FGAMCL_h : ATP_h + FGAM_h --> ADP_h + AIR_h + H_h + Pi_h
# AIRC_h : AIR_h + CO2_h --> CAIR_h + H_h
# SAICARS_h : ATP_h + Asp_h + CAIR_h --> ADP_h + H_h + Pi_h + SAICAR_h
# DCAMPL1_h : H_h + SAICAR_h --> AICAR_h + Fum_h
# AICARFT_h : AICAR_h + F_DASH_THF_h --> FAICAR_h + 2.0 H_h + THF_h
# IMPCH_h : FAICAR_h --> H2O_h + IMP_h
# AMPDA_c : AMP_c + H2O_c + H_c --> IMP_c + NH4_c
# IMPDH_c : H2O_c + IMP_c + NAD_c --> H_c + NADH_c + XMP_c
# GMPS_c : ATP_c + Gln_c + H2O_c + XMP_c --> AMP_c + GMP_c + Glu_c + H_c + PPi_c
# DCAMPS_h : Asp_h + GTP_h + IMP_h --> DC_DASH_AMP_h + GDP_h + H_h + Pi_h
# DCAMPL2_h : DC_DASH_AMP_h --> AMP_h + Fum_h
# AspCT_h : Asp_h + CBP_h --> CB_DASH_Asp_h + Pi_h
# DHOase_h : CB_DASH_Asp_h --> DHO_h + H2O_h
# DHODH_m : DHO_m + H_m + Q_m --> ORO_m + QH2_m
# OROPRT_c : ORO_c + PRPP_c --> H_c + OMP_c + PPi_c
# OMPDC_c : H_c + OMP_c --> CO2_c + UMP_c
# CTPS_c : ATP_c + Gln_c + H2O_c + UTP_c --> ADP_c + CTP_c + Glu_c + 2.0 H_c + Pi_c
# AMPK_c : AMP_c + ATP_c --> 2.0 ADP_c
# AMPK_h : AMP_h + ATP_h --> 2.0 ADP_h
# GMPK_c : ATP_c + GMP_c + H_c --> ADP_c + GDP_c
# NMPK_c : ATP_c + H_c + UMP_c --> ADP_c + UDP_c
# CTPP_c : CTP_c + H2O_c --> CDP_c + Pi_c
# ADPR_c : ADP_c + H_c + TRXrd_c --> H2O_c + TRXox_c + dADP_c
# CDPR_c : CDP_c + TRXrd_c --> H2O_c + TRXox_c + dCDP_c
# GDPR_c : GDP_c + TRXrd_c --> H2O_c + TRXox_c + dGDP_c
# UDPR_c : TRXrd_c + UDP_c --> H2O_c + TRXox_c + dUDP_c
# dUTPP_c : H2O_c + dUTP_c --> 2.0 H_c + PPi_c + dUMP_c
# dTMPS_c : M_DASH_THF_c + dUMP_c --> DHF_c + dTMP_c
# dTMPK_c : ATP_c + H_c + dTMP_c --> ADP_c + dTDP_c
# GDPK_c : ATP_c + GDP_c --> ADP_c + GTP_c + H_c
# GDPK_h : ATP_h + GDP_h --> ADP_h + GTP_h + H_h
# UDPK_c : ATP_c + UDP_c --> ADP_c + H_c + UTP_c
# dADPK_c : ATP_c + dADP_c --> ADP_c + dATP_c
# dCDPK_c : ATP_c + dCDP_c --> ADP_c + dCTP_c
# dGDPK_c : ATP_c + dGDP_c --> ADP_c + dGTP_c
# dTDPK_c : ATP_c + dTDP_c --> ADP_c + dTTP_c
# dUDPK_c : ATP_c + dUDP_c --> ADP_c + dUTP_c
# Tr_SO4 : SO4_c <=> SO4_h
# Tr_NO2 : NO2_c <=> NO2_h
# Tr_NTT : ADP_h + ATP_c --> ADP_c + ATP_h
# Tr_AAC : ADP_c + ATP_m <=> ADP_m + ATP_c
# Tr_BT11 : AMP_h <=> AMP_c
# Tr_BT12 : ADP_h <=> ADP_c
# Tr_BT13 : ATP_h <=> ATP_c
# Tr_NDT1 : AMP_h + NAD_c <=> AMP_c + NAD_h
# Tr_NDT2 : ADP_h + NAD_c <=> ADP_c + NAD_h
# Tr_TPT1 : PGA_h + Pi_c <=> PGA_c + Pi_h
# Tr_TPT2 : GAP_h + Pi_c <=> GAP_c + Pi_h
# Tr_TPT3 : DHAP_h + Pi_c <=> DHAP_c + Pi_h
# Tr_PPT : H_c + PEP_c + Pi_h <=> H_h + PEP_h + Pi_c
# Tr_GCA1 : GCA_h <=> GCA_c
# Tr_GCEA1 : GCEA_c <=> GCEA_h
# Tr_GPT1 : G6P_c + Pi_h <=> G6P_h + Pi_c
# Tr_pGlc : Glc_h <=> Glc_c
# Tr_Mex1 : Mas_h <=> Mas_c
# Tr_PLT5 : Rib_c <=> Rib_h
# Tr_DIC1 : Mal_c + Pi_m <=> Mal_m + Pi_c
# Tr_DIC2 : Pi_m + SCA_c <=> Pi_c + SCA_m
# Tr_DIT1 : KG_c + Mal_h <=> KG_h + Mal_c
# Tr_DIT2 : Glu_h + Mal_c <=> Glu_c + Mal_h
# Tr_DTC1A : Cit_m + KG_c <=> Cit_c + KG_m
# Tr_DTC1B : KG_c + iCit_m <=> KG_m + iCit_c
# Tr_DTC1C : KG_c + cACN_m <=> KG_m + cACN_c
# Tr_DTC2A : Cit_m + Mal_c <=> Cit_c + Mal_m
# Tr_DTC2B : Mal_c + iCit_m <=> Mal_m + iCit_c
# Tr_DTC2C : Mal_c + cACN_m <=> Mal_m + cACN_c
# Tr_DTC3A : Cit_m + OAA_c <=> Cit_c + OAA_m
# Tr_DTC3B : OAA_c + iCit_m <=> OAA_m + iCit_c
# Tr_DTC3C : OAA_c + cACN_m <=> OAA_m + cACN_c
# Tr_DTC4A : Cit_m + SCA_c <=> Cit_c + SCA_m
# Tr_DTC4B : SCA_c + iCit_m <=> SCA_m + iCit_c
# Tr_DTC4C : SCA_c + cACN_m <=> SCA_m + cACN_c
# Tr_SFC : Fum_m + SCA_c <=> Fum_c + SCA_m
# Tr_BAC1 : Arg_c + His_m <=> Arg_m + His_c
# Tr_BAC2 : Arg_c + Lys_m <=> Arg_m + Lys_c
# Tr_ProU : Pro_c <=> Pro_m
# Tr_ProA : Glu_m + Pro_c <=> Glu_c + Pro_m
# Tr_P5C1 : P5C_h <=> P5C_c
# Tr_P5C2 : P5C_m <=> P5C_c
# Tr_PRPP : H_h + PRPP_h <=> PRPP_c
# Tr_Fum : Fum_h <=> Fum_c
# Tr_HCys : H_DASH_Cys_h <=> H_DASH_Cys_c
# Tr_ORO : ORO_m <=> ORO_c
# Tr_DHO1 : DHO_h <=> DHO_c
# Tr_DHO2 : DHO_c <=> DHO_m
# Tr_GlySer : Gly_c + Ser_m <=> Gly_m + Ser_c
# Tr_O2h : O2_c <=> O2_h
# Tr_O2m : O2_c <=> O2_m
# Tr_O2p : O2_c <=> O2_p
# Tr_CO2h : CO2_c <=> CO2_h
# Tr_CO2m : CO2_c <=> CO2_m
# Tr_H2Oh : H2O_c <=> H2O_h
# Tr_H2Om : H2O_c <=> H2O_m
# Tr_H2Op : H2O_c <=> H2O_p
# Tr_Hp : H_c <=> H_p
# Tr_NH41 : NH4_c <=> NH4_h
# Tr_NH42 : NH4_c <=> NH4_m
# Tr_H2S1 : H2S_c <=> H2S_h
# Tr_H2S2 : H2S_c <=> H2S_m
# Tr_AC1 : AC_c <=> AC_h
# Tr_AC2 : AC_c <=> AC_m
# Tr_Pyr1 : Pyr_c <=> Pyr_h
# Tr_Pyr_H_hc : H_c + Pyr_c <=> H_h + Pyr_h
# Tr_Pyr_Na_hc : Na_c + Pyr_c <=> Na_h + Pyr_h
# Tr_Pyr2 : Pyr_c <=> Pyr_m
# Tr_Pyr3 : Pyr_c <=> Pyr_p
# Tr_GCA2 : GCA_c <=> GCA_p
# Tr_GCEA2 : GCEA_c <=> GCEA_p
# Tr_Mal : Mal_c <=> Mal_p
# Tr_OAA : OAA_c <=> OAA_p
# Tr_KG : KG_c <=> KG_p
# Tr_Ala1 : Ala_c <=> Ala_p
# Tr_Arg1 : Arg_c <=> Arg_p
# Tr_Asn1 : Asn_c <=> Asn_p + H_p
# Tr_Asp : Asp_c <=> Asp_p
# Tr_Cys : Cys_c <=> Cys_p
# Tr_Glu1 : Glu_c <=> Glu_p
# Tr_Gln : Gln_c <=> Gln_p + H_p
# Tr_Gly : Gly_c <=> Gly_p
# Tr_His1 : His_c <=> His_p
# Tr_Ile1 : Ile_c <=> Ile_p
# Tr_Leu1 : Leu_c <=> Leu_p
# Tr_Lys1 : Lys_c <=> Lys_p
# Tr_Met1 : Met_c <=> Met_p
# Tr_Phe1 : Phe_c <=> Phe_p
# Tr_Pro1 : Pro_c <=> Pro_p
# Tr_Ser1 : Ser_c <=> Ser_p
# Tr_Thr1 : Thr_c <=> Thr_p
# Tr_Trp1 : Trp_c <=> Trp_p
# Tr_Tyr1 : Tyr_c <=> Tyr_p
# Tr_Val1 : Val_c <=> Val_p
# Tr_Ala2 : Ala_h <=> Ala_c
# Tr_Arg2 : Arg_h <=> Arg_c
# Tr_Asn2 : Asn_c <=> Asn_h + H_h
# Tr_Asn3 : Asn_c <=> Asn_m
# Tr_Glu2 : Glu_c <=> Glu_h
# Tr_His2 : His_h <=> His_c
# Tr_His3 : His_c <=> His_m
# Tr_Ile2 : Ile_h <=> Ile_c
# Tr_Ile3 : Ile_c <=> Ile_m
# Tr_Leu2 : Leu_h <=> Leu_c
# Tr_Leu3 : Leu_c <=> Leu_m
# Tr_Lys2 : Lys_h <=> Lys_c
# Tr_Met2 : Met_c <=> Met_h
# Tr_Met3 : Met_c <=> Met_m
# Tr_Phe2 : Phe_h <=> Phe_c
# Tr_Phe3 : Phe_c <=> Phe_m
# Tr_Pro2 : Pro_c <=> Pro_h
# Tr_Ser2 : Ser_h <=> Ser_c
# Tr_Ser3 : Ser_c <=> Ser_m
# Tr_Thr2 : Thr_h <=> Thr_c
# Tr_Thr3 : Thr_c <=> Thr_m
# Tr_Trp2 : Trp_h <=> Trp_c
# Tr_Trp3 : Trp_c <=> Trp_m
# Tr_Tyr2 : Tyr_h <=> Tyr_c
# Tr_Tyr3 : Tyr_c <=> Tyr_m
# Tr_Val2 : Val_h <=> Val_c
# Tr_Val3 : Val_c <=> Val_m
# Tr_Pi : H_c + Pi_h <=> H_h + Pi_c
# Tr_H_Na_hc : H_c + Na_h <=> H_h + Na_c
# Tr_DIT1_OAA : Mal_h + OAA_c <=> Mal_c + OAA_h
# Tr_Asp_OAA_hc : Asp_h + OAA_c <=> Asp_c + OAA_h
# Tr_THF : THF_c <=> H_c + THF_h
# Tr_PIC : H_m + Pi_c <=> H_c + Pi_m
# Tr_UCP : H_m <=> H_c
# Tr_DTC5 : Mal_m + OAA_c <=> Mal_c + OAA_m
# Tr_DIC4 : OAA_c + Pi_m <=> OAA_m + Pi_c
# Tr_PXN3 : NADH_p + NAD_c <=> NADH_c + NAD_p
# Tr_iCit : iCit_c <=> iCit_p
# Tr_SCA : SCA_c <=> SCA_p
# Si_H_c :  <=> H_c
# Si_H_m :  <=> H_m
# Si_H_h :  <=> H_h
# Si_H_p :  <=> H_p
# Im_hnu :  --> hnu_h
# Im_CO2 :  --> CO2_c
# Im_H2O :  <=> H2O_c
# Im_Pi : 3.0 ATP_c + 3.0 H2O_c --> 3.0 ADP_c + H_c + 3.0 Pi_c
# Im_NO3 : 2.0 ATP_c + 2.0 H2O_c --> 2.0 ADP_c + 2.0 H_c + NO3_c + 2.0 Pi_c
# Im_NH4 :  --> NH4_c
# Im_SO4 : 3.0 ATP_c + 3.0 H2O_c --> 3.0 ADP_c + 3.0 H_c + 3.0 Pi_c + SO4_c
# Im_H2S :  --> H2S_c
# Ex_O2 : O2_c <=>
# Ex_Ala_c : Ala_c -->
# Ex_Ala_h : Ala_h -->
# Ex_Ala_m : Ala_m -->
# Ex_Ala_p : Ala_p -->
# Ex_Arg_c : Arg_c -->
# Ex_Arg_h : Arg_h -->
# Ex_Arg_m : Arg_m -->
# Ex_Arg_p : Arg_p -->
# Ex_Asn_c : Asn_c -->
# Ex_Asn_h : Asn_h -->
# Ex_Asn_m : Asn_m -->
# Ex_Asn_p : Asn_p -->
# Ex_Asp_c : Asp_c -->
# Ex_Asp_h : Asp_h -->
# Ex_Asp_m : Asp_m -->
# Ex_Asp_p : Asp_p -->
# Ex_Cys_c : Cys_c -->
# Ex_Cys_h : Cys_h -->
# Ex_Cys_m : Cys_m -->
# Ex_Cys_p : Cys_p -->
# Ex_Gln_c : Gln_c -->
# Ex_Gln_h : Gln_h -->
# Ex_Gln_m : Gln_m -->
# Ex_Gln_p : Gln_p -->
# Ex_Glu_c : Glu_c -->
# Ex_Glu_h : Glu_h -->
# Ex_Glu_m : Glu_m -->
# Ex_Glu_p : Glu_p -->
# Ex_Gly_c : Gly_c -->
# Ex_Gly_h : Gly_h -->
# Ex_Gly_m : Gly_m -->
# Ex_Gly_p : Gly_p -->
# Ex_His_c : His_c -->
# Ex_His_h : His_h -->
# Ex_His_m : His_m -->
# Ex_His_p : His_p -->
# Ex_Ile_c : Ile_c -->
# Ex_Ile_h : Ile_h -->
# Ex_Ile_m : Ile_m -->
# Ex_Ile_p : Ile_p -->
# Ex_Leu_c : Leu_c -->
# Ex_Leu_h : Leu_h -->
# Ex_Leu_m : Leu_m -->
# Ex_Leu_p : Leu_p -->
# Ex_Lys_c : Lys_c -->
# Ex_Lys_h : Lys_h -->
# Ex_Lys_m : Lys_m -->
# Ex_Lys_p : Lys_p -->
# Ex_Met_c : Met_c -->
# Ex_Met_h : Met_h -->
# Ex_Met_m : Met_m -->
# Ex_Met_p : Met_p -->
# Ex_Phe_c : Phe_c -->
# Ex_Phe_h : Phe_h -->
# Ex_Phe_m : Phe_m -->
# Ex_Phe_p : Phe_p -->
# Ex_Pro_c : Pro_c -->
# Ex_Pro_h : Pro_h -->
# Ex_Pro_m : Pro_m -->
# Ex_Pro_p : Pro_p -->
# Ex_Ser_c : Ser_c -->
# Ex_Ser_h : Ser_h -->
# Ex_Ser_m : Ser_m -->
# Ex_Ser_p : Ser_p -->
# Ex_Thr_c : Thr_c -->
# Ex_Thr_h : Thr_h -->
# Ex_Thr_m : Thr_m -->
# Ex_Thr_p : Thr_p -->
# Ex_Trp_c : Trp_c -->
# Ex_Trp_h : Trp_h -->
# Ex_Trp_m : Trp_m -->
# Ex_Trp_p : Trp_p -->
# Ex_Tyr_c : Tyr_c -->
# Ex_Tyr_h : Tyr_h -->
# Ex_Tyr_m : Tyr_m -->
# Ex_Tyr_p : Tyr_p -->
# Ex_Val_c : Val_c -->
# Ex_Val_h : Val_h -->
# Ex_Val_m : Val_m -->
# Ex_Val_p : Val_p -->
# Ex_starch : starch2_h -->
# Ex_Glc : Glc_c -->
# Ex_Frc : Frc_c -->
# Ex_Suc : Suc_c -->
# Ex_cellulose : cellulose3_c -->
# Ex_Mas : Mas_c -->
# Ex_MACP : M_DASH_ACP_h --> ACP_h + H_h
# Ex_Tre : Tre_c -->
# NGAM_c : ATP_c + H2O_c --> ADP_c + H_c + Pi_c
# NGAM_h : ATP_h + H2O_h --> ADP_h + H_h + Pi_h
# NGAM_m : ATP_m + H2O_m --> ADP_m + H_m + Pi_m
# NDA2_1_m : H_m + NADH_m + Q_m --> NAD_m + QH2_m
# NDA2_2_m : H_m + NADPH_m + Q_m --> NADP_m + QH2_m
# AOX1A_m : O2_m + 2.0 QH2_m --> 2.0 H2O_m + 2.0 Q_m
# NDC1_1_h : H_h + NADH_h + PQ_h --> NAD_h + PQH2_h
# NDC1_2_h : H_h + NADPH_h + PQ_h --> NADP_h + PQH2_h
# AOX4_h : O2_h + 2.0 PQH2_h --> 2.0 H2O_h + 2.0 PQ_h
# Ex_AA : 0.097 Ala_c + 0.016 Arg_c + 0.101 Asn_c + 0.095 Asp_c + 0.332 Gln_c + 0.114 Glu_c + 0.007 Gly_c + 0.004 His_c + 0.012 Ile_c + 0.012 Leu_c + 0.018 Lys_c + 0.007 Met_c + 0.011 Phe_c + 0.077 Ser_c + 0.056 Thr_c + 0.009 Trp_c + 0.006 Tyr_c + 0.024 Val_c -->
# AlaTA_c : Ala_c + KG_c <=> Glu_c + Pyr_c
# Tr_Cit_iCit_mc : Cit_m + iCit_c <=> Cit_c + iCit_m
# Tr_KG_Mal_mc : KG_m + Mal_c <=> KG_c + Mal_m
# Tr_Asp_mc : Asp_m <=> Asp_c
# Tr_Asp_Glu_mc : Asp_m + Glu_c <=> Asp_c + Glu_m
# Tr_Pyr_Mal_hc : Mal_c + Pyr_h <=> Mal_h + Pyr_c
# Tr_Ala_mc : Ala_c <=> Ala_m
# Metabolites
# -----------
#     hnu_h : X
#      PQ_h : C13H16O2
#     H2O_h : H2O
#       H_h : H
#    PQH2_h : C13H18O2
#      O2_h : O2
#       H_l : H
#    PCox_h : X
#    PCrd_h : X
#    Fdox_h : S8FeX
#    Fdrd_h : S8FeX
#    NADP_h : C21H25N7O17P3
#   NADPH_h : C21H26N7O17P3
#     ADP_h : C10H12N5O10P2
#      Pi_h : HO4P
#     ATP_h : C10H12N5O13P3
#    RuBP_h : C5H8O11P2
#     CO2_h : CO2
#     PGA_h : C3H4O7P
#    DPGA_h : C3H4O10P2
#     GAP_h : C3H5O6P
#    DHAP_h : C3H5O6P
#     FBP_h : C6H10O12P2
#     F6P_h : C6H11O9P
#     E4P_h : C4H7O7P
#     X5P_h : C5H9O8P
#     SBP_h : C7H12O13P2
#     S7P_h : C7H13O10P
#     R5P_h : C5H9O8P
#    Ru5P_h : C5H9O8P
#     G6P_h : C6H11O9P
#     G1P_h : C6H11O9P
#    ADPG_h : C16H23N5O15P2
#     PPi_h : O7P2
# starch1_h : C6H12O6
# starch2_h : C12H22O11
# starch3_h : C18H32O16
# starch5_h : C30H52O26
#     Mas_h : C12H22O11
#     Glc_h : C6H12O6
# starch1_c : C6H12O6
#     Mas_c : C12H22O11
# starch2_c : C12H22O11
#     Glc_c : C6H12O6
#     ATP_c : C10H12N5O13P3
#     G6P_c : C6H11O9P
#     ADP_c : C10H12N5O10P2
#       H_c : H
#      Na_c : Na
#      Na_h : Na
#      Pi_c : HO4P
#     G1P_c : C6H11O9P
#     GAP_c : C3H5O6P
#    DHAP_c : C3H5O6P
#     FBP_c : C6H10O12P2
#     H2O_c : H2O
#     F6P_c : C6H11O9P
#   F26BP_c : C6H10O12P2
#     UTP_c : C9H11N2O15P3
#    UDPG_c : C15H22N2O17P2
#     PPi_c : HO7P2
#     S6P_c : C12H21O14P
#     UDP_c : C9H12N2O12P2
#     Suc_c : C12H22O11
#     Frc_c : C6H12O6
#     T6P_c : C12H21O14P
#     Tre_c : C12H22O11
# cellulose1_c : C6H12O6
# cellulose2_c : C12H22O11
# cellulose3_c : C18H32O16
#     Mal_c : C4H4O5
#     NAD_c : C21H26N7O14P2
#     OAA_c : C4H2O5
#    NADH_c : C21H27N7O14P2
#     PEP_c : C3H2O6P
#     CO2_c : CO2
#    HCO3_c : CHO3
#    2PGA_c : C3H4O7P
#     PGA_c : C3H4O7P
#    DPGA_c : C3H4O10P2
#    NADP_c : C21H25N7O17P3
#   NADPH_c : C21H26N7O17P3
#     NAD_h : C21H26N7O14P2
#    NADH_h : C21H27N7O14P2
#    2PGA_h : C3H4O7P
#     PEP_h : C3H2O6P
#     Pyr_c : C3H3O3
#     Pyr_h : C3H3O3
#     Pyr_m : C3H3O3
#    ThPP_m : C12H16N4O7P2S
#       H_m : H
# H_DASH_Eth_DASH_ThPP_m : C14H20N4O8P2S
#     CO2_m : CO2
#     LPA_m : C8H15NOS2
# A_DASH_DHL_m : C10H19NO2S2
#     CoA_m : C21H32N7O16P3S
# A_DASH_CoA_m : C23H34N7O17P3S
#     DHL_m : C8H17NOS2
#     NAD_m : C21H26N7O14P2
#    NADH_m : C21H27N7O14P2
#     OAA_m : C4H2O5
#     H2O_m : H2O
#     Cit_m : C6H5O7
#    cACN_m : C6H3O6
#    iCit_m : C6H5O7
#      KG_m : C5H4O5
# S_DASH_DHL_m : C12H20NO4S2
# S_DASH_CoA_m : C25H35N7O19P3S
#     ADP_m : C10H12N5O10P2
#      Pi_m : HO4P
#     SCA_m : C4H4O4
#     ATP_m : C10H12N5O13P3
#       Q_m : C49H74O4
#     Fum_m : C4H2O4
#     QH2_m : C49H76O4
#     Mal_m : C4H4O5
#       H_i : H
#  Cytcox_m : C42H42N8O8S2FeR4
#  Cytcrd_m : C42H42N8O8S2FeR4
#      O2_m : O2
#    PGCA_h : C2H2O6P
#     GCA_h : C2H3O3
#     GCA_p : C2H3O3
#      O2_p : O2
#     GLX_p : C2HO3
#    H2O2_p : H2O2
#     H2O_p : H2O
#     Glu_p : C5H8NO4
#     Gly_p : C2H5NO2
#      KG_p : C5H4O5
#     Gly_m : C2H5NO2
#     LPL_m : C8H14NOS2R
#   amDHP_m : C9H20N2OS2R
#     THF_m : C19H21N7O6
#     DHP_m : C8H16NOS2R
# M_DASH_THF_m : C20H21N7O6
#     NH4_m : H4N
#     Ser_m : C3H7NO3
#     Ser_p : C3H7NO3
#     HPR_p : C3H3O4
#    NADH_p : C21H27N7O14P2
#       H_p : H
#    GCEA_p : C3H5O4
#     NAD_p : C21H26N7O14P2
#     Mal_p : C4H4O5
#     OAA_p : C4H2O5
#    GCEA_h : C3H5O4
#     GLP_h : C6H9O9P
#     6PG_h : C6H10O10P
#    DAHP_h : C7H10O10P
#     DHQ_h : C7H9O6
#     DHS_h : C7H7O5
#      SA_h : C7H9O5
#     S3P_h : C7H8O8P
#    EPSP_h : C10H9O10P
#     CHR_h : C10H8O6
#    PRPP_h : C5H8O14P3
#     AMP_h : C10H12N5O7P
#     Mal_h : C4H4O5
#     OAA_h : C4H2O5
#   NADPH_m : C21H26N7O17P3
#    NADP_m : C21H25N7O17P3
# A_DASH_CoA_c : C23H35N7O17P3S
#     Cit_c : C6H5O7
#     CoA_c : C21H33N7O16P3S
# A_DASH_CoA_h : C23H34N7O17P3S
#     Cit_h : C6H5O7
#     CoA_h : C21H32N7O16P3S
#    cACN_c : C6H3O6
#    cACN_h : C6H3O6
#    iCit_c : C6H5O7
#    iCit_p : C6H5O7
#    iCit_h : C6H5O7
#      KG_c : C5H4O5
#      KG_h : C5H4O5
#     SCA_c : C4H4O4
#     SCA_p : C4H4O4
#      AC_h : C2H3O2
#    HCO3_h : CHO3
# M_DASH_CoA_h : C24H33N7O19P3S
#     ACP_h : HSR
# M_DASH_ACP_h : C3H2O3SR
#     For_h : CHO2
#     THF_h : C19H21N7O6
# F_DASH_THF_h : C20H22N7O7
#     DHF_c : C19H20N7O6
#     THF_c : C19H22N7O6
#   TRXox_c : C10H12N4O4S2R4
#   TRXrd_c : C10H14N4O4S2R4
#     ADN_c : C10H13N5O4
#     AMP_c : C10H12N5O7P
#     Rib_c : C5H10O5
#      AD_c : C5H4N5
#    PRPP_c : C5H9O14P3
#     Rib_h : C5H10O5
#     NO3_c : NO3
#     NO2_c : NO2
#     NO2_h : NO2
#     NH4_h : H4N
#     SO4_h : O4S
#     SO4_m : O4S
#     APS_h : C10H12N5O10PS
#     GSH_h : C10H16N3O6S
#     SO3_h : HO3S
#    GSSG_h : C20H30N6O12S2
#     H2S_h : H2S
#     Glu_h : C5H8NO4
#     Ala_h : C3H7NO2
#     Glu_m : C5H8NO4
#     Ala_m : C3H7NO2
#     Pyr_p : C3H3O3
#     Ala_p : C3H7NO2
# A_DASH_Glu_h : C7H8NO5
# A_DASH_GluP_h : C7H8NO8P
# A_DASH_Glu_DASH_SeA_h : C7H9NO4
# A_DASH_Orn_h : C7H13N2O3
#     Orn_h : C5H13N2O2
#     Gln_h : C5H10N2O3
#     CBP_h : CHNO5P
#     CTL_h : C6H14N3O3
#     Asp_h : C4H6NO4
# Arg_DASH_SCA_h : C10H17N4O6
#     Arg_h : C6H15N4O2
#     Fum_h : C4H2O4
#     Fum_c : C4H2O4
#     Gln_c : C5H10N2O3
#     Asp_c : C4H6NO4
#     Glu_c : C5H8NO4
#     Asn_c : C4H8N2O3
#     Asp_m : C4H6NO4
#     Asp_p : C4H6NO4
#     NH4_c : H4N
#     Ser_c : C3H7NO3
# A_DASH_Ser_c : C5H9NO4
#     Ser_h : C3H7NO3
# A_DASH_Ser_h : C5H9NO4
# A_DASH_Ser_m : C5H9NO4
#     H2S_c : H2S
#     Cys_c : C3H7NO2S
#      AC_c : C2H3O2
#     Cys_h : C3H7NO2S
#     H2S_m : H2S
#     Cys_m : C3H7NO2S
#      AC_m : C2H3O2
#    GABA_c : C4H9NO2
#    GABA_m : C4H9NO2
# SCA_DASH_SeA_m : C4H5O3
#     Gln_m : C5H10N2O3
#     Thr_c : C4H9NO3
#     ACD_c : C2H4O
#     Gly_c : C2H5NO2
#     GLX_h : C2HO3
#    H2O2_h : H2O2
#     Gly_h : C2H5NO2
# PR_DASH_ATP_h : C15H19N5O20P4
# PR_DASH_AMP_h : C15H19N5O14P2
# P_DASH_AICAR_DASH_P_h : C15H21N5O15P2
# Pu_DASH_AICAR_DASH_P_h : C15H21N5O15P2
#    EIGP_h : C6H9N2O6P
#   AICAR_h : C9H14N4O8P
# IA_DASH_P_h : C6H7N2O5P
# Hisol_DASH_P_h : C6H11N3O4P
#   Hisol_h : C6H12N3O
#   Hisal_h : C6H9N3O
#     His_h : C6H9N3O2
#     Thr_h : C4H9NO3
#      OB_h : C4H5O3
#    ThPP_h : C12H16N4O7P2S
# H_DASH_Eth_DASH_ThPP_h : C14H20N4O8P2S
#     AHB_h : C6H9O4
#    DHMP_h : C6H11O4
#     MOP_h : C6H9O3
#     Ile_h : C6H13NO2
#      AL_h : C5H7O4
#    DHMB_h : C5H9O4
#     MOB_h : C5H7O3
#    2IPM_h : C7H10O5
#     IPM_h : C7H8O4
#    3IPM_h : C7H10O5
#     IPO_h : C7H8O5
#    4MOP_h : C6H9O3
#     Leu_h : C6H13NO2
#    AspP_h : C4H6NO7P
# Asp_DASH_SeA_h : C4H7NO3
#     DHD_h : C7H5NO4
#     THD_h : C7H7NO4
#     DAP_h : C7H14N2O4
#    mDAP_h : C7H14N2O4
#     Lys_h : C6H15N2O2
# H_DASH_Ser_h : C4H9NO3
# PH_DASH_Ser_h : C4H8NO6P
#     CTH_h : C7H14N2O4S
# H_DASH_Cys_h : C4H9NO2S
# M_DASH_THF_c : C20H22N7O6
# 5M_DASH_THF_c : C20H24N7O6
# H_DASH_Cys_c : C4H9NO2S
#     Met_c : C5H11NO2S
#    aMet_c : C15H22N6O5S
# aH_DASH_Cys_c : C14H20N6O5S
#     PRE_h : C10H8O6
#     AGN_h : C10H12NO5
#     Phe_h : C9H11NO2
#     Arg_m : C6H15N4O2
#     Orn_m : C5H13N2O2
#    urea_m : CH5N2O
# Glu_DASH_SeA_m : C5H9NO3
#    GluP_c : C5H8NO7P
#    GluP_h : C5H8NO7P
#    GluP_m : C5H8NO7P
# Glu_DASH_SeA_c : C5H9NO3
# Glu_DASH_SeA_h : C5H9NO3
#     P5C_c : C5H6NO2
#     P5C_h : C5H6NO2
#     P5C_m : C5H6NO2
#     Pro_c : C5H9NO2
#     Pro_m : C5H9NO2
# P_DASH_HPR_h : C3H2O7P
#    PSer_h : C3H6NO6P
#     ANT_h : C7H6NO2
# PR_DASH_ANT_h : C12H13NO9P
# CPD_DASH_Ru5P_h : C12H13NO9P
# Ind_DASH_GP_h : C11H12NO6P
#     Ind_h : C8H7N
#     Trp_h : C11H12N2O2
#     Tyr_h : C9H11NO3
#     Val_h : C5H11NO2
#     PRA_h : C5H11NO7P
#     GAR_h : C7H14N2O8P
#    FGAR_h : C8H13N2O9P
#    FGAM_h : C8H14N3O8P
#     AIR_h : C8H12N3O7P
#    CAIR_h : C9H11N3O9P
#  SAICAR_h : C13H15N4O12P
#  FAICAR_h : C10H13N4O9P
#     IMP_h : C10H11N4O8P
#     IMP_c : C10H11N4O8P
#     XMP_c : C10H11N4O9P
#     GMP_c : C10H13N5O8P
#     GTP_h : C10H13N5O14P3
# DC_DASH_AMP_h : C14H14N5O11P
#     GDP_h : C10H14N5O11P2
# CB_DASH_Asp_h : C5H6N2O5
#     DHO_h : C5H4N2O4
#     DHO_m : C5H4N2O4
#     ORO_m : C5H3N2O4
#     ORO_c : C5H3N2O4
#     OMP_c : C10H10N2O11P
#     UMP_c : C9H11N2O9P
#     CTP_c : C9H12N3O14P3
#     GDP_c : C10H14N5O11P2
#     CDP_c : C9H13N3O11P2
#    dADP_c : C10H13N5O9P2
#    dCDP_c : C9H13N3O10P2
#    dGDP_c : C10H14N5O10P2
#    dUDP_c : C9H12N2O11P2
#    dUTP_c : C9H12N2O14P3
#    dUMP_c : C9H11N2O8P
#    dTMP_c : C10H13N2O8P
#    dTDP_c : C10H14N2O11P2
#     GTP_c : C10H13N5O14P3
#    dATP_c : C10H13N5O12P3
#    dCTP_c : C9H13N3O13P3
#    dGTP_c : C10H14N5O13P3
#    dTTP_c : C10H14N2O14P3
#     SO4_c : O4S
#     GCA_c : C2H3O3
#    GCEA_c : C3H5O4
#     Ala_c : C3H7NO2
#     Arg_c : C6H15N4O2
#     Lys_c : C6H15N2O2
#     Lys_m : C6H15N2O2
#     His_m : C6H9N3O2
#     His_c : C6H9N3O2
#     DHO_c : C5H4N2O4
#      O2_c : O2
#     Arg_p : C6H15N4O2
#     Asn_p : C4H7N2O3
#     Cys_p : C3H7NO2S
#     Gln_p : C5H9N2O3
#     His_p : C6H9N3O2
#     Ile_c : C6H13NO2
#     Ile_p : C6H13NO2
#     Leu_c : C6H13NO2
#     Leu_p : C6H13NO2
#     Lys_p : C6H15N2O2
#     Met_p : C5H11NO2S
#     Phe_c : C9H11NO2
#     Phe_p : C9H11NO2
#     Pro_p : C5H9NO2
#     Thr_p : C4H9NO3
#     Trp_c : C11H12N2O2
#     Trp_p : C11H12N2O2
#     Tyr_c : C9H11NO3
#     Tyr_p : C9H11NO3
#     Val_c : C5H11NO2
#     Val_p : C5H11NO2
#     Asn_h : C4H7N2O3
#     Asn_m : C4H8N2O3
#     Ile_m : C6H13NO2
#     Leu_m : C6H13NO2
#     Met_h : C5H11NO2S
#     Met_m : C5H11NO2S
#     Phe_m : C9H11NO2
#     Pro_h : C5H9NO2
#     Thr_m : C4H9NO3
#     Trp_m : C11H12N2O2
#     Tyr_m : C9H11NO3
#     Val_m : C5H11NO2
#  PQstar_h : C13H16O2
# PGR5_PGRL1ox_h : X
# PGR5_PGRL1rd_h : X
#   NDHox_h : X
#   NDHrd_h : X
# Genes
# -----
# AT4G05180 is associated with reactions: {PSII_h}
# AT2G30570 is associated with reactions: {PSII_h}
# ATCG00560 is associated with reactions: {PSII_h}
# AT4G21280 is associated with reactions: {PSII_h}
# ATCG00300 is associated with reactions: {PSII_h}
# AT1G06680 is associated with reactions: {PSII_h}
# ATCG00080 is associated with reactions: {PSII_h}
# AT2G06520 is associated with reactions: {PSII_h}
# AT1G79040 is associated with reactions: {PSII_h}
# AT5G66570 is associated with reactions: {PSII_h}
# AT3G21055 is associated with reactions: {PSII_h}
# ATCG00020 is associated with reactions: {PSII_h}
# ATCG00270 is associated with reactions: {PSII_h}
# ATCG00690 is associated with reactions: {PSII_h}
# ATCG00710 is associated with reactions: {PSII_h}
# ATCG00550 is associated with reactions: {PSII_h}
# ATCG00570 is associated with reactions: {PSII_h}
# AT1G67740 is associated with reactions: {PSII_h}
# ATCG00580 is associated with reactions: {PSII_h}
# AT3G50820 is associated with reactions: {PSII_h}
# ATCG00680 is associated with reactions: {PSII_h}
# ATCG00280 is associated with reactions: {PSII_h}
# AT1G44575 is associated with reactions: {PSII_h}
# ATCG00220 is associated with reactions: {PSII_h}
# ATCG00700 is associated with reactions: {PSII_h}
# ATCG00070 is associated with reactions: {PSII_h}
# ATCG00730 is associated with reactions: {Cytb6f1_h, Cytb6f2_h}
# ATCG00600 is associated with reactions: {Cytb6f1_h, Cytb6f2_h}
# ATCG00210 is associated with reactions: {Cytb6f1_h, Cytb6f2_h}
# ATCG00590 is associated with reactions: {Cytb6f1_h, Cytb6f2_h}
# AT2G26500 is associated with reactions: {Cytb6f1_h, Cytb6f2_h}
# AT4G03280 is associated with reactions: {Cytb6f1_h, Cytb6f2_h}
# ATCG00720 is associated with reactions: {Cytb6f1_h, Cytb6f2_h}
# ATCG00540 is associated with reactions: {Cytb6f1_h, Cytb6f2_h}
# AT2G05620 is associated with reactions: {PGR5PGRL11_h, PGR5PGRL12_h}
# AT4G22890 is associated with reactions: {PGR5PGRL11_h, PGR5PGRL12_h}
# AT4G11960 is associated with reactions: {PGR5PGRL11_h, PGR5PGRL12_h}
# AT5G58260 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG01090 is associated with reactions: {NDH2_h, NDH1_h}
# AT1G14150 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG00440 is associated with reactions: {NDH2_h, NDH1_h}
# AT1G70760 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG01100 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG00890 is associated with reactions: {NDH2_h, NDH1_h}
# AT5G43750 is associated with reactions: {NDH2_h, NDH1_h}
# AT1G74880 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG00430 is associated with reactions: {NDH2_h, NDH1_h}
# AT4G37925 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG01080 is associated with reactions: {NDH2_h, NDH1_h}
# AT1G15980 is associated with reactions: {NDH2_h, NDH1_h}
# AT4G39710 is associated with reactions: {NDH2_h, NDH1_h}
# AT1G18730 is associated with reactions: {NDH2_h, NDH1_h}
# AT3G01440 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG01110 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG01070 is associated with reactions: {NDH2_h, NDH1_h}
# AT5G13120 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG01010 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG00420 is associated with reactions: {NDH2_h, NDH1_h}
# ATCG01050 is associated with reactions: {NDH2_h, NDH1_h}
# AT2G39470 is associated with reactions: {NDH2_h, NDH1_h}
# AT3G16250 is associated with reactions: {NDH2_h, NDH1_h}
# AT4G02770 is associated with reactions: {PSI_h}
# AT1G08380 is associated with reactions: {PSI_h}
# AT2G20260 is associated with reactions: {PSI_h}
# AT1G03130 is associated with reactions: {PSI_h}
# AT1G31330 is associated with reactions: {PSI_h}
# AT2G46820 is associated with reactions: {PSI_h}
# ATCG00630 is associated with reactions: {PSI_h}
# ATCG00340 is associated with reactions: {PSI_h}
# ATCG00350 is associated with reactions: {PSI_h}
# AT1G30380 is associated with reactions: {PSI_h}
# AT4G12800 is associated with reactions: {PSI_h}
# ATCG01060 is associated with reactions: {PSI_h}
# AT3G16140 is associated with reactions: {PSI_h}
# AT1G55670 is associated with reactions: {PSI_h}
# AT4G28750 is associated with reactions: {PSI_h}
# ATCG00510 is associated with reactions: {PSI_h}
# AT5G64040 is associated with reactions: {PSI_h}
# AT1G52230 is associated with reactions: {PSI_h}
# AT1G20020 is associated with reactions: {Fd_DASH_NADPR_h}
# AT4G05390 is associated with reactions: {Fd_DASH_NADPR_h}
# AT1G30510 is associated with reactions: {Fd_DASH_NADPR_h}
# AT5G66190 is associated with reactions: {Fd_DASH_NADPR_h}
# AT1G15700 is associated with reactions: {ATPase_h}
# ATCG00470 is associated with reactions: {ATPase_h}
# ATCG00140 is associated with reactions: {ATPase_h}
# ATCG00480 is associated with reactions: {ATPase_h}
# AT4G04640 is associated with reactions: {ATPase_h}
# ATCG00150 is associated with reactions: {ATPase_h}
# ATCG00120 is associated with reactions: {ATPase_h}
# ATCG00130 is associated with reactions: {ATPase_h}
# AT4G09650 is associated with reactions: {ATPase_h}
# AT1G67090 is associated with reactions: {RBO_h, RBC_h}
# ATCG00490 is associated with reactions: {RBO_h, RBC_h}
# AT5G38410 is associated with reactions: {RBO_h, RBC_h}
# AT5G38420 is associated with reactions: {RBO_h, RBC_h}
# AT5G38430 is associated with reactions: {RBO_h, RBC_h}
# AT1G79550 is associated with reactions: {PGAK_h, PGAK_c}
# AT1G56190 is associated with reactions: {PGAK_h, PGAK_c}
# AT3G12780 is associated with reactions: {PGAK_h, PGAK_c}
# AT1G42970 is associated with reactions: {GAPDH2_c, GAPDH2_h, GAPDH1_h}
# AT1G12900 is associated with reactions: {GAPDH2_c, GAPDH2_h, GAPDH1_h}
# AT3G26650 is associated with reactions: {GAPDH2_c, GAPDH2_h, GAPDH1_h}
# AT3G55440 is associated with reactions: {TPI_h, TPI_c}
# AT2G21170 is associated with reactions: {TPI_h, TPI_c}
# AT4G26530 is associated with reactions: {FBPA_c, SBPA_h, FBPA_h}
# AT2G21330 is associated with reactions: {SBPA_h, FBPA_h}
# AT2G01140 is associated with reactions: {SBPA_h, FBPA_h}
# AT4G38970 is associated with reactions: {SBPA_h, FBPA_h}
# AT3G52930 is associated with reactions: {FBPA_c, SBPA_h, FBPA_h}
# AT3G54050 is associated with reactions: {FBPase_h}
# AT2G45290 is associated with reactions: {STK_h, TA_h, FTK_h}
# AT3G60750 is associated with reactions: {STK_h, TA_h, FTK_h}
# AT3G55800 is associated with reactions: {SBPase_h}
# AT5G61410 is associated with reactions: {Ru5PE_h}
# AT3G04790 is associated with reactions: {R5PI_h}
# AT5G44520 is associated with reactions: {R5PI_h}
# AT1G32060 is associated with reactions: {Ru5PK_h}
# AT4G24620 is associated with reactions: {PGI_c, PGI_h}
# AT5G51820 is associated with reactions: {PGM_h, PGM_c}
# AT1G70730 is associated with reactions: {PGM_h, PGM_c}
# AT1G23190 is associated with reactions: {PGM_h, PGM_c}
# AT4G39210 is associated with reactions: {AGPase_h}
# AT5G48300 is associated with reactions: {AGPase_h}
# AT1G27680 is associated with reactions: {AGPase_h}
# AT2G21590 is associated with reactions: {AGPase_h}
# AT5G19220 is associated with reactions: {AGPase_h}
# AT1G05610 is associated with reactions: {AGPase_h}
# AT5G24300 is associated with reactions: {StS_h2, StS_h1, StS_h3}
# AT4G18240 is associated with reactions: {StS_h2, StS_h1, StS_h3}
# AT1G11720 is associated with reactions: {StS_h2, StS_h1, StS_h3}
# AT3G01180 is associated with reactions: {StS_h2, StS_h1, StS_h3}
# AT4G00490 is associated with reactions: {bAMY2_h, bAMY1_h}
# AT2G32290 is associated with reactions: {bAMY2_h, bAMY1_h}
# AT4G17090 is associated with reactions: {bAMY2_h, bAMY1_h}
# AT3G23920 is associated with reactions: {bAMY2_h, bAMY1_h}
# AT5G64860 is associated with reactions: {DPE11_h, DPE12_h, DPE13_h}
# AT2G40840 is associated with reactions: {DPE2_c}
# AT4G29130 is associated with reactions: {HEXK_c, FrcK_c}
# AT2G19860 is associated with reactions: {HEXK_c, FrcK_c}
# AT3G46970 is associated with reactions: {StP21_c, StP1_h}
# AT3G29320 is associated with reactions: {StP21_c, StP1_h}
# AT2G36460 is associated with reactions: {FBPA_c}
# AT4G26520 is associated with reactions: {FBPA_c}
# AT5G03690 is associated with reactions: {FBPA_c}
# AT1G43670 is associated with reactions: {FBPase_c}
# AT1G07110 is associated with reactions: {F6PK2_c, F26BPPh_c}
# AT5G42740 is associated with reactions: {PGI_c}
# AT5G52560 is associated with reactions: {UGPase_c}
# AT2G35020 is associated with reactions: {UGPase_c}
# AT5G17310 is associated with reactions: {UGPase_c}
# AT3G56040 is associated with reactions: {UGPase_c}
# AT3G03250 is associated with reactions: {UGPase_c}
# AT5G11110 is associated with reactions: {S6PS_c}
# AT4G10120 is associated with reactions: {S6PS_c}
# AT5G20280 is associated with reactions: {S6PS_c}
# AT3G52340 is associated with reactions: {S6PPh_c}
# AT2G35840 is associated with reactions: {S6PPh_c}
# AT4G02280 is associated with reactions: {SucS_c}
# AT5G49190 is associated with reactions: {SucS_c}
# AT5G20830 is associated with reactions: {SucS_c}
# AT1G73370 is associated with reactions: {SucS_c}
# AT3G43190 is associated with reactions: {SucS_c}
# AT5G37180 is associated with reactions: {SucS_c}
# AT1G72000 is associated with reactions: {FrcFD_c}
# AT4G09510 is associated with reactions: {FrcFD_c}
# AT1G35580 is associated with reactions: {FrcFD_c}
# AT1G50460 is associated with reactions: {FrcK_c}
# AT3G20040 is associated with reactions: {FrcK_c}
# AT4G37840 is associated with reactions: {FrcK_c}
# AT2G31390 is associated with reactions: {FrcK_c}
# AT3G54090 is associated with reactions: {FrcK_c}
# AT1G47840 is associated with reactions: {FrcK_c}
# AT3G59480 is associated with reactions: {FrcK_c}
# AT5G51830 is associated with reactions: {FrcK_c}
# AT4G27550 is associated with reactions: {TPS_c}
# AT1G16980 is associated with reactions: {TPS_c}
# AT1G23870 is associated with reactions: {TPS_c, TPP_c}
# AT2G18700 is associated with reactions: {TPS_c, TPP_c}
# AT1G78580 is associated with reactions: {TPS_c}
# AT1G60140 is associated with reactions: {TPS_c}
# AT1G17000 is associated with reactions: {TPS_c}
# AT1G70290 is associated with reactions: {TPS_c, TPP_c}
# AT1G06410 is associated with reactions: {TPS_c, TPP_c}
# AT1G68020 is associated with reactions: {TPS_c, TPP_c}
# AT4G17770 is associated with reactions: {TPS_c, TPP_c}
# AT5G51460 is associated with reactions: {TPP_c}
# AT1G78090 is associated with reactions: {TPP_c}
# AT4G12430 is associated with reactions: {TPP_c}
# AT1G22210 is associated with reactions: {TPP_c}
# AT4G22590 is associated with reactions: {TPP_c}
# AT5G10100 is associated with reactions: {TPP_c}
# AT5G65140 is associated with reactions: {TPP_c}
# AT4G39770 is associated with reactions: {TPP_c}
# AT5G09870 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT1G02730 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT3G07330 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT5G44030 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G15320 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G24010 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G07960 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G32410 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT2G21770 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G39350 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G23990 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT5G05170 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT2G32620 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT1G55850 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT2G32540 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT2G25540 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G31590 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT2G24630 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G24000 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT5G64740 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT3G28180 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G15290 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT4G18780 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT2G32530 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT5G17420 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT2G32610 is associated with reactions: {CeS_c2, CeS_c1, CeS_c3}
# AT5G43330 is associated with reactions: {MalDH1_c}
# AT5G56720 is associated with reactions: {MalDH1_c}
# AT1G53240 is associated with reactions: {MalDH1_m, MalDH1_c, MalDH1_h}
# AT3G15020 is associated with reactions: {MalDH1_m, MalDH1_c}
# AT5G09660 is associated with reactions: {MalDH1_p, MalDH1_c, MalDH1_h}
# AT1G04410 is associated with reactions: {MalDH1_c, MalDH1_h}
# AT5G65690 is associated with reactions: {PEPC1_c}
# AT4G37870 is associated with reactions: {PEPC1_c}
# AT1G53310 is associated with reactions: {PEPC2_c}
# AT2G42600 is associated with reactions: {PEPC2_c}
# AT1G68750 is associated with reactions: {PEPC2_c}
# AT3G14940 is associated with reactions: {PEPC2_c}
# AT2G29560 is associated with reactions: {Enol_c}
# AT2G36530 is associated with reactions: {Enol_h, Enol_c}
# AT1G09780 is associated with reactions: {PGAM_h, PGAM_c}
# AT3G08590 is associated with reactions: {PGAM_c}
# AT1G13440 is associated with reactions: {GAPDH2_c}
# AT3G04120 is associated with reactions: {GAPDH2_c}
# AT2G24270 is associated with reactions: {GAPDH3_c}
# AT4G29220 is associated with reactions: {F6PK1_c}
# AT5G56630 is associated with reactions: {F6PK1_c}
# AT4G32840 is associated with reactions: {F6PK1_c}
# AT4G26270 is associated with reactions: {F6PK1_c}
# AT5G61580 is associated with reactions: {F6PK1_h, F6PK1_c}
# AT5G47810 is associated with reactions: {F6PK1_c}
# AT2G22480 is associated with reactions: {F6PK1_h, F6PK1_c}
# AT1G16300 is associated with reactions: {GAPDH2_h}
# AT1G79530 is associated with reactions: {GAPDH2_h}
# AT1G78050 is associated with reactions: {PGAM_h}
# AT1G22170 is associated with reactions: {PGAM_h}
# AT1G74030 is associated with reactions: {Enol_h}
# AT3G52990 is associated with reactions: {PyrK_c}
# AT3G04050 is associated with reactions: {PyrK_c}
# AT3G55810 is associated with reactions: {PyrK_c}
# AT2G36580 is associated with reactions: {PyrK_c}
# AT5G52920 is associated with reactions: {PyrK_c, PyrK_h}
# AT5G63680 is associated with reactions: {PyrK_c}
# AT3G25960 is associated with reactions: {PyrK_c}
# AT3G55650 is associated with reactions: {PyrK_c}
# AT5G56350 is associated with reactions: {PyrK_c}
# AT5G08570 is associated with reactions: {PyrK_c, PyrK_h}
# AT4G26390 is associated with reactions: {PyrK_c}
# AT3G49160 is associated with reactions: {PyrK_c, PyrK_h}
# AT3G22960 is associated with reactions: {PyrK_c, PyrK_h}
# AT1G32440 is associated with reactions: {PyrK_h}
# AT5G50850 is associated with reactions: {PyrDH2_m, PyrDH1_m}
# AT1G59900 is associated with reactions: {PyrDH2_m, PyrDH1_m}
# AT1G54220 is associated with reactions: {DHLAcT_m}
# AT3G13930 is associated with reactions: {DHLAcT_m}
# AT3G52200 is associated with reactions: {DHLAcT_m}
# AT3G17240 is associated with reactions: {DHLDH2_m, DHLDH1_m}
# AT1G48030 is associated with reactions: {DHLDH2_m, DHLDH1_m}
# AT3G60100 is associated with reactions: {CitS_m}
# AT2G44350 is associated with reactions: {CitS_h, CitS_m}
# AT4G35830 is associated with reactions: {cACNDHA_c, cACNHA_c, cACNDHA_m, cACNHA_m}
# ...
# AT2G03667 is associated with reactions: {AsnS_c, Glnase_c}
# AT5G65010 is associated with reactions: {AsnS_c}
# AT5G19550 is associated with reactions: {AspAT2_c, AspAT_c}
# AT5G51690 is associated with reactions: {AspAT2_c, AspAT_c}
# AT2G22250 is associated with reactions: {AspAT_h, AspAT2_h, AspAT2_c, GPAT_h, AspAT_c}
# AT1G62960 is associated with reactions: {AspAT2_c, AspAT_c}
# AT5G11520 is associated with reactions: {AspAT_h, AspAT2_h, AspAT2_c, AspAT2_p, AspAT_p, AspAT_c}
# AT1G62800 is associated with reactions: {AspAT2_c, AspAT_c}
# AT4G31990 is associated with reactions: {AspAT_h, AspAT2_h, AspAT_m, AspAT2_m}
# AT2G30970 is associated with reactions: {AspAT_m, AspAT2_m}
# AT5G08100 is associated with reactions: {Asnase_c}
# AT3G16150 is associated with reactions: {Asnase_c}
# AT5G56760 is associated with reactions: {SerAcT_c}
# AT4G35640 is associated with reactions: {SerAcT_c}
# AT3G13110 is associated with reactions: {SerAcT_m, SerAcT_h, SerAcT_c}
# AT1G55920 is associated with reactions: {SerAcT_m, SerAcT_h, SerAcT_c}
# AT2G17640 is associated with reactions: {SerAcT_c}
# AT4G14880 is associated with reactions: {CysS_c, CysS_h}
# AT5G28020 is associated with reactions: {CysS_c}
# AT5G28030 is associated with reactions: {CysS_c}
# AT3G22460 is associated with reactions: {CysS_c}
# AT3G04940 is associated with reactions: {CysS_c}
# AT3G03630 is associated with reactions: {CysS_h, CysS_m}
# AT2G43750 is associated with reactions: {CysS_h, CysS_m}
# AT3G61440 is associated with reactions: {CysS_h, CysS_m}
# AT3G59760 is associated with reactions: {CysS_m}
# AT1G51720 is associated with reactions: {GluDH3NADP_c}
# AT5G60540 is associated with reactions: {Glnase_c}
# AT5G53460 is associated with reactions: {GluSNAD_h}
# AT2G41220 is associated with reactions: {GluSFd_h}
# AT5G04140 is associated with reactions: {GluSFd_h}
# AT5G18170 is associated with reactions: {GluDH1NAD_m, GluDH1NADP_m}
# AT3G03910 is associated with reactions: {GluDH1NAD_m, GluDH1NADP_m}
# AT5G07440 is associated with reactions: {GluDH1NAD_m, GluDH1NADP_m}
# AT2G02000 is associated with reactions: {GluDC_c}
# AT2G02010 is associated with reactions: {GluDC_c}
# AT1G65960 is associated with reactions: {GluDC_c}
# AT5G17330 is associated with reactions: {GluDC_c}
# AT3G22200 is associated with reactions: {GABATA1_m, GABATA2_m}
# AT1G79440 is associated with reactions: {SCASeADH_m}
# AT5G37600 is associated with reactions: {GlnS_c}
# AT1G66200 is associated with reactions: {GlnS_c}
# AT5G16570 is associated with reactions: {GlnS_c}
# AT3G17820 is associated with reactions: {GlnS_c, GlnS_h}
# AT1G48470 is associated with reactions: {GlnS_c, GlnS_h}
# AT5G35630 is associated with reactions: {GlnS_m, GlnS_h}
# AT1G08630 is associated with reactions: {ThrA_c}
# AT1G54100 is associated with reactions: {ACDOxRed_c}
# AT3G66658 is associated with reactions: {ACDOxRed_c}
# AT1G44170 is associated with reactions: {ACDOxRed_c}
# AT4G36250 is associated with reactions: {ACDOxRed_c}
# AT3G24503 is associated with reactions: {ACDOxRed_c}
# AT1G09795 is associated with reactions: {ATPPRT_h}
# AT1G58080 is associated with reactions: {ATPPRT_h}
# AT1G31860 is associated with reactions: {PrAMPCy_h, PrATPDP_h}
# AT2G36230 is associated with reactions: {PAICARPI_h}
# AT4G26900 is associated with reactions: {IGPS_h}
# AT4G14910 is associated with reactions: {IGPDA_h}
# AT3G22425 is associated with reactions: {IGPDA_h}
# AT5G10330 is associated with reactions: {HisolPTA_h}
# AT1G71920 is associated with reactions: {HisolPTA_h}
# AT4G39120 is associated with reactions: {HisolPP_h}
# AT5G63890 is associated with reactions: {HisalPDH_h, HisolPDH_h}
# AT3G10050 is associated with reactions: {ThrDA_h}
# AT1G30120 is associated with reactions: {ALS1_h}
# AT1G01090 is associated with reactions: {ALS1_h}
# AT2G34590 is associated with reactions: {ALS1_h}
# AT2G31810 is associated with reactions: {ALS2_h, ALS3_h}
# AT3G48560 is associated with reactions: {ALS2_h, ALS3_h}
# AT5G16290 is associated with reactions: {ALS2_h, ALS3_h}
# AT3G58610 is associated with reactions: {KARI34_h, KARI12_h}
# AT3G23940 is associated with reactions: {DHADA1_h, DHADA2_h}
# AT5G65780 is associated with reactions: {BAATA3_h, BAATA1_h, BAATA2_h}
# AT1G10070 is associated with reactions: {BAATA3_h, BAATA1_h, BAATA2_h}
# AT3G49680 is associated with reactions: {BAATA3_h, BAATA1_h, BAATA2_h}
# AT5G23010 is associated with reactions: {2IPMS_h}
# AT1G18500 is associated with reactions: {2IPMS_h}
# AT5G23020 is associated with reactions: {2IPMS_h}
# AT1G74040 is associated with reactions: {2IPMS_h}
# AT4G13430 is associated with reactions: {3IPMDA1_h, 3IPMDA2_h}
# AT3G58990 is associated with reactions: {3IPMDA1_h, 3IPMDA2_h}
# AT2G43090 is associated with reactions: {3IPMDA1_h, 3IPMDA2_h}
# AT2G43100 is associated with reactions: {3IPMDA1_h, 3IPMDA2_h}
# AT5G14200 is associated with reactions: {IPODC_h, 3IPMDH_h}
# AT1G31180 is associated with reactions: {IPODC_h, 3IPMDH_h}
# AT1G80560 is associated with reactions: {IPODC_h, 3IPMDH_h}
# AT1G80555 is associated with reactions: {IPODC_h}
# AT5G14060 is associated with reactions: {AspK_h}
# AT4G19710 is associated with reactions: {AspK_h, HSerDHNAD_h, HSerDHNADP_h}
# AT3G02020 is associated with reactions: {AspK_h}
# AT5G13280 is associated with reactions: {AspK_h}
# AT1G31230 is associated with reactions: {AspK_h, HSerDHNAD_h, HSerDHNADP_h}
# AT1G14810 is associated with reactions: {Asp_DASH_SeADH_h}
# AT2G45440 is associated with reactions: {DHDS_h}
# AT3G60880 is associated with reactions: {DHDS_h}
# AT2G44040 is associated with reactions: {DHDRNAD_h, DHDRNADP_h}
# AT3G59890 is associated with reactions: {DHDRNAD_h, DHDRNADP_h}
# AT5G52100 is associated with reactions: {DHDRNAD_h, DHDRNADP_h}
# AT4G33680 is associated with reactions: {DAPAT_h}
# AT3G53580 is associated with reactions: {DAPE_h}
# AT5G11880 is associated with reactions: {DAPDC_h}
# AT3G14390 is associated with reactions: {DAPDC_h}
# AT5G21060 is associated with reactions: {HSerDHNAD_h, HSerDHNADP_h}
# AT2G17265 is associated with reactions: {HSerK_h}
# AT3G01120 is associated with reactions: {CTHS_h}
# AT3G57050 is associated with reactions: {CTHL_h}
# AT2G44160 is associated with reactions: {5M_DASH_THFOR_c}
# AT3G59970 is associated with reactions: {5M_DASH_THFOR_c}
# AT5G20980 is associated with reactions: {MetS_c}
# AT1G36370 is associated with reactions: {GlyHMT_c}
# AT4G13890 is associated with reactions: {GlyHMT_c}
# AT1G22020 is associated with reactions: {GlyHMT_c}
# AT4G13930 is associated with reactions: {GlyHMT_c}
# AT4G01850 is associated with reactions: {MetAdT_c}
# AT2G36880 is associated with reactions: {MetAdT_c}
# AT3G17390 is associated with reactions: {MetAdT_c}
# AT1G02500 is associated with reactions: {MetAdT_c}
# AT3G63250 is associated with reactions: {HCysMT_c}
# AT3G22740 is associated with reactions: {HCysMT_c}
# AT3G25900 is associated with reactions: {HCysMT_c}
# AT4G13940 is associated with reactions: {Cysase_c}
# AT3G23810 is associated with reactions: {Cysase_c}
# AT5G10870 is associated with reactions: {CHRM_h}
# AT3G29200 is associated with reactions: {CHRM_h}
# AT1G69370 is associated with reactions: {CHRM_h}
# AT1G11790 is associated with reactions: {AGNDA_h}
# AT5G22630 is associated with reactions: {AGNDA_h}
# AT1G08250 is associated with reactions: {AGNDA_h}
# AT2G27820 is associated with reactions: {AGNDA_h}
# AT3G44720 is associated with reactions: {AGNDA_h}
# AT3G07630 is associated with reactions: {AGNDA_h}
# AT4G08870 is associated with reactions: {Arginase_m}
# AT4G08900 is associated with reactions: {Arginase_m}
# AT1G67550 is associated with reactions: {Urease_m}
# AT5G46180 is associated with reactions: {OrnAT_m}
# AT2G39800 is associated with reactions: {GluSeADH_c, GluSeADH_m, GluSeADH_h, GluK_c, GluK_m, GluK_h}
# AT3G55610 is associated with reactions: {GluSeADH_c, GluSeADH_m, GluSeADH_h, GluK_c, GluK_m, GluK_h}
# AT5G14800 is associated with reactions: {P5CRNAD_c}
# AT3G30775 is associated with reactions: {ProDHNAD_m, ProDHNADP_m}
# AT5G38710 is associated with reactions: {ProDHNAD_m, ProDHNADP_m}
# AT5G62530 is associated with reactions: {P5CDHNAD_h, P5CDHNAD_m, P5CDHNADP_m, P5CDHNADP_h}
# AT4G34200 is associated with reactions: {PGADH_h}
# AT1G17745 is associated with reactions: {PGADH_h}
# AT3G19480 is associated with reactions: {PGADH_h}
# AT2G17630 is associated with reactions: {PSerAT_h}
# AT4G35630 is associated with reactions: {PSerAT_h}
# AT1G18640 is associated with reactions: {PSerP_h}
# AT4G11640 is associated with reactions: {SerRM_c}
# AT1G72810 is associated with reactions: {ThrS_h}
# AT4G29840 is associated with reactions: {ThrS_h}
# AT1G25220 is associated with reactions: {ANTS_h}
# AT5G57890 is associated with reactions: {ANTS_h}
# AT2G29690 is associated with reactions: {ANTS_h}
# AT5G05730 is associated with reactions: {ANTS_h}
# AT5G17990 is associated with reactions: {ANTPRT_h}
# AT5G05590 is associated with reactions: {PRANTI_h}
# AT1G07780 is associated with reactions: {PRANTI_h}
# AT1G29410 is associated with reactions: {PRANTI_h}
# AT5G48220 is associated with reactions: {IndGPS_h}
# AT2G04400 is associated with reactions: {IndGPS_h}
# AT3G54640 is associated with reactions: {IndGPL_h}
# AT4G02610 is associated with reactions: {IndGPL_h}
# AT5G54810 is associated with reactions: {TrpS_h}
# AT4G27070 is associated with reactions: {TrpS_h}
# AT5G34920 is associated with reactions: {AGNDH_h}
# AT1G15710 is associated with reactions: {AGNDH_h}
# AT2G16570 is associated with reactions: {ATase_h}
# AT4G34740 is associated with reactions: {ATase_h}
# AT4G38880 is associated with reactions: {ATase_h}
# AT1G09830 is associated with reactions: {PRAGlyL_h}
# AT1G31220 is associated with reactions: {GARFT_h}
# AT1G74260 is associated with reactions: {FGAMS_h}
# AT3G55010 is associated with reactions: {FGAMCL_h}
# AT2G37690 is associated with reactions: {AIRC_h}
# AT3G21110 is associated with reactions: {SAICARS_h}
# AT1G36280 is associated with reactions: {DCAMPL1_h, DCAMPL2_h}
# AT4G18440 is associated with reactions: {DCAMPL1_h, DCAMPL2_h}
# AT2G35040 is associated with reactions: {AICARFT_h, IMPCH_h}
# AT2G38280 is associated with reactions: {AMPDA_c}
# AT1G79470 is associated with reactions: {IMPDH_c}
# AT1G16350 is associated with reactions: {IMPDH_c}
# AT1G63660 is associated with reactions: {GMPS_c}
# AT3G57610 is associated with reactions: {DCAMPS_h}
# AT3G20330 is associated with reactions: {AspCT_h}
# AT4G22930 is associated with reactions: {DHOase_h}
# AT5G23300 is associated with reactions: {DHODH_m}
# AT3G54470 is associated with reactions: {OROPRT_c, OMPDC_c}
# AT4G02120 is associated with reactions: {CTPS_c}
# AT1G30820 is associated with reactions: {CTPS_c}
# AT4G20320 is associated with reactions: {CTPS_c}
# AT3G12670 is associated with reactions: {CTPS_c}
# AT2G34890 is associated with reactions: {CTPS_c}
# AT2G37250 is associated with reactions: {AMPK_c, AMPK_h}
# AT5G63400 is associated with reactions: {AMPK_c}
# AT5G50370 is associated with reactions: {AMPK_c}
# AT5G60340 is associated with reactions: {AMPK_c}
# AT5G35170 is associated with reactions: {AMPK_h}
# AT2G39270 is associated with reactions: {AMPK_h}
# AT5G47840 is associated with reactions: {AMPK_h}
# AT3G57550 is associated with reactions: {GMPK_c}
# AT3G06200 is associated with reactions: {GMPK_c}
# AT2G41880 is associated with reactions: {GMPK_c}
# AT3G600180 is associated with reactions: {NMPK_c}
# AT5G26667 is associated with reactions: {NMPK_c}
# AT1G14240 is associated with reactions: {CTPP_c}
# AT1G14250 is associated with reactions: {CTPP_c}
# AT3G04080 is associated with reactions: {CTPP_c}
# AT1G14230 is associated with reactions: {CTPP_c}
# AT4G19180 is associated with reactions: {CTPP_c}
# AT2G02970 is associated with reactions: {CTPP_c}
# AT3G23580 is associated with reactions: {ADPR_c, UDPR_c, GDPR_c, CDPR_c}
# AT2G21790 is associated with reactions: {ADPR_c, UDPR_c, GDPR_c, CDPR_c}
# AT3G27060 is associated with reactions: {ADPR_c, UDPR_c, GDPR_c, CDPR_c}
# AT4G13720 is associated with reactions: {dUTPP_c}
# AT3G46940 is associated with reactions: {dUTPP_c}
# AT5G59440 is associated with reactions: {dTMPK_c}
# AT4G23895 is associated with reactions: {UDPK_c, dCDPK_c, dADPK_c, dTDPK_c, GDPK_c, dGDPK_c, dUDPK_c}
# AT5G63310 is associated with reactions: {GDPK_h, dTDPK_c, UDPK_c, dCDPK_c, dADPK_c, GDPK_c, dGDPK_c, dUDPK_c}
# AT4G09320 is associated with reactions: {GDPK_h, dTDPK_c, UDPK_c, dCDPK_c, dADPK_c, GDPK_c, dGDPK_c, dUDPK_c}
# AT4G11010 is associated with reactions: {GDPK_h, dTDPK_c, UDPK_c, dCDPK_c, dADPK_c, GDPK_c, dGDPK_c, dUDPK_c}
# AT4G23900 is associated with reactions: {GDPK_h, dTDPK_c, UDPK_c, dCDPK_c, dADPK_c, GDPK_c, dGDPK_c, dUDPK_c}
# AT4G02700 is associated with reactions: {Tr_SO4}
# AT3G51895 is associated with reactions: {Tr_SO4}
# AT5G13550 is associated with reactions: {Tr_SO4}
# AT1G68570 is associated with reactions: {Tr_NO2}
# AT1G80300 is associated with reactions: {Tr_NTT}
# AT1G15500 is associated with reactions: {Tr_NTT}
# AT4G28390 is associated with reactions: {Tr_AAC}
# AT3G08580 is associated with reactions: {Tr_AAC}
# AT5G14490 is associated with reactions: {Tr_AAC}
# AT4G01100 is associated with reactions: {Tr_AAC}
# AT4G32400 is associated with reactions: {Tr_BT13, Tr_BT11, Tr_BT12}
# AT2G47490 is associated with reactions: {Tr_NDT1, Tr_NDT2}
# AT1G25380 is associated with reactions: {Tr_NDT1, Tr_NDT2}
# AT5G17630 is associated with reactions: {Tr_TPT1, Tr_TPT2, Tr_TPT3}
# AT5G54800 is associated with reactions: {Tr_TPT1, Tr_GPT1, Tr_TPT2, Tr_TPT3}
# AT1G61800 is associated with reactions: {Tr_TPT1, Tr_GPT1, Tr_TPT2, Tr_TPT3}
# AT3G01550 is associated with reactions: {Tr_PPT}
# AT5G33320 is associated with reactions: {Tr_PPT}
# AT1G32080 is associated with reactions: {Tr_GCEA1, Tr_GCA1}
# AT5G16150 is associated with reactions: {Tr_pGlc}
# AT5G17520 is associated with reactions: {Tr_Mex1}
# AT3G18830 is associated with reactions: {Tr_PLT5}
# AT5G09470 is associated with reactions: {Tr_DIC1, Tr_DIC2, Tr_DIC4}
# AT2G22500 is associated with reactions: {Tr_DIC1, Tr_DIC2, Tr_DIC4}
# AT4G24570 is associated with reactions: {Tr_DIC1, Tr_DIC2, Tr_DIC4}
# AT5G12860 is associated with reactions: {Tr_DIT1_OAA, Tr_DIT1}
# AT5G64290 is associated with reactions: {Tr_DIT2}
# AT5G64280 is associated with reactions: {Tr_DIT2, Tr_Asp_OAA_hc}
# AT5G19760 is associated with reactions: {Tr_UCP, Tr_DTC3C, Tr_DTC5, Tr_DTC1A, Tr_DTC2C, Tr_DTC2A, Tr_DTC4A, Tr_DTC3A, Tr_DTC4B, Tr_DTC1B, Tr_DTC2B, Tr_DTC3B, Tr_DTC1C, Tr_DTC4C}
# AT5G01340 is associated with reactions: {Tr_SFC}
# AT2G01170 is associated with reactions: {}
# AT1G79900 is associated with reactions: {Tr_BAC2, Tr_BAC1}
# AT2G33820 is associated with reactions: {Tr_BAC2, Tr_BAC1}
# AT2G26900 is associated with reactions: {Tr_Pyr_Na_hc}
# AT4G05590 is associated with reactions: {Tr_Pyr2}
# AT4G14695 is associated with reactions: {Tr_Pyr2}
# AT5G20090 is associated with reactions: {Tr_Pyr2}
# AT4G22310 is associated with reactions: {Tr_Pyr2}
# AT2G38060 is associated with reactions: {Tr_Pi}
# AT3G46980 is associated with reactions: {Tr_Pi}
# AT5G20380 is associated with reactions: {Tr_Pi}
# AT3G26570 is associated with reactions: {Tr_Pi}
# AT4G00370 is associated with reactions: {Tr_Pi}
# AT3G19490 is associated with reactions: {Tr_H_Na_hc}
# AT2G32040 is associated with reactions: {Tr_THF}
# AT5G66380 is associated with reactions: {Tr_THF}
# AT5G14040 is associated with reactions: {Tr_PIC}
# AT3G48850 is associated with reactions: {Tr_PIC}
# AT3G54110 is associated with reactions: {Tr_UCP}
# AT5G58970 is associated with reactions: {Tr_UCP}
# AT2G39970 is associated with reactions: {Tr_PXN3}
# AT4G28220 is associated with reactions: {NDA2_2_m, NDA2_1_m}
# AT1G07180 is associated with reactions: {NDA2_2_m, NDA2_1_m}
# AT2G29990 is associated with reactions: {NDA2_2_m, NDA2_1_m}
# AT5G08740 is associated with reactions: {NDA2_2_m, NDA2_1_m, NDC1_2_h, NDC1_1_h}
# AT4G05020 is associated with reactions: {NDA2_2_m, NDA2_1_m}
# AT2G20800 is associated with reactions: {NDA2_2_m, NDA2_1_m}
# AT4G21490 is associated with reactions: {NDA2_2_m, NDA2_1_m}
# AT3G22370 is associated with reactions: {AOX1A_m}
# AT3G27620 is associated with reactions: {AOX1A_m}
# AT5G64210 is associated with reactions: {AOX1A_m}
# AT1G32350 is associated with reactions: {AOX1A_m}
# AT3G22360 is associated with reactions: {AOX1A_m}
# AT4G22260 is associated with reactions: {AOX4_h}

# %%
###################################################################
################## II/ Annotate the initial model
###################################################################



###################
############ Goal : Introducing new annotations to the initial model => Get as many BIGG/ModelSEED Ids based for the reactions
############ The plan is to extract the kegg_ids from the annotation of the AraCore model and to extract the kegg_ids from the 
############ BIGG reaction table. After that the kegg_id columns in the two resulting dataframes for the arcore model and bigg 
############ can be used to perform the mapping. (Similar approach for ModelSeed).
###################



# (1) Get the KEGG ids that are given in the annotation of our model 
# (2) Import the bigg_models_reactions.txt as a pandas table in python
# (3) the pandas table will have a column 'database_links', which provides in text format serveral urls to external databases.
# (4) We need to parse the column 'database_links' to get the KEGG url (it will probably start with 
# http://identifiers.org/kegg/ and continue with the KEGG reactions id. 
# -> We may want to use df['kegg_urls'] = df['database_links'].apply(lambda x: myfun(x)), my_fun(x) needs to convert the string
# of urls into a list of url, and than extract the url that starts with  http://identifiers.org/kegg/
# (5) So after we grabbed the correct url, we need to extract the KEGG reactions id from the url and put them into a new 
# column
# df['kegg_ids'] = df['kegg_urls'].split(....)



############
### 1st step : Get the KEGG ids that are given in the annotation of our model
############


fileName = datadir
model = cobra.io.read_sbml_model(fileName)
df_mapping_table_reactions = pd.DataFrame(
    {
        "IDs" : [x.id for x in model.reactions],
        "Name" : [x.name for x in model.reactions],
        "Annotations" : [x.annotation for x in model.reactions]
    })
df_mapping_table_reactions # mapping table
# Out:
#                IDs                                               Name  \
# 0           PSII_h                                     photosystem II
# 1        Cytb6f1_h                              cytochrom b6f complex
# 2        Cytb6f2_h                              cytochrom b6f complex
# 3     PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4     PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# ..             ...                                                ...
# 567   Tr_KG_Mal_mc                                       Tr_KG_Mal_mc
# 568      Tr_Asp_mc                                          Tr_Asp_mc
# 569  Tr_Asp_Glu_mc                                      Tr_Asp_Glu_mc
# 570  Tr_Pyr_Mal_hc                                    R_Tr_Pyr_Mal_hc
# 571      Tr_Ala_mc                                        R_Tr_Ala_mc
#
#                                            Annotations
# 0    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 1    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 2    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 3    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# 4    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# ..                                                 ...
# 567                               {'go': 'GO:0006810'}
# 568                               {'go': 'GO:0006810'}
# 569                               {'go': 'GO:0006810'}
# 570                               {'go': 'GO:0006810'}
# 571                               {'go': 'GO:0006810'}
#
# [572 rows x 3 columns]

# %%
df_mapping_table_reactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   IDs          572 non-null    object
#  1   Name         572 non-null    object
#  2   Annotations  572 non-null    object
# dtypes: object(3)
# memory usage: 13.5+ KB

# %%
df_mapping_table_reactions_no_index = df_mapping_table_reactions.set_index('IDs')
df_mapping_table_reactions_no_index
# Out:
#                                                             Name  \
# IDs
# PSII_h                                            photosystem II
# Cytb6f1_h                                  cytochrom b6f complex
# Cytb6f2_h                                  cytochrom b6f complex
# PGR5PGRL11_h   proton gradient regulation 5 (PGR5)/PGR5-like ...
# PGR5PGRL12_h   proton gradient regulation 5 (PGR5)/PGR5-like ...
# ...                                                          ...
# Tr_KG_Mal_mc                                        Tr_KG_Mal_mc
# Tr_Asp_mc                                              Tr_Asp_mc
# Tr_Asp_Glu_mc                                      Tr_Asp_Glu_mc
# Tr_Pyr_Mal_hc                                    R_Tr_Pyr_Mal_hc
# Tr_Ala_mc                                            R_Tr_Ala_mc
#
#                                                      Annotations
# IDs
# PSII_h         {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Cytb6f1_h      {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Cytb6f2_h      {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# PGR5PGRL11_h   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# PGR5PGRL12_h   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# ...                                                          ...
# Tr_KG_Mal_mc                                {'go': 'GO:0006810'}
# Tr_Asp_mc                                   {'go': 'GO:0006810'}
# Tr_Asp_Glu_mc                               {'go': 'GO:0006810'}
# Tr_Pyr_Mal_hc                               {'go': 'GO:0006810'}
# Tr_Ala_mc                                   {'go': 'GO:0006810'}
#
# [572 rows x 2 columns]

# %%
# Save the mapping table as a CSV file with IDs as index
df_mapping_table_reactions_no_index.to_csv("../data/processed/2021-05-29-CA-reactions-mapping-table1-output.csv")

# %%
df_mapping_table_reactions.shape
# Out:
# (572, 3)

# %%
df_mapping_table_reactions.loc[:,"Annotations"]
# Out:
# 0      {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 1      {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 2      {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 3      {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# 4      {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
#                              ...
# 567                                 {'go': 'GO:0006810'}
# 568                                 {'go': 'GO:0006810'}
# 569                                 {'go': 'GO:0006810'}
# 570                                 {'go': 'GO:0006810'}
# 571                                 {'go': 'GO:0006810'}
# Name: Annotations, Length: 572, dtype: object

# %%
# Function to get kegg_ids from dictionary in annotation column
def apply_split_annotations(dict_anno):
    if 'kegg.reaction' in dict_anno.keys():
        kegg_id = dict_anno['kegg.reaction']
    else:
        kegg_id = '' # False, np.nan, because, if we have another dataframe, the type of the data would be different
    return kegg_id
#apply_split_annotations(df_mapping_table_reactions)
# Out:
# ''

# %%
df_mapping_table_reactions["kegg_id"] = df_mapping_table_reactions["Annotations"].apply(lambda dict_anno:apply_split_annotations(dict_anno))
# I write where I want to apply the apply() function and on which dataframe, then I write the lambda function = function defined on one line
# x is the variable on which I want to apply the lambda function
# The apply() function applies the function to every row of the dataframe
# => more efficient than for loops or while ones when we have big dataframes
# After that, we correct the function we have defined before : apply_split_annotation() here : for loop for example
# Lambda function : we define a function which takes dict_anno as parameter; then, we write the function we defined just before,
# including the parameter of interest (here, dict_anno)
# Written equivalent : df_mapping_table_reactions["kegg_id"] = df_mapping_table_reactions["Annotations"].apply(apply_split_annotations)
# => Here, we pass the function itself in parameter
df_mapping_table_reactions
# Out:
#                IDs                                               Name  \
# 0           PSII_h                                     photosystem II
# 1        Cytb6f1_h                              cytochrom b6f complex
# 2        Cytb6f2_h                              cytochrom b6f complex
# 3     PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4     PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# ..             ...                                                ...
# 567   Tr_KG_Mal_mc                                       Tr_KG_Mal_mc
# 568      Tr_Asp_mc                                          Tr_Asp_mc
# 569  Tr_Asp_Glu_mc                                      Tr_Asp_Glu_mc
# 570  Tr_Pyr_Mal_hc                                    R_Tr_Pyr_Mal_hc
# 571      Tr_Ala_mc                                        R_Tr_Ala_mc
#
#                                            Annotations kegg_id
# 0    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  R09503
# 1    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  R03817
# 2    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  R03817
# 3    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...  R03817
# 4    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...  R03817
# ..                                                 ...     ...
# 567                               {'go': 'GO:0006810'}
# 568                               {'go': 'GO:0006810'}
# 569                               {'go': 'GO:0006810'}
# 570                               {'go': 'GO:0006810'}
# 571                               {'go': 'GO:0006810'}
#
# [572 rows x 4 columns]

# %%
############
### 2nd step : Import the bigg_models_reactions.txt as a pandas table in python
############

bigg_models_reactions = pd.read_csv('../data/external/bigg_models_reactions.txt', sep = "\t")
bigg_models_reactions.head()
# Out:
#                           bigg_id  \
# 0                     DM_4crsol_c
# 1                     DM_aacald_c
# 2                       DM_amob_c
# 3  BIOMASS_Ec_iJO1366_core_53p95M
# 4                   EX_12ppd__S_e
#
#                                                 name  \
# 0      Sink needed to allow p-Cresol to leave system
# 1  Sink needed to allow aminoacetaldehyde to leav...
# 2  Sink needed to allow S-Adenosyl-4-methylthio-2...
# 3  E. coli biomass objective function (iJO1366) -...
# 4                      (S)-Propane-1,2-diol exchange
#
#                                      reaction_string  \
# 0                                      4crsol_c <->
# 1                                      aacald_c <->
# 2                                        amob_c <->
# 3  0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223...
# 4                                    12ppd__S_e <->
#
#                                           model_list  \
# 0  iEcDH1_1363; iJO1366; iE2348C_1286; iECB_1328;...
# 1  iECB_1328; iBWG_1329; iE2348C_1286; iECBD_1354...
# 2  iECNA114_1301; iECDH10B_1368; iECP_1309; iECIA...
# 3  iZ_1308; iWFL_1372; iUTI89_1310; iUMNK88_1353;...
# 4  iECH74115_1262; iECP_1309; iECS88_1305; iECED1...
#
#                                       database_links  \
# 0  RHEA: http://identifiers.org/rhea/35071; RHEA:...
# 1  MetaNetX (MNX) Equation: http://identifiers.or...
# 2  MetaNetX (MNX) Equation: http://identifiers.or...
# 3  MetaNetX (MNX) Equation: http://identifiers.or...
# 4  MetaNetX (MNX) Equation: http://identifiers.or...
#
#                                         old_bigg_ids
# 0                             DM_4CRSOL; DM_4crsol_c
# 1                DM_AACALD; DM_aacald_c; R_DM_AACALD
# 2                      DM_AMOB; DM_amob_c; sink_amob
# 3                     Ec_biomass_iJO1366_core_53p95M
# 4  EX_12ppd_DASH_S_LPAREN_e_RPAREN_; EX_12ppd_S_L...

# %%
bigg_models_reactions.shape
# Out:
# (28301, 6)

# %%
#############
# 3rd step : The pandas table will have a column 'database_links', which provides in text format serveral urls to external databases.
#############

# Selection of the columns of interest
bigg_database_links = bigg_models_reactions.iloc[:, 4] # WARNING ! count the number of columns from 0 !!
bigg_database_links
# Out:
# 0        RHEA: http://identifiers.org/rhea/35071; RHEA:...
# 1        MetaNetX (MNX) Equation: http://identifiers.or...
# 2        MetaNetX (MNX) Equation: http://identifiers.or...
# 3        MetaNetX (MNX) Equation: http://identifiers.or...
# 4        MetaNetX (MNX) Equation: http://identifiers.or...
#                                ...
# 28296                                                  NaN
# 28297                                                  NaN
# 28298                                                  NaN
# 28299                                                  NaN
# 28300                                                  NaN
# Name: database_links, Length: 28301, dtype: object

# %%
bigg_database_links.iloc[0]
# Out:
# 'RHEA: http://identifiers.org/rhea/35071; RHEA: http://identifiers.org/rhea/35072; RHEA: http://identifiers.org/rhea/35073; RHEA: http://identifiers.org/rhea/35074; BioCyc: http://identifiers.org/biocyc/META:TRANS-RXN0-500; MetaNetX (MNX) Equation: http://identifiers.org/metanetx.reaction/MNXR96888'

# %%
#############
# 4th step : We need to parse the column 'database_links' to get the KEGG url
#############

# it will probably start with http://identifiers.org/kegg/) and continue with the KEGG reactions id. 
# -> We may want to use df['kegg_urls'] = df['database_links'].apply(lambda x: myfun(x)), my_fun(x) needs to convert the string
# of urls into a list of url, and then extract the url that starts with  http://identifiers.org/kegg/

def parsing_database_links(line):
    if type(line) is str:
        if "http://identifiers.org/kegg" in line:
            line_splited = line.rstrip(';').split(' ') # line_splited is the list containing 
            #print(line_splited)
            for string in line_splited:
                if 'kegg' in string:
                    kegg_url = string
                    kegg_url = kegg_url.rstrip(';')
                    print(kegg_url)
                else:
                    pass
        else:
            kegg_url = None
    else:
        kegg_url = None
    return kegg_url
#parsing_database_links(bigg_database_links)

# %%
bigg_models_reactions["kegg_url"] = bigg_models_reactions["database_links"].apply(lambda line:parsing_database_links(line))
# Out:
# http://identifiers.org/kegg.reaction/R03538
# http://identifiers.org/kegg.reaction/R05135
# http://identifiers.org/kegg.reaction/R04544
# http://identifiers.org/kegg.reaction/R07764
# http://identifiers.org/kegg.reaction/R04537
# http://identifiers.org/kegg.reaction/R07127
# http://identifiers.org/kegg.reaction/R01877
# http://identifiers.org/kegg.reaction/R02148
# http://identifiers.org/kegg.reaction/R04964
# http://identifiers.org/kegg.reaction/R04543
# http://identifiers.org/kegg.reaction/R05086
# http://identifiers.org/kegg.reaction/R01530
# http://identifiers.org/kegg.reaction/R01648
# http://identifiers.org/kegg.reaction/R01177
# http://identifiers.org/kegg.reaction/R03778
# http://identifiers.org/kegg.reaction/R05222
# http://identifiers.org/kegg.reaction/R00259
# http://identifiers.org/kegg.reaction/R00226
# http://identifiers.org/kegg.reaction/R04477
# http://identifiers.org/kegg.reaction/R01811
# http://identifiers.org/kegg.reaction/R01175
# http://identifiers.org/kegg.reaction/R03857
# http://identifiers.org/kegg.reaction/R01279
# http://identifiers.org/kegg.reaction/R01624
# http://identifiers.org/kegg.reaction/R00669
# http://identifiers.org/kegg.reaction/R02244
# http://identifiers.org/kegg.reaction/R05763
# http://identifiers.org/kegg.reaction/R01010
# http://identifiers.org/kegg.reaction/R01041
# http://identifiers.org/kegg.reaction/R01138
# http://identifiers.org/kegg.reaction/R01151
# http://identifiers.org/kegg.reaction/R01280
# http://identifiers.org/kegg.reaction/R01357
# http://identifiers.org/kegg.reaction/R01414
# http://identifiers.org/kegg.reaction/R01514
# http://identifiers.org/kegg.reaction/R01139
# http://identifiers.org/kegg.reaction/R01327
# http://identifiers.org/kegg.reaction/R01330
# http://identifiers.org/kegg.reaction/R01964
# http://identifiers.org/kegg.reaction/R01965
# http://identifiers.org/kegg.reaction/R01608
# http://identifiers.org/kegg.reaction/R01855
# http://identifiers.org/kegg.reaction/R01899
# http://identifiers.org/kegg.reaction/R02037
# http://identifiers.org/kegg.reaction/R02092
# http://identifiers.org/kegg.reaction/R02095
# http://identifiers.org/kegg.reaction/R02235
# http://identifiers.org/kegg.reaction/R02236
# http://identifiers.org/kegg.reaction/R02536
# http://identifiers.org/kegg.reaction/R02743
# http://identifiers.org/kegg.reaction/R02971
# http://identifiers.org/kegg.reaction/R01104
# http://identifiers.org/kegg.reaction/R04285
# http://identifiers.org/kegg.reaction/R04639
# http://identifiers.org/kegg.reaction/R06869
# http://identifiers.org/kegg.reaction/R00124#2

# %%
bigg_models_reactions
# Out:
#                               bigg_id  \
# 0                         DM_4crsol_c
# 1                         DM_aacald_c
# 2                           DM_amob_c
# 3      BIOMASS_Ec_iJO1366_core_53p95M
# 4                       EX_12ppd__S_e
# ...                               ...
# 28296                   EX_LPS30__L_e
# 28297                         GTLOA38
# 28298                      GTGAL13RMN
# 28299              DM_LPS9_46_27_ST_p
# 28300                           OA18F
#
#                                                     name  \
# 0          Sink needed to allow p-Cresol to leave system
# 1      Sink needed to allow aminoacetaldehyde to leav...
# 2      Sink needed to allow S-Adenosyl-4-methylthio-2...
# 3      E. coli biomass objective function (iJO1366) -...
# 4                          (S)-Propane-1,2-diol exchange
# ...                                                  ...
# 28296                   Long O-antigen group O:30 export
# 28297  Lumped glycosyltransferase reactions group O:3...
# 28298                  Rhamnosyltransferase gal(a1-3)rmn
# 28299  Lipopolysaccharide with a short O-antigenconsi...
# 28300                      O antigen group O:18 flippase
#
#                                          reaction_string  \
# 0                                          4crsol_c <->
# 1                                          aacald_c <->
# 2                                            amob_c <->
# 3      0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223...
# 4                                        12ppd__S_e <->
# ...                                                  ...
# 28296                                    LPS30__L_e <->
# 28297  uacgam_c + udcdpgalnac_c + udpg_c + 2.0 udpgal...
# 28298  dtdprmn_c + udcdpgal_c <-> dtdp_c + h_c + udcd...
# 28299                               LPS9_46_27_ST_p <->
# 28300  udcdpgalnac_b1_3_man_a1_2_man_a1_2_man_c <-> u...
#
#                                               model_list  \
# 0      iEcDH1_1363; iJO1366; iE2348C_1286; iECB_1328;...
# 1      iECB_1328; iBWG_1329; iE2348C_1286; iECBD_1354...
# 2      iECNA114_1301; iECDH10B_1368; iECP_1309; iECIA...
# 3      iZ_1308; iWFL_1372; iUTI89_1310; iUMNK88_1353;...
# 4      iECH74115_1262; iECP_1309; iECS88_1305; iECED1...
# ...                                                  ...
# 28296                                            iYS1720
# 28297                                            iYS1720
# 28298                                            iYS1720
# 28299                                            iYS1720
# 28300                                            iYS1720
#
#                                           database_links  \
# 0      RHEA: http://identifiers.org/rhea/35071; RHEA:...
# 1      MetaNetX (MNX) Equation: http://identifiers.or...
# 2      MetaNetX (MNX) Equation: http://identifiers.or...
# 3      MetaNetX (MNX) Equation: http://identifiers.or...
# 4      MetaNetX (MNX) Equation: http://identifiers.or...
# ...                                                  ...
# 28296                                                NaN
# 28297                                                NaN
# 28298                                                NaN
# 28299                                                NaN
# 28300                                                NaN
#
#                                             old_bigg_ids kegg_url
# 0                                 DM_4CRSOL; DM_4crsol_c     None
# 1                    DM_AACALD; DM_aacald_c; R_DM_AACALD     None
# 2                          DM_AMOB; DM_amob_c; sink_amob     None
# 3                         Ec_biomass_iJO1366_core_53p95M     None
# 4      EX_12ppd_DASH_S_LPAREN_e_RPAREN_; EX_12ppd_S_L...     None
# ...                                                  ...      ...
# 28296                                         EX_LPS30_L     None
# 28297                                            GTLOA38     None
# 28298                                         GTGAL13RMN     None
# 28299                                   EX_LPS9_46_27_ST     None
# 28300                                              OA18F     None
#
# [28301 rows x 7 columns]

# %%
bigg_models_reactions.to_csv("../data/processed/2021-05-29-CA-reactions-mapping-table2-kegg-url-output.csv")

# %%
#############
# 5th step : So after we grabbed the correct url, we need to extract the KEGG reactions id from the url and put them into a 
# new column
#############

# df['kegg_ids'] = df['kegg_urls'].split(....)
bigg_models_reactions['kegg_ids'] = bigg_models_reactions['kegg_url'].str.split('/')
bigg_models_reactions
# Out:
#                               bigg_id  \
# 0                         DM_4crsol_c
# 1                         DM_aacald_c
# 2                           DM_amob_c
# 3      BIOMASS_Ec_iJO1366_core_53p95M
# 4                       EX_12ppd__S_e
# ...                               ...
# 28296                   EX_LPS30__L_e
# 28297                         GTLOA38
# 28298                      GTGAL13RMN
# 28299              DM_LPS9_46_27_ST_p
# 28300                           OA18F
#
#                                                     name  \
# 0          Sink needed to allow p-Cresol to leave system
# 1      Sink needed to allow aminoacetaldehyde to leav...
# 2      Sink needed to allow S-Adenosyl-4-methylthio-2...
# 3      E. coli biomass objective function (iJO1366) -...
# 4                          (S)-Propane-1,2-diol exchange
# ...                                                  ...
# 28296                   Long O-antigen group O:30 export
# 28297  Lumped glycosyltransferase reactions group O:3...
# 28298                  Rhamnosyltransferase gal(a1-3)rmn
# 28299  Lipopolysaccharide with a short O-antigenconsi...
# 28300                      O antigen group O:18 flippase
#
#                                          reaction_string  \
# 0                                          4crsol_c <->
# 1                                          aacald_c <->
# 2                                            amob_c <->
# 3      0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223...
# 4                                        12ppd__S_e <->
# ...                                                  ...
# 28296                                    LPS30__L_e <->
# 28297  uacgam_c + udcdpgalnac_c + udpg_c + 2.0 udpgal...
# 28298  dtdprmn_c + udcdpgal_c <-> dtdp_c + h_c + udcd...
# 28299                               LPS9_46_27_ST_p <->
# 28300  udcdpgalnac_b1_3_man_a1_2_man_a1_2_man_c <-> u...
#
#                                               model_list  \
# 0      iEcDH1_1363; iJO1366; iE2348C_1286; iECB_1328;...
# 1      iECB_1328; iBWG_1329; iE2348C_1286; iECBD_1354...
# 2      iECNA114_1301; iECDH10B_1368; iECP_1309; iECIA...
# 3      iZ_1308; iWFL_1372; iUTI89_1310; iUMNK88_1353;...
# 4      iECH74115_1262; iECP_1309; iECS88_1305; iECED1...
# ...                                                  ...
# 28296                                            iYS1720
# 28297                                            iYS1720
# 28298                                            iYS1720
# 28299                                            iYS1720
# 28300                                            iYS1720
#
#                                           database_links  \
# 0      RHEA: http://identifiers.org/rhea/35071; RHEA:...
# 1      MetaNetX (MNX) Equation: http://identifiers.or...
# 2      MetaNetX (MNX) Equation: http://identifiers.or...
# 3      MetaNetX (MNX) Equation: http://identifiers.or...
# 4      MetaNetX (MNX) Equation: http://identifiers.or...
# ...                                                  ...
# 28296                                                NaN
# 28297                                                NaN
# 28298                                                NaN
# 28299                                                NaN
# 28300                                                NaN
#
#                                             old_bigg_ids kegg_url kegg_ids
# 0                                 DM_4CRSOL; DM_4crsol_c     None     None
# 1                    DM_AACALD; DM_aacald_c; R_DM_AACALD     None     None
# 2                          DM_AMOB; DM_amob_c; sink_amob     None     None
# 3                         Ec_biomass_iJO1366_core_53p95M     None     None
# 4      EX_12ppd_DASH_S_LPAREN_e_RPAREN_; EX_12ppd_S_L...     None     None
# ...                                                  ...      ...      ...
# 28296                                         EX_LPS30_L     None     None
# 28297                                            GTLOA38     None     None
# 28298                                         GTGAL13RMN     None     None
# 28299                                   EX_LPS9_46_27_ST     None     None
# 28300                                              OA18F     None     None
#
# [28301 rows x 8 columns]

# %%
# Filter the column "kegg_ids" of the dataframe to select the ids which are not null
bigg_models_reactions_kegg_ids = bigg_models_reactions[bigg_models_reactions["kegg_ids"].notna()]
bigg_models_reactions_kegg_ids
# Out:
#         bigg_id                                               name  \
# 175    23PDE2pp  2',3'-cyclic-nucleotide phosphodiesterase (UMP...
# 176    23PDE9pp  2',3'-cyclic-nucleotide phosphodiesterase (GMP...
# 198     3HAD160  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 200     3HAD180  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 201      3HAD80  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# ...         ...                                                ...
# 21049     r0627  Galactosylglycerol galactohydrolase Galactose ...
# 21057     r0673  6-Lactoyl-5,6,7,8-tetrahydropterin:NADP+ 2-oxi...
# 21058     r0708  2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxyp...
# 21072     r0789  S-Adenosyl-L-methionine:phosphodimethylethanol...
# 21085     r0860                                 Utilized transport
#
#                                       reaction_string  \
# 175                 23cump_p + h2o_p <-> 3ump_p + h_p
# 176                 23cgmp_p + h2o_p <-> 3gmp_p + h_p
# 198              3hpalmACP_c <-> h2o_c + tpalm2eACP_c
# 200              3hoctaACP_c <-> h2o_c + toctd2eACP_c
# 201                3hoctACP_c <-> h2o_c + toct2eACP_c
# ...                                               ...
# 21049            HC01444_e + h2o_e <-> gal_e + glyc_e
# 21057  6pthp_c + h_c + nadph_c <-> HC01254_c + nadp_c
# 21058          ahdt_c + h2o_c + 4.0 h_c <-> HC01710_c
# 21072        HC01842_c + amet_c <-> ahcys_c + cholp_c
# 21085                 adp_c + atp_x <-> adp_x + atp_c
#
#                                               model_list  \
# 175    iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC135...
# 176    iEcHS_1320; iEcE24377_1341; iECS88_1305; iECOK...
# 198    iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iSynCJ...
# 200    iSFV_1184; iSbBS512_1146; iECUMN_1333; iECSP_1...
# 201    iAF1260; iECDH1ME8569_1439; iPC815; iJN746; iA...
# ...                                                  ...
# 21049                       iCHOv1_DG44; Recon3D; iCHOv1
# 21057                                    iCHOv1; Recon3D
# 21058                                             iCHOv1
# 21072                       Recon3D; iCHOv1_DG44; iCHOv1
# 21085                       Recon3D; iCHOv1_DG44; iCHOv1
#
#                                           database_links       old_bigg_ids  \
# 175    RHEA: http://identifiers.org/rhea/27878; RHEA:...           23PDE2pp
# 176    RHEA: http://identifiers.org/rhea/27858; RHEA:...           23PDE9pp
# 198    EC Number: http://identifiers.org/ec-code/2.3....  3HAD160; _3HAD160
# 200    EC Number: http://identifiers.org/ec-code/2.3....  3HAD180; _3HAD180
# 201    EC Number: http://identifiers.org/ec-code/2.3....    3HAD80; _3HAD80
# ...                                                  ...                ...
# 21049  EC Number: http://identifiers.org/ec-code/3.2....              r0627
# 21057  EC Number: http://identifiers.org/ec-code/1.1....              r0673
# 21058  EC Number: http://identifiers.org/ec-code/3.5....              r0708
# 21072  EC Number: http://identifiers.org/ec-code/2.1....              r0789
# 21085  EC Number: http://identifiers.org/ec-code/2.7....              r0860
#
#                                             kegg_url  \
# 175      http://identifiers.org/kegg.reaction/R03538
# 176      http://identifiers.org/kegg.reaction/R05135
# 198      http://identifiers.org/kegg.reaction/R04544
# 200      http://identifiers.org/kegg.reaction/R07764
# 201      http://identifiers.org/kegg.reaction/R04537
# ...                                              ...
# 21049    http://identifiers.org/kegg.reaction/R01104
# 21057    http://identifiers.org/kegg.reaction/R04285
# 21058    http://identifiers.org/kegg.reaction/R04639
# 21072    http://identifiers.org/kegg.reaction/R06869
# 21085  http://identifiers.org/kegg.reaction/R00124#2
#
#                                                 kegg_ids
# 175    [http:, , identifiers.org, kegg.reaction, R03538]
# 176    [http:, , identifiers.org, kegg.reaction, R05135]
# 198    [http:, , identifiers.org, kegg.reaction, R04544]
# 200    [http:, , identifiers.org, kegg.reaction, R07764]
# 201    [http:, , identifiers.org, kegg.reaction, R04537]
# ...                                                  ...
# 21049  [http:, , identifiers.org, kegg.reaction, R01104]
# 21057  [http:, , identifiers.org, kegg.reaction, R04285]
# 21058  [http:, , identifiers.org, kegg.reaction, R04639]
# 21072  [http:, , identifiers.org, kegg.reaction, R06869]
# 21085  [http:, , identifiers.org, kegg.reaction, R001...
#
# [2749 rows x 8 columns]

# %%
# The split() seems to work
# We will take the last element of each line, e.g. the kegg id
def last_element_kegg_id(l):
    if l is not None:
        kegg_id = l[-1]
    else:
        kegg_id = None
    return kegg_id

# %%
bigg_models_reactions["kegg_ids_test"] = bigg_models_reactions["kegg_ids"].apply(lambda l:last_element_kegg_id(l))
bigg_models_reactions
# Out:
#                               bigg_id  \
# 0                         DM_4crsol_c
# 1                         DM_aacald_c
# 2                           DM_amob_c
# 3      BIOMASS_Ec_iJO1366_core_53p95M
# 4                       EX_12ppd__S_e
# ...                               ...
# 28296                   EX_LPS30__L_e
# 28297                         GTLOA38
# 28298                      GTGAL13RMN
# 28299              DM_LPS9_46_27_ST_p
# 28300                           OA18F
#
#                                                     name  \
# 0          Sink needed to allow p-Cresol to leave system
# 1      Sink needed to allow aminoacetaldehyde to leav...
# 2      Sink needed to allow S-Adenosyl-4-methylthio-2...
# 3      E. coli biomass objective function (iJO1366) -...
# 4                          (S)-Propane-1,2-diol exchange
# ...                                                  ...
# 28296                   Long O-antigen group O:30 export
# 28297  Lumped glycosyltransferase reactions group O:3...
# 28298                  Rhamnosyltransferase gal(a1-3)rmn
# 28299  Lipopolysaccharide with a short O-antigenconsi...
# 28300                      O antigen group O:18 flippase
#
#                                          reaction_string  \
# 0                                          4crsol_c <->
# 1                                          aacald_c <->
# 2                                            amob_c <->
# 3      0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223...
# 4                                        12ppd__S_e <->
# ...                                                  ...
# 28296                                    LPS30__L_e <->
# 28297  uacgam_c + udcdpgalnac_c + udpg_c + 2.0 udpgal...
# 28298  dtdprmn_c + udcdpgal_c <-> dtdp_c + h_c + udcd...
# 28299                               LPS9_46_27_ST_p <->
# 28300  udcdpgalnac_b1_3_man_a1_2_man_a1_2_man_c <-> u...
#
#                                               model_list  \
# 0      iEcDH1_1363; iJO1366; iE2348C_1286; iECB_1328;...
# 1      iECB_1328; iBWG_1329; iE2348C_1286; iECBD_1354...
# 2      iECNA114_1301; iECDH10B_1368; iECP_1309; iECIA...
# 3      iZ_1308; iWFL_1372; iUTI89_1310; iUMNK88_1353;...
# 4      iECH74115_1262; iECP_1309; iECS88_1305; iECED1...
# ...                                                  ...
# 28296                                            iYS1720
# 28297                                            iYS1720
# 28298                                            iYS1720
# 28299                                            iYS1720
# 28300                                            iYS1720
#
#                                           database_links  \
# 0      RHEA: http://identifiers.org/rhea/35071; RHEA:...
# 1      MetaNetX (MNX) Equation: http://identifiers.or...
# 2      MetaNetX (MNX) Equation: http://identifiers.or...
# 3      MetaNetX (MNX) Equation: http://identifiers.or...
# 4      MetaNetX (MNX) Equation: http://identifiers.or...
# ...                                                  ...
# 28296                                                NaN
# 28297                                                NaN
# 28298                                                NaN
# 28299                                                NaN
# 28300                                                NaN
#
#                                             old_bigg_ids kegg_url kegg_ids  \
# 0                                 DM_4CRSOL; DM_4crsol_c     None     None
# 1                    DM_AACALD; DM_aacald_c; R_DM_AACALD     None     None
# 2                          DM_AMOB; DM_amob_c; sink_amob     None     None
# 3                         Ec_biomass_iJO1366_core_53p95M     None     None
# 4      EX_12ppd_DASH_S_LPAREN_e_RPAREN_; EX_12ppd_S_L...     None     None
# ...                                                  ...      ...      ...
# 28296                                         EX_LPS30_L     None     None
# 28297                                            GTLOA38     None     None
# 28298                                         GTGAL13RMN     None     None
# 28299                                   EX_LPS9_46_27_ST     None     None
# 28300                                              OA18F     None     None
#
#       kegg_ids_test
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 28296          None
# 28297          None
# 28298          None
# 28299          None
# 28300          None
#
# [28301 rows x 9 columns]

# %%
bigg_models_reactions_kegg_ids_test = bigg_models_reactions[bigg_models_reactions["kegg_ids_test"].notna()]
bigg_models_reactions_kegg_ids_test
# Out:
#         bigg_id                                               name  \
# 175    23PDE2pp  2',3'-cyclic-nucleotide phosphodiesterase (UMP...
# 176    23PDE9pp  2',3'-cyclic-nucleotide phosphodiesterase (GMP...
# 198     3HAD160  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 200     3HAD180  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 201      3HAD80  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# ...         ...                                                ...
# 21049     r0627  Galactosylglycerol galactohydrolase Galactose ...
# 21057     r0673  6-Lactoyl-5,6,7,8-tetrahydropterin:NADP+ 2-oxi...
# 21058     r0708  2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxyp...
# 21072     r0789  S-Adenosyl-L-methionine:phosphodimethylethanol...
# 21085     r0860                                 Utilized transport
#
#                                       reaction_string  \
# 175                 23cump_p + h2o_p <-> 3ump_p + h_p
# 176                 23cgmp_p + h2o_p <-> 3gmp_p + h_p
# 198              3hpalmACP_c <-> h2o_c + tpalm2eACP_c
# 200              3hoctaACP_c <-> h2o_c + toctd2eACP_c
# 201                3hoctACP_c <-> h2o_c + toct2eACP_c
# ...                                               ...
# 21049            HC01444_e + h2o_e <-> gal_e + glyc_e
# 21057  6pthp_c + h_c + nadph_c <-> HC01254_c + nadp_c
# 21058          ahdt_c + h2o_c + 4.0 h_c <-> HC01710_c
# 21072        HC01842_c + amet_c <-> ahcys_c + cholp_c
# 21085                 adp_c + atp_x <-> adp_x + atp_c
#
#                                               model_list  \
# 175    iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC135...
# 176    iEcHS_1320; iEcE24377_1341; iECS88_1305; iECOK...
# 198    iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iSynCJ...
# 200    iSFV_1184; iSbBS512_1146; iECUMN_1333; iECSP_1...
# 201    iAF1260; iECDH1ME8569_1439; iPC815; iJN746; iA...
# ...                                                  ...
# 21049                       iCHOv1_DG44; Recon3D; iCHOv1
# 21057                                    iCHOv1; Recon3D
# 21058                                             iCHOv1
# 21072                       Recon3D; iCHOv1_DG44; iCHOv1
# 21085                       Recon3D; iCHOv1_DG44; iCHOv1
#
#                                           database_links       old_bigg_ids  \
# 175    RHEA: http://identifiers.org/rhea/27878; RHEA:...           23PDE2pp
# 176    RHEA: http://identifiers.org/rhea/27858; RHEA:...           23PDE9pp
# 198    EC Number: http://identifiers.org/ec-code/2.3....  3HAD160; _3HAD160
# 200    EC Number: http://identifiers.org/ec-code/2.3....  3HAD180; _3HAD180
# 201    EC Number: http://identifiers.org/ec-code/2.3....    3HAD80; _3HAD80
# ...                                                  ...                ...
# 21049  EC Number: http://identifiers.org/ec-code/3.2....              r0627
# 21057  EC Number: http://identifiers.org/ec-code/1.1....              r0673
# 21058  EC Number: http://identifiers.org/ec-code/3.5....              r0708
# 21072  EC Number: http://identifiers.org/ec-code/2.1....              r0789
# 21085  EC Number: http://identifiers.org/ec-code/2.7....              r0860
#
#                                             kegg_url  \
# 175      http://identifiers.org/kegg.reaction/R03538
# 176      http://identifiers.org/kegg.reaction/R05135
# 198      http://identifiers.org/kegg.reaction/R04544
# 200      http://identifiers.org/kegg.reaction/R07764
# 201      http://identifiers.org/kegg.reaction/R04537
# ...                                              ...
# 21049    http://identifiers.org/kegg.reaction/R01104
# 21057    http://identifiers.org/kegg.reaction/R04285
# 21058    http://identifiers.org/kegg.reaction/R04639
# 21072    http://identifiers.org/kegg.reaction/R06869
# 21085  http://identifiers.org/kegg.reaction/R00124#2
#
#                                                 kegg_ids kegg_ids_test
# 175    [http:, , identifiers.org, kegg.reaction, R03538]        R03538
# 176    [http:, , identifiers.org, kegg.reaction, R05135]        R05135
# 198    [http:, , identifiers.org, kegg.reaction, R04544]        R04544
# 200    [http:, , identifiers.org, kegg.reaction, R07764]        R07764
# 201    [http:, , identifiers.org, kegg.reaction, R04537]        R04537
# ...                                                  ...           ...
# 21049  [http:, , identifiers.org, kegg.reaction, R01104]        R01104
# 21057  [http:, , identifiers.org, kegg.reaction, R04285]        R04285
# 21058  [http:, , identifiers.org, kegg.reaction, R04639]        R04639
# 21072  [http:, , identifiers.org, kegg.reaction, R06869]        R06869
# 21085  [http:, , identifiers.org, kegg.reaction, R001...      R00124#2
#
# [2749 rows x 9 columns]

# %%
###################
# ModelSEED : Similar approach and method used previously for BIGG Model
###################

# (1) Get the KEGG ids that are given in the annotation of our model 
# (2) Import the bigg_models_reactions.txt as a pandas table in python
# (3) the pandas table will have a column 'database_links', which provides in text format serveral urls to external databases.
# (4) We need to parse the column 'database_links' to get the KEGG url (it will probably start with 
# http://identifiers.org/kegg/ and continue with the KEGG reactions id. 
# -> We may want to use df['kegg_urls'] = df['database_links'].apply(lambda x: myfun(x)), my_fun(x) needs to convert the string
# of urls into a list of url, and than extract the url that starts with  http://identifiers.org/kegg/
# (5) So after we grabbed the correct url, we need to extract the KEGG reactions id from the url and put them into a new 
# column
# df['kegg_ids'] = df['kegg_urls'].split(....)

# %%
# Load the ModelSEED reaction file
df_ModelSEED_reactions = pd.read_csv("2021-05-20-CA-reaction-mapping/data-databases/reactionsModelSEED.txt", sep= "\t")
df_ModelSEED_reactions.head()
# Out:
#          id abbreviation                                               name  \
# 0  rxn00001       R00004                       diphosphate phosphohydrolase
# 1  rxn00002       R00005                  urea-1-carboxylate amidohydrolase
# 2  rxn00003       R00006  pyruvate:pyruvate acetaldehydetransferase (dec...
# 3  rxn00004       R00008  4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lya...
# 4  rxn00006       R00009  hydrogen-peroxide:hydrogen-peroxide oxidoreduc...
#
#                                                 code  \
# 0  (1) cpd00001[0] + (1) cpd00012[0] <=> (2) cpd0...
# 1  (1) cpd00001[0] + (1) cpd00742[0] <=> (2) cpd0...
# 2  (1) cpd00011[0] + (1) cpd00668[0] <=> (2) cpd0...
# 3                (1) cpd02570[0] <=> (2) cpd00020[0]
# 4  (2) cpd00025[0] <=> (2) cpd00001[0] + (1) cpd0...
#
#                                        stoichiometry  is_transport  \
# 0  -1:cpd00001:0:0:"H2O";-1:cpd00012:0:0:"PPi";2:...             0
# 1  -1:cpd00001:0:0:"H2O";-3:cpd00067:0:0:"H+";-1:...             0
# 2  -1:cpd00011:0:0:"CO2";-1:cpd00668:0:0:"ALCTT";...             0
# 3  -1:cpd02570:0:0:"Parapyruvate";2:cpd00020:0:0:...             0
# 4  -2:cpd00025:0:0:"H2O2";2:cpd00001:0:0:"H2O";1:...             0
#
#                                             equation  \
# 0  (1) cpd00001[0] + (1) cpd00012[0] <=> (2) cpd0...
# 1  (1) cpd00001[0] + (3) cpd00067[0] + (1) cpd007...
# 2  (1) cpd00011[0] + (1) cpd00668[0] <= (2) cpd00...
# 3                (1) cpd02570[0] <=> (2) cpd00020[0]
# 4  (2) cpd00025[0] => (2) cpd00001[0] + (1) cpd00...
#
#                                           definition reversibility direction  \
# 0  (1) H2O[0] + (1) PPi[0] <=> (2) Phosphate[0] +...             >         =
# 1  (1) H2O[0] + (3) H+[0] + (1) Allophanate[0] =>...             >         >
# 2  (1) CO2[0] + (1) ALCTT[0] <= (2) Pyruvate[0] +...             <         <
# 3            (1) Parapyruvate[0] <=> (2) Pyruvate[0]             =         =
# 4              (2) H2O2[0] => (2) H2O[0] + (1) O2[0]             >         >
#
#    ...                                            aliases          ec_numbers  \
# 0  ...  AraCyc: INORGPYROPHOSPHAT-RXN|BiGG: IPP1; PPA;...             3.6.1.1
# 1  ...  AraCyc: ALLOPHANATE-HYDROLASE-RXN|BiGG: ALPHNH...            3.5.1.54
# 2  ...  AlgaGEM: R_R00006_c|AraGEM: R_R00006_c|BiGG: I...             2.2.1.6
# 3  ...  KEGG: R00008|Name: 4-Hydroxy-4-methyl-2-oxoglu...            4.1.3.17
# 4  ...  AraCyc: CATAL-RXN|BiGG: CAT; CATp; CTA1; CTT1|...  1.11.1.21|1.11.1.6
#
#   deltag deltagerr                                  compound_ids  status  \
# 0  -3.46      0.05           cpd00001;cpd00009;cpd00012;cpd00067      OK
# 1 -20.14      1.86  cpd00001;cpd00011;cpd00013;cpd00067;cpd00742      OK
# 2   8.27      0.90           cpd00011;cpd00020;cpd00067;cpd00668      OK
# 3   4.49      0.57                             cpd00020;cpd02570      OK
# 4 -46.06      1.64                    cpd00001;cpd00007;cpd00025      OK
#
#   is_obsolete                                    linked_reaction  \
# 0           0  rxn27946;rxn27947;rxn27948;rxn32487;rxn38157;r...
# 1           0                                  rxn30346;rxn35525
# 2           0                                  rxn30144;rxn33164
# 3           0                                                NaN
# 4           0                rxn19264;rxn22404;rxn27744;rxn31381
#
#             notes            source
# 0  GCC|HB|EQC|EQU  Primary Database
# 1     GCC|EQC|EQU  Primary Database
# 2     GCC|EQC|EQU  Primary Database
# 3     GCC|EQC|EQU  Primary Database
# 4     GCC|EQC|EQU  Primary Database
#
# [5 rows x 22 columns]

# %%
# Select the columns of interest
modelSEED_id = df_ModelSEED_reactions.iloc[:, :1]
modelSEED_id
# Out:
#              id
# 0      rxn00001
# 1      rxn00002
# 2      rxn00003
# 3      rxn00004
# 4      rxn00006
# ...         ...
# 43769  rxn48571
# 43770  rxn48572
# 43771  rxn48573
# 43772  rxn48574
# 43773  rxn48575
#
# [43774 rows x 1 columns]

# %%
df_merge_modelSEED = df_mapping_table_reactions.merge(modelSEED_id, how = 'left', left_on = 'IDs', right_on = 'id')
df_merge_modelSEED
# Out:
#                IDs                                               Name  \
# 0           PSII_h                                     photosystem II
# 1        Cytb6f1_h                              cytochrom b6f complex
# 2        Cytb6f2_h                              cytochrom b6f complex
# 3     PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4     PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# ..             ...                                                ...
# 567   Tr_KG_Mal_mc                                       Tr_KG_Mal_mc
# 568      Tr_Asp_mc                                          Tr_Asp_mc
# 569  Tr_Asp_Glu_mc                                      Tr_Asp_Glu_mc
# 570  Tr_Pyr_Mal_hc                                    R_Tr_Pyr_Mal_hc
# 571      Tr_Ala_mc                                        R_Tr_Ala_mc
#
#                                            Annotations   id
# 0    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  NaN
# 1    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  NaN
# 2    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  NaN
# 3    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...  NaN
# 4    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...  NaN
# ..                                                 ...  ...
# 567                               {'go': 'GO:0006810'}  NaN
# 568                               {'go': 'GO:0006810'}  NaN
# 569                               {'go': 'GO:0006810'}  NaN
# 570                               {'go': 'GO:0006810'}  NaN
# 571                               {'go': 'GO:0006810'}  NaN
#
# [572 rows x 4 columns]

# %%
# (1) need to find a way to get the kegg ids that are already in the annotation of the model itself : add a column named
# "Annotations" in the CSV file, then parse this column to get the kegg ids if they have one
# (2) Add the model KEGG ids to our mapping table => apply() function
# (3) Map the KEGG model ids to the kegg ids in the bigg table for the reaction => merge() function
mapping_table_reactions = pd.read_csv('2021-05-20-CA-reaction-mapping/output/2021-05-25-CA-reaction-mapping-table2.csv', index_col = 0)
mapping_table_reactions.head()
# Out:
#                                                            Name  \
# IDs
# PSII_h                                           photosystem II
# Cytb6f1_h                                 cytochrom b6f complex
# Cytb6f2_h                                 cytochrom b6f complex
# PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
#
#                                                     Annotations
# IDs
# PSII_h        {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Cytb6f1_h     {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Cytb6f2_h     {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# PGR5PGRL11_h  {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# PGR5PGRL12_h  {'doi': '10.1016/j.tplants.2011.10.004', 'go':...

# %%
df_mapping_table_reactions_bigg_merge = df_mapping_table_reactions.merge(bigg_models_reactions, how = 'left', left_on = 'kegg_id', right_on = 'bigg_id')
df_mapping_table_reactions_bigg_merge
# Out:
#                IDs                                               Name  \
# 0           PSII_h                                     photosystem II
# 1        Cytb6f1_h                              cytochrom b6f complex
# 2        Cytb6f2_h                              cytochrom b6f complex
# 3     PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4     PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# ..             ...                                                ...
# 567   Tr_KG_Mal_mc                                       Tr_KG_Mal_mc
# 568      Tr_Asp_mc                                          Tr_Asp_mc
# 569  Tr_Asp_Glu_mc                                      Tr_Asp_Glu_mc
# 570  Tr_Pyr_Mal_hc                                    R_Tr_Pyr_Mal_hc
# 571      Tr_Ala_mc                                        R_Tr_Ala_mc
#
#                                            Annotations kegg_id bigg_id name  \
# 0    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  R09503     NaN  NaN
# 1    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  R03817     NaN  NaN
# 2    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  R03817     NaN  NaN
# 3    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...  R03817     NaN  NaN
# 4    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...  R03817     NaN  NaN
# ..                                                 ...     ...     ...  ...
# 567                               {'go': 'GO:0006810'}             NaN  NaN
# 568                               {'go': 'GO:0006810'}             NaN  NaN
# 569                               {'go': 'GO:0006810'}             NaN  NaN
# 570                               {'go': 'GO:0006810'}             NaN  NaN
# 571                               {'go': 'GO:0006810'}             NaN  NaN
#
#     reaction_string model_list database_links old_bigg_ids
# 0               NaN        NaN            NaN          NaN
# 1               NaN        NaN            NaN          NaN
# 2               NaN        NaN            NaN          NaN
# 3               NaN        NaN            NaN          NaN
# 4               NaN        NaN            NaN          NaN
# ..              ...        ...            ...          ...
# 567             NaN        NaN            NaN          NaN
# 568             NaN        NaN            NaN          NaN
# 569             NaN        NaN            NaN          NaN
# 570             NaN        NaN            NaN          NaN
# 571             NaN        NaN            NaN          NaN
#
# [572 rows x 10 columns]

# %%
df_mapping_table_reactions_bigg_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 572 entries, 0 to 571
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   IDs              572 non-null    object
#  1   Name             572 non-null    object
#  2   Annotations      572 non-null    object
#  3   kegg_id          572 non-null    object
#  4   bigg_id          0 non-null      object
#  5   name             0 non-null      object
#  6   reaction_string  0 non-null      object
#  7   model_list       0 non-null      object
#  8   database_links   0 non-null      object
#  9   old_bigg_ids     0 non-null      object
# dtypes: object(10)
# memory usage: 49.2+ KB

# %%
df_modelSEED_reactions = pd.read_csv('2021-05-20-CA-reaction-mapping/data-databases/reactionsModelSEED.txt', sep = '\t')
df_modelSEED_reactions.head()
# Out:
#          id abbreviation                                               name  \
# 0  rxn00001       R00004                       diphosphate phosphohydrolase
# 1  rxn00002       R00005                  urea-1-carboxylate amidohydrolase
# 2  rxn00003       R00006  pyruvate:pyruvate acetaldehydetransferase (dec...
# 3  rxn00004       R00008  4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lya...
# 4  rxn00006       R00009  hydrogen-peroxide:hydrogen-peroxide oxidoreduc...
#
#                                                 code  \
# 0  (1) cpd00001[0] + (1) cpd00012[0] <=> (2) cpd0...
# 1  (1) cpd00001[0] + (1) cpd00742[0] <=> (2) cpd0...
# 2  (1) cpd00011[0] + (1) cpd00668[0] <=> (2) cpd0...
# 3                (1) cpd02570[0] <=> (2) cpd00020[0]
# 4  (2) cpd00025[0] <=> (2) cpd00001[0] + (1) cpd0...
#
#                                        stoichiometry  is_transport  \
# 0  -1:cpd00001:0:0:"H2O";-1:cpd00012:0:0:"PPi";2:...             0
# 1  -1:cpd00001:0:0:"H2O";-3:cpd00067:0:0:"H+";-1:...             0
# 2  -1:cpd00011:0:0:"CO2";-1:cpd00668:0:0:"ALCTT";...             0
# 3  -1:cpd02570:0:0:"Parapyruvate";2:cpd00020:0:0:...             0
# 4  -2:cpd00025:0:0:"H2O2";2:cpd00001:0:0:"H2O";1:...             0
#
#                                             equation  \
# 0  (1) cpd00001[0] + (1) cpd00012[0] <=> (2) cpd0...
# 1  (1) cpd00001[0] + (3) cpd00067[0] + (1) cpd007...
# 2  (1) cpd00011[0] + (1) cpd00668[0] <= (2) cpd00...
# 3                (1) cpd02570[0] <=> (2) cpd00020[0]
# 4  (2) cpd00025[0] => (2) cpd00001[0] + (1) cpd00...
#
#                                           definition reversibility direction  \
# 0  (1) H2O[0] + (1) PPi[0] <=> (2) Phosphate[0] +...             >         =
# 1  (1) H2O[0] + (3) H+[0] + (1) Allophanate[0] =>...             >         >
# 2  (1) CO2[0] + (1) ALCTT[0] <= (2) Pyruvate[0] +...             <         <
# 3            (1) Parapyruvate[0] <=> (2) Pyruvate[0]             =         =
# 4              (2) H2O2[0] => (2) H2O[0] + (1) O2[0]             >         >
#
#    ...                                            aliases          ec_numbers  \
# 0  ...  AraCyc: INORGPYROPHOSPHAT-RXN|BiGG: IPP1; PPA;...             3.6.1.1
# 1  ...  AraCyc: ALLOPHANATE-HYDROLASE-RXN|BiGG: ALPHNH...            3.5.1.54
# 2  ...  AlgaGEM: R_R00006_c|AraGEM: R_R00006_c|BiGG: I...             2.2.1.6
# 3  ...  KEGG: R00008|Name: 4-Hydroxy-4-methyl-2-oxoglu...            4.1.3.17
# 4  ...  AraCyc: CATAL-RXN|BiGG: CAT; CATp; CTA1; CTT1|...  1.11.1.21|1.11.1.6
#
#   deltag deltagerr                                  compound_ids  status  \
# 0  -3.46      0.05           cpd00001;cpd00009;cpd00012;cpd00067      OK
# 1 -20.14      1.86  cpd00001;cpd00011;cpd00013;cpd00067;cpd00742      OK
# 2   8.27      0.90           cpd00011;cpd00020;cpd00067;cpd00668      OK
# 3   4.49      0.57                             cpd00020;cpd02570      OK
# 4 -46.06      1.64                    cpd00001;cpd00007;cpd00025      OK
#
#   is_obsolete                                    linked_reaction  \
# 0           0  rxn27946;rxn27947;rxn27948;rxn32487;rxn38157;r...
# 1           0                                  rxn30346;rxn35525
# 2           0                                  rxn30144;rxn33164
# 3           0                                                NaN
# 4           0                rxn19264;rxn22404;rxn27744;rxn31381
#
#             notes            source
# 0  GCC|HB|EQC|EQU  Primary Database
# 1     GCC|EQC|EQU  Primary Database
# 2     GCC|EQC|EQU  Primary Database
# 3     GCC|EQC|EQU  Primary Database
# 4     GCC|EQC|EQU  Primary Database
#
# [5 rows x 22 columns]

# %%
df_mapping_table_reactions_modelSEED_merge = df_mapping_table_reactions.merge(df_modelSEED_reactions, how = 'left', left_on = 'kegg_id', right_on = 'abbreviation')
df_mapping_table_reactions_modelSEED_merge
# Out:
#                IDs                                               Name  \
# 0           PSII_h                                     photosystem II
# 1        Cytb6f1_h                              cytochrom b6f complex
# 2        Cytb6f2_h                              cytochrom b6f complex
# 3     PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4     PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# ..             ...                                                ...
# 595   Tr_KG_Mal_mc                                       Tr_KG_Mal_mc
# 596      Tr_Asp_mc                                          Tr_Asp_mc
# 597  Tr_Asp_Glu_mc                                      Tr_Asp_Glu_mc
# 598  Tr_Pyr_Mal_hc                                    R_Tr_Pyr_Mal_hc
# 599      Tr_Ala_mc                                        R_Tr_Ala_mc
#
#                                            Annotations kegg_id        id  \
# 0    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  R09503  rxn16345
# 1    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  R03817  rxn11995
# 2    {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...  R03817  rxn11995
# 3    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...  R03817  rxn11995
# 4    {'doi': '10.1016/j.tplants.2011.10.004', 'go':...  R03817  rxn11995
# ..                                                 ...     ...       ...
# 595                               {'go': 'GO:0006810'}               NaN
# 596                               {'go': 'GO:0006810'}               NaN
# 597                               {'go': 'GO:0006810'}               NaN
# 598                               {'go': 'GO:0006810'}               NaN
# 599                               {'go': 'GO:0006810'}               NaN
#
#     abbreviation                                               name  \
# 0         R09503      H2O:plastoquinone reductase (light-dependent)
# 1         R03817  plastoquinol:oxidized-plastocyanin oxidoreductase
# 2         R03817  plastoquinol:oxidized-plastocyanin oxidoreductase
# 3         R03817  plastoquinol:oxidized-plastocyanin oxidoreductase
# 4         R03817  plastoquinol:oxidized-plastocyanin oxidoreductase
# ..           ...                                                ...
# 595          NaN                                                NaN
# 596          NaN                                                NaN
# 597          NaN                                                NaN
# 598          NaN                                                NaN
# 599          NaN                                                NaN
#
#                                                   code  \
# 0    (2) cpd00001[0] + (4) cpd11632[0] + (2) cpd120...
# 1    (1) cpd01475[0] + (2) cpd12265[0] <=> (2) cpd1...
# 2    (1) cpd01475[0] + (2) cpd12265[0] <=> (2) cpd1...
# 3    (1) cpd01475[0] + (2) cpd12265[0] <=> (2) cpd1...
# 4    (1) cpd01475[0] + (2) cpd12265[0] <=> (2) cpd1...
# ..                                                 ...
# 595                                                NaN
# 596                                                NaN
# 597                                                NaN
# 598                                                NaN
# 599                                                NaN
#
#                                          stoichiometry  is_transport  ...  \
# 0    -2:cpd00001:0:0:"H2O";-4:cpd11632:0:0:"hn";-2:...           0.0  ...
# 1    -1:cpd01475:0:0:"Plastoquinol-1";-2:cpd12265:0...           0.0  ...
# 2    -1:cpd01475:0:0:"Plastoquinol-1";-2:cpd12265:0...           0.0  ...
# 3    -1:cpd01475:0:0:"Plastoquinol-1";-2:cpd12265:0...           0.0  ...
# 4    -1:cpd01475:0:0:"Plastoquinol-1";-2:cpd12265:0...           0.0  ...
# ..                                                 ...           ...  ...
# 595                                                NaN           NaN  ...
# 596                                                NaN           NaN  ...
# 597                                                NaN           NaN  ...
# 598                                                NaN           NaN  ...
# 599                                                NaN           NaN  ...
#
#                                                aliases ec_numbers      deltag  \
# 0    JP_Creinhardtii_NMeth: R_PSII|KEGG: R09503|Nam...   1.10.3.9  10000000.0
# 1    KEGG: R03817|Name: plastoquinol:oxidized-plast...   1.10.9.1  10000000.0
# 2    KEGG: R03817|Name: plastoquinol:oxidized-plast...   1.10.9.1  10000000.0
# 3    KEGG: R03817|Name: plastoquinol:oxidized-plast...   1.10.9.1  10000000.0
# 4    KEGG: R03817|Name: plastoquinol:oxidized-plast...   1.10.9.1  10000000.0
# ..                                                 ...        ...         ...
# 595                                                NaN        NaN         NaN
# 596                                                NaN        NaN         NaN
# 597                                                NaN        NaN         NaN
# 598                                                NaN        NaN         NaN
# 599                                                NaN        NaN         NaN
#
#       deltagerr                                  compound_ids status  \
# 0    10000000.0  cpd00001;cpd00007;cpd11632;cpd12011;cpd16486     OK
# 1    10000000.0  cpd00067;cpd01475;cpd12239;cpd12265;cpd16487     OK
# 2    10000000.0  cpd00067;cpd01475;cpd12239;cpd12265;cpd16487     OK
# 3    10000000.0  cpd00067;cpd01475;cpd12239;cpd12265;cpd16487     OK
# 4    10000000.0  cpd00067;cpd01475;cpd12239;cpd12265;cpd16487     OK
# ..          ...                                           ...    ...
# 595         NaN                                           NaN    NaN
# 596         NaN                                           NaN    NaN
# 597         NaN                                           NaN    NaN
# 598         NaN                                           NaN    NaN
# 599         NaN                                           NaN    NaN
#
#     is_obsolete linked_reaction       notes            source
# 0           0.0        rxn34264     GCP|EQP  Primary Database
# 1           0.0             NaN  HB|GCP|EQP  Primary Database
# 2           0.0             NaN  HB|GCP|EQP  Primary Database
# 3           0.0             NaN  HB|GCP|EQP  Primary Database
# 4           0.0             NaN  HB|GCP|EQP  Primary Database
# ..          ...             ...         ...               ...
# 595         NaN             NaN         NaN               NaN
# 596         NaN             NaN         NaN               NaN
# 597         NaN             NaN         NaN               NaN
# 598         NaN             NaN         NaN               NaN
# 599         NaN             NaN         NaN               NaN
#
# [600 rows x 26 columns]

# %%
df_mapping_table_reactions_modelSEED_merge.info() # 256 reactions with no KEGG ID or with no correspondence between KEGG ID and
# abbreviation
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 0 to 599
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   IDs                600 non-null    object
#  1   Name               600 non-null    object
#  2   Annotations        600 non-null    object
#  3   kegg_id            600 non-null    object
#  4   id                 344 non-null    object
#  5   abbreviation       344 non-null    object
#  6   name               344 non-null    object
#  7   code               344 non-null    object
#  8   stoichiometry      344 non-null    object
#  9   is_transport       344 non-null    float64
#  10  equation           344 non-null    object
#  11  definition         344 non-null    object
#  12  reversibility      344 non-null    object
#  13  direction          344 non-null    object
#  14  abstract_reaction  0 non-null      float64
#  15  pathways           310 non-null    object
#  16  aliases            344 non-null    object
#  17  ec_numbers         340 non-null    object
#  18  deltag             344 non-null    float64
#  19  deltagerr          344 non-null    float64
#  20  compound_ids       344 non-null    object
#  21  status             344 non-null    object
#  22  is_obsolete        344 non-null    float64
#  23  linked_reaction    309 non-null    object
#  24  notes              344 non-null    object
#  25  source             344 non-null    object
# dtypes: float64(5), object(21)
# memory usage: 126.6+ KB

# %%
# We would like to search the reactions which have not an abbreviation linked to the KEGG ID 
df_mapping_table_NaN = df_mapping_table_reactions_modelSEED_merge[df_mapping_table_reactions_modelSEED_merge["abbreviation"].isna()]
df_mapping_table_NaN
# Out:
#                IDs                Name  \
# 57          CeS_c1  cellulose synthase
# 58          CeS_c2  cellulose synthase
# 59          CeS_c3  cellulose synthase
# 218      GABATA1_m   GABA transaminase
# 265         CTHS_h        CTH synthase
# ..             ...                 ...
# 595   Tr_KG_Mal_mc        Tr_KG_Mal_mc
# 596      Tr_Asp_mc           Tr_Asp_mc
# 597  Tr_Asp_Glu_mc       Tr_Asp_Glu_mc
# 598  Tr_Pyr_Mal_hc     R_Tr_Pyr_Mal_hc
# 599      Tr_Ala_mc         R_Tr_Ala_mc
#
#                                            Annotations kegg_id   id  \
# 57   {'ec-code': '2.4.1.12', 'go': 'GO:0030244', 'k...  R02889  NaN
# 58   {'ec-code': '2.4.1.12', 'go': 'GO:0030244', 'k...  R02889  NaN
# 59   {'ec-code': '2.4.1.12', 'go': 'GO:0030244', 'k...  R02889  NaN
# 218  {'ec-code': '2.6.1.96', 'go': 'GO:0006538', 'p...          NaN
# 265        {'ec-code': '2.5.1.48', 'go': 'GO:0009086'}          NaN
# ..                                                 ...     ...  ...
# 595                               {'go': 'GO:0006810'}          NaN
# 596                               {'go': 'GO:0006810'}          NaN
# 597                               {'go': 'GO:0006810'}          NaN
# 598                               {'go': 'GO:0006810'}          NaN
# 599                               {'go': 'GO:0006810'}          NaN
#
#     abbreviation name code stoichiometry  is_transport  ... aliases  \
# 57           NaN  NaN  NaN           NaN           NaN  ...     NaN
# 58           NaN  NaN  NaN           NaN           NaN  ...     NaN
# 59           NaN  NaN  NaN           NaN           NaN  ...     NaN
# 218          NaN  NaN  NaN           NaN           NaN  ...     NaN
# 265          NaN  NaN  NaN           NaN           NaN  ...     NaN
# ..           ...  ...  ...           ...           ...  ...     ...
# 595          NaN  NaN  NaN           NaN           NaN  ...     NaN
# 596          NaN  NaN  NaN           NaN           NaN  ...     NaN
# 597          NaN  NaN  NaN           NaN           NaN  ...     NaN
# 598          NaN  NaN  NaN           NaN           NaN  ...     NaN
# 599          NaN  NaN  NaN           NaN           NaN  ...     NaN
#
#     ec_numbers deltag deltagerr  compound_ids status is_obsolete  \
# 57         NaN    NaN       NaN           NaN    NaN         NaN
# 58         NaN    NaN       NaN           NaN    NaN         NaN
# 59         NaN    NaN       NaN           NaN    NaN         NaN
# 218        NaN    NaN       NaN           NaN    NaN         NaN
# 265        NaN    NaN       NaN           NaN    NaN         NaN
# ..         ...    ...       ...           ...    ...         ...
# 595        NaN    NaN       NaN           NaN    NaN         NaN
# 596        NaN    NaN       NaN           NaN    NaN         NaN
# 597        NaN    NaN       NaN           NaN    NaN         NaN
# 598        NaN    NaN       NaN           NaN    NaN         NaN
# 599        NaN    NaN       NaN           NaN    NaN         NaN
#
#     linked_reaction  notes  source
# 57              NaN    NaN     NaN
# 58              NaN    NaN     NaN
# 59              NaN    NaN     NaN
# 218             NaN    NaN     NaN
# 265             NaN    NaN     NaN
# ..              ...    ...     ...
# 595             NaN    NaN     NaN
# 596             NaN    NaN     NaN
# 597             NaN    NaN     NaN
# 598             NaN    NaN     NaN
# 599             NaN    NaN     NaN
#
# [256 rows x 26 columns]

# %%
df_keggID_merge.info() # 253 reactions with a KEGG ID => OK
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 256 entries, 0 to 255
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   IDs                256 non-null    object
#  1   Name               256 non-null    object
#  2   Annotations        256 non-null    object
#  3   kegg_id            256 non-null    object
#  4   id                 0 non-null      object
#  5   abbreviation       0 non-null      object
#  6   name               0 non-null      object
#  7   code               0 non-null      object
#  8   stoichiometry      0 non-null      object
#  9   is_transport       0 non-null      float64
#  10  equation           0 non-null      object
#  11  definition         0 non-null      object
#  12  reversibility      0 non-null      object
#  13  direction          0 non-null      object
#  14  abstract_reaction  0 non-null      float64
#  15  pathways           0 non-null      object
#  16  aliases            0 non-null      object
#  17  ec_numbers         0 non-null      object
#  18  deltag             0 non-null      float64
#  19  deltagerr          0 non-null      float64
#  20  compound_ids       0 non-null      object
#  21  status             0 non-null      object
#  22  is_obsolete        0 non-null      float64
#  23  linked_reaction    0 non-null      object
#  24  notes              0 non-null      object
#  25  source             0 non-null      object
#  26  RHEA_ID            3 non-null      float64
#  27  DIRECTION          3 non-null      object
#  28  MASTER_ID          3 non-null      float64
#  29  ID                 3 non-null      object
# dtypes: float64(7), object(23)
# memory usage: 62.0+ KB

# %%
df_keggID_merge.to_csv('kegg_id.csv')
