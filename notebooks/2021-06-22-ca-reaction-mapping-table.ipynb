# %% [markdown]
# # Creating reaction mapping table

# %% [markdown]
# **General steps to build the reaction mapping table:**
#
# > I / Import the resources: modules and AraCore model
#
# > II / Create reaction table for AraCore model
#
# > III / Import BiGG reaction file
#
# > IV / Import ModelSEED reaction file
#
# > V / Mapping AraCore and BiGG
#
# > VI / Aggregate the information
#
# > VII / Mapping AraCore and ModelSEED
#
# > VIII / Counting

# %% [markdown]
# # I / Import the resources : modules and AraCore model

# %% [markdown]
# ## 1) Install missing modules and load modules

# %%
import pandas as pd
import numpy as np
import cobra
import requests

# %% [markdown]
# ## 2) Load AraCore Model

# %%
#Get file from internet : GitHub
fileName = 'https://raw.githubusercontent.com/ma-blaetke/CBM_C3_C4_Metabolism/master/data/2018-23-05-mb-genC3.sbml'
r = requests.get(fileName)

# %%
#Create the model
model = cobra.io.read_sbml_model(r.text)
model
# Out:
# <Model c3_model at 0x7f242881e100>

# %% [markdown]
# ## 3) Correct compartment naming in AraCore Model according to BiGG naming conventions

# %%
#print the names of the compartments, then correct each of them
model.compartments
# Out:
# {'h': 'Chloroplast',
#  'l': 'Lumen',
#  'c': 'Cytosol',
#  'm': 'Mitochondrion',
#  'i': 'IntermembraneSpace',
#  'p': 'Peroxisome'}

# %%
bigg_compartments_corrected = {"c":"cytosol",
                             "e":"extracellular space",
                             "p":"periplasm",
                             "m":"mitochondria",
                             "x":"peroxisome/glyoxysome",
                             "r":"endoplasmic reticulum",
                             "v":"vacuole",
                             "n":"nucleus",
                             "g":"golgi apparatus",
                             "u":"thylakoid",
                             "l":"lysosome",
                             "h":"chloroplast",
                             "f":"flagellum",
                             "s":"eyespot",
                             "im":"intermembrane space of mitochondria",
                             "cx":"carboxyzome",
                             "um":"thylakoid membrane",
                             "cm":"cytosolic membrane",
                             "i":"inner mitochondrial compartment",
                             "mm":"mitochondrial intermembrane",
                             "w":"wildtype staph aureus",
                             "y":"cytochrome complex"}

# %%
bigg_compartments_corrected
# Out:
# {'c': 'cytosol',
#  'e': 'extracellular space',
#  'p': 'periplasm',
#  'm': 'mitochondria',
#  'x': 'peroxisome/glyoxysome',
#  'r': 'endoplasmic reticulum',
#  'v': 'vacuole',
#  'n': 'nucleus',
#  'g': 'golgi apparatus',
#  'u': 'thylakoid',
#  'l': 'lysosome',
#  'h': 'chloroplast',
#  'f': 'flagellum',
#  's': 'eyespot',
#  'im': 'intermembrane space of mitochondria',
#  'cx': 'carboxyzome',
#  'um': 'thylakoid membrane',
#  'cm': 'cytosolic membrane',
#  'i': 'inner mitochondrial compartment',
#  'mm': 'mitochondrial intermembrane',
#  'w': 'wildtype staph aureus',
#  'y': 'cytochrome complex'}

# %% [markdown]
# On internet, we can access to this following page to find compartments which can figure in the model : http://bigg.ucsd.edu/compartments
#
# **Summary of the notations used:**
#
# - c : cytosol
# - h : chloroplast
# - m : mitochondria
# - x : peroxisome/glyoxysome
# - im :intermembrane space of mitochondria
# - h : chloroplast
# - ul : thylakoid lumen <<< NEW

# %%
#Create a pandas Series for compartment mapping
#pandas Series = One-dimensional ndarray with axis labels
df_compartment_mapping = pd.Series(
    {"c":"c", #cytosol
    "h":"h", #chloroplast
    "m":"m", #mitochondria
    "l":"ul", #thylakoid lumen <<< NEW, not in BiGG compartment list
    "i":"im", #intermembrane space of mitochondria
    "p":"x", #peroxisome/glyoxysome
    "e":"e" #extracellular space << NEW, not yet in model
    })
df_compartment_mapping
# Out:
# c     c
# h     h
# m     m
# l    ul
# i    im
# p     x
# e     e
# dtype: object

# %% [markdown]
# # II / Create Reaction Table for AraCore Model

# %% [markdown]
# ## 1) Create mapping table

# %% [markdown]
# ### 1) a. Create the dataframe

# %%
#Create mapping table
df_reactions_aracore = pd.DataFrame(
    {
        "aracore_ids":[x.id for x in model.reactions],
        "aracore_name":[x.name for x in model.reactions],
        "aracore_annotations":[x.annotation for x in model.reactions]
    })
df_reactions_aracore.head(25)
# Out:
#         aracore_ids                                       aracore_name  \
# 0            PSII_h                                     photosystem II
# 1         Cytb6f1_h                              cytochrom b6f complex
# 2         Cytb6f2_h                              cytochrom b6f complex
# 3      PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4      PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 5            NDH1_h              NADH dehydrogenase-like (NDH) complex
# 6            NDH2_h              NADH dehydrogenase-like (NDH) complex
# 7             PSI_h                                      photosystem I
# 8   Fd_DASH_NADPR_h                          ferredoxin-NADP reductase
# 9          ATPase_h                                             ATPase
# 10            RBC_h                                            RuBisCO
# 11           PGAK_h                                         PGA kinase
# 12         GAPDH1_h                                  GAP dehydrogenase
# 13            TPI_h                                       TP isomerase
# 14           FBPA_h                                       FBP aldolase
# 15         FBPase_h                                             FBPase
# 16            FTK_h                                  F6P transketolase
# 17           SBPA_h                                       SBP aldolase
# 18         SBPase_h                                             SBPase
# 19            STK_h                                  S7P transketolase
# 20          Ru5PE_h                                     Ru5P epimerase
# 21           R5PI_h                                      R5P isomerase
# 22          Ru5PK_h                                        Ru5P kinase
# 23            PGI_h                                      G6P isomerase
# 24            PGM_h                                 Phosphoglucomutase
#
#                                   aracore_annotations
# 0   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 1   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 2   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 3   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# 4   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# 5   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# 6   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# 7   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 8   {'ec-code': '1.18.1.2', 'go': 'GO:0019684', 'k...
# 9   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# 10  {'doi': '10.1146/annurev.arplant.53.100301.135...
# 11  {'ec-code': '2.7.2.3', 'go': ['GO:0019253', 'G...
# 12  {'doi': ['10.1107/S1744309110013527', ' 10.107...
# 13  {'ec-code': '5.3.1.1', 'go': ['GO:0019253', 'G...
# 14  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# 15  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....
# 16  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# 17  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# 18  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....
# 19  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# 20  {'doi': '10.1104/pp.118.1.199', 'ec-code': '5....
# 21  {'ec-code': '5.3.1.6', 'go': ['GO:0019253', 'G...
# 22  {'doi': '10.1104/pp.105.068445', 'ec-code': '2...
# 23  {'doi': '10.1104/pp.105.068445', 'ec-code': '5...
# 24  {'ec-code': '5.4.2.2', 'go': 'GO:0019252', 'ke...

# %%
#Set index to acacore_ids to make the renaming of certain labels "easier"
df_reactions_aracore.set_index("aracore_ids",inplace=True) # "inplace=True" means that the modifications occur in place, 
#no new object is created  
df_reactions_aracore.head(25)
# Out:
#                                                       aracore_name  \
# aracore_ids
# PSII_h                                              photosystem II
# Cytb6f1_h                                    cytochrom b6f complex
# Cytb6f2_h                                    cytochrom b6f complex
# PGR5PGRL11_h     proton gradient regulation 5 (PGR5)/PGR5-like ...
# PGR5PGRL12_h     proton gradient regulation 5 (PGR5)/PGR5-like ...
# NDH1_h                       NADH dehydrogenase-like (NDH) complex
# NDH2_h                       NADH dehydrogenase-like (NDH) complex
# PSI_h                                                photosystem I
# Fd_DASH_NADPR_h                          ferredoxin-NADP reductase
# ATPase_h                                                    ATPase
# RBC_h                                                      RuBisCO
# PGAK_h                                                  PGA kinase
# GAPDH1_h                                         GAP dehydrogenase
# TPI_h                                                 TP isomerase
# FBPA_h                                                FBP aldolase
# FBPase_h                                                    FBPase
# FTK_h                                            F6P transketolase
# SBPA_h                                                SBP aldolase
# SBPase_h                                                    SBPase
# STK_h                                            S7P transketolase
# Ru5PE_h                                             Ru5P epimerase
# R5PI_h                                               R5P isomerase
# Ru5PK_h                                                Ru5P kinase
# PGI_h                                                G6P isomerase
# PGM_h                                           Phosphoglucomutase
#
#                                                aracore_annotations
# aracore_ids
# PSII_h           {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Cytb6f1_h        {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Cytb6f2_h        {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# PGR5PGRL11_h     {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# PGR5PGRL12_h     {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# NDH1_h           {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# NDH2_h           {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# PSI_h            {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Fd_DASH_NADPR_h  {'ec-code': '1.18.1.2', 'go': 'GO:0019684', 'k...
# ATPase_h         {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# RBC_h            {'doi': '10.1146/annurev.arplant.53.100301.135...
# PGAK_h           {'ec-code': '2.7.2.3', 'go': ['GO:0019253', 'G...
# GAPDH1_h         {'doi': ['10.1107/S1744309110013527', ' 10.107...
# TPI_h            {'ec-code': '5.3.1.1', 'go': ['GO:0019253', 'G...
# FBPA_h           {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# FBPase_h         {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....
# FTK_h            {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# SBPA_h           {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# SBPase_h         {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....
# STK_h            {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# Ru5PE_h          {'doi': '10.1104/pp.118.1.199', 'ec-code': '5....
# R5PI_h           {'ec-code': '5.3.1.6', 'go': ['GO:0019253', 'G...
# Ru5PK_h          {'doi': '10.1104/pp.105.068445', 'ec-code': '2...
# PGI_h            {'doi': '10.1104/pp.105.068445', 'ec-code': '5...
# PGM_h            {'ec-code': '5.4.2.2', 'go': 'GO:0019252', 'ke...

# %% [markdown]
# ### 1) b. Changes to the dataframe

# %% [markdown]
# On internet, we can access to this following page to find BiGG naming conventions, including reactions: https://github.com/SBRG/bigg_models/wiki/BiGG-Models-ID-Specification-and-Guidelines
#
# **Summary of the conventions:**
#
# - Reaction symbols all need to be uppercase
# - Only contain upper and lowercase letters, numbers and underscores
#
# **Rename names of a few reactions:**
#
# - StS_h1
# - StS_h2
# - StS_h3
# - CeS_c1
# - CeS_c2
# - CeS_c3
# - AGluK
#
# **Nomenclature:**
#
# df.rename(index = {'name':'new_name'})

# %%
#df.rename(index= {'name': 'new_name'})
#Rename reaction ids StS_h1, StS_h3, StS_h2
df_reactions_aracore.rename(index={'StS_h1':'StS1_h'}, inplace=True)
df_reactions_aracore.rename(index={'StS_h2':'StS2_h'}, inplace=True)
df_reactions_aracore.rename(index={'StS_h3':'StS3_h'}, inplace=True)

#Rename reaction ids CeS_c1, CeS_c2, CeS_c3
df_reactions_aracore.rename(index={'CeS_c1':'CeS1_c'}, inplace=True)
df_reactions_aracore.rename(index={'CeS_c2':'CeS2_c'}, inplace=True)
df_reactions_aracore.rename(index={'CeS_c3':'CeS3_c'}, inplace=True)

#Rename reaction id AGluK
df_reactions_aracore.rename(index={'AGluK':'AGluK_h'}, inplace=True)


#Rename all import reaction ids, add "_e" for extracellular space
for r_obj in model.reactions.query(lambda rxn: (rxn.id.startswith('Im_'))):
  df_reactions_aracore.rename(index={r_obj.id: f"{r_obj.id}_e"}, inplace=True)
# lambda rxn: (rxn.id.startswith('Im_')) = research function, applyed for all the reactions (rxn)
# id is the attribute of the reaction (rxn)
# query() = method of reactions
    
    
#Rename all export reaction ids, add "_e" for extracellular space
for r_obj in model.reactions.query(lambda rxn: (rxn.id.startswith('Ex_'))):
    df_reactions_aracore.rename(index={r_obj.id: f"{r_obj.id}_e"}, inplace=True)
    

#Rename all transport reaction ids, add compartment symbol of first metabolite
for r_obj in model.reactions.query(lambda rxn: (rxn.id.startswith('Tr_'))): 
    met_first_comp = list(r_obj.metabolites.keys())[0].compartment
    if r_obj.id.rsplit('_',1)[-1] in ['mc','hc']:
        r_id_new = f"{r_obj.id.rsplit('_',1)[0]}_{met_first_comp}"
    else:
        r_id_new = f"{r_obj.id}_{met_first_comp}"
    df_reactions_aracore.rename(index={r_obj.id: r_id_new}, inplace=True)

df_reactions_aracore.reset_index(inplace=True) #Reset index to numeric labels, to be able to use the apply function on 'aracore_updated_ids' which is not possible as index

#Update compartment symbols in metabolite ids and make metabolite ids lower case
df_reactions_aracore['aracore_updated_ids'] = df_reactions_aracore['aracore_ids'].apply(lambda r_id: f"{r_id.rsplit('_',1)[0].upper()}_{df_compartment_mapping[r_id.rsplit('_',1)[-1]]}")

#Create universal metabolite ids by removing compartment symbols
df_reactions_aracore['aracore_updated_universal_ids'] = df_reactions_aracore['aracore_updated_ids'].apply(lambda r_id: r_id.rsplit('_',1)[0])

df_reactions_aracore.head(25)
# Out:
#     index      aracore_ids                                       aracore_name  \
# 0       0           PSII_h                                     photosystem II
# 1       1        Cytb6f1_h                              cytochrom b6f complex
# 2       2        Cytb6f2_h                              cytochrom b6f complex
# 3       3     PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4       4     PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 5       5           NDH1_h              NADH dehydrogenase-like (NDH) complex
# 6       6           NDH2_h              NADH dehydrogenase-like (NDH) complex
# 7       7            PSI_h                                      photosystem I
# 8       8  Fd_DASH_NADPR_h                          ferredoxin-NADP reductase
# 9       9         ATPase_h                                             ATPase
# 10     10            RBC_h                                            RuBisCO
# 11     11           PGAK_h                                         PGA kinase
# 12     12         GAPDH1_h                                  GAP dehydrogenase
# 13     13            TPI_h                                       TP isomerase
# 14     14           FBPA_h                                       FBP aldolase
# 15     15         FBPase_h                                             FBPase
# 16     16            FTK_h                                  F6P transketolase
# 17     17           SBPA_h                                       SBP aldolase
# 18     18         SBPase_h                                             SBPase
# 19     19            STK_h                                  S7P transketolase
# 20     20          Ru5PE_h                                     Ru5P epimerase
# 21     21           R5PI_h                                      R5P isomerase
# 22     22          Ru5PK_h                                        Ru5P kinase
# 23     23            PGI_h                                      G6P isomerase
# 24     24            PGM_h                                 Phosphoglucomutase
#
#                                   aracore_annotations aracore_updated_ids  \
# 0   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...              PSII_h
# 1   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...           CYTB6F1_h
# 2   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...           CYTB6F2_h
# 3   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...        PGR5PGRL11_h
# 4   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...        PGR5PGRL12_h
# 5   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...              NDH1_h
# 6   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...              NDH2_h
# 7   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...               PSI_h
# 8   {'ec-code': '1.18.1.2', 'go': 'GO:0019684', 'k...     FD_DASH_NADPR_h
# 9   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...            ATPASE_h
# 10  {'doi': '10.1146/annurev.arplant.53.100301.135...               RBC_h
# 11  {'ec-code': '2.7.2.3', 'go': ['GO:0019253', 'G...              PGAK_h
# 12  {'doi': ['10.1107/S1744309110013527', ' 10.107...            GAPDH1_h
# 13  {'ec-code': '5.3.1.1', 'go': ['GO:0019253', 'G...               TPI_h
# 14  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...              FBPA_h
# 15  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....            FBPASE_h
# 16  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...               FTK_h
# 17  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...              SBPA_h
# 18  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....            SBPASE_h
# 19  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...               STK_h
# 20  {'doi': '10.1104/pp.118.1.199', 'ec-code': '5....             RU5PE_h
# 21  {'ec-code': '5.3.1.6', 'go': ['GO:0019253', 'G...              R5PI_h
# 22  {'doi': '10.1104/pp.105.068445', 'ec-code': '2...             RU5PK_h
# 23  {'doi': '10.1104/pp.105.068445', 'ec-code': '5...               PGI_h
# 24  {'ec-code': '5.4.2.2', 'go': 'GO:0019252', 'ke...               PGM_h
#
#    aracore_updated_universal_ids kegg_id    ec-code
# 0                           PSII  R09503   1.10.3.9
# 1                        CYTB6F1  R03817   1.10.9.1
# 2                        CYTB6F2  R03817   1.10.9.1
# 3                     PGR5PGRL11  R03817       None
# 4                     PGR5PGRL12  R03817       None
# 5                           NDH1  R03817       None
# 6                           NDH2  R03817       None
# 7                            PSI  R09542  1.97.1.12
# 8                  FD_DASH_NADPR  R01195   1.18.1.2
# 9                         ATPASE  R00086   3.6.3.14
# 10                           RBC  R00024   4.1.1.39
# 11                          PGAK  R01512    2.7.2.3
# 12                        GAPDH1  R01063   1.2.1.13
# 13                           TPI  R01015    5.3.1.1
# 14                          FBPA  R01068   4.1.2.13
# 15                        FBPASE  R00762   3.1.3.11
# 16                           FTK  R01067    2.2.1.1
# 17                          SBPA  R01829   4.1.2.13
# 18                        SBPASE  R01845   3.1.3.37
# 19                           STK  R01641    2.2.1.1
# 20                         RU5PE  R01529    5.1.3.1
# 21                          R5PI  R01056    5.3.1.6
# 22                         RU5PK  R01523   2.7.1.19
# 23                           PGI  R00771    5.3.1.9
# 24                           PGM  R08639    5.4.2.2

# %%
df_reactions_aracore[df_reactions_aracore['aracore_ids'].str.contains('DASH')]
# Out:
#           aracore_ids               aracore_name  \
# 8     Fd_DASH_NADPR_h  ferredoxin-NADP reductase
# 227  Asp_DASH_SeADH_h      Asp-SeA dehydrogenase
# 239   5M_DASH_THFOR_c      5M-THF oxidoreductase
#
#                                    aracore_annotations aracore_updated_ids  \
# 8    {'ec-code': '1.18.1.2', 'go': 'GO:0019684', 'k...     FD_DASH_NADPR_h
# 227  {'doi': '10.1006/prep.2001.1538', 'ec-code': '...    ASP_DASH_SEADH_h
# 239  {'doi': '10.1074/jbc.274.51.36089', 'ec-code':...     5M_DASH_THFOR_c
#
#     aracore_updated_universal_ids
# 8                   FD_DASH_NADPR
# 227                ASP_DASH_SEADH
# 239                 5M_DASH_THFOR

# %% [markdown]
# ## 2) Extraction of information

# %% [markdown]
# ### 2) a. Extract Kegg identifiers

# %%
# Extract Kegg Id from 'aracore_annotations' column (annotations are already provided as dictionaries => key "kegg.reactions")
df_reactions_aracore['kegg_id'] = df_reactions_aracore['aracore_annotations'].apply(lambda anno_dict: anno_dict['kegg.reaction'] if 'kegg.reaction' in anno_dict.keys() else None)

df_reactions_aracore.head(25)
# Out:
#         aracore_ids                                       aracore_name  \
# 0            PSII_h                                     photosystem II
# 1         Cytb6f1_h                              cytochrom b6f complex
# 2         Cytb6f2_h                              cytochrom b6f complex
# 3      PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4      PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 5            NDH1_h              NADH dehydrogenase-like (NDH) complex
# 6            NDH2_h              NADH dehydrogenase-like (NDH) complex
# 7             PSI_h                                      photosystem I
# 8   Fd_DASH_NADPR_h                          ferredoxin-NADP reductase
# 9          ATPase_h                                             ATPase
# 10            RBC_h                                            RuBisCO
# 11           PGAK_h                                         PGA kinase
# 12         GAPDH1_h                                  GAP dehydrogenase
# 13            TPI_h                                       TP isomerase
# 14           FBPA_h                                       FBP aldolase
# 15         FBPase_h                                             FBPase
# 16            FTK_h                                  F6P transketolase
# 17           SBPA_h                                       SBP aldolase
# 18         SBPase_h                                             SBPase
# 19            STK_h                                  S7P transketolase
# 20          Ru5PE_h                                     Ru5P epimerase
# 21           R5PI_h                                      R5P isomerase
# 22          Ru5PK_h                                        Ru5P kinase
# 23            PGI_h                                      G6P isomerase
# 24            PGM_h                                 Phosphoglucomutase
#
#                                   aracore_annotations aracore_updated_ids  \
# 0   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...              PSII_h
# 1   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...           CYTB6F1_h
# 2   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...           CYTB6F2_h
# 3   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...        PGR5PGRL11_h
# 4   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...        PGR5PGRL12_h
# 5   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...              NDH1_h
# 6   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...              NDH2_h
# 7   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...               PSI_h
# 8   {'ec-code': '1.18.1.2', 'go': 'GO:0019684', 'k...     FD_DASH_NADPR_h
# 9   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...            ATPASE_h
# 10  {'doi': '10.1146/annurev.arplant.53.100301.135...               RBC_h
# 11  {'ec-code': '2.7.2.3', 'go': ['GO:0019253', 'G...              PGAK_h
# 12  {'doi': ['10.1107/S1744309110013527', ' 10.107...            GAPDH1_h
# 13  {'ec-code': '5.3.1.1', 'go': ['GO:0019253', 'G...               TPI_h
# 14  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...              FBPA_h
# 15  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....            FBPASE_h
# 16  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...               FTK_h
# 17  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...              SBPA_h
# 18  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....            SBPASE_h
# 19  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...               STK_h
# 20  {'doi': '10.1104/pp.118.1.199', 'ec-code': '5....             RU5PE_h
# 21  {'ec-code': '5.3.1.6', 'go': ['GO:0019253', 'G...              R5PI_h
# 22  {'doi': '10.1104/pp.105.068445', 'ec-code': '2...             RU5PK_h
# 23  {'doi': '10.1104/pp.105.068445', 'ec-code': '5...               PGI_h
# 24  {'ec-code': '5.4.2.2', 'go': 'GO:0019252', 'ke...               PGM_h
#
#    aracore_updated_universal_ids kegg_id
# 0                           PSII  R09503
# 1                        CYTB6F1  R03817
# 2                        CYTB6F2  R03817
# 3                     PGR5PGRL11  R03817
# 4                     PGR5PGRL12  R03817
# 5                           NDH1  R03817
# 6                           NDH2  R03817
# 7                            PSI  R09542
# 8                  FD_DASH_NADPR  R01195
# 9                         ATPASE  R00086
# 10                           RBC  R00024
# 11                          PGAK  R01512
# 12                        GAPDH1  R01063
# 13                           TPI  R01015
# 14                          FBPA  R01068
# 15                        FBPASE  R00762
# 16                           FTK  R01067
# 17                          SBPA  R01829
# 18                        SBPASE  R01845
# 19                           STK  R01641
# 20                         RU5PE  R01529
# 21                          R5PI  R01056
# 22                         RU5PK  R01523
# 23                           PGI  R00771
# 24                           PGM  R08639

# %% [markdown]
# ### 2) b. Extract Ec codes

# %%
# Extract Ec code from 'aracore_annotations' column (annotations are already provided as dictionaries => key "ec-code")
df_reactions_aracore['ec-code'] = df_reactions_aracore['aracore_annotations'].apply(lambda anno_dict: anno_dict['ec-code'] if 'ec-code' in anno_dict.keys() else None)

df_reactions_aracore.head(25)
# Out:
#         aracore_ids                                       aracore_name  \
# 0            PSII_h                                     photosystem II
# 1         Cytb6f1_h                              cytochrom b6f complex
# 2         Cytb6f2_h                              cytochrom b6f complex
# 3      PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4      PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 5            NDH1_h              NADH dehydrogenase-like (NDH) complex
# 6            NDH2_h              NADH dehydrogenase-like (NDH) complex
# 7             PSI_h                                      photosystem I
# 8   Fd_DASH_NADPR_h                          ferredoxin-NADP reductase
# 9          ATPase_h                                             ATPase
# 10            RBC_h                                            RuBisCO
# 11           PGAK_h                                         PGA kinase
# 12         GAPDH1_h                                  GAP dehydrogenase
# 13            TPI_h                                       TP isomerase
# 14           FBPA_h                                       FBP aldolase
# 15         FBPase_h                                             FBPase
# 16            FTK_h                                  F6P transketolase
# 17           SBPA_h                                       SBP aldolase
# 18         SBPase_h                                             SBPase
# 19            STK_h                                  S7P transketolase
# 20          Ru5PE_h                                     Ru5P epimerase
# 21           R5PI_h                                      R5P isomerase
# 22          Ru5PK_h                                        Ru5P kinase
# 23            PGI_h                                      G6P isomerase
# 24            PGM_h                                 Phosphoglucomutase
#
#                                   aracore_annotations aracore_updated_ids  \
# 0   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...              PSII_h
# 1   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...           CYTB6F1_h
# 2   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...           CYTB6F2_h
# 3   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...        PGR5PGRL11_h
# 4   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...        PGR5PGRL12_h
# 5   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...              NDH1_h
# 6   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...              NDH2_h
# 7   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...               PSI_h
# 8   {'ec-code': '1.18.1.2', 'go': 'GO:0019684', 'k...     FD_DASH_NADPR_h
# 9   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...            ATPASE_h
# 10  {'doi': '10.1146/annurev.arplant.53.100301.135...               RBC_h
# 11  {'ec-code': '2.7.2.3', 'go': ['GO:0019253', 'G...              PGAK_h
# 12  {'doi': ['10.1107/S1744309110013527', ' 10.107...            GAPDH1_h
# 13  {'ec-code': '5.3.1.1', 'go': ['GO:0019253', 'G...               TPI_h
# 14  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...              FBPA_h
# 15  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....            FBPASE_h
# 16  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...               FTK_h
# 17  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...              SBPA_h
# 18  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....            SBPASE_h
# 19  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...               STK_h
# 20  {'doi': '10.1104/pp.118.1.199', 'ec-code': '5....             RU5PE_h
# 21  {'ec-code': '5.3.1.6', 'go': ['GO:0019253', 'G...              R5PI_h
# 22  {'doi': '10.1104/pp.105.068445', 'ec-code': '2...             RU5PK_h
# 23  {'doi': '10.1104/pp.105.068445', 'ec-code': '5...               PGI_h
# 24  {'ec-code': '5.4.2.2', 'go': 'GO:0019252', 'ke...               PGM_h
#
#    aracore_updated_universal_ids kegg_id    ec-code
# 0                           PSII  R09503   1.10.3.9
# 1                        CYTB6F1  R03817   1.10.9.1
# 2                        CYTB6F2  R03817   1.10.9.1
# 3                     PGR5PGRL11  R03817       None
# 4                     PGR5PGRL12  R03817       None
# 5                           NDH1  R03817       None
# 6                           NDH2  R03817       None
# 7                            PSI  R09542  1.97.1.12
# 8                  FD_DASH_NADPR  R01195   1.18.1.2
# 9                         ATPASE  R00086   3.6.3.14
# 10                           RBC  R00024   4.1.1.39
# 11                          PGAK  R01512    2.7.2.3
# 12                        GAPDH1  R01063   1.2.1.13
# 13                           TPI  R01015    5.3.1.1
# 14                          FBPA  R01068   4.1.2.13
# 15                        FBPASE  R00762   3.1.3.11
# 16                           FTK  R01067    2.2.1.1
# 17                          SBPA  R01829   4.1.2.13
# 18                        SBPASE  R01845   3.1.3.37
# 19                           STK  R01641    2.2.1.1
# 20                         RU5PE  R01529    5.1.3.1
# 21                          R5PI  R01056    5.3.1.6
# 22                         RU5PK  R01523   2.7.1.19
# 23                           PGI  R00771    5.3.1.9
# 24                           PGM  R08639    5.4.2.2

# %% [markdown]
# # III / Import BiGG reaction file

# %% [markdown]
# ## 1) Load BiGG reaction table

# %%
# Loag BIGG Reaction Table
bigg_reactions_url = 'http://bigg.ucsd.edu/static/namespace/bigg_models_reactions.txt'
df_reactions_bigg = pd.read_csv(bigg_reactions_url, sep='\t')
df_reactions_bigg.loc[170:200,:] # I just selected a range of reactions that will have a kegg identifier for sure, its only for demo
# Out:
#            bigg_id                                               name  \
# 170   12DGR181tipp  1,2 diacylglycerol transport via flipping (per...
# 171      12PPDStex  (S)-Propane-1,2-diol transport via diffusion (...
# 172  14GLUCANabcpp  1,4-alpha-D-glucan transport via ABC system (p...
# 173      23CCMPtex  23cCMP transport via diffusion (extracellular ...
# 174      23CGMPtex  23cGMP transport via diffusion (extracellular ...
# 175       23PDE2pp  2',3'-cyclic-nucleotide phosphodiesterase (UMP...
# 176       23PDE9pp  2',3'-cyclic-nucleotide phosphodiesterase (GMP...
# 177   2AGPA120tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C12:0) tr...
# 178   2AGPA140tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C14:0) tr...
# 179   2AGPA180tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C18:0) tr...
# 180   2AGPA181tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C18:1) tr...
# 181   2AGPE140tipp  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14...
# 182   2AGPE141tipp  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14...
# 183     2AGPEAT141  2-acyl-glycerophospho-ethanolamine acyltransfe...
# 184   2AGPG160tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0) ...
# 185   2AGPG161tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1) ...
# 186   2AGPG180tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0) ...
# 187   2AGPG181tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1) ...
# 188     2AGPGAT120  2-acyl-glycerophospho-glycerol acyltransferase...
# 189     2AGPGAT141  2-acyl-glycerophospho-glycerol acyltransferase...
# 190     2AGPGAT160  2-acyl-glycerophospho-glycerol acyltransferase...
# 191     2AGPGAT180  2-acyl-glycerophospho-glycerol acyltransferase...
# 192       2DGULRGx  2-Dehydro-L-gulonate reductase to gluconate (N...
# 193        2DGULRx              2-dehydro-L-gulonate reductase (NADH)
# 194         2MAHMP  2-Methyl-4-amino-5-hydroxymethylpyrimidine dip...
# 195        3AMPtex  3AMP transport via diffusion (extracellular to...
# 196        3GMPtex  3GMP transport via diffusion (extracellular to...
# 197        3HAD121  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 198        3HAD160  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 199        3HAD161  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 200        3HAD180  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
#
#                                        reaction_string  \
# 170                          12dgr181_p <-> 12dgr181_c
# 171                          12ppd__S_e <-> 12ppd__S_p
# 172  atp_c + h2o_c + 14glucan_p <-> 14glucan_c + ad...
# 173                              23ccmp_e <-> 23ccmp_p
# 174                              23cgmp_e <-> 23cgmp_p
# 175                  23cump_p + h2o_p <-> 3ump_p + h_p
# 176                  23cgmp_p + h2o_p <-> 3gmp_p + h_p
# 177                          2ddecg3p_p <-> 2ddecg3p_c
# 178                          2tdecg3p_p <-> 2tdecg3p_c
# 179                          2odecg3p_p <-> 2odecg3p_c
# 180                    2odec11eg3p_p <-> 2odec11eg3p_c
# 181                          2agpe140_p <-> 2agpe140_c
# 182                          2agpe141_p <-> 2agpe141_c
# 183  2agpe141_c + atp_c + ttdcea_c <-> amp_c + pe14...
# 184                          2agpg160_p <-> 2agpg160_c
# 185                          2agpg161_p <-> 2agpg161_c
# 186                          2agpg180_p <-> 2agpg180_c
# 187                          2agpg181_p <-> 2agpg181_c
# 188  2agpg120_c + atp_c + ddca_c <-> amp_c + pg120_...
# 189  2agpg141_c + atp_c + ttdcea_c <-> amp_c + pg14...
# 190  2agpg160_c + atp_c + hdca_c <-> amp_c + pg160_...
# 191  2agpg180_c + atp_c + ocdca_c <-> amp_c + pg180...
# 192        2dhguln_c + h_c + nadh_c <-> glcn_c + nad_c
# 193     2dhguln_c + h_c + nadh_c <-> idon__L_c + nad_c
# 194          2mahmp_c + h2o_c <-> 4ampm_c + h_c + pi_c
# 195                                  3amp_e <-> 3amp_p
# 196                                  3gmp_e <-> 3gmp_p
# 197          3hcddec5eACP_c <-> h2o_c + t3c5ddeceACP_c
# 198               3hpalmACP_c <-> h2o_c + tpalm2eACP_c
# 199          3hcpalm9eACP_c <-> h2o_c + t3c9palmeACP_c
# 200               3hoctaACP_c <-> h2o_c + toctd2eACP_c
#
#                                             model_list  \
# 170  iYS1720; iEC1344_C; iEC1364_W; iEC1349_Crooks;...
# 171  iEC1364_W; iEC1372_W3110; iEC1356_Bl21DE3; iEC...
# 172  iYS1720; iEC1356_Bl21DE3; iEC1349_Crooks; iEC1...
# 173  iEC1356_Bl21DE3; iEC1364_W; iEC1349_Crooks; iE...
# 174  iPC815; iECBD_1354; iE2348C_1286; iEcDH1_1363;...
# 175  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC135...
# 176  iEcHS_1320; iEcE24377_1341; iECS88_1305; iECOK...
# 177  iEC1344_C; iEC1372_W3110; iEC1364_W; iEC1349_C...
# 178  iBWG_1329; iEC042_1314; iEC55989_1330; iAF1260...
# 179  iEC1356_Bl21DE3; iEC1349_Crooks; iEC1364_W; iE...
# 180  iAF1260; iECD_1391; iEC042_1314; iAPECO1_1312;...
# 181  iECO26_1355; iECs_1301; iECP_1309; iEcolC_1368...
# 182  iZ_1308; STM_v1_0; iYL1228; iML1515; iUTI89_13...
# 183  iAPECO1_1312; iECABU_c1320; iEC55989_1330; iAF...
# 184  iZ_1308; iAF1260b; iUTI89_1310; iY75_1357; STM...
# 185  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC134...
# 186  iEC042_1314; iECB_1328; iEC55989_1330; iAF1260...
# 187  iYS1720; iEC1344_C; iEC1368_DH5a; iEC1356_Bl21...
# 188  iECO103_1326; iEcolC_1368; iECOK1_1307; iECNA1...
# 189  iEC1364_W; iEC1344_C; iEC1372_W3110; iEC1356_B...
# 190  iECABU_c1320; iEC55989_1330; ic_1306; iBWG_132...
# 191  iECO111_1330; iECP_1309; iECH74115_1262; iECDH...
# 192  iEC1368_DH5a; iEC1349_Crooks; iEC1344_C; iEC13...
# 193  iYS1720; iEC1349_Crooks; iEC1356_Bl21DE3; iEC1...
# 194  iAF1260b; iYL1228; iZ_1308; STM_v1_0; iWFL_137...
# 195  iS_1188; iLF82_1304; iNRG857_1313; iSSON_1240;...
# 196  iZ_1308; iY75_1357; iAF1260b; iUMNK88_1353; iY...
# 197  iUMN146_1321; iETEC_1333; iSDY_1059; iSBO_1134...
# 198  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iSynCJ...
# 199  iEcDH1_1363; iEC042_1314; iAPECO1_1312; iECBD_...
# 200  iSFV_1184; iSbBS512_1146; iECUMN_1333; iECSP_1...
#
#                                         database_links  \
# 170  MetaNetX (MNX) Equation: http://identifiers.or...
# 171  MetaNetX (MNX) Equation: http://identifiers.or...
# 172  MetaNetX (MNX) Equation: http://identifiers.or...
# 173  MetaNetX (MNX) Equation: http://identifiers.or...
# 174  MetaNetX (MNX) Equation: http://identifiers.or...
# 175  RHEA: http://identifiers.org/rhea/27878; RHEA:...
# 176  RHEA: http://identifiers.org/rhea/27858; RHEA:...
# 177  MetaNetX (MNX) Equation: http://identifiers.or...
# 178  MetaNetX (MNX) Equation: http://identifiers.or...
# 179  MetaNetX (MNX) Equation: http://identifiers.or...
# 180  MetaNetX (MNX) Equation: http://identifiers.or...
# 181  MetaNetX (MNX) Equation: http://identifiers.or...
# 182  MetaNetX (MNX) Equation: http://identifiers.or...
# 183  MetaNetX (MNX) Equation: http://identifiers.or...
# 184  MetaNetX (MNX) Equation: http://identifiers.or...
# 185  MetaNetX (MNX) Equation: http://identifiers.or...
# 186  MetaNetX (MNX) Equation: http://identifiers.or...
# 187  MetaNetX (MNX) Equation: http://identifiers.or...
# 188  MetaNetX (MNX) Equation: http://identifiers.or...
# 189  MetaNetX (MNX) Equation: http://identifiers.or...
# 190  MetaNetX (MNX) Equation: http://identifiers.or...
# 191  MetaNetX (MNX) Equation: http://identifiers.or...
# 192  MetaNetX (MNX) Equation: http://identifiers.or...
# 193  MetaNetX (MNX) Equation: http://identifiers.or...
# 194  MetaNetX (MNX) Equation: http://identifiers.or...
# 195  MetaNetX (MNX) Equation: http://identifiers.or...
# 196  MetaNetX (MNX) Equation: http://identifiers.or...
# 197  EC Number: http://identifiers.org/ec-code/4.2....
# 198  EC Number: http://identifiers.org/ec-code/2.3....
# 199  EC Number: http://identifiers.org/ec-code/4.2....
# 200  EC Number: http://identifiers.org/ec-code/2.3....
#
#                 old_bigg_ids
# 170             12DGR181tipp
# 171                12PPDStex
# 172            14GLUCANabcpp
# 173                23CCMPtex
# 174                23CGMPtex
# 175                 23PDE2pp
# 176                 23PDE9pp
# 177             2AGPA120tipp
# 178             2AGPA140tipp
# 179             2AGPA180tipp
# 180             2AGPA181tipp
# 181             2AGPE140tipp
# 182             2AGPE141tipp
# 183  2AGPEAT141; _2AGPEAT141
# 184             2AGPG160tipp
# 185             2AGPG161tipp
# 186             2AGPG180tipp
# 187             2AGPG181tipp
# 188  2AGPGAT120; _2AGPGAT120
# 189  2AGPGAT141; _2AGPGAT141
# 190  2AGPGAT160; _2AGPGAT160
# 191  2AGPGAT180; _2AGPGAT180
# 192                 2DGULRGx
# 193                  2DGULRx
# 194                   2MAHMP
# 195                  3AMPtex
# 196                  3GMPtex
# 197        3HAD121; _3HAD121
# 198        3HAD160; _3HAD160
# 199        3HAD161; _3HAD161
# 200        3HAD180; _3HAD180

# %% [markdown]
# ## 2) Changes to the extracted information

# %%
#Convert string of database links into dictionaries of database identifier/symbol (key) and database-specific metabolite/annotation id (value)
df_reactions_bigg['database_links'] = df_reactions_bigg['database_links'].apply(lambda str_links: {db_link.split(':',1)[-1].split('/')[-2]: db_link.split(':',1)[-1].split('/')[-1] for db_link in str_links.split(';')} if isinstance(str_links,str) else {})

# %%
#All database keys in database_links
np.unique(df_reactions_bigg['database_links'].apply(lambda x: list(x.keys())).sum())
# Out:
# array(['biocyc', 'ec-code', 'kegg.reaction', 'metanetx.reaction',
#        'reactome', 'rhea', 'seed.reaction'], dtype='<U17')

# %% [markdown]
# ## 3) Extract Kegg and Ec-code identifiers from "database_links" column

# %%
#Extract kegg id from 'database_links' column (dictionary => key "kegg.reaction")
df_reactions_bigg['kegg.reaction'] = df_reactions_bigg['database_links'].apply(lambda dict_db_link:  dict_db_link['kegg.reaction'] if 'kegg.reaction' in dict_db_link.keys() else None)
df_reactions_bigg.loc[170:200]
# Out:
#            bigg_id                                               name  \
# 170   12DGR181tipp  1,2 diacylglycerol transport via flipping (per...
# 171      12PPDStex  (S)-Propane-1,2-diol transport via diffusion (...
# 172  14GLUCANabcpp  1,4-alpha-D-glucan transport via ABC system (p...
# 173      23CCMPtex  23cCMP transport via diffusion (extracellular ...
# 174      23CGMPtex  23cGMP transport via diffusion (extracellular ...
# 175       23PDE2pp  2',3'-cyclic-nucleotide phosphodiesterase (UMP...
# 176       23PDE9pp  2',3'-cyclic-nucleotide phosphodiesterase (GMP...
# 177   2AGPA120tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C12:0) tr...
# 178   2AGPA140tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C14:0) tr...
# 179   2AGPA180tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C18:0) tr...
# 180   2AGPA181tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C18:1) tr...
# 181   2AGPE140tipp  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14...
# 182   2AGPE141tipp  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14...
# 183     2AGPEAT141  2-acyl-glycerophospho-ethanolamine acyltransfe...
# 184   2AGPG160tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0) ...
# 185   2AGPG161tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1) ...
# 186   2AGPG180tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0) ...
# 187   2AGPG181tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1) ...
# 188     2AGPGAT120  2-acyl-glycerophospho-glycerol acyltransferase...
# 189     2AGPGAT141  2-acyl-glycerophospho-glycerol acyltransferase...
# 190     2AGPGAT160  2-acyl-glycerophospho-glycerol acyltransferase...
# 191     2AGPGAT180  2-acyl-glycerophospho-glycerol acyltransferase...
# 192       2DGULRGx  2-Dehydro-L-gulonate reductase to gluconate (N...
# 193        2DGULRx              2-dehydro-L-gulonate reductase (NADH)
# 194         2MAHMP  2-Methyl-4-amino-5-hydroxymethylpyrimidine dip...
# 195        3AMPtex  3AMP transport via diffusion (extracellular to...
# 196        3GMPtex  3GMP transport via diffusion (extracellular to...
# 197        3HAD121  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 198        3HAD160  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 199        3HAD161  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 200        3HAD180  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
#
#                                        reaction_string  \
# 170                          12dgr181_p <-> 12dgr181_c
# 171                          12ppd__S_e <-> 12ppd__S_p
# 172  atp_c + h2o_c + 14glucan_p <-> 14glucan_c + ad...
# 173                              23ccmp_e <-> 23ccmp_p
# 174                              23cgmp_e <-> 23cgmp_p
# 175                  23cump_p + h2o_p <-> 3ump_p + h_p
# 176                  23cgmp_p + h2o_p <-> 3gmp_p + h_p
# 177                          2ddecg3p_p <-> 2ddecg3p_c
# 178                          2tdecg3p_p <-> 2tdecg3p_c
# 179                          2odecg3p_p <-> 2odecg3p_c
# 180                    2odec11eg3p_p <-> 2odec11eg3p_c
# 181                          2agpe140_p <-> 2agpe140_c
# 182                          2agpe141_p <-> 2agpe141_c
# 183  2agpe141_c + atp_c + ttdcea_c <-> amp_c + pe14...
# 184                          2agpg160_p <-> 2agpg160_c
# 185                          2agpg161_p <-> 2agpg161_c
# 186                          2agpg180_p <-> 2agpg180_c
# 187                          2agpg181_p <-> 2agpg181_c
# 188  2agpg120_c + atp_c + ddca_c <-> amp_c + pg120_...
# 189  2agpg141_c + atp_c + ttdcea_c <-> amp_c + pg14...
# 190  2agpg160_c + atp_c + hdca_c <-> amp_c + pg160_...
# 191  2agpg180_c + atp_c + ocdca_c <-> amp_c + pg180...
# 192        2dhguln_c + h_c + nadh_c <-> glcn_c + nad_c
# 193     2dhguln_c + h_c + nadh_c <-> idon__L_c + nad_c
# 194          2mahmp_c + h2o_c <-> 4ampm_c + h_c + pi_c
# 195                                  3amp_e <-> 3amp_p
# 196                                  3gmp_e <-> 3gmp_p
# 197          3hcddec5eACP_c <-> h2o_c + t3c5ddeceACP_c
# 198               3hpalmACP_c <-> h2o_c + tpalm2eACP_c
# 199          3hcpalm9eACP_c <-> h2o_c + t3c9palmeACP_c
# 200               3hoctaACP_c <-> h2o_c + toctd2eACP_c
#
#                                             model_list  \
# 170  iYS1720; iEC1344_C; iEC1364_W; iEC1349_Crooks;...
# 171  iEC1364_W; iEC1372_W3110; iEC1356_Bl21DE3; iEC...
# 172  iYS1720; iEC1356_Bl21DE3; iEC1349_Crooks; iEC1...
# 173  iEC1356_Bl21DE3; iEC1364_W; iEC1349_Crooks; iE...
# 174  iPC815; iECBD_1354; iE2348C_1286; iEcDH1_1363;...
# 175  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC135...
# 176  iEcHS_1320; iEcE24377_1341; iECS88_1305; iECOK...
# 177  iEC1344_C; iEC1372_W3110; iEC1364_W; iEC1349_C...
# 178  iBWG_1329; iEC042_1314; iEC55989_1330; iAF1260...
# 179  iEC1356_Bl21DE3; iEC1349_Crooks; iEC1364_W; iE...
# 180  iAF1260; iECD_1391; iEC042_1314; iAPECO1_1312;...
# 181  iECO26_1355; iECs_1301; iECP_1309; iEcolC_1368...
# 182  iZ_1308; STM_v1_0; iYL1228; iML1515; iUTI89_13...
# 183  iAPECO1_1312; iECABU_c1320; iEC55989_1330; iAF...
# 184  iZ_1308; iAF1260b; iUTI89_1310; iY75_1357; STM...
# 185  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC134...
# 186  iEC042_1314; iECB_1328; iEC55989_1330; iAF1260...
# 187  iYS1720; iEC1344_C; iEC1368_DH5a; iEC1356_Bl21...
# 188  iECO103_1326; iEcolC_1368; iECOK1_1307; iECNA1...
# 189  iEC1364_W; iEC1344_C; iEC1372_W3110; iEC1356_B...
# 190  iECABU_c1320; iEC55989_1330; ic_1306; iBWG_132...
# 191  iECO111_1330; iECP_1309; iECH74115_1262; iECDH...
# 192  iEC1368_DH5a; iEC1349_Crooks; iEC1344_C; iEC13...
# 193  iYS1720; iEC1349_Crooks; iEC1356_Bl21DE3; iEC1...
# 194  iAF1260b; iYL1228; iZ_1308; STM_v1_0; iWFL_137...
# 195  iS_1188; iLF82_1304; iNRG857_1313; iSSON_1240;...
# 196  iZ_1308; iY75_1357; iAF1260b; iUMNK88_1353; iY...
# 197  iUMN146_1321; iETEC_1333; iSDY_1059; iSBO_1134...
# 198  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iSynCJ...
# 199  iEcDH1_1363; iEC042_1314; iAPECO1_1312; iECBD_...
# 200  iSFV_1184; iSbBS512_1146; iECUMN_1333; iECSP_1...
#
#                                         database_links  \
# 170                 {'metanetx.reaction': 'MNXR94681'}
# 171                 {'metanetx.reaction': 'MNXR94684'}
# 172                 {'metanetx.reaction': 'MNXR94693'}
# 173  {'metanetx.reaction': 'MNXR94720', 'seed.react...
# 174  {'metanetx.reaction': 'MNXR94721', 'seed.react...
# 175  {'rhea': '27881', 'ec-code': '3.1.4.16', 'bioc...
# 176  {'rhea': '27861', 'ec-code': '3.1.4.16', 'bioc...
# 177  {'metanetx.reaction': 'MNXR94743', 'seed.react...
# 178  {'metanetx.reaction': 'MNXR94744', 'seed.react...
# 179  {'metanetx.reaction': 'MNXR94748', 'seed.react...
# 180  {'metanetx.reaction': 'MNXR94749', 'seed.react...
# 181                 {'metanetx.reaction': 'MNXR94751'}
# 182                 {'metanetx.reaction': 'MNXR94752'}
# 183                 {'metanetx.reaction': 'MNXR94759'}
# 184                 {'metanetx.reaction': 'MNXR94767'}
# 185                 {'metanetx.reaction': 'MNXR94768'}
# 186                 {'metanetx.reaction': 'MNXR94769'}
# 187                 {'metanetx.reaction': 'MNXR94770'}
# 188                 {'metanetx.reaction': 'MNXR94771'}
# 189                 {'metanetx.reaction': 'MNXR94773'}
# 190                 {'metanetx.reaction': 'MNXR94774'}
# 191                 {'metanetx.reaction': 'MNXR94776'}
# 192                 {'metanetx.reaction': 'MNXR94785'}
# 193  {'metanetx.reaction': 'MNXR94787', 'seed.react...
# 194  {'metanetx.reaction': 'MNXR142616', 'seed.reac...
# 195  {'metanetx.reaction': 'MNXR94857', 'seed.react...
# 196  {'metanetx.reaction': 'MNXR94868', 'seed.react...
# 197  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
# 198  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
# 199  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
# 200  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
#
#                 old_bigg_ids kegg.reaction
# 170             12DGR181tipp          None
# 171                12PPDStex          None
# 172            14GLUCANabcpp          None
# 173                23CCMPtex          None
# 174                23CGMPtex          None
# 175                 23PDE2pp        R03538
# 176                 23PDE9pp        R05135
# 177             2AGPA120tipp          None
# 178             2AGPA140tipp          None
# 179             2AGPA180tipp          None
# 180             2AGPA181tipp          None
# 181             2AGPE140tipp          None
# 182             2AGPE141tipp          None
# 183  2AGPEAT141; _2AGPEAT141          None
# 184             2AGPG160tipp          None
# 185             2AGPG161tipp          None
# 186             2AGPG180tipp          None
# 187             2AGPG181tipp          None
# 188  2AGPGAT120; _2AGPGAT120          None
# 189  2AGPGAT141; _2AGPGAT141          None
# 190  2AGPGAT160; _2AGPGAT160          None
# 191  2AGPGAT180; _2AGPGAT180          None
# 192                 2DGULRGx          None
# 193                  2DGULRx          None
# 194                   2MAHMP          None
# 195                  3AMPtex          None
# 196                  3GMPtex          None
# 197        3HAD121; _3HAD121          None
# 198        3HAD160; _3HAD160        R04544
# 199        3HAD161; _3HAD161          None
# 200        3HAD180; _3HAD180        R07764

# %%
#Extract ec-code from 'database_links' column (dictionary => key "ec-code")
df_reactions_bigg['ec-code'] = df_reactions_bigg['database_links'].apply(lambda dict_db_link:  dict_db_link['ec-code'] if 'ec-code' in dict_db_link.keys() else None)
df_reactions_bigg.loc[170:200]
# Out:
#            bigg_id                                               name  \
# 170   12DGR181tipp  1,2 diacylglycerol transport via flipping (per...
# 171      12PPDStex  (S)-Propane-1,2-diol transport via diffusion (...
# 172  14GLUCANabcpp  1,4-alpha-D-glucan transport via ABC system (p...
# 173      23CCMPtex  23cCMP transport via diffusion (extracellular ...
# 174      23CGMPtex  23cGMP transport via diffusion (extracellular ...
# 175       23PDE2pp  2',3'-cyclic-nucleotide phosphodiesterase (UMP...
# 176       23PDE9pp  2',3'-cyclic-nucleotide phosphodiesterase (GMP...
# 177   2AGPA120tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C12:0) tr...
# 178   2AGPA140tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C14:0) tr...
# 179   2AGPA180tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C18:0) tr...
# 180   2AGPA181tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C18:1) tr...
# 181   2AGPE140tipp  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14...
# 182   2AGPE141tipp  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14...
# 183     2AGPEAT141  2-acyl-glycerophospho-ethanolamine acyltransfe...
# 184   2AGPG160tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0) ...
# 185   2AGPG161tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1) ...
# 186   2AGPG180tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0) ...
# 187   2AGPG181tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1) ...
# 188     2AGPGAT120  2-acyl-glycerophospho-glycerol acyltransferase...
# 189     2AGPGAT141  2-acyl-glycerophospho-glycerol acyltransferase...
# 190     2AGPGAT160  2-acyl-glycerophospho-glycerol acyltransferase...
# 191     2AGPGAT180  2-acyl-glycerophospho-glycerol acyltransferase...
# 192       2DGULRGx  2-Dehydro-L-gulonate reductase to gluconate (N...
# 193        2DGULRx              2-dehydro-L-gulonate reductase (NADH)
# 194         2MAHMP  2-Methyl-4-amino-5-hydroxymethylpyrimidine dip...
# 195        3AMPtex  3AMP transport via diffusion (extracellular to...
# 196        3GMPtex  3GMP transport via diffusion (extracellular to...
# 197        3HAD121  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 198        3HAD160  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 199        3HAD161  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 200        3HAD180  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
#
#                                        reaction_string  \
# 170                          12dgr181_p <-> 12dgr181_c
# 171                          12ppd__S_e <-> 12ppd__S_p
# 172  atp_c + h2o_c + 14glucan_p <-> 14glucan_c + ad...
# 173                              23ccmp_e <-> 23ccmp_p
# 174                              23cgmp_e <-> 23cgmp_p
# 175                  23cump_p + h2o_p <-> 3ump_p + h_p
# 176                  23cgmp_p + h2o_p <-> 3gmp_p + h_p
# 177                          2ddecg3p_p <-> 2ddecg3p_c
# 178                          2tdecg3p_p <-> 2tdecg3p_c
# 179                          2odecg3p_p <-> 2odecg3p_c
# 180                    2odec11eg3p_p <-> 2odec11eg3p_c
# 181                          2agpe140_p <-> 2agpe140_c
# 182                          2agpe141_p <-> 2agpe141_c
# 183  2agpe141_c + atp_c + ttdcea_c <-> amp_c + pe14...
# 184                          2agpg160_p <-> 2agpg160_c
# 185                          2agpg161_p <-> 2agpg161_c
# 186                          2agpg180_p <-> 2agpg180_c
# 187                          2agpg181_p <-> 2agpg181_c
# 188  2agpg120_c + atp_c + ddca_c <-> amp_c + pg120_...
# 189  2agpg141_c + atp_c + ttdcea_c <-> amp_c + pg14...
# 190  2agpg160_c + atp_c + hdca_c <-> amp_c + pg160_...
# 191  2agpg180_c + atp_c + ocdca_c <-> amp_c + pg180...
# 192        2dhguln_c + h_c + nadh_c <-> glcn_c + nad_c
# 193     2dhguln_c + h_c + nadh_c <-> idon__L_c + nad_c
# 194          2mahmp_c + h2o_c <-> 4ampm_c + h_c + pi_c
# 195                                  3amp_e <-> 3amp_p
# 196                                  3gmp_e <-> 3gmp_p
# 197          3hcddec5eACP_c <-> h2o_c + t3c5ddeceACP_c
# 198               3hpalmACP_c <-> h2o_c + tpalm2eACP_c
# 199          3hcpalm9eACP_c <-> h2o_c + t3c9palmeACP_c
# 200               3hoctaACP_c <-> h2o_c + toctd2eACP_c
#
#                                             model_list  \
# 170  iYS1720; iEC1344_C; iEC1364_W; iEC1349_Crooks;...
# 171  iEC1364_W; iEC1372_W3110; iEC1356_Bl21DE3; iEC...
# 172  iYS1720; iEC1356_Bl21DE3; iEC1349_Crooks; iEC1...
# 173  iEC1356_Bl21DE3; iEC1364_W; iEC1349_Crooks; iE...
# 174  iPC815; iECBD_1354; iE2348C_1286; iEcDH1_1363;...
# 175  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC135...
# 176  iEcHS_1320; iEcE24377_1341; iECS88_1305; iECOK...
# 177  iEC1344_C; iEC1372_W3110; iEC1364_W; iEC1349_C...
# 178  iBWG_1329; iEC042_1314; iEC55989_1330; iAF1260...
# 179  iEC1356_Bl21DE3; iEC1349_Crooks; iEC1364_W; iE...
# 180  iAF1260; iECD_1391; iEC042_1314; iAPECO1_1312;...
# 181  iECO26_1355; iECs_1301; iECP_1309; iEcolC_1368...
# 182  iZ_1308; STM_v1_0; iYL1228; iML1515; iUTI89_13...
# 183  iAPECO1_1312; iECABU_c1320; iEC55989_1330; iAF...
# 184  iZ_1308; iAF1260b; iUTI89_1310; iY75_1357; STM...
# 185  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC134...
# 186  iEC042_1314; iECB_1328; iEC55989_1330; iAF1260...
# 187  iYS1720; iEC1344_C; iEC1368_DH5a; iEC1356_Bl21...
# 188  iECO103_1326; iEcolC_1368; iECOK1_1307; iECNA1...
# 189  iEC1364_W; iEC1344_C; iEC1372_W3110; iEC1356_B...
# 190  iECABU_c1320; iEC55989_1330; ic_1306; iBWG_132...
# 191  iECO111_1330; iECP_1309; iECH74115_1262; iECDH...
# 192  iEC1368_DH5a; iEC1349_Crooks; iEC1344_C; iEC13...
# 193  iYS1720; iEC1349_Crooks; iEC1356_Bl21DE3; iEC1...
# 194  iAF1260b; iYL1228; iZ_1308; STM_v1_0; iWFL_137...
# 195  iS_1188; iLF82_1304; iNRG857_1313; iSSON_1240;...
# 196  iZ_1308; iY75_1357; iAF1260b; iUMNK88_1353; iY...
# 197  iUMN146_1321; iETEC_1333; iSDY_1059; iSBO_1134...
# 198  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iSynCJ...
# 199  iEcDH1_1363; iEC042_1314; iAPECO1_1312; iECBD_...
# 200  iSFV_1184; iSbBS512_1146; iECUMN_1333; iECSP_1...
#
#                                         database_links  \
# 170                 {'metanetx.reaction': 'MNXR94681'}
# 171                 {'metanetx.reaction': 'MNXR94684'}
# 172                 {'metanetx.reaction': 'MNXR94693'}
# 173  {'metanetx.reaction': 'MNXR94720', 'seed.react...
# 174  {'metanetx.reaction': 'MNXR94721', 'seed.react...
# 175  {'rhea': '27881', 'ec-code': '3.1.4.16', 'bioc...
# 176  {'rhea': '27861', 'ec-code': '3.1.4.16', 'bioc...
# 177  {'metanetx.reaction': 'MNXR94743', 'seed.react...
# 178  {'metanetx.reaction': 'MNXR94744', 'seed.react...
# 179  {'metanetx.reaction': 'MNXR94748', 'seed.react...
# 180  {'metanetx.reaction': 'MNXR94749', 'seed.react...
# 181                 {'metanetx.reaction': 'MNXR94751'}
# 182                 {'metanetx.reaction': 'MNXR94752'}
# 183                 {'metanetx.reaction': 'MNXR94759'}
# 184                 {'metanetx.reaction': 'MNXR94767'}
# 185                 {'metanetx.reaction': 'MNXR94768'}
# 186                 {'metanetx.reaction': 'MNXR94769'}
# 187                 {'metanetx.reaction': 'MNXR94770'}
# 188                 {'metanetx.reaction': 'MNXR94771'}
# 189                 {'metanetx.reaction': 'MNXR94773'}
# 190                 {'metanetx.reaction': 'MNXR94774'}
# 191                 {'metanetx.reaction': 'MNXR94776'}
# 192                 {'metanetx.reaction': 'MNXR94785'}
# 193  {'metanetx.reaction': 'MNXR94787', 'seed.react...
# 194  {'metanetx.reaction': 'MNXR142616', 'seed.reac...
# 195  {'metanetx.reaction': 'MNXR94857', 'seed.react...
# 196  {'metanetx.reaction': 'MNXR94868', 'seed.react...
# 197  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
# 198  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
# 199  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
# 200  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
#
#                 old_bigg_ids kegg.reaction   ec-code
# 170             12DGR181tipp          None      None
# 171                12PPDStex          None      None
# 172            14GLUCANabcpp          None      None
# 173                23CCMPtex          None      None
# 174                23CGMPtex          None      None
# 175                 23PDE2pp        R03538  3.1.4.16
# 176                 23PDE9pp        R05135  3.1.4.16
# 177             2AGPA120tipp          None      None
# 178             2AGPA140tipp          None      None
# 179             2AGPA180tipp          None      None
# 180             2AGPA181tipp          None      None
# 181             2AGPE140tipp          None      None
# 182             2AGPE141tipp          None      None
# 183  2AGPEAT141; _2AGPEAT141          None      None
# 184             2AGPG160tipp          None      None
# 185             2AGPG161tipp          None      None
# 186             2AGPG180tipp          None      None
# 187             2AGPG181tipp          None      None
# 188  2AGPGAT120; _2AGPGAT120          None      None
# 189  2AGPGAT141; _2AGPGAT141          None      None
# 190  2AGPGAT160; _2AGPGAT160          None      None
# 191  2AGPGAT180; _2AGPGAT180          None      None
# 192                 2DGULRGx          None      None
# 193                  2DGULRx          None      None
# 194                   2MAHMP          None      None
# 195                  3AMPtex          None      None
# 196                  3GMPtex          None      None
# 197        3HAD121; _3HAD121          None  4.2.1.61
# 198        3HAD160; _3HAD160        R04544  4.2.1.61
# 199        3HAD161; _3HAD161          None  4.2.1.61
# 200        3HAD180; _3HAD180        R07764  4.2.1.61

# %% [markdown]
# ## 4) Extract seed.reaction from "database_links" column

# %%
#Extract seed.reaction from 'database_links' column (dictionary => key "seed.reaction")
df_reactions_bigg['seed.reaction'] = df_reactions_bigg['database_links'].apply(lambda dict_db_link:  dict_db_link['seed.reaction'] if 'seed.reaction' in dict_db_link.keys() else None)
df_reactions_bigg.loc[170:200] # put ","
# Out:
#            bigg_id                                               name  \
# 170   12DGR181tipp  1,2 diacylglycerol transport via flipping (per...
# 171      12PPDStex  (S)-Propane-1,2-diol transport via diffusion (...
# 172  14GLUCANabcpp  1,4-alpha-D-glucan transport via ABC system (p...
# 173      23CCMPtex  23cCMP transport via diffusion (extracellular ...
# 174      23CGMPtex  23cGMP transport via diffusion (extracellular ...
# 175       23PDE2pp  2',3'-cyclic-nucleotide phosphodiesterase (UMP...
# 176       23PDE9pp  2',3'-cyclic-nucleotide phosphodiesterase (GMP...
# 177   2AGPA120tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C12:0) tr...
# 178   2AGPA140tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C14:0) tr...
# 179   2AGPA180tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C18:0) tr...
# 180   2AGPA181tipp  2-Acyl-sn-glycero-3-phosphatidate (n-C18:1) tr...
# 181   2AGPE140tipp  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14...
# 182   2AGPE141tipp  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14...
# 183     2AGPEAT141  2-acyl-glycerophospho-ethanolamine acyltransfe...
# 184   2AGPG160tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0) ...
# 185   2AGPG161tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1) ...
# 186   2AGPG180tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0) ...
# 187   2AGPG181tipp  2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1) ...
# 188     2AGPGAT120  2-acyl-glycerophospho-glycerol acyltransferase...
# 189     2AGPGAT141  2-acyl-glycerophospho-glycerol acyltransferase...
# 190     2AGPGAT160  2-acyl-glycerophospho-glycerol acyltransferase...
# 191     2AGPGAT180  2-acyl-glycerophospho-glycerol acyltransferase...
# 192       2DGULRGx  2-Dehydro-L-gulonate reductase to gluconate (N...
# 193        2DGULRx              2-dehydro-L-gulonate reductase (NADH)
# 194         2MAHMP  2-Methyl-4-amino-5-hydroxymethylpyrimidine dip...
# 195        3AMPtex  3AMP transport via diffusion (extracellular to...
# 196        3GMPtex  3GMP transport via diffusion (extracellular to...
# 197        3HAD121  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 198        3HAD160  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 199        3HAD161  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
# 200        3HAD180  3-hydroxyacyl-[acyl-carrier-protein] dehydrata...
#
#                                        reaction_string  \
# 170                          12dgr181_p <-> 12dgr181_c
# 171                          12ppd__S_e <-> 12ppd__S_p
# 172  atp_c + h2o_c + 14glucan_p <-> 14glucan_c + ad...
# 173                              23ccmp_e <-> 23ccmp_p
# 174                              23cgmp_e <-> 23cgmp_p
# 175                  23cump_p + h2o_p <-> 3ump_p + h_p
# 176                  23cgmp_p + h2o_p <-> 3gmp_p + h_p
# 177                          2ddecg3p_p <-> 2ddecg3p_c
# 178                          2tdecg3p_p <-> 2tdecg3p_c
# 179                          2odecg3p_p <-> 2odecg3p_c
# 180                    2odec11eg3p_p <-> 2odec11eg3p_c
# 181                          2agpe140_p <-> 2agpe140_c
# 182                          2agpe141_p <-> 2agpe141_c
# 183  2agpe141_c + atp_c + ttdcea_c <-> amp_c + pe14...
# 184                          2agpg160_p <-> 2agpg160_c
# 185                          2agpg161_p <-> 2agpg161_c
# 186                          2agpg180_p <-> 2agpg180_c
# 187                          2agpg181_p <-> 2agpg181_c
# 188  2agpg120_c + atp_c + ddca_c <-> amp_c + pg120_...
# 189  2agpg141_c + atp_c + ttdcea_c <-> amp_c + pg14...
# 190  2agpg160_c + atp_c + hdca_c <-> amp_c + pg160_...
# 191  2agpg180_c + atp_c + ocdca_c <-> amp_c + pg180...
# 192        2dhguln_c + h_c + nadh_c <-> glcn_c + nad_c
# 193     2dhguln_c + h_c + nadh_c <-> idon__L_c + nad_c
# 194          2mahmp_c + h2o_c <-> 4ampm_c + h_c + pi_c
# 195                                  3amp_e <-> 3amp_p
# 196                                  3gmp_e <-> 3gmp_p
# 197          3hcddec5eACP_c <-> h2o_c + t3c5ddeceACP_c
# 198               3hpalmACP_c <-> h2o_c + tpalm2eACP_c
# 199          3hcpalm9eACP_c <-> h2o_c + t3c9palmeACP_c
# 200               3hoctaACP_c <-> h2o_c + toctd2eACP_c
#
#                                             model_list  \
# 170  iYS1720; iEC1344_C; iEC1364_W; iEC1349_Crooks;...
# 171  iEC1364_W; iEC1372_W3110; iEC1356_Bl21DE3; iEC...
# 172  iYS1720; iEC1356_Bl21DE3; iEC1349_Crooks; iEC1...
# 173  iEC1356_Bl21DE3; iEC1364_W; iEC1349_Crooks; iE...
# 174  iPC815; iECBD_1354; iE2348C_1286; iEcDH1_1363;...
# 175  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC135...
# 176  iEcHS_1320; iEcE24377_1341; iECS88_1305; iECOK...
# 177  iEC1344_C; iEC1372_W3110; iEC1364_W; iEC1349_C...
# 178  iBWG_1329; iEC042_1314; iEC55989_1330; iAF1260...
# 179  iEC1356_Bl21DE3; iEC1349_Crooks; iEC1364_W; iE...
# 180  iAF1260; iECD_1391; iEC042_1314; iAPECO1_1312;...
# 181  iECO26_1355; iECs_1301; iECP_1309; iEcolC_1368...
# 182  iZ_1308; STM_v1_0; iYL1228; iML1515; iUTI89_13...
# 183  iAPECO1_1312; iECABU_c1320; iEC55989_1330; iAF...
# 184  iZ_1308; iAF1260b; iUTI89_1310; iY75_1357; STM...
# 185  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iEC134...
# 186  iEC042_1314; iECB_1328; iEC55989_1330; iAF1260...
# 187  iYS1720; iEC1344_C; iEC1368_DH5a; iEC1356_Bl21...
# 188  iECO103_1326; iEcolC_1368; iECOK1_1307; iECNA1...
# 189  iEC1364_W; iEC1344_C; iEC1372_W3110; iEC1356_B...
# 190  iECABU_c1320; iEC55989_1330; ic_1306; iBWG_132...
# 191  iECO111_1330; iECP_1309; iECH74115_1262; iECDH...
# 192  iEC1368_DH5a; iEC1349_Crooks; iEC1344_C; iEC13...
# 193  iYS1720; iEC1349_Crooks; iEC1356_Bl21DE3; iEC1...
# 194  iAF1260b; iYL1228; iZ_1308; STM_v1_0; iWFL_137...
# 195  iS_1188; iLF82_1304; iNRG857_1313; iSSON_1240;...
# 196  iZ_1308; iY75_1357; iAF1260b; iUMNK88_1353; iY...
# 197  iUMN146_1321; iETEC_1333; iSDY_1059; iSBO_1134...
# 198  iEC1364_W; iEC1368_DH5a; iEC1372_W3110; iSynCJ...
# 199  iEcDH1_1363; iEC042_1314; iAPECO1_1312; iECBD_...
# 200  iSFV_1184; iSbBS512_1146; iECUMN_1333; iECSP_1...
#
#                                         database_links  \
# 170                 {'metanetx.reaction': 'MNXR94681'}
# 171                 {'metanetx.reaction': 'MNXR94684'}
# 172                 {'metanetx.reaction': 'MNXR94693'}
# 173  {'metanetx.reaction': 'MNXR94720', 'seed.react...
# 174  {'metanetx.reaction': 'MNXR94721', 'seed.react...
# 175  {'rhea': '27881', 'ec-code': '3.1.4.16', 'bioc...
# 176  {'rhea': '27861', 'ec-code': '3.1.4.16', 'bioc...
# 177  {'metanetx.reaction': 'MNXR94743', 'seed.react...
# 178  {'metanetx.reaction': 'MNXR94744', 'seed.react...
# 179  {'metanetx.reaction': 'MNXR94748', 'seed.react...
# 180  {'metanetx.reaction': 'MNXR94749', 'seed.react...
# 181                 {'metanetx.reaction': 'MNXR94751'}
# 182                 {'metanetx.reaction': 'MNXR94752'}
# 183                 {'metanetx.reaction': 'MNXR94759'}
# 184                 {'metanetx.reaction': 'MNXR94767'}
# 185                 {'metanetx.reaction': 'MNXR94768'}
# 186                 {'metanetx.reaction': 'MNXR94769'}
# 187                 {'metanetx.reaction': 'MNXR94770'}
# 188                 {'metanetx.reaction': 'MNXR94771'}
# 189                 {'metanetx.reaction': 'MNXR94773'}
# 190                 {'metanetx.reaction': 'MNXR94774'}
# 191                 {'metanetx.reaction': 'MNXR94776'}
# 192                 {'metanetx.reaction': 'MNXR94785'}
# 193  {'metanetx.reaction': 'MNXR94787', 'seed.react...
# 194  {'metanetx.reaction': 'MNXR142616', 'seed.reac...
# 195  {'metanetx.reaction': 'MNXR94857', 'seed.react...
# 196  {'metanetx.reaction': 'MNXR94868', 'seed.react...
# 197  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
# 198  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
# 199  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
# 200  {'ec-code': '4.2.1.61', 'metanetx.reaction': '...
#
#                 old_bigg_ids kegg.reaction   ec-code seed.reaction
# 170             12DGR181tipp          None      None          None
# 171                12PPDStex          None      None          None
# 172            14GLUCANabcpp          None      None          None
# 173                23CCMPtex          None      None      rxn07926
# 174                23CGMPtex          None      None      rxn07927
# 175                 23PDE2pp        R03538  3.1.4.16      rxn02522
# 176                 23PDE9pp        R05135  3.1.4.16      rxn03483
# 177             2AGPA120tipp          None      None      rxn07932
# 178             2AGPA140tipp          None      None      rxn07933
# 179             2AGPA180tipp          None      None      rxn07937
# 180             2AGPA181tipp          None      None      rxn07938
# 181             2AGPE140tipp          None      None          None
# 182             2AGPE141tipp          None      None          None
# 183  2AGPEAT141; _2AGPEAT141          None      None          None
# 184             2AGPG160tipp          None      None          None
# 185             2AGPG161tipp          None      None          None
# 186             2AGPG180tipp          None      None          None
# 187             2AGPG181tipp          None      None          None
# 188  2AGPGAT120; _2AGPGAT120          None      None          None
# 189  2AGPGAT141; _2AGPGAT141          None      None          None
# 190  2AGPGAT160; _2AGPGAT160          None      None          None
# 191  2AGPGAT180; _2AGPGAT180          None      None          None
# 192                 2DGULRGx          None      None          None
# 193                  2DGULRx          None      None      rxn07969
# 194                   2MAHMP          None      None      rxn07971
# 195                  3AMPtex          None      None      rxn07973
# 196                  3GMPtex          None      None      rxn07975
# 197        3HAD121; _3HAD121          None  4.2.1.61      rxn07976
# 198        3HAD160; _3HAD160        R04544  4.2.1.61      rxn05332
# 199        3HAD161; _3HAD161          None  4.2.1.61      rxn07978
# 200        3HAD180; _3HAD180        R07764  4.2.1.61      rxn07979

# %% [markdown]
# # IV / Import ModelSEED reaction file

# %% [markdown]
# ## 1) Load ModelSEED reaction table

# %%
# Load ModelSeed Reaction Table

seed_reactions_url = 'https://raw.githubusercontent.com/ModelSEED/ModelSEEDDatabase/master/Biochemistry/reactions.tsv'
df_reactions_seed = pd.read_csv(seed_reactions_url, sep='\t')

df_reactions_seed.head(25)
# Out:
#           id abbreviation                                               name  \
# 0   rxn00001       R00004                       diphosphate phosphohydrolase
# 1   rxn00002       R00005                  urea-1-carboxylate amidohydrolase
# 2   rxn00003       R00006  pyruvate:pyruvate acetaldehydetransferase (dec...
# 3   rxn00004       R00008  4-hydroxy-4-methyl-2-oxoglutarate pyruvate-lya...
# 4   rxn00006       R00009  hydrogen-peroxide:hydrogen-peroxide oxidoreduc...
# 5   rxn00007       R00010               alpha,alpha-trehalose glucohydrolase
# 6   rxn00008       R00011            Mn(II):hydrogen-peroxide oxidoreductase
# 7   rxn00009       R00012                        GTP:GTP guanylyltransferase
# 8   rxn00010       R00013  glyoxylate carboxy-lyase (dimerizing; tartrona...
# 9   rxn00011       R00014  pyruvate:thiamin diphosphate acetaldehydetrans...
# 10  rxn00012       R00015     sucrose:sucrose 1'-beta-D-fructosyltransferase
# 11  rxn00013       G1PPDM  D-Glucose-1-phosphate:D-glucose-1-phosphate 6-...
# 12  rxn00014       R00017  ferrocytochrome-c:hydrogen-peroxide oxidoreduc...
# 13  rxn00015       R00018  putrescine:putrescine 4-aminobutyltransferase ...
# 14  rxn00016       R00022            chitobiose N-acetylglucosaminohydrolase
# 15  rxn00017       R00023                  hydroxylamine:NAD+ oxidoreductase
# 16  rxn00018       R00024  3-phospho-D-glycerate carboxy-lyase (dimerizin...
# 17  rxn00019        2NPDO             2-Nitropropane:oxygen 2-oxidoreductase
# 18  rxn00020       R00026                          cellobiose glucohydrolase
# 19  rxn00021       R00027  2-hydroxy-1,2-diphenylethanone benzaldehyde-ly...
# 20  rxn00022       R00028                             maltose glucohydrolase
# 21  rxn00023       R00029       thiosulfate:ferricytochrome-c oxidoreductase
# 22  rxn00024       R00031              1,2-Benzenediol:oxygen oxidoreductase
# 23  rxn00025       R00032  beta-Carotene:oxygen 15,15'-oxidoreductase (bo...
# 24  rxn00026       R00033                   thiamine:oxygen 5-oxidoreductase
#
#                                                  code  \
# 0   (1) cpd00001[0] + (1) cpd00012[0] <=> (2) cpd0...
# 1   (1) cpd00001[0] + (1) cpd00742[0] <=> (2) cpd0...
# 2   (1) cpd00011[0] + (1) cpd00668[0] <=> (2) cpd0...
# 3                 (1) cpd02570[0] <=> (2) cpd00020[0]
# 4   (2) cpd00025[0] <=> (2) cpd00001[0] + (1) cpd0...
# 5   (1) cpd00001[0] + (1) cpd00794[0] <=> (2) cpd0...
# 6                 (2) cpd00001[0] <=> (1) cpd00025[0]
# 7   (2) cpd00038[0] <=> (1) cpd00012[0] + (1) cpd0...
# 8   (2) cpd00040[0] <=> (1) cpd00011[0] + (1) cpd0...
# 9   (1) cpd00011[0] + (1) cpd03049[0] <=> (1) cpd0...
# 10  (2) cpd00076[0] <=> (1) cpd00027[0] + (1) cpd0...
# 11  (2) cpd00089[0] <=> (1) cpd00027[0] + (1) cpd0...
# 12  (1) cpd00025[0] + (2) cpd00110[0] <=> (2) cpd0...
# 13  (2) cpd00118[0] <=> (1) cpd00013[0] + (1) cpd0...
# 14  (1) cpd00001[0] + (1) cpd01157[0] <=> (2) cpd0...
# 15  (2) cpd00003[0] + (2) cpd00165[0] <=> (2) cpd0...
# 16  (1) cpd00001[0] + (1) cpd00011[0] + (1) cpd008...
# 17  (1) cpd00007[0] + (2) cpd01433[0] <=> (2) cpd0...
# 18  (1) cpd00001[0] + (1) cpd00158[0] <=> (2) cpd0...
# 19                (1) cpd01008[0] <=> (2) cpd00225[0]
# 20  (1) cpd00001[0] + (1) cpd00179[0] <=> (2) cpd0...
# 21  (2) cpd00109[0] + (2) cpd00268[0] <=> (2) cpd0...
# 22  (1) cpd00007[0] + (2) cpd00069[0] <=> (2) cpd0...
# 23  (1) cpd00007[0] + (1) cpd01420[0] <=> (2) cpd0...
# 24  (1) cpd00007[0] + (1) cpd00305[0] <=> (1) cpd0...
#
#                                         stoichiometry  is_transport  \
# 0   -1:cpd00001:0:0:"H2O";-1:cpd00012:0:0:"PPi";2:...             0
# 1   -1:cpd00001:0:0:"H2O";-3:cpd00067:0:0:"H+";-1:...             0
# 2   -1:cpd00011:0:0:"CO2";-1:cpd00668:0:0:"ALCTT";...             0
# 3   -1:cpd02570:0:0:"Parapyruvate";2:cpd00020:0:0:...             0
# 4   -2:cpd00025:0:0:"H2O2";2:cpd00001:0:0:"H2O";1:...             0
# 5   -1:cpd00001:0:0:"H2O";-1:cpd00794:0:0:"TRHL";2...             0
# 6   -2:cpd00001:0:0:"H2O";1:cpd00025:0:0:"H2O2";2:...             0
# 7   -2:cpd00038:0:0:"GTP";1:cpd00012:0:0:"PPi";1:c...             0
# 8   -2:cpd00040:0:0:"Glyoxalate";-1:cpd00067:0:0:"...             0
# 9   -1:cpd00011:0:0:"CO2";-1:cpd03049:0:0:"2-Hydro...             0
# 10  -2:cpd00076:0:0:"Sucrose";1:cpd00027:0:0:"D-Gl...             0
# 11  -2:cpd00089:0:0:"Glucose-1-phosphate";1:cpd000...             0
# 12  -1:cpd00025:0:0:"H2O2";-2:cpd00067:0:0:"H+";-2...             0
# 13  -2:cpd00118:0:0:"Putrescine";1:cpd00013:0:0:"N...             0
# 14  -1:cpd00001:0:0:"H2O";-1:cpd01157:0:0:"Chitobi...             0
# 15  -2:cpd00003:0:0:"NAD";-2:cpd00165:0:0:"Hydroxy...             0
# 16  -1:cpd00001:0:0:"H2O";-1:cpd00011:0:0:"CO2";-1...             0
# 17  -1:cpd00007:0:0:"O2";-2:cpd01433:0:0:"2-Nitrop...             0
# 18  -1:cpd00001:0:0:"H2O";-1:cpd00158:0:0:"CELB";2...             0
# 19  -1:cpd01008:0:0:"Benzoin";2:cpd00225:0:0:"Benz...             0
# 20  -1:cpd00001:0:0:"H2O";-1:cpd00179:0:0:"Maltose...             0
# 21  -2:cpd00109:0:0:"Cytochrome c3+";-2:cpd00268:0...             0
# 22  -1:cpd00007:0:0:"O2";-2:cpd00069:0:0:"L-Tyrosi...             0
# 23  -1:cpd00007:0:0:"O2";-1:cpd01420:0:0:"beta-Car...             0
# 24  -1:cpd00007:0:0:"O2";-1:cpd00305:0:0:"Thiamin"...             0
#
#                                              equation  \
# 0   (1) cpd00001[0] + (1) cpd00012[0] <=> (2) cpd0...
# 1   (1) cpd00001[0] + (3) cpd00067[0] + (1) cpd007...
# 2   (1) cpd00011[0] + (1) cpd00668[0] <= (2) cpd00...
# 3                 (1) cpd02570[0] <=> (2) cpd00020[0]
# 4   (2) cpd00025[0] => (2) cpd00001[0] + (1) cpd00...
# 5   (1) cpd00001[0] + (1) cpd00794[0] => (2) cpd00...
# 6   (2) cpd00001[0] <=> (1) cpd00025[0] + (2) cpd0...
# 7   (2) cpd00038[0] => (1) cpd00012[0] + (1) cpd00...
# 8   (2) cpd00040[0] + (1) cpd00067[0] => (1) cpd00...
# 9   (1) cpd00011[0] + (1) cpd03049[0] => (1) cpd00...
# 10  (2) cpd00076[0] <=> (1) cpd00027[0] + (1) cpd0...
# 11  (2) cpd00089[0] <=> (1) cpd00027[0] + (1) cpd0...
# 12  (1) cpd00025[0] + (2) cpd00067[0] + (2) cpd001...
# 13  (2) cpd00118[0] <=> (1) cpd00013[0] + (1) cpd0...
# 14  (1) cpd00001[0] + (1) cpd01157[0] => (2) cpd00...
# 15  (2) cpd00003[0] + (2) cpd00165[0] <= (2) cpd00...
# 16  (1) cpd00001[0] + (1) cpd00011[0] + (1) cpd008...
# 17  (1) cpd00007[0] + (2) cpd01433[0] <=> (2) cpd0...
# 18  (1) cpd00001[0] + (1) cpd00158[0] => (2) cpd00...
# 19                (1) cpd01008[0] <=> (2) cpd00225[0]
# 20  (1) cpd00001[0] + (1) cpd00179[0] => (2) cpd00...
# 21  (2) cpd00109[0] + (2) cpd00268[0] <=> (2) cpd0...
# 22  (1) cpd00007[0] + (2) cpd00069[0] => (2) cpd00...
# 23  (1) cpd00007[0] + (1) cpd01420[0] => (2) cpd00...
# 24  (1) cpd00007[0] + (1) cpd00305[0] => (1) cpd00...
#
#                                            definition reversibility direction  \
# 0   (1) H2O[0] + (1) PPi[0] <=> (2) Phosphate[0] +...             >         =
# 1   (1) H2O[0] + (3) H+[0] + (1) Allophanate[0] =>...             >         >
# 2   (1) CO2[0] + (1) ALCTT[0] <= (2) Pyruvate[0] +...             <         <
# 3             (1) Parapyruvate[0] <=> (2) Pyruvate[0]             =         =
# 4               (2) H2O2[0] => (2) H2O[0] + (1) O2[0]             >         >
# 5        (1) H2O[0] + (1) TRHL[0] => (2) D-Glucose[0]             =         >
# 6              (2) H2O[0] <=> (1) H2O2[0] + (2) H+[0]             <         =
# 7   (2) GTP[0] => (1) PPi[0] + (1) H+[0] + (1) Gpp...             =         >
# 8   (2) Glyoxalate[0] + (1) H+[0] => (1) CO2[0] + ...             =         >
# 9   (1) CO2[0] + (1) 2-Hydroxyethyl-ThPP[0] => (1)...             <         >
# 10  (2) Sucrose[0] <=> (1) D-Glucose[0] + (1) 1F-b...             =         =
# 11  (2) Glucose-1-phosphate[0] <=> (1) D-Glucose[0...             =         =
# 12  (1) H2O2[0] + (2) H+[0] + (2) Cytochrome c2+[0...             ?         >
# 13  (2) Putrescine[0] <=> (1) NH3[0] + (1) Homospe...             =         =
# 14  (1) H2O[0] + (1) Chitobiose[0] => (2) N-Acetyl...             =         >
# 15  (2) NAD[0] + (2) Hydroxylamine[0] <= (2) NADH[...             =         <
# 16  (1) H2O[0] + (1) CO2[0] + (1) D-Ribulose 1,5-b...             =         <
# 17  (1) O2[0] + (2) 2-Nitropropane[0] <=> (2) Nitr...             ?         =
# 18  (1) H2O[0] + (1) CELB[0] => (2) beta-D-Glucose[0]             =         >
# 19             (1) Benzoin[0] <=> (2) Benzaldehyde[0]             =         =
# 20    (1) H2O[0] + (1) Maltose[0] => (2) D-Glucose[0]             =         >
# 21  (2) Cytochrome c3+[0] + (2) H2S2O3[0] <=> (2) ...             ?         =
# 22     (1) O2[0] + (2) L-Tyrosine[0] => (2) L-Dopa[0]             >         >
# 23  (1) O2[0] + (1) beta-Carotene[0] => (2) Retina...             >         >
# 24  (1) O2[0] + (1) Thiamin[0] => (1) H2O2[0] + (1...             >         >
#
#     ...                                            aliases  \
# 0   ...  AraCyc: INORGPYROPHOSPHAT-RXN|BiGG: IPP1; PPA;...
# 1   ...  AraCyc: ALLOPHANATE-HYDROLASE-RXN|BiGG: ALPHNH...
# 2   ...  AlgaGEM: R_R00006_c|AraGEM: R_R00006_c|BiGG: I...
# 3   ...  KEGG: R00008|Name: 4-Hydroxy-4-methyl-2-oxoglu...
# 4   ...  AraCyc: CATAL-RXN|BiGG: CAT; CATp; CTA1; CTT1|...
# 5   ...  AlgaGEM: R_R00010_c|AraGEM: R_R00010_c|BiGG: A...
# 6   ...  KEGG: R00011|MetaCyc: MANGANESE-PEROXIDASE-RXN...
# 7   ...  KEGG: R00012|MetaCyc: 2.7.7.45-RXN|TS_Athalian...
# 8   ...  BiGG: GLXCBL; GLXCL|EcoCyc: GLYOCARBOLIG-RXN|K...
# 9   ...  AraCyc: RXN-12583|CornCyc: RXN-12583|EcoCyc: R...
# 10  ...  KEGG: R00015|MetaCyc: RXN-1781|Name: Sucrose:s...
# 11  ...  KEGG: R00016|MetaCyc: GLUCOSE-1-PHOSPHATE-PHOS...
# 12  ...  BiGG: CCP; CCP2m; CYCPO|JP_Creinhardtii_MSB: R...
# 13  ...  BiGG: HSPMS|KEGG: R00018|MetaCyc: 2.5.1.44-RXN...
# 14  ...  AraCyc: RXN-12625|BiGG: HXAD|CornCyc: RXN-1262...
# 15  ...  KEGG: R00023|MetaCyc: HYPONITRITE-REDUCTASE-RX...
# 16  ...  AraCyc: RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN|...
# 17  ...  iMO1053-PAO1: 2NPDO|iMO1056: 2NPDO|Name: 2-Nit...
# 18  ...  AraGEM: R_R00026_c|KEGG: R00026; R06092|Maize_...
# 19  ...  KEGG: R00027|Name: 2-Hydroxy-1,2-diphenylethan...
# 20  ...  AlgaGEM: R_R00028_c|BiGG: FSP2_1; MAL12; MAL32...
# 21  ...  KEGG: R00029|Name: Thiosulfate:ferricytochrome...
# 22  ...  KEGG: R00031|MetaCyc: RXN-5861|iRS1563: R_R000...
# 23  ...  AraCyc: 1.14.99.36-RXN; BETA-CAROTENE-1515-DIO...
# 24  ...  KEGG: R00033|Name: thiamine:oxygen 5-oxidoredu...
#
#                  ec_numbers       deltag    deltagerr  \
# 0                   3.6.1.1        -3.46         0.05
# 1                  3.5.1.54       -20.14         1.86
# 2                   2.2.1.6         8.27         0.90
# 3                  4.1.3.17         4.49         0.57
# 4        1.11.1.21|1.11.1.6       -46.06         1.64
# 5                  3.2.1.28        -2.79         0.26
# 6                 1.11.1.13        62.53         0.80
# 7                  2.7.7.45         2.70         1.52
# 8                  4.1.1.47        -4.57         1.08
# 9   1.2.4.1|2.2.1.6|4.1.1.1         7.23         0.84
# 10                 2.4.1.99        -1.36         1.32
# 11                 2.7.1.41        -3.73         0.95
# 12                 1.11.1.5  10000000.00  10000000.00
# 13                 2.5.1.44        -1.20         1.08
# 14                 3.2.1.52        -3.20         0.86
# 15                  1.7.1.5        18.48        13.84
# 16                 4.1.1.39        -6.24         0.92
# 17               1.13.11.32  10000000.00  10000000.00
# 18                 3.2.1.21        -2.63         0.42
# 19                 4.1.2.38         2.81         0.44
# 20                 3.2.1.20        -3.48         0.38
# 21                  1.8.2.2  10000000.00  10000000.00
# 22                 1.10.3.1      -125.98         2.59
# 23    1.13.11.63|1.14.99.36       -86.46         1.22
# 24                 1.1.3.23       -26.84         1.03
#
#                                     compound_ids  status is_obsolete  \
# 0            cpd00001;cpd00009;cpd00012;cpd00067      OK           0
# 1   cpd00001;cpd00011;cpd00013;cpd00067;cpd00742      OK           0
# 2            cpd00011;cpd00020;cpd00067;cpd00668      OK           0
# 3                              cpd00020;cpd02570      OK           0
# 4                     cpd00001;cpd00007;cpd00025      OK           0
# 5                     cpd00001;cpd00027;cpd00794      OK           0
# 6                     cpd00001;cpd00025;cpd00067    CI:2           0
# 7            cpd00012;cpd00038;cpd00067;cpd00925      OK           0
# 8            cpd00011;cpd00040;cpd00067;cpd00843      OK           0
# 9   cpd00011;cpd00020;cpd00056;cpd00067;cpd03049      OK           0
# 10                    cpd00027;cpd00076;cpd02298      OK           0
# 11                    cpd00027;cpd00089;cpd00499      OK           0
# 12  cpd00001;cpd00025;cpd00067;cpd00109;cpd00110      OK           0
# 13                    cpd00013;cpd00118;cpd03802      OK           0
# 14                    cpd00001;cpd00122;cpd01157      OK           0
# 15  cpd00003;cpd00004;cpd00067;cpd00165;cpd01252      OK           0
# 16  cpd00001;cpd00011;cpd00067;cpd00169;cpd00871      OK           0
# 17           cpd00007;cpd00075;cpd00178;cpd01433      OK           0
# 18                    cpd00001;cpd00158;cpd00190      OK           0
# 19                             cpd00225;cpd01008      OK           0
# 20                    cpd00001;cpd00027;cpd00179      OK           0
# 21  cpd00067;cpd00109;cpd00110;cpd00268;cpd01414      OK           0
# 22                    cpd00007;cpd00069;cpd00291      OK           0
# 23                    cpd00007;cpd00304;cpd01420      OK           0
# 24           cpd00007;cpd00025;cpd00305;cpd03484      OK           0
#
#                                       linked_reaction           notes  \
# 0   rxn27946;rxn27947;rxn27948;rxn32487;rxn38157;r...  GCC|HB|EQC|EQU
# 1                                   rxn30346;rxn35525     GCC|EQC|EQU
# 2                                   rxn30144;rxn33164     GCC|EQC|EQU
# 3                                                 NaN     GCC|EQC|EQU
# 4                 rxn19264;rxn22404;rxn27744;rxn31381     GCC|EQC|EQU
# 5                          rxn29977;rxn30219;rxn30442     GCC|EQC|EQU
# 6                                                 NaN     GCC|EQC|EQU
# 7                                   rxn33150;rxn33152  GCC|HB|EQC|EQU
# 8                                                 NaN     GCC|EQC|EQU
# 9                                   rxn31360;rxn31361     GCC|EQC|EQU
# 10                                                NaN     GCC|EQC|EQU
# 11                                                NaN  GCC|HB|EQC|EQU
# 12                                           rxn30356         GCP|EQP
# 13                                           rxn30077     GCC|EQC|EQU
# 14                                           rxn23055     GCC|EQC|EQU
# 15                                                NaN         GCC|EQP
# 16                                  rxn20788;rxn38286     GCC|EQC|EQU
# 17                                                NaN      HB|GCP|EQP
# 18                                           rxn33580     GCC|EQC|EQU
# 19                                                NaN     GCC|EQC|EQU
# 20                                           rxn30130     GCC|EQC|EQU
# 21                                                NaN      HB|GCP|EQP
# 22                                                NaN     GCC|EQC|EQU
# 23                                           rxn35456     GCC|EQC|EQU
# 24                                                NaN     GCC|EQC|EQU
#
#               source
# 0   Primary Database
# 1   Primary Database
# 2   Primary Database
# 3   Primary Database
# 4   Primary Database
# 5   Primary Database
# 6   Primary Database
# 7   Primary Database
# 8   Primary Database
# 9   Primary Database
# 10  Primary Database
# 11  Primary Database
# 12  Primary Database
# 13  Primary Database
# 14  Primary Database
# 15  Primary Database
# 16  Primary Database
# 17   Published Model
# 18  Primary Database
# 19  Primary Database
# 20  Primary Database
# 21  Primary Database
# 22  Primary Database
# 23  Primary Database
# 24  Primary Database
#
# [25 rows x 22 columns]

# %% [markdown]
# ## 2) Changes to the ModelSEED reaction table

# %%
#Convert string of alias pairs into dictionaries of keys and value - 
# 1) split by "|" to sepertae the different key - value pairs
# 2) split by ":" to seperate keys and values
df_reactions_seed['aliases'] = df_reactions_seed['aliases'].apply(lambda aliases_str: 
                                                                      {alias.split(':',1)[0]: alias.split(':',1)[-1] 
                                                                       for alias in aliases_str.split('|')} if isinstance(aliases_str, str) else {} )

# Some of the keys have values that are again a strings with multiple items that need to be splitted
# 3) split those  string by ';' and also remove leading and tailing white spaces 
df_reactions_seed['aliases'] = df_reactions_seed['aliases'].apply(lambda aliases_dict: 
                                                                      {alias_key:
                                                                       [alias_value.strip() for alias_value in alias_values.split(';')]
                                                                       for alias_key, alias_values in aliases_dict.items()}
                                                                      )

df_reactions_seed.head(25)

# %%
#All possible keys in ModelSEED aliases => seems like only KEGG, BiGG and AraCyc would make sense
#array(['AlgaGEM', 'AraCyc', 'AraGEM', 'BiGG', 'BrachyCyc', 'ChlamyCyc',
#       'CornCyc', 'DF_Athaliana', 'EcoCyc', 'JM_Creinhardtii',
#       'JP_Creinhardtii_MSB', 'JP_Creinhardtii_NMeth', 'KEGG', 'MaizeCyc',
#       'Maize_C4GEM', 'MetaCyc', 'Name', 'PlantCyc', 'PoplarCyc',
#       'RiceCyc', 'SorghumCyc', 'SoyCyc', 'TS_Athaliana', 'iAF1260',
#       'iAF692', 'iAG612', 'iAO358', 'iAbaylyiv4', 'iGT196', 'iIN800',
#       'iIT341', 'iJN746', 'iJR904', 'iMA945', 'iMEO21', 'iMM904',
#       'iMO1053-PAO1', 'iMO1056', 'iND750', 'iNJ661', 'iPS189', 'iRR1083',
#       'iRS1563', 'iRS1597', 'iSB619', 'iSO783', 'iYO844'], dtype='<U21')

# %% [markdown]
# ## 3) Get BiGG and AraCyc reaction identifiers and conversion of "ec_numbers"

# %%
#Get BiGG reaction ids
df_reactions_seed['BiGG'] = df_reactions_seed['aliases'].apply(lambda dict_aliases:  dict_aliases['BiGG'] if 'BiGG' in dict_aliases.keys() else None)
df_reactions_seed.head(25)

# %%
#Get BiGG reaction ids
df_reactions_seed['BiGG'] = df_reactions_seed['aliases'].apply(lambda dict_aliases:  dict_aliases['BiGG'] if 'BiGG' in dict_aliases.keys() else None)
df_reactions_seed.head(25)

# %%
#Get BiGG reaction ids
df_reactions_seed['KEGG'] = df_reactions_seed['aliases'].apply(lambda dict_aliases:  dict_aliases['KEGG'] if 'KEGG' in dict_aliases.keys() else None)
df_reactions_seed.head(25)

# %%
#Get AraCyc reaction ids
df_reactions_seed['AraCyc'] = df_reactions_seed['aliases'].apply(lambda dict_aliases:  dict_aliases['AraCyc'] if 'AraCyc' in dict_aliases.keys() else None)
df_reactions_seed.head(25)

# %%
# 'ec_numbers' should also be convert into a list 
df_reactions_seed['ec_numbers'] = df_reactions_seed['ec_numbers'].astype(str)
df_reactions_seed['ec_numbers'] = df_reactions_seed['ec_numbers'].apply(lambda x: x.split('|') if x else None)
df_reactions_seed.head(25)

# %% [markdown]
# # V / Mapping AraCore and BiGG

# %% [markdown]
# ## 1) Using KEGG Ids

# %%
#Check if kegg_id of the aracore reactions is in any of the list of kegg ids mapped in the BiGG table
df_reactions_aracore['is_bigg_kegg_id'] = df_reactions_aracore['kegg_id'].apply(lambda kegg_id: ((df_reactions_bigg['kegg.reaction'] == kegg_id).sum() > 0) if isinstance(kegg_id, str) else False)

#get the BiGG ids where kegg ids are matching
df_reactions_aracore['kegg_bigg_ids'] = df_reactions_aracore[['kegg_id','is_bigg_kegg_id']].apply(lambda x: 
                                                                                            df_reactions_bigg[df_reactions_bigg['kegg.reaction'] == x[0]]['bigg_id'].tolist() 
                                                                                            if x[1] 
                                                                                            else [None], axis=1)
df_reactions_aracore.head(25)
# Out:
#     index      aracore_ids                                       aracore_name  \
# 0       0           PSII_h                                     photosystem II
# 1       1        Cytb6f1_h                              cytochrom b6f complex
# 2       2        Cytb6f2_h                              cytochrom b6f complex
# 3       3     PGR5PGRL11_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 4       4     PGR5PGRL12_h  proton gradient regulation 5 (PGR5)/PGR5-like ...
# 5       5           NDH1_h              NADH dehydrogenase-like (NDH) complex
# 6       6           NDH2_h              NADH dehydrogenase-like (NDH) complex
# 7       7            PSI_h                                      photosystem I
# 8       8  Fd_DASH_NADPR_h                          ferredoxin-NADP reductase
# 9       9         ATPase_h                                             ATPase
# 10     10            RBC_h                                            RuBisCO
# 11     11           PGAK_h                                         PGA kinase
# 12     12         GAPDH1_h                                  GAP dehydrogenase
# 13     13            TPI_h                                       TP isomerase
# 14     14           FBPA_h                                       FBP aldolase
# 15     15         FBPase_h                                             FBPase
# 16     16            FTK_h                                  F6P transketolase
# 17     17           SBPA_h                                       SBP aldolase
# 18     18         SBPase_h                                             SBPase
# 19     19            STK_h                                  S7P transketolase
# 20     20          Ru5PE_h                                     Ru5P epimerase
# 21     21           R5PI_h                                      R5P isomerase
# 22     22          Ru5PK_h                                        Ru5P kinase
# 23     23            PGI_h                                      G6P isomerase
# 24     24            PGM_h                                 Phosphoglucomutase
#
#                                   aracore_annotations aracore_updated_ids  \
# 0   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...              PSII_h
# 1   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...           CYTB6F1_h
# 2   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...           CYTB6F2_h
# 3   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...        PGR5PGRL11_h
# 4   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...        PGR5PGRL12_h
# 5   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...              NDH1_h
# 6   {'doi': '10.1016/j.tplants.2011.10.004', 'go':...              NDH2_h
# 7   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...               PSI_h
# 8   {'ec-code': '1.18.1.2', 'go': 'GO:0019684', 'k...     FD_DASH_NADPR_h
# 9   {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...            ATPASE_h
# 10  {'doi': '10.1146/annurev.arplant.53.100301.135...               RBC_h
# 11  {'ec-code': '2.7.2.3', 'go': ['GO:0019253', 'G...              PGAK_h
# 12  {'doi': ['10.1107/S1744309110013527', ' 10.107...            GAPDH1_h
# 13  {'ec-code': '5.3.1.1', 'go': ['GO:0019253', 'G...               TPI_h
# 14  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...              FBPA_h
# 15  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....            FBPASE_h
# 16  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...               FTK_h
# 17  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...              SBPA_h
# 18  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....            SBPASE_h
# 19  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...               STK_h
# 20  {'doi': '10.1104/pp.118.1.199', 'ec-code': '5....             RU5PE_h
# 21  {'ec-code': '5.3.1.6', 'go': ['GO:0019253', 'G...              R5PI_h
# 22  {'doi': '10.1104/pp.105.068445', 'ec-code': '2...             RU5PK_h
# 23  {'doi': '10.1104/pp.105.068445', 'ec-code': '5...               PGI_h
# 24  {'ec-code': '5.4.2.2', 'go': 'GO:0019252', 'ke...               PGM_h
#
#    aracore_updated_universal_ids kegg_id    ec-code  is_bigg_kegg_id  \
# 0                           PSII  R09503   1.10.3.9            False
# 1                        CYTB6F1  R03817   1.10.9.1            False
# 2                        CYTB6F2  R03817   1.10.9.1            False
# 3                     PGR5PGRL11  R03817       None            False
# 4                     PGR5PGRL12  R03817       None            False
# 5                           NDH1  R03817       None            False
# 6                           NDH2  R03817       None            False
# 7                            PSI  R09542  1.97.1.12            False
# 8                  FD_DASH_NADPR  R01195   1.18.1.2             True
# 9                         ATPASE  R00086   3.6.3.14             True
# 10                           RBC  R00024   4.1.1.39             True
# 11                          PGAK  R01512    2.7.2.3             True
# 12                        GAPDH1  R01063   1.2.1.13             True
# 13                           TPI  R01015    5.3.1.1             True
# 14                          FBPA  R01068   4.1.2.13             True
# 15                        FBPASE  R00762   3.1.3.11            False
# 16                           FTK  R01067    2.2.1.1            False
# 17                          SBPA  R01829   4.1.2.13             True
# 18                        SBPASE  R01845   3.1.3.37             True
# 19                           STK  R01641    2.2.1.1            False
# 20                         RU5PE  R01529    5.1.3.1             True
# 21                          R5PI  R01056    5.3.1.6            False
# 22                         RU5PK  R01523   2.7.1.19             True
# 23                           PGI  R00771    5.3.1.9            False
# 24                           PGM  R08639    5.4.2.2             True
#
#                   kegg_bigg_ids
# 0                        [None]
# 1                        [None]
# 2                        [None]
# 3                        [None]
# 4                        [None]
# 5                        [None]
# 6                        [None]
# 7                        [None]
# 8                        [FNOR]
# 9    [ATPM, NTP1, ATPPHm, ATPS]
# 10                [RBPCh, RBPC]
# 11      [PGKm, PGK, PGKf, PGKh]
# 12  [GAPDi_nadp, GAPDH_nadp_hi]
# 13                  [TPI, TPIh]
# 14                        [FBA]
# 15                       [None]
# 16                       [None]
# 17               [FBA3hi, FBA3]
# 18                 [SBP, SBP_1]
# 19                       [None]
# 20                  [RPEh, RPE]
# 21                       [None]
# 22               [PRUK, PRUK_1]
# 23                       [None]
# 24                       [PGMT]

# %%
df_reactions_aracore['is_bigg_kegg_id'].value_counts() #=> 249 reactions mapped
# Out:
# False    323
# True     249
# Name: is_bigg_kegg_id, dtype: int64

# %% [markdown]
# ## 2) Using Ec-code

# %%
#Check if ec-code of the aracore reactions is in any of the list of ec-code mapped in the BiGG table
df_reactions_aracore['is_bigg_ec_code'] = df_reactions_aracore['ec-code'].apply(lambda kegg_id: ((df_reactions_bigg['ec-code'] == kegg_id).sum() > 0) if isinstance(kegg_id, str) else False)

#get the ec-code ids where kegg ids are matching
df_reactions_aracore['ec_bigg_ids'] = df_reactions_aracore[['ec-code','is_bigg_ec_code']].apply(lambda x: 
                                                                                            df_reactions_bigg[df_reactions_bigg['ec-code'] == x[0]]['bigg_id'].tolist() 
                                                                                            if x[1] 
                                                                                            else [None], axis=1)
df_reactions_aracore.head(50)

# %%
df_reactions_aracore['is_bigg_ec_code'].value_counts() #=> 249 reactions mapped

# %% [markdown]
# # VI / Aggregate the information

# %% [markdown]
# ## 1) Aggregate all BiGG ids from mapping of KEGG ids and Ec-codes

# %%
#Fuse list of mapped BiGG ids by kegg and ec code 
df_reactions_aracore['kegg_ec_bigg_id'] = df_reactions_aracore[['ec_bigg_ids','kegg_bigg_ids']].apply(lambda x: list(filter(None, x[0]+x[1])), axis=1)

#Create list of unique BiGG ids
df_reactions_aracore['kegg_ec_bigg_id'].apply(lambda x: list(np.unique(x)))

#Clean dataframe and remove cols
df_reactions_aracore.drop(['is_bigg_ec_code','is_bigg_kegg_id','ec_bigg_ids','kegg_bigg_ids'], axis=1, inplace=True)

df_reactions_aracore.head(50)

# %% [markdown]
# ## 2) Add SEED Reaction ids that are known from the BiGG Table

# %%
#Add all ModelSeed ids that have already been mapped to BiGG ids in the Bigg Table
df_reactions_aracore['bigg_seed_id'] = df_reactions_aracore['kegg_ec_bigg_id'].apply(lambda bigg_id_list: 
                                      [df_reactions_bigg[df_reactions_bigg['bigg_id'] == bigg_id]['seed.reaction'] for bigg_id in bigg_id_list] if bigg_id_list else [[None]] )
#Process packed lists of ModelSEED Ids
df_reactions_aracore['bigg_seed_id'] = df_reactions_aracore['bigg_seed_id'].apply(lambda x: [item_x  for sub_x in x for item_x in sub_x] )

#Create list of unique ModelSEED ids
df_reactions_aracore['bigg_seed_id'] = df_reactions_aracore['bigg_seed_id'].apply(lambda x: list(np.unique(list(filter(None,x)))))

# %% [markdown]
# # VII / Mapping AraCore and ModelSeed

# %% [markdown]
# ## 1) Using KEGG ids

# %%
def check_for_kegg_modelseed(kegg_id):
  return df_reactions_seed[df_reactions_seed['KEGG'].apply(lambda x: kegg_id in x if x else False)]['id'].tolist() 

#Map KEGG ids in the aracore table and the ModelSEED table to get additional Seed ids
df_reactions_aracore['kegg_seed_ids'] = df_reactions_aracore['kegg_id'].apply(lambda kegg_id: check_for_kegg_modelseed(kegg_id) if isinstance(kegg_id, str) else [None])

df_reactions_aracore.head(25)

# %%
df_reactions_aracore['kegg_seed_ids'].apply(lambda x: isinstance(x,list)).value_counts() #319 reactions with ModelSeed Id

# %% [markdown]
# ## 2) Add BiGG Reaction ids that are known from the ModelSeed Table

# %%
#Add all BiGG ids that have already been mapped to ModelSEED ids in the ModelSEED Table
df_reactions_aracore['seed_bigg_id'] = df_reactions_aracore['kegg_seed_ids'].apply(lambda kegg_seed_ids: 
                                            [df_reactions_seed[df_reactions_seed['id'] == seed_id]['BiGG'].tolist() 
                                            for seed_id in kegg_seed_ids ]
                                            if isinstance(kegg_seed_ids, list) else None ) 

#Process packed lists of BiGG Ids
df_reactions_aracore['seed_bigg_id'] = df_reactions_aracore['seed_bigg_id'].apply(lambda x: [item_x  for sub_x in x for item_x in sub_x] if x else None )

#Create list of unique BiGG Ids
df_reactions_aracore['seed_bigg_id'] = df_reactions_aracore['seed_bigg_id'].apply(lambda x: list(np.unique(list(filter(None,x)))) if x else [None])

# %%
df_reactions_aracore.head(50)

# %% [markdown]
# ## 3) Aggregate Seed and BiGG Ids

# %%
#Fuse list of mapped BiGG ids and create list of unique ids
df_reactions_aracore['bigg_id_aggr'] = df_reactions_aracore[['seed_bigg_id','kegg_ec_bigg_id']].apply(lambda x: list(filter(None, x[0]+x[1])), axis=1)
df_reactions_aracore['bigg_id_aggr'].apply(lambda x: list(np.unique(x)))

#Fuse list of mapped Seeds ids and create list of unique ids
df_reactions_aracore['seed_id_aggr'] = df_reactions_aracore[['kegg_seed_ids','bigg_seed_id']].apply(lambda x: list(filter(None, x[0]+x[1])), axis=1)
df_reactions_aracore['seed_id_aggr'].apply(lambda x: list(np.unique(x)))

#Clean dataframe and drop cols
df_reactions_aracore.drop(['kegg_ec_bigg_id','bigg_seed_id','kegg_seed_ids','seed_bigg_id'], axis=1, inplace=True)

df_reactions_aracore.head(50)

# %% [markdown]
# # VIII / Counting

# %%
(df_reactions_aracore['bigg_id_aggr'].apply(len) != 0).value_counts() #298 reactions have at least one bigg id

# %%
(df_reactions_aracore['seed_id_aggr'].apply(len) != 0).value_counts() #320 reactions have at least one seed id

# %%
#Export final mapping table for manual mapping
df_reactions_aracore.to_csv('../data/processed/2021-05-31-reactions-mapping-table.csv')
