# %% [markdown]
# # Create metabolite mapping table

# %% [markdown]
# **General steps to build the metabolite mapping table:**
#
# > I / Install and load the modules.
#
# > II / Create the metabolite table for the AraCore model.
#
# > III / BiGG metabolites.
#
# > IV / ModelSEED metabolites table.
#
# > V / Mapping AraCore.
#
# > VI / Aggregation of compounds identifiers.
#
# > VII / Mapping by chemical formulas.

# %% [markdown]
# # I / Install missing modules and load modules

# %%
import pandas as pd
import numpy as np
import cobra
import requests # requests module allows us to send HTTP requests

# %% [markdown]
# ## 1) Load AraCore Model

# %% [markdown]
# ### 1) a. Get file from github

# %%
fileName = 'https://raw.githubusercontent.com/ma-blaetke/CBM_C3_C4_Metabolism/master/data/2018-23-05-mb-genC3.sbml'
r = requests.get(fileName) # requests module allows us to send HTTP requests

# %% [markdown]
# ### 1) b. Create model

# %%
model = cobra.io.read_sbml_model(r.text)

# %%
model
# Out:
# <Model c3_model at 0x7f8dc65fab50>

# %% [markdown]
# ## 2) Correct Compartment Naming in AraCore Model according to BiGG naming conventions

# %%
model.compartments
# Out:
# {'h': 'Chloroplast',
#  'l': 'Lumen',
#  'c': 'Cytosol',
#  'm': 'Mitochondrion',
#  'i': 'IntermembraneSpace',
#  'p': 'Peroxisome'}

# %%
bigg_compartments = {'c':'cytosol',
'e':'extracellular space',
'p':'periplasm',
'm':'mitochondria',
'x':'peroxisome/glyoxysome',
'r':'endoplasmic reticulum',
'v':'vacuole',
'n':'nucleus',
'g':'golgi apparatus',
'u':'thylakoid',
'l':'lysosome',
'h':'chloroplast',
'f':'flagellum',
's':'eyespot',
'im':'intermembrane space of mitochondria',
'cx':'carboxyzome',
'um':'thylakoid membrane',
'cm':'cytosolic membrane',
'i':'inner mitochondrial compartment',
'mm':'mitochondrial intermembrane',
'w':'wildtype staph aureus',
'y':'cytochrome complex'}

# %%
bigg_compartments
# Out:
# {'c': 'cytosol',
#  'e': 'extracellular space',
#  'p': 'periplasm',
#  'm': 'mitochondria',
#  'x': 'peroxisome/glyoxysome',
#  'r': 'endoplasmic reticulum',
#  'v': 'vacuole',
#  'n': 'nucleus',
#  'g': 'golgi apparatus',
#  'u': 'thylakoid',
#  'l': 'lysosome',
#  'h': 'chloroplast',
#  'f': 'flagellum',
#  's': 'eyespot',
#  'im': 'intermembrane space of mitochondria',
#  'cx': 'carboxyzome',
#  'um': 'thylakoid membrane',
#  'cm': 'cytosolic membrane',
#  'i': 'inner mitochondrial compartment',
#  'mm': 'mitochondrial intermembrane',
#  'w': 'wildtype staph aureus',
#  'y': 'cytochrome complex'}

# %% [markdown]
# On internet, we can access to this following page to find compartments which can figure in the model : http://bigg.ucsd.edu/compartments
#
# **Summary of the notations used :**
#
# - c :	cytosol
# - h :	chloroplast
# - m :	mitochondria
# - x :	peroxisome/glyoxysome
# - im :intermembrane space of mitochondria
# - h :	chloroplast
# - ul : thylakoid lumen <<< NEW

# %%
df_compartment_mapping = pd.Series(
  { 'c': 'c', #cytosol
  'h': 'h', #chloroplast
  'm': 'm', #mitochondria
  'p': 'x', #peroxisome/glyoxysome
  'i': 'im', #intermembrane space of mitochondria
  'l': 'ul', #thylakoid lumen <<< NEW
  }
 )

# %% [markdown]
# # II / Create Metabolite Table for AraCore Model

# %% [markdown]
# ## 1) Create mapping table

# %% [markdown]
# ### 1) a. Create the dataframe

# %%
#Create mapping table
df_metabolites_aracore = pd.DataFrame(
    {
        "aracore_ids" : [met_obj.id for met_obj in model.metabolites],
        "aracore_name" : [met_obj.name for met_obj in model.metabolites],
        "aracore_formula": [met_obj.formula for met_obj in model.metabolites],
        "aracore_annotations" : [met_obj.annotation for met_obj in model.metabolites]
    })

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids                                       aracore_name  \
# 0        hnu_h                                             Photon
# 1         PQ_h                             Oxidized plastoquinone
# 2        H2O_h                                         H2O, water
# 3          H_h                                         H+, proton
# 4       PQH2_h                              Reduced plastoquinone
# 5         O2_h                                         O2, oxygen
# 6          H_l                                         H+, proton
# 7       PCox_h                              Oxidized plastocyanin
# 8       PCrd_h                               Reduced plastocyanin
# 9       Fdox_h                                Oxidized ferredoxin
# 10      Fdrd_h                                 Reduced ferredoxin
# 11      NADP_h        Nicotinamide adenine dinucleotide phosphate
# 12     NADPH_h  Nicotinamide adenine dinucleotide phosphate - ...
# 13       ADP_h                              Adenosine diphosphate
# 14        Pi_h                                     Orthophosphate
# 15       ATP_h                             Adenosine triphosphate
# 16      RuBP_h                          Ribulose 1,5-bisphosphate
# 17       CO2_h                                CO2, carbon dioxide
# 18       PGA_h                                 3-Phosphoglycerate
# 19      DPGA_h                    3-Phospho-D-glyceroyl phosphate
# 20       GAP_h                         Glyceraldehyde 3-phosphate
# 21      DHAP_h                         Dihydroxyacetone phosphate
# 22       FBP_h                          Fructose 1,6-bisphosphate
# 23       F6P_h                               Fructose 6-phosphate
# 24       E4P_h                              Erythrose 4-phosphate
#
#    aracore_formula aracore_annotations
# 0                X                  {}
# 1         C13H16O2                  {}
# 2              H2O                  {}
# 3                H                  {}
# 4         C13H18O2                  {}
# 5               O2                  {}
# 6                H                  {}
# 7                X                  {}
# 8                X                  {}
# 9            S8FeX                  {}
# 10           S8FeX                  {}
# 11   C21H25N7O17P3                  {}
# 12   C21H26N7O17P3                  {}
# 13   C10H12N5O10P2                  {}
# 14            HO4P                  {}
# 15   C10H12N5O13P3                  {}
# 16       C5H8O11P2                  {}
# 17             CO2                  {}
# 18         C3H4O7P                  {}
# 19       C3H4O10P2                  {}
# 20         C3H5O6P                  {}
# 21         C3H5O6P                  {}
# 22      C6H10O12P2                  {}
# 23        C6H11O9P                  {}
# 24         C4H7O7P                  {}

# %% [markdown]
# ### 1) b. Changes to the dataframe

# %% [markdown]
# According to the instructions reported in the website we mentionned previously concerning BiGG conventions, a few changes have to be performed:
# > - The compartment symbols need to be updated in metabolites identifiers:
# >>  - we split the metabolite identifiers in order to isolate the compartment.
# >>  - we replace the compartment symbol by the one presented in the website (see dictionary "bigg_compartments" above).
#
# > - Universal identifiers need to be created in order to make the correspondence between these ones and the ones presented in the BiGG metabolite table (mapping):
# >>  - we split according to the symbol "_" and we keep the first part of each list
# >>  - The universal metabolite identifiers need to be in lower case to avoid problems with the case of the letters

# %%
#Update compartment symbols in metabolite ids and make metabolite ids lower case
def apply_split_aracore_ids(aracore_id):
    aracore_id_splited = aracore_id.rsplit('_',1) # "1" corresponds to the maxsplit => specifies the number of split to do
    #print(aracore_id_splited[0])
    #print(aracore_id_splited[1])
    name_molecule = aracore_id_splited[0]
    compartment = aracore_id_splited[1]
    # Use the dataframe and consider it as a dictionary, included into the pandas dataframe => we have the access to the value
    # of the dictionary by passing the compartment as key
    bigg_compartment = df_compartment_mapping[compartment] # to access the value by the key
    # [] = accession operator
    #print(f"{name_molecule}_{bigg_compartment}")
    return (f"{name_molecule}_{bigg_compartment}")

df_metabolites_aracore['aracore_updated_ids'] = df_metabolites_aracore['aracore_ids'].apply(lambda aracore_id:apply_split_aracore_ids(aracore_id))
# Lambda function : what is written after "x:" is what is needed to be returned


#Create universal metabolite ids by removing compartment symbols
def apply_split_updated_universal_ids(aracore_universal_id):
    aracore_universal_id_splited = aracore_universal_id.rsplit('_', 1)
    #print(aracore_universal_id_splited[0])
    return aracore_universal_id_splited[0]

df_metabolites_aracore['aracore_updated_universal_ids'] = df_metabolites_aracore['aracore_updated_ids'].apply(lambda aracore_universal_id:apply_split_updated_universal_ids(aracore_universal_id))

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids                                       aracore_name  \
# 0        hnu_h                                             Photon
# 1         PQ_h                             Oxidized plastoquinone
# 2        H2O_h                                         H2O, water
# 3          H_h                                         H+, proton
# 4       PQH2_h                              Reduced plastoquinone
# 5         O2_h                                         O2, oxygen
# 6          H_l                                         H+, proton
# 7       PCox_h                              Oxidized plastocyanin
# 8       PCrd_h                               Reduced plastocyanin
# 9       Fdox_h                                Oxidized ferredoxin
# 10      Fdrd_h                                 Reduced ferredoxin
# 11      NADP_h        Nicotinamide adenine dinucleotide phosphate
# 12     NADPH_h  Nicotinamide adenine dinucleotide phosphate - ...
# 13       ADP_h                              Adenosine diphosphate
# 14        Pi_h                                     Orthophosphate
# 15       ATP_h                             Adenosine triphosphate
# 16      RuBP_h                          Ribulose 1,5-bisphosphate
# 17       CO2_h                                CO2, carbon dioxide
# 18       PGA_h                                 3-Phosphoglycerate
# 19      DPGA_h                    3-Phospho-D-glyceroyl phosphate
# 20       GAP_h                         Glyceraldehyde 3-phosphate
# 21      DHAP_h                         Dihydroxyacetone phosphate
# 22       FBP_h                          Fructose 1,6-bisphosphate
# 23       F6P_h                               Fructose 6-phosphate
# 24       E4P_h                              Erythrose 4-phosphate
#
#    aracore_formula aracore_annotations aracore_updated_ids  \
# 0                X                  {}               hnu_h
# 1         C13H16O2                  {}                PQ_h
# 2              H2O                  {}               H2O_h
# 3                H                  {}                 H_h
# 4         C13H18O2                  {}              PQH2_h
# 5               O2                  {}                O2_h
# 6                H                  {}                H_ul
# 7                X                  {}              PCox_h
# 8                X                  {}              PCrd_h
# 9            S8FeX                  {}              Fdox_h
# 10           S8FeX                  {}              Fdrd_h
# 11   C21H25N7O17P3                  {}              NADP_h
# 12   C21H26N7O17P3                  {}             NADPH_h
# 13   C10H12N5O10P2                  {}               ADP_h
# 14            HO4P                  {}                Pi_h
# 15   C10H12N5O13P3                  {}               ATP_h
# 16       C5H8O11P2                  {}              RuBP_h
# 17             CO2                  {}               CO2_h
# 18         C3H4O7P                  {}               PGA_h
# 19       C3H4O10P2                  {}              DPGA_h
# 20         C3H5O6P                  {}               GAP_h
# 21         C3H5O6P                  {}              DHAP_h
# 22      C6H10O12P2                  {}               FBP_h
# 23        C6H11O9P                  {}               F6P_h
# 24         C4H7O7P                  {}               E4P_h
#
#    aracore_updated_universal_ids
# 0                            hnu
# 1                             PQ
# 2                            H2O
# 3                              H
# 4                           PQH2
# 5                             O2
# 6                              H
# 7                           PCox
# 8                           PCrd
# 9                           Fdox
# 10                          Fdrd
# 11                          NADP
# 12                         NADPH
# 13                           ADP
# 14                            Pi
# 15                           ATP
# 16                          RuBP
# 17                           CO2
# 18                           PGA
# 19                          DPGA
# 20                           GAP
# 21                          DHAP
# 22                           FBP
# 23                           F6P
# 24                           E4P

# %%
df_metabolites_aracore['aracore_updated_universal_ids_lower'] = df_metabolites_aracore['aracore_updated_universal_ids'].str.lower()
df_metabolites_aracore.head(25)
# Out:
#    aracore_ids                                       aracore_name  \
# 0        hnu_h                                             Photon
# 1         PQ_h                             Oxidized plastoquinone
# 2        H2O_h                                         H2O, water
# 3          H_h                                         H+, proton
# 4       PQH2_h                              Reduced plastoquinone
# 5         O2_h                                         O2, oxygen
# 6          H_l                                         H+, proton
# 7       PCox_h                              Oxidized plastocyanin
# 8       PCrd_h                               Reduced plastocyanin
# 9       Fdox_h                                Oxidized ferredoxin
# 10      Fdrd_h                                 Reduced ferredoxin
# 11      NADP_h        Nicotinamide adenine dinucleotide phosphate
# 12     NADPH_h  Nicotinamide adenine dinucleotide phosphate - ...
# 13       ADP_h                              Adenosine diphosphate
# 14        Pi_h                                     Orthophosphate
# 15       ATP_h                             Adenosine triphosphate
# 16      RuBP_h                          Ribulose 1,5-bisphosphate
# 17       CO2_h                                CO2, carbon dioxide
# 18       PGA_h                                 3-Phosphoglycerate
# 19      DPGA_h                    3-Phospho-D-glyceroyl phosphate
# 20       GAP_h                         Glyceraldehyde 3-phosphate
# 21      DHAP_h                         Dihydroxyacetone phosphate
# 22       FBP_h                          Fructose 1,6-bisphosphate
# 23       F6P_h                               Fructose 6-phosphate
# 24       E4P_h                              Erythrose 4-phosphate
#
#    aracore_formula aracore_annotations aracore_updated_ids  \
# 0                X                  {}               hnu_h
# 1         C13H16O2                  {}                PQ_h
# 2              H2O                  {}               H2O_h
# 3                H                  {}                 H_h
# 4         C13H18O2                  {}              PQH2_h
# 5               O2                  {}                O2_h
# 6                H                  {}                H_ul
# 7                X                  {}              PCox_h
# 8                X                  {}              PCrd_h
# 9            S8FeX                  {}              Fdox_h
# 10           S8FeX                  {}              Fdrd_h
# 11   C21H25N7O17P3                  {}              NADP_h
# 12   C21H26N7O17P3                  {}             NADPH_h
# 13   C10H12N5O10P2                  {}               ADP_h
# 14            HO4P                  {}                Pi_h
# 15   C10H12N5O13P3                  {}               ATP_h
# 16       C5H8O11P2                  {}              RuBP_h
# 17             CO2                  {}               CO2_h
# 18         C3H4O7P                  {}               PGA_h
# 19       C3H4O10P2                  {}              DPGA_h
# 20         C3H5O6P                  {}               GAP_h
# 21         C3H5O6P                  {}              DHAP_h
# 22      C6H10O12P2                  {}               FBP_h
# 23        C6H11O9P                  {}               F6P_h
# 24         C4H7O7P                  {}               E4P_h
#
#    aracore_updated_universal_ids aracore_updated_universal_ids_lower
# 0                            hnu                                 hnu
# 1                             PQ                                  pq
# 2                            H2O                                 h2o
# 3                              H                                   h
# 4                           PQH2                                pqh2
# 5                             O2                                  o2
# 6                              H                                   h
# 7                           PCox                                pcox
# 8                           PCrd                                pcrd
# 9                           Fdox                                fdox
# 10                          Fdrd                                fdrd
# 11                          NADP                                nadp
# 12                         NADPH                               nadph
# 13                           ADP                                 adp
# 14                            Pi                                  pi
# 15                           ATP                                 atp
# 16                          RuBP                                rubp
# 17                           CO2                                 co2
# 18                           PGA                                 pga
# 19                          DPGA                                dpga
# 20                           GAP                                 gap
# 21                          DHAP                                dhap
# 22                           FBP                                 fbp
# 23                           F6P                                 f6p
# 24                           E4P                                 e4p

# %% [markdown]
# # III / BiGG Metabolites

# %% [markdown]
# ## 1) Load BiGG metabolites table

# %%
# Load BIGG Metabolites Table
bigg_metabolites_url = 'http://bigg.ucsd.edu/static/namespace/bigg_models_metabolites.txt'
df_metabolites_bigg = pd.read_csv(bigg_metabolites_url, sep='\t') # load the file and parse it according to the separator

df_metabolites_bigg.head(25)
# Out:
#          bigg_id universal_bigg_id  \
# 0     12dgr120_c          12dgr120
# 1     12dgr140_c          12dgr140
# 2     12dgr180_c          12dgr180
# 3     14glucan_c          14glucan
# 4        15dap_c             15dap
# 5       23ddhb_c            23ddhb
# 6       23dhba_c            23dhba
# 7      23dhbzs_c           23dhbzs
# 8     26dap_LL_c          26dap_LL
# 9     2agpe141_c          2agpe141
# 10    2agpe160_c          2agpe160
# 11    2agpg120_c          2agpg120
# 12    2agpg140_c          2agpg140
# 13      2aobut_c            2aobut
# 14  2dh3dgal6p_c        2dh3dgal6p
# 15        2dhp_c              2dhp
# 16     2dmmql8_c           2dmmql8
# 17    2h3oppan_c          2h3oppan
# 18    2hdecg3p_c          2hdecg3p
# 19    2odecg3p_c          2odecg3p
# 20       2ohph_c             2ohph
# 21      2ombzl_c            2ombzl
# 22       2omph_c             2omph
# 23        2oph_c              2oph
# 24      2pglyc_c            2pglyc
#
#                                                  name  \
# 0      1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)
# 1   1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 2    1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)
# 3                                  1,4-alpha-D-glucan
# 4                                  1,5-Diaminopentane
# 5                   2,3-Dihydro-2,3-dihydroxybenzoate
# 6                     (2,3-Dihydroxybenzoyl)adenylate
# 7                          2,3-dihydroxybenzoylserine
# 8                         LL-2,6-Diaminoheptanedioate
# 9   2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1)
# 10  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0)
# 11      2-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0)
# 12      2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0)
# 13                           L-2-Amino-3-oxobutanoate
# 14        2-Dehydro-3-deoxy-D-galactonate 6-phosphate
# 15                                  2-Dehydropantoate
# 16                             2-Demethylmenaquinol 8
# 17                          2-Hydroxy-3-oxopropanoate
# 18             2-hexadecanoyl-sn-glycerol 3-phosphate
# 19             2-octadecanoyl-sn-glycerol 3-phosphate
# 20                       2-Octaprenyl-6-hydroxyphenol
# 21             2-Octaprenyl-6-methoxy-1,4-benzoquinol
# 22                       2-Octaprenyl-6-methoxyphenol
# 23                                 2-Octaprenylphenol
# 24                                 2-Phosphoglycolate
#
#                                            model_list  \
# 0   iEC1364_W; iEC1349_Crooks; iEC1356_Bl21DE3; iM...
# 1   iECNA114_1301; iECSE_1348; iECO111_1330; iECOK...
# 2   iECB_1328; iECDH10B_1368; iEcE24377_1341; iECD...
# 3   iSFxv_1172; iUTI89_1310; iSSON_1240; iSbBS512_...
# 4   iECUMN_1333; iLF82_1304; iETEC_1333; iECSF_132...
# 5   iEC1372_W3110; iEC1368_DH5a; iCN900; iEC1364_W...
# 6   iECs_1301; iECO111_1330; iECP_1309; iECIAI1_13...
# 7   STM_v1_0; iY75_1357; iAF1260b; iML1515; iEC134...
# 8   iLJ478; iAF1260b; STM_v1_0; iJN678; iY75_1357;...
# 9   iEC1344_C; iYS1720; iEC1368_DH5a; iEC1372_W311...
# 10  iB21_1397; iJO1366; iE2348C_1286; ic_1306; iSF...
# 11  iWFL_1372; iYL1228; iSDY_1059; iSSON_1240; iUT...
# 12  iECUMN_1333; iNRG857_1313; iECW_1372; iEKO11_1...
# 13  iETEC_1333; iLF82_1304; iECW_1372; iNRG857_131...
# 14  iSBO_1134; iSFxv_1172; iJR904; iUMN146_1321; i...
# 15  iECD_1391; iEcDH1_1363; iECED1_1282; iECB_1328...
# 16  ic_1306; iE2348C_1286; iBWG_1329; iSB619; iEC5...
# 17  iNRG857_1313; iETEC_1333; iLF82_1304; iECSP_13...
# 18  iYS1720; iEC1372_W3110; iEC1368_DH5a; iEC1344_...
# 19  iPC815; iAPECO1_1312; iE2348C_1286; iEC042_131...
# 20  iEC1364_W; iML1515; iEC1349_Crooks; iEC1356_Bl...
# 21  iEcHS_1320; iECO103_1326; iECS88_1305; iEcolC_...
# 22  iS_1188; iETEC_1333; iEcSMS35_1347; iECW_1372;...
# 23  iEC55989_1330; iECH74115_1262; iECBD_1354; iEC...
# 24  iECOK1_1307; iEcolC_1368; iECP_1309; iECO26_13...
#
#                                        database_links  \
# 0   MetaNetX (MNX) Chemical: http://identifiers.or...
# 1   MetaNetX (MNX) Chemical: http://identifiers.or...
# 2   MetaNetX (MNX) Chemical: http://identifiers.or...
# 3   BioCyc: http://identifiers.org/biocyc/META:1-4...
# 4   KEGG Compound: http://identifiers.org/kegg.com...
# 5   KEGG Compound: http://identifiers.org/kegg.com...
# 6   KEGG Compound: http://identifiers.org/kegg.com...
# 7   KEGG Compound: http://identifiers.org/kegg.com...
# 8   KEGG Compound: http://identifiers.org/kegg.com...
# 9   MetaNetX (MNX) Chemical: http://identifiers.or...
# 10  CHEBI: http://identifiers.org/chebi/CHEBI:1317...
# 11  MetaNetX (MNX) Chemical: http://identifiers.or...
# 12  BioCyc: http://identifiers.org/biocyc/META:CPD...
# 13  Reactome Compound: http://identifiers.org/reac...
# 14  KEGG Compound: http://identifiers.org/kegg.com...
# 15  KEGG Compound: http://identifiers.org/kegg.com...
# 16  CHEBI: http://identifiers.org/chebi/CHEBI:6187...
# 17  KEGG Compound: http://identifiers.org/kegg.com...
# 18  Human Metabolome Database: http://identifiers....
# 19  Human Metabolome Database: http://identifiers....
# 20  KEGG Compound: http://identifiers.org/kegg.com...
# 21  CHEBI: http://identifiers.org/chebi/CHEBI:6065...
# 22  KEGG Compound: http://identifiers.org/kegg.com...
# 23  KEGG Compound: http://identifiers.org/kegg.com...
# 24  InChI Key: https://identifiers.org/inchikey/AS...
#
#                                          old_bigg_ids
# 0      12dgr120; 12dgr120[c]; 12dgr120_c; _12dgr120_c
# 1      12dgr140; 12dgr140[c]; 12dgr140_c; _12dgr140_c
# 2      12dgr180; 12dgr180[c]; 12dgr180_c; _12dgr180_c
# 3                                14glucan; 14glucan_c
# 4                            15dap; 15dap[c]; 15dap_c
# 5                                    23ddhb; 23ddhb_c
# 6                                    23dhba; 23dhba_c
# 7                                  23dhbzs; 23dhbzs_c
# 8   26dap-LL[c]; 26dap_DASH_LL_c; 26dap_LL; 26dap_...
# 9                   2agpe141; 2agpe141_c; _2agpe141_c
# 10                  2agpe160; 2agpe160_c; _2agpe160_c
# 11                  2agpg120; 2agpg120_c; _2agpg120_c
# 12                  2agpg140; 2agpg140_c; _2agpg140_c
# 13                        2aobut; 2aobut[c]; 2aobut_c
# 14                           2dh3dgal6p; 2dh3dgal6p_c
# 15                     2dhp; 2dhp[c]; 2dhp_c; _2dhp_c
# 16         2dmmql8; 2dmmql8[c]; 2dmmql8_c; _2dmmql8_c
# 17                  2h3oppan; 2h3oppan[c]; 2h3oppan_c
# 18                               2hdecg3p; 2hdecg3p_c
# 19                               2odecg3p; 2odecg3p_c
# 20                                     2ohph; 2ohph_c
# 21                                   2ombzl; 2ombzl_c
# 22                                     2omph; 2omph_c
# 23                                       2oph; 2oph_c
# 24                        2pglyc; 2pglyc[c]; 2pglyc_c

# %% [markdown]
# ## 2) Changes to the universal BiGG ids

# %% [markdown]
# In order to make the correspondence between the universal BiGG identifiers and the aracore and ModelSEED ones, a few changes in the universal BiGG ids need to be performed:
#
# > **For the BiGG database, we use the database links as "references", because they contain information about ModelSEED ids**
#
# - convert the universal BiGG ids to lower case
# - convert the string of database links into dictionaries:
#     - key: database identifier/symbol
#     - value: database-specific metabolite/annotation identifier

# %%
#Convert universal bigg id for metabolites to lower case
df_metabolites_bigg['universal_bigg_id_lower'] = df_metabolites_bigg['universal_bigg_id'].str.lower()

# %%
#Convert string of database links into dictionaries of database identifier/symbol (key) and database-specific metabolite/annotation id (value)
#Parse the string to get the seed_id
def apply_parsing_databaseLinks(databaseLink):
    if isinstance(databaseLink, str):
        #isinstance(object, classinfo): returns True if the object argument is an instance of the classinfo argument.
        #If object is not an object of the given type, the function always returns False
        dictionary = {}
        databaseLink_splited = databaseLink.split(';')
        for db_link in databaseLink_splited:
            db_link_splited = db_link.split(':',1)
            intermediate_variable = db_link_splited[-1]
            intermediate_variable_splited = intermediate_variable.split('/')
            key = intermediate_variable_splited[-2]
            value = intermediate_variable_splited[-1]
            dictionary[key] = value
        #print(dictionary)
    else:
        dictionary = {}
    return dictionary

df_metabolites_bigg['database_links'] = df_metabolites_bigg['database_links'].apply(apply_parsing_databaseLinks) 
df_metabolites_bigg.head(25)
# Out:
#          bigg_id universal_bigg_id  \
# 0     12dgr120_c          12dgr120
# 1     12dgr140_c          12dgr140
# 2     12dgr180_c          12dgr180
# 3     14glucan_c          14glucan
# 4        15dap_c             15dap
# 5       23ddhb_c            23ddhb
# 6       23dhba_c            23dhba
# 7      23dhbzs_c           23dhbzs
# 8     26dap_LL_c          26dap_LL
# 9     2agpe141_c          2agpe141
# 10    2agpe160_c          2agpe160
# 11    2agpg120_c          2agpg120
# 12    2agpg140_c          2agpg140
# 13      2aobut_c            2aobut
# 14  2dh3dgal6p_c        2dh3dgal6p
# 15        2dhp_c              2dhp
# 16     2dmmql8_c           2dmmql8
# 17    2h3oppan_c          2h3oppan
# 18    2hdecg3p_c          2hdecg3p
# 19    2odecg3p_c          2odecg3p
# 20       2ohph_c             2ohph
# 21      2ombzl_c            2ombzl
# 22       2omph_c             2omph
# 23        2oph_c              2oph
# 24      2pglyc_c            2pglyc
#
#                                                  name  \
# 0      1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)
# 1   1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 2    1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)
# 3                                  1,4-alpha-D-glucan
# 4                                  1,5-Diaminopentane
# 5                   2,3-Dihydro-2,3-dihydroxybenzoate
# 6                     (2,3-Dihydroxybenzoyl)adenylate
# 7                          2,3-dihydroxybenzoylserine
# 8                         LL-2,6-Diaminoheptanedioate
# 9   2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1)
# 10  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0)
# 11      2-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0)
# 12      2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0)
# 13                           L-2-Amino-3-oxobutanoate
# 14        2-Dehydro-3-deoxy-D-galactonate 6-phosphate
# 15                                  2-Dehydropantoate
# 16                             2-Demethylmenaquinol 8
# 17                          2-Hydroxy-3-oxopropanoate
# 18             2-hexadecanoyl-sn-glycerol 3-phosphate
# 19             2-octadecanoyl-sn-glycerol 3-phosphate
# 20                       2-Octaprenyl-6-hydroxyphenol
# 21             2-Octaprenyl-6-methoxy-1,4-benzoquinol
# 22                       2-Octaprenyl-6-methoxyphenol
# 23                                 2-Octaprenylphenol
# 24                                 2-Phosphoglycolate
#
#                                            model_list  \
# 0   iEC1364_W; iEC1349_Crooks; iEC1356_Bl21DE3; iM...
# 1   iECNA114_1301; iECSE_1348; iECO111_1330; iECOK...
# 2   iECB_1328; iECDH10B_1368; iEcE24377_1341; iECD...
# 3   iSFxv_1172; iUTI89_1310; iSSON_1240; iSbBS512_...
# 4   iECUMN_1333; iLF82_1304; iETEC_1333; iECSF_132...
# 5   iEC1372_W3110; iEC1368_DH5a; iCN900; iEC1364_W...
# 6   iECs_1301; iECO111_1330; iECP_1309; iECIAI1_13...
# 7   STM_v1_0; iY75_1357; iAF1260b; iML1515; iEC134...
# 8   iLJ478; iAF1260b; STM_v1_0; iJN678; iY75_1357;...
# 9   iEC1344_C; iYS1720; iEC1368_DH5a; iEC1372_W311...
# 10  iB21_1397; iJO1366; iE2348C_1286; ic_1306; iSF...
# 11  iWFL_1372; iYL1228; iSDY_1059; iSSON_1240; iUT...
# 12  iECUMN_1333; iNRG857_1313; iECW_1372; iEKO11_1...
# 13  iETEC_1333; iLF82_1304; iECW_1372; iNRG857_131...
# 14  iSBO_1134; iSFxv_1172; iJR904; iUMN146_1321; i...
# 15  iECD_1391; iEcDH1_1363; iECED1_1282; iECB_1328...
# 16  ic_1306; iE2348C_1286; iBWG_1329; iSB619; iEC5...
# 17  iNRG857_1313; iETEC_1333; iLF82_1304; iECSP_13...
# 18  iYS1720; iEC1372_W3110; iEC1368_DH5a; iEC1344_...
# 19  iPC815; iAPECO1_1312; iE2348C_1286; iEC042_131...
# 20  iEC1364_W; iML1515; iEC1349_Crooks; iEC1356_Bl...
# 21  iEcHS_1320; iECO103_1326; iECS88_1305; iEcolC_...
# 22  iS_1188; iETEC_1333; iEcSMS35_1347; iECW_1372;...
# 23  iEC55989_1330; iECH74115_1262; iECBD_1354; iEC...
# 24  iECOK1_1307; iEcolC_1368; iECP_1309; iECO26_13...
#
#                                        database_links  \
# 0                   {'metanetx.chemical': 'MNXM4939'}
# 1                 {'metanetx.chemical': 'MNXM146479'}
# 2                   {'metanetx.chemical': 'MNXM4217'}
# 3   {'biocyc': 'META:1-4-alpha-D-Glucan', 'metanet...
# 4   {'kegg.compound': 'C01672', 'chebi': 'CHEBI:58...
# 5   {'kegg.compound': 'C04171', 'chebi': 'CHEBI:87...
# 6   {'kegg.compound': 'C04030', 'chebi': 'CHEBI:57...
# 7   {'kegg.compound': 'C04204', 'chebi': 'CHEBI:70...
# 8   {'kegg.compound': 'C00666', 'chebi': 'CHEBI:63...
# 9                   {'metanetx.chemical': 'MNXM3447'}
# 10  {'chebi': 'CHEBI:132926', 'inchikey': 'CKPBBEO...
# 11                  {'metanetx.chemical': 'MNXM3450'}
# 12  {'biocyc': 'META:CPD0-2173', 'metanetx.chemica...
# 13  {'reactome': 'R-ALL-6798652', 'kegg.compound':...
# 14  {'kegg.compound': 'C01286', 'chebi': 'CHEBI:58...
# 15  {'kegg.compound': 'C00966', 'chebi': 'CHEBI:19...
# 16  {'chebi': 'CHEBI:61873', 'inchikey': 'FGYPGICS...
# 17  {'kegg.compound': 'C01146', 'chebi': 'CHEBI:57...
# 18  {'hmdb': 'HMDB07849', 'lipidmaps': 'LMGP100500...
# 19  {'hmdb': 'HMDB07850', 'lipidmaps': 'LMGP100500...
# 20  {'kegg.compound': 'C05811', 'chebi': 'CHEBI:62...
# 21  {'chebi': 'CHEBI:60655', 'inchikey': 'CZFRMASE...
# 22  {'kegg.compound': 'C05812', 'chebi': 'CHEBI:12...
# 23  {'kegg.compound': 'C05810', 'chebi': 'CHEBI:40...
# 24  {'inchikey': 'ASCFNMCAHFUBCO-UHFFFAOYSA-K', 'k...
#
#                                          old_bigg_ids universal_bigg_id_lower
# 0      12dgr120; 12dgr120[c]; 12dgr120_c; _12dgr120_c                12dgr120
# 1      12dgr140; 12dgr140[c]; 12dgr140_c; _12dgr140_c                12dgr140
# 2      12dgr180; 12dgr180[c]; 12dgr180_c; _12dgr180_c                12dgr180
# 3                                14glucan; 14glucan_c                14glucan
# 4                            15dap; 15dap[c]; 15dap_c                   15dap
# 5                                    23ddhb; 23ddhb_c                  23ddhb
# 6                                    23dhba; 23dhba_c                  23dhba
# 7                                  23dhbzs; 23dhbzs_c                 23dhbzs
# 8   26dap-LL[c]; 26dap_DASH_LL_c; 26dap_LL; 26dap_...                26dap_ll
# 9                   2agpe141; 2agpe141_c; _2agpe141_c                2agpe141
# 10                  2agpe160; 2agpe160_c; _2agpe160_c                2agpe160
# 11                  2agpg120; 2agpg120_c; _2agpg120_c                2agpg120
# 12                  2agpg140; 2agpg140_c; _2agpg140_c                2agpg140
# 13                        2aobut; 2aobut[c]; 2aobut_c                  2aobut
# 14                           2dh3dgal6p; 2dh3dgal6p_c              2dh3dgal6p
# 15                     2dhp; 2dhp[c]; 2dhp_c; _2dhp_c                    2dhp
# 16         2dmmql8; 2dmmql8[c]; 2dmmql8_c; _2dmmql8_c                 2dmmql8
# 17                  2h3oppan; 2h3oppan[c]; 2h3oppan_c                2h3oppan
# 18                               2hdecg3p; 2hdecg3p_c                2hdecg3p
# 19                               2odecg3p; 2odecg3p_c                2odecg3p
# 20                                     2ohph; 2ohph_c                   2ohph
# 21                                   2ombzl; 2ombzl_c                  2ombzl
# 22                                     2omph; 2omph_c                   2omph
# 23                                       2oph; 2oph_c                    2oph
# 24                        2pglyc; 2pglyc[c]; 2pglyc_c                  2pglyc

# %%
#All database keys in database_links
np.unique(df_metabolites_bigg['database_links'].apply(lambda x: list(x.keys())).sum())
#np.unique() function returns the sorted unique elements of an array
# Out:
# array(['biocyc', 'chebi', 'hmdb', 'inchikey', 'kegg.compound',
#        'kegg.drug', 'kegg.glycan', 'lipidmaps', 'metanetx.chemical',
#        'reactome', 'seed.compound'], dtype='<U17')

# %% [markdown]
# ## 3) Get ModelSEED compound ids (metabolite ids) into the BiGG model file

# %%
#Get ModelSEED compound ids (metabolite ids) into the BiGG model file
def apply_modelSEED_id(dict_db_link):
    if "seed.compound" in dict_db_link.keys():
        seed_id = dict_db_link["seed.compound"]
    else:
        seed_id = None
    #print(seed_id)
    return seed_id

df_metabolites_bigg['seed.compound'] = df_metabolites_bigg['database_links'].apply(apply_modelSEED_id)

df_metabolites_bigg.head(25)
# Out:
#          bigg_id universal_bigg_id  \
# 0     12dgr120_c          12dgr120
# 1     12dgr140_c          12dgr140
# 2     12dgr180_c          12dgr180
# 3     14glucan_c          14glucan
# 4        15dap_c             15dap
# 5       23ddhb_c            23ddhb
# 6       23dhba_c            23dhba
# 7      23dhbzs_c           23dhbzs
# 8     26dap_LL_c          26dap_LL
# 9     2agpe141_c          2agpe141
# 10    2agpe160_c          2agpe160
# 11    2agpg120_c          2agpg120
# 12    2agpg140_c          2agpg140
# 13      2aobut_c            2aobut
# 14  2dh3dgal6p_c        2dh3dgal6p
# 15        2dhp_c              2dhp
# 16     2dmmql8_c           2dmmql8
# 17    2h3oppan_c          2h3oppan
# 18    2hdecg3p_c          2hdecg3p
# 19    2odecg3p_c          2odecg3p
# 20       2ohph_c             2ohph
# 21      2ombzl_c            2ombzl
# 22       2omph_c             2omph
# 23        2oph_c              2oph
# 24      2pglyc_c            2pglyc
#
#                                                  name  \
# 0      1,2-Diacyl-sn-glycerol (didodecanoyl, n-C12:0)
# 1   1,2-Diacyl-sn-glycerol (ditetradecanoyl, n-C14:0)
# 2    1,2-Diacyl-sn-glycerol (dioctadecanoyl, n-C18:0)
# 3                                  1,4-alpha-D-glucan
# 4                                  1,5-Diaminopentane
# 5                   2,3-Dihydro-2,3-dihydroxybenzoate
# 6                     (2,3-Dihydroxybenzoyl)adenylate
# 7                          2,3-dihydroxybenzoylserine
# 8                         LL-2,6-Diaminoheptanedioate
# 9   2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1)
# 10  2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0)
# 11      2-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0)
# 12      2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0)
# 13                           L-2-Amino-3-oxobutanoate
# 14        2-Dehydro-3-deoxy-D-galactonate 6-phosphate
# 15                                  2-Dehydropantoate
# 16                             2-Demethylmenaquinol 8
# 17                          2-Hydroxy-3-oxopropanoate
# 18             2-hexadecanoyl-sn-glycerol 3-phosphate
# 19             2-octadecanoyl-sn-glycerol 3-phosphate
# 20                       2-Octaprenyl-6-hydroxyphenol
# 21             2-Octaprenyl-6-methoxy-1,4-benzoquinol
# 22                       2-Octaprenyl-6-methoxyphenol
# 23                                 2-Octaprenylphenol
# 24                                 2-Phosphoglycolate
#
#                                            model_list  \
# 0   iEC1364_W; iEC1349_Crooks; iEC1356_Bl21DE3; iM...
# 1   iECNA114_1301; iECSE_1348; iECO111_1330; iECOK...
# 2   iECB_1328; iECDH10B_1368; iEcE24377_1341; iECD...
# 3   iSFxv_1172; iUTI89_1310; iSSON_1240; iSbBS512_...
# 4   iECUMN_1333; iLF82_1304; iETEC_1333; iECSF_132...
# 5   iEC1372_W3110; iEC1368_DH5a; iCN900; iEC1364_W...
# 6   iECs_1301; iECO111_1330; iECP_1309; iECIAI1_13...
# 7   STM_v1_0; iY75_1357; iAF1260b; iML1515; iEC134...
# 8   iLJ478; iAF1260b; STM_v1_0; iJN678; iY75_1357;...
# 9   iEC1344_C; iYS1720; iEC1368_DH5a; iEC1372_W311...
# 10  iB21_1397; iJO1366; iE2348C_1286; ic_1306; iSF...
# 11  iWFL_1372; iYL1228; iSDY_1059; iSSON_1240; iUT...
# 12  iECUMN_1333; iNRG857_1313; iECW_1372; iEKO11_1...
# 13  iETEC_1333; iLF82_1304; iECW_1372; iNRG857_131...
# 14  iSBO_1134; iSFxv_1172; iJR904; iUMN146_1321; i...
# 15  iECD_1391; iEcDH1_1363; iECED1_1282; iECB_1328...
# 16  ic_1306; iE2348C_1286; iBWG_1329; iSB619; iEC5...
# 17  iNRG857_1313; iETEC_1333; iLF82_1304; iECSP_13...
# 18  iYS1720; iEC1372_W3110; iEC1368_DH5a; iEC1344_...
# 19  iPC815; iAPECO1_1312; iE2348C_1286; iEC042_131...
# 20  iEC1364_W; iML1515; iEC1349_Crooks; iEC1356_Bl...
# 21  iEcHS_1320; iECO103_1326; iECS88_1305; iEcolC_...
# 22  iS_1188; iETEC_1333; iEcSMS35_1347; iECW_1372;...
# 23  iEC55989_1330; iECH74115_1262; iECBD_1354; iEC...
# 24  iECOK1_1307; iEcolC_1368; iECP_1309; iECO26_13...
#
#                                        database_links  \
# 0                   {'metanetx.chemical': 'MNXM4939'}
# 1                 {'metanetx.chemical': 'MNXM146479'}
# 2                   {'metanetx.chemical': 'MNXM4217'}
# 3   {'biocyc': 'META:1-4-alpha-D-Glucan', 'metanet...
# 4   {'kegg.compound': 'C01672', 'chebi': 'CHEBI:58...
# 5   {'kegg.compound': 'C04171', 'chebi': 'CHEBI:87...
# 6   {'kegg.compound': 'C04030', 'chebi': 'CHEBI:57...
# 7   {'kegg.compound': 'C04204', 'chebi': 'CHEBI:70...
# 8   {'kegg.compound': 'C00666', 'chebi': 'CHEBI:63...
# 9                   {'metanetx.chemical': 'MNXM3447'}
# 10  {'chebi': 'CHEBI:132926', 'inchikey': 'CKPBBEO...
# 11                  {'metanetx.chemical': 'MNXM3450'}
# 12  {'biocyc': 'META:CPD0-2173', 'metanetx.chemica...
# 13  {'reactome': 'R-ALL-6798652', 'kegg.compound':...
# 14  {'kegg.compound': 'C01286', 'chebi': 'CHEBI:58...
# 15  {'kegg.compound': 'C00966', 'chebi': 'CHEBI:19...
# 16  {'chebi': 'CHEBI:61873', 'inchikey': 'FGYPGICS...
# 17  {'kegg.compound': 'C01146', 'chebi': 'CHEBI:57...
# 18  {'hmdb': 'HMDB07849', 'lipidmaps': 'LMGP100500...
# 19  {'hmdb': 'HMDB07850', 'lipidmaps': 'LMGP100500...
# 20  {'kegg.compound': 'C05811', 'chebi': 'CHEBI:62...
# 21  {'chebi': 'CHEBI:60655', 'inchikey': 'CZFRMASE...
# 22  {'kegg.compound': 'C05812', 'chebi': 'CHEBI:12...
# 23  {'kegg.compound': 'C05810', 'chebi': 'CHEBI:40...
# 24  {'inchikey': 'ASCFNMCAHFUBCO-UHFFFAOYSA-K', 'k...
#
#                                          old_bigg_ids universal_bigg_id_lower  \
# 0      12dgr120; 12dgr120[c]; 12dgr120_c; _12dgr120_c                12dgr120
# 1      12dgr140; 12dgr140[c]; 12dgr140_c; _12dgr140_c                12dgr140
# 2      12dgr180; 12dgr180[c]; 12dgr180_c; _12dgr180_c                12dgr180
# 3                                14glucan; 14glucan_c                14glucan
# 4                            15dap; 15dap[c]; 15dap_c                   15dap
# 5                                    23ddhb; 23ddhb_c                  23ddhb
# 6                                    23dhba; 23dhba_c                  23dhba
# 7                                  23dhbzs; 23dhbzs_c                 23dhbzs
# 8   26dap-LL[c]; 26dap_DASH_LL_c; 26dap_LL; 26dap_...                26dap_ll
# 9                   2agpe141; 2agpe141_c; _2agpe141_c                2agpe141
# 10                  2agpe160; 2agpe160_c; _2agpe160_c                2agpe160
# 11                  2agpg120; 2agpg120_c; _2agpg120_c                2agpg120
# 12                  2agpg140; 2agpg140_c; _2agpg140_c                2agpg140
# 13                        2aobut; 2aobut[c]; 2aobut_c                  2aobut
# 14                           2dh3dgal6p; 2dh3dgal6p_c              2dh3dgal6p
# 15                     2dhp; 2dhp[c]; 2dhp_c; _2dhp_c                    2dhp
# 16         2dmmql8; 2dmmql8[c]; 2dmmql8_c; _2dmmql8_c                 2dmmql8
# 17                  2h3oppan; 2h3oppan[c]; 2h3oppan_c                2h3oppan
# 18                               2hdecg3p; 2hdecg3p_c                2hdecg3p
# 19                               2odecg3p; 2odecg3p_c                2odecg3p
# 20                                     2ohph; 2ohph_c                   2ohph
# 21                                   2ombzl; 2ombzl_c                  2ombzl
# 22                                     2omph; 2omph_c                   2omph
# 23                                       2oph; 2oph_c                    2oph
# 24                        2pglyc; 2pglyc[c]; 2pglyc_c                  2pglyc
#
#    seed.compound
# 0           None
# 1           None
# 2           None
# 3       cpd21754
# 4       cpd01155
# 5       cpd29666
# 6       cpd02494
# 7       cpd15332
# 8       cpd00504
# 9           None
# 10      cpd26438
# 11          None
# 12      cpd26437
# 13      cpd02211
# 14      cpd00945
# 15      cpd00712
# 16      cpd15353
# 17      cpd00843
# 18      cpd15355
# 19      cpd15358
# 20      cpd03445
# 21      cpd15359
# 22      cpd03446
# 23      cpd03444
# 24      cpd00727

# %% [markdown]
# # IV / ModelSEED Metabolites table

# %% [markdown]
# ## 1) Load ModelSEED metabolites table

# %%
# Load ModelSeed Metabolites Table

seed_metabolites_url = 'https://raw.githubusercontent.com/ModelSEED/ModelSEEDDatabase/master/Biochemistry/compounds.tsv'
df_metabolites_seed = pd.read_csv(seed_metabolites_url, sep='\t')

df_metabolites_seed.head(25)
# Out:
# /home/caujoulat/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (4,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           id abbreviation                     name         formula   mass  \
# 0   cpd00001          h2o                      H2O             H2O   18.0
# 1   cpd00002          atp                      ATP   C10H13N5O13P3  504.0
# 2   cpd00003          nad                      NAD   C21H26N7O14P2  662.0
# 3   cpd00004         nadh                     NADH   C21H27N7O14P2  663.0
# 4   cpd00005        nadph                    NADPH   C21H26N7O17P3  742.0
# 5   cpd00006         nadp                     NADP   C21H25N7O17P3  741.0
# 6   cpd00007           o2                       O2              O2   32.0
# 7   cpd00008          adp                      ADP   C10H13N5O10P2  425.0
# 8   cpd00009           pi                Phosphate            HO4P   96.0
# 9   cpd00010          coa                      CoA  C21H32N7O16P3S  764.0
# 10  cpd00011          co2                      CO2             CO2   44.0
# 11  cpd00012          ppi                      PPi           HO7P2  176.0
# 12  cpd00013          nh4                      NH3             H4N   18.0
# 13  cpd00014          udp                      UDP    C9H12N2O12P2  402.0
# 14  cpd00015          fad                      FAD   C27H31N9O15P2  783.0
# 15  cpd00016       pydx5p      Pyridoxal phosphate        C8H8NO6P  246.0
# 16  cpd00017         amet  S-Adenosyl-L-methionine     C15H23N6O5S  399.0
# 17  cpd00018          amp                      AMP     C10H12N5O7P  346.0
# 18  cpd00019        ahcys  S-Adenosyl-homocysteine     C14H20N6O5S  384.0
# 19  cpd00020          pyr                 Pyruvate          C3H3O3   87.0
# 20  cpd00021         Iron                       Fe              Fe   56.0
# 21  cpd00022        accoa               Acetyl-CoA  C23H34N7O17P3S  806.0
# 22  cpd00023        glu-L              L-Glutamate         C5H8NO4  146.0
# 23  cpd00024          akg           2-Oxoglutarate          C5H4O5  144.0
# 24  cpd00025         h2o2                     H2O2            H2O2   34.0
#
#               source                     inchikey  charge  is_core  \
# 0   Primary Database  XLYOFNOQVPJJNP-UHFFFAOYSA-N       0        1
# 1   Primary Database  ZKHQWZAMYRWXGA-KQYNXXCUSA-K      -3        1
# 2   Primary Database  BAWFJGJZGIEFAR-NNYOXOHSSA-M      -1        1
# 3   Primary Database  BOPGDPNILDQYTO-NNYOXOHSSA-L      -2        1
# 4   Primary Database  ACFIXJIJDZMPPO-NNYOXOHSSA-J      -4        1
# 5   Primary Database  XJLXINKUBYWONI-NNYOXOHSSA-K      -3        1
# 6   Primary Database  MYMOFIZGZYHOMD-UHFFFAOYSA-N       0        1
# 7   Primary Database  XTWYTFMLZFPYCI-KQYNXXCUSA-L      -2        1
# 8   Primary Database  NBIIXXVUZAFLBC-UHFFFAOYSA-L      -2        1
# 9   Primary Database  RGJOEKWQDUBAIZ-IBOSZNHHSA-J      -4        1
# 10  Primary Database  CURLTUGMZLYLDI-UHFFFAOYSA-N       0        1
# 11  Primary Database  XPPKVPWEQAFLFU-UHFFFAOYSA-K      -3        1
# 12  Primary Database  QGZKDVFQNNGYKY-UHFFFAOYSA-O       1        1
# 13  Primary Database  XCCTYIAWTASOJW-XVFCMESISA-L      -2        1
# 14  Primary Database  IMGVNJNCCGXBHD-UYBVJOGSSA-K      -2        1
# 15  Primary Database  NGVDGCNFYWLIFO-UHFFFAOYSA-L      -2        1
# 16  Primary Database  MEFKEPWMEQBLKI-AIRLBKTGSA-O       1        1
# 17  Primary Database  UDMBCSSLTHHNCD-KQYNXXCUSA-L      -2        1
# 18  Primary Database  ZJUKTBDSGOFHSH-WFMPWKQPSA-N       0        1
# 19  Primary Database  LCTONWCANYUPML-UHFFFAOYSA-M      -1        1
# 20  Primary Database  XEEYBQQBJWHFJM-UHFFFAOYSA-N       0        1
# 21  Primary Database  ZSLZBFCDCINBPY-ZSJPKINUSA-J      -4        1
# 22  Primary Database  WHUUTDBJXJRKMK-VKHMYHEASA-M      -1        1
# 23  Primary Database  KPGXRSRHYNQIFN-UHFFFAOYSA-L      -2        1
# 24  Primary Database  MHAJPDPJQMAIIY-UHFFFAOYSA-N       0        1
#
#     is_obsolete  ... is_cofactor  deltag  deltagerr  \
# 0             0  ...           0  -37.54       0.18
# 1             0  ...           0 -548.85       0.36
# 2             0  ...           0 -286.41       1.59
# 3             0  ...           0 -271.15       1.59
# 4             0  ...           0 -483.10       1.62
# 5             0  ...           0 -498.36       1.63
# 6             0  ...           0    3.92       0.71
# 7             0  ...           0 -340.04       0.30
# 8             0  ...           0 -252.51       0.18
# 9             0  ...           0 -429.53       1.87
# 10            0  ...           0  -92.26       0.71
# 11            0  ...           0 -464.02       0.27
# 12            0  ...           0   19.05       0.26
# 13            0  ...           0 -480.68       1.14
# 14            0  ...           0 -229.75       2.22
# 15            0  ...           0 -202.34       0.93
# 16            0  ...           0  -66.63       3.68
# 17            0  ...           0 -130.80       0.29
# 18            0  ...           0  115.75       0.96
# 19            0  ...           0  -82.56       0.18
# 20            0  ...           0   -0.00       0.71
# 21            0  ...           0 -443.56       1.86
# 22            0  ...           0  -87.67       0.30
# 23            0  ...           0 -150.81       0.32
# 24            0  ...           0  -12.55       0.71
#
#                                                   pka  \
# 0                                           1:1:15.70
# 1   1:14:12.60;1:22:3.29;1:26:0.90;1:29:7.42;1:30:...
# 2   1:6:11.94;1:17:1.85;1:18:2.28;1:25:11.38;1:35:...
# 3   1:14:12.28;1:18:14.00;1:22:-7.46;1:26:-1.05;1:...
# 4   1:18:0.90;1:19:5.78;1:26:0.66;1:30:3.26;1:40:1...
# 5   1:18:0.90;1:19:5.78;1:26:3.26;1:30:0.66;1:47:1...
# 6                                                 NaN
# 7   1:14:12.46;1:18:13.98;1:22:2.22;1:25:7.42;1:26...
# 8                         1:2:12.90;1:3:1.80;1:4:6.95
# 9   1:22:0.92;1:23:5.94;1:26:0.83;1:30:3.27;1:48:1...
# 10                                                NaN
# 11                1:3:8.17;1:4:1.70;1:7:3.06;1:8:6.98
# 12                                                NaN
# 13  1:9:12.62;1:10:9.70;1:14:14.07;1:20:3.21;1:23:...
# 14  1:1:6.01;1:31:2.28;1:35:1.85;1:42:13.98;1:43:1...
# 15                      1:10:8.00;1:14:1.68;1:15:6.69
# 16                    1:14:12.44;1:18:13.95;1:26:1.70
# 17  1:14:12.46;1:16:18.54;1:18:13.98;1:21:1.23;1:2...
# 18                      1:6:12.47;1:8:14.01;1:24:1.81
# 19                                           1:4:2.93
# 20                                                NaN
# 21  1:24:3.27;1:31:12.61;1:34:0.92;1:35:5.94;1:49:...
# 22                                  1:6:1.88;1:9:4.27
# 23                                 1:6:2.66;1:10:3.87
# 24                                1:1:11.52;1:2:14.40
#
#                                                   pkb abstract_compound  \
# 0                                           1:1:-1.80               NaN
# 1            1:6:-7.46;1:9:-1.06;1:14:-3.85;1:15:4.93               NaN
# 2   1:6:-4.22;1:35:-3.85;1:37:-1.05;1:41:4.93;1:43...               NaN
# 3   1:6:2.28;1:9:1.85;1:14:-3.85;1:15:4.93;1:18:-3...               NaN
# 4          1:11:-7.46;1:12:-1.06;1:22:4.87;1:40:-3.78               NaN
# 5                     1:11:-7.46;1:12:-1.06;1:22:4.87               NaN
# 6                                                 NaN               NaN
# 7   1:6:-7.46;1:9:-1.05;1:14:-3.85;1:15:4.93;1:18:...               NaN
# 8                                                 NaN               NaN
# 9                       1:8:-7.46;1:9:-1.06;1:17:4.89               NaN
# 10                                                NaN               NaN
# 11                                                NaN               NaN
# 12                                           1:1:8.86               NaN
# 13          1:3:-4.29;1:9:-3.79;1:14:-3.66;1:17:-5.40               NaN
# 14  1:42:-3.67;1:43:-3.85;1:44:4.89;1:46:-7.46;1:5...               NaN
# 15                                1:7:4.11;1:10:-5.84               NaN
# 16  1:6:-7.46;1:9:-1.05;1:14:-3.85;1:15:3.94;1:18:...               NaN
# 17  1:6:-7.46;1:9:-1.05;1:14:-3.85;1:15:3.92;1:16:...               NaN
# 18  1:6:-3.85;1:8:-3.65;1:12:-1.05;1:14:-7.46;1:16...               NaN
# 19                                          1:5:-9.58               NaN
# 20                                                NaN               NaN
# 21         1:31:-3.87;1:41:-1.06;1:43:4.89;1:45:-7.46               NaN
# 22                                           1:4:9.54               NaN
# 23                                          1:4:-9.67               NaN
# 24                                1:1:-4.19;1:2:-4.19               NaN
#
#     comprised_of                                            aliases  \
# 0            NaN  Name: H20; H2O; H3O+; HO-; Hydroxide ion; OH; ...
# 1            NaN  Name: ATP; Adenosine 5'-triphosphate; adenosin...
# 2            NaN  Name: DPN; DPN+; DPN-ox; Diphosphopyridine nuc...
# 3            NaN  Name: DPNH; NAD-reduced; NADH; NADH+H+; NADH2;...
# 4            NaN  Name: NADP(H); NADP-red; NADP-reduced; NADPH; ...
# 5            NaN  Name: NADP; NADP(+); NADP+; NADP-ox; NADP-oxid...
# 6            NaN  Name: O2; Oxygen; dioxygen; oxygen; oxygen mol...
# 7            NaN  Name: ADP; Adenosine 5'-diphosphate; Adenosine...
# 8            NaN  Name: H2PO4-; HPO4-2; HPO42-; Orthophosphate; ...
# 9            NaN  Name: CoA; CoA-SH; Coenzyme A; CoenzymeA; Coen...
# 10           NaN  Name: CO2; Carbon dioxide; carbon dioxide; car...
# 11           NaN  Name: Diphosphate; Diphosphoric acid; PP; PPi;...
# 12           NaN  Name: Ammonia; Ammonia ion; Ammonium; Ammonium...
# 13           NaN  Name: UDP; Uridine 5'-diphosphate; uridine-5'-...
# 14           NaN  Name: FAD; Flavin adenine dinucleotide; Flavin...
# 15           NaN  Name: PLP; Pyridoxal 5'-phosphate; Pyridoxal 5...
# 16           NaN  Name: 2-S-adenosyl-L-methionine; Acylcarnitine...
# 17           NaN  Name: 5'-AMP; 5'-Adenosine monophosphate; 5'-A...
# 18           NaN  Name: 2-S-adenosyl-L-homocysteine; AdoHcy; S-A...
# 19           NaN  Name: 2-Oxopropanoate; 2-Oxopropanoic acid; 2-...
# 20           NaN          Name: Iron|KEGG: C00023|iMO1053-PAO1: fe2
# 21           NaN  Name: Acetyl coenzyme A; Acetyl-CoA; ac-CoA; a...
# 22           NaN  Name: 1-amino-propane-1,3-dicarboxylic acid; 2...
# 23           NaN  Name: 2-Ketoglutaric acid; 2-Oxoglutarate; 2-k...
# 24           NaN  Name: H2O2; Hydrogen peroxide; Hydrogenperoxid...
#
#                                                smiles      notes
# 0                                                   O  GC|EQ|EQU
# 1   Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O...  GC|EQ|EQU
# 2   NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(...  GC|EQ|EQU
# 3   NC(=O)C1=CN([C@@H]2O[C@H](COP(=O)([O-])OP(=O)(...  GC|EQ|EQU
# 4   NC(=O)C1=CN([C@@H]2O[C@H](COP(=O)([O-])OP(=O)(...  GC|EQ|EQU
# 5   NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(...  GC|EQ|EQU
# 6                                                 O=O  GC|EQ|EQU
# 7   Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O...  GC|EQ|EQU
# 8                                    O=P([O-])([O-])O  GC|EQ|EQU
# 9   CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H]...  GC|EQ|EQU
# 10                                              O=C=O  GC|EQ|EQU
# 11                       O=P([O-])([O-])OP(=O)([O-])O  GC|EQ|EQU
# 12                                             [NH4+]  GC|EQ|EQU
# 13  O=c1ccn([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-]...  GC|EQ|EQU
# 14  Cc1cc2nc3c(=O)[n-]c(=O)nc-3n(C[C@H](O)[C@H](O)...  GC|EQ|EQU
# 15                 Cc1ncc(COP(=O)([O-])[O-])c(C=O)c1O  GC|EQ|EQU
# 16  C[S+](CC[C@H]([NH3+])C(=O)[O-])C[C@H]1O[C@@H](...      GC|EQ
# 17  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])[O-])...  GC|EQ|EQU
# 18  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CSCC[C@H]([NH3+])C...  GC|EQ|EQU
# 19                                    CC(=O)C(=O)[O-]  GC|EQ|EQU
# 20                                               [Fe]  GC|EQ|EQU
# 21  CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(...  GC|EQ|EQU
# 22                 [NH3+][C@@H](CCC(=O)[O-])C(=O)[O-]  GC|EQ|EQU
# 23                          O=C([O-])CCC(=O)C(=O)[O-]  GC|EQ|EQU
# 24                                                 OO  GC|EQ|EQU
#
# [25 rows x 21 columns]

# %% [markdown]
# ## 2) Changes to the abbreviation

# %% [markdown]
# As previously described for the aracore and BiGG ids, a few changes need to be made in order to make the correspondences between the databses and the AraCore model. In this case, we will focus on "abbreviation" column, because it seems to look like the previous BiGG ids and the aracore ones.
#
# > **For the ModelSEED database, we use aliases as "references" because they contain information about BiGG ids**
#
# Thus, we need to perform the following changes:
# - convert the abbreviation to lower case
# - convert string of the "aliases" pairs into dictionaries of keys and values:
#     1. split by "|" to separate the different key - value pairs
#     2. split by ":" to separate keys and values
#     3. split the strings (keys and values) that are again strings with multiple items that need to be splitted:
#         - split those strings by ";" and also remove leading and tailing white spaces

# %%
df_metabolites_seed['abbreviation_lower'] = df_metabolites_seed['abbreviation'].str.lower()

# %%
#Convert string of alias pairs into dictionaries of keys and value - 
# 1) split by "|" to seperate the different key - value pairs
# 2) split by ":" to seperate keys and values
def apply_alias_into_dict(aliases_str):
    if isinstance(aliases_str, str):
        dictionary = {}        
        for alias in aliases_str.split("|"): 
            intermediate_alias = alias.split(":", 1)
            key = intermediate_alias[0]
            value = intermediate_alias[-1]
            dictionary[key] = value
    else:
        dictionary = {}
    #print(dictionary)
    return dictionary
    
df_metabolites_seed['aliases_dict'] = df_metabolites_seed['aliases'].apply(apply_alias_into_dict)


#Some of the keys have values that are again strings with multiple items that need to be splitted
# 3) split those strings by ';' and also remove leading and tailing white spaces 
def apply_items_splited(alias_dict):
    dict_alias = {}
    for alias_key, alias_values in alias_dict.items(): # dictionary comprehension
        alias_values_splited = alias_values.split(';')
        list_strip_elements = [] # we initialize the list for each value of the dictionary => at the same level of the list comprehension
        for alias_values in alias_values_splited: # list comprehension           
            alias_values_strip = alias_values.strip()
            list_strip_elements.append(alias_values_strip)
            #print(list_strip_elements)
        dict_alias[alias_key] = list_strip_elements
    #print(dict_alias)
    return dict_alias

df_metabolites_seed['aliases_dict_items_splitted'] = df_metabolites_seed['aliases_dict'].apply(apply_items_splited)
        
df_metabolites_seed.head(25)
# Out:
#           id abbreviation                     name         formula   mass  \
# 0   cpd00001          h2o                      H2O             H2O   18.0
# 1   cpd00002          atp                      ATP   C10H13N5O13P3  504.0
# 2   cpd00003          nad                      NAD   C21H26N7O14P2  662.0
# 3   cpd00004         nadh                     NADH   C21H27N7O14P2  663.0
# 4   cpd00005        nadph                    NADPH   C21H26N7O17P3  742.0
# 5   cpd00006         nadp                     NADP   C21H25N7O17P3  741.0
# 6   cpd00007           o2                       O2              O2   32.0
# 7   cpd00008          adp                      ADP   C10H13N5O10P2  425.0
# 8   cpd00009           pi                Phosphate            HO4P   96.0
# 9   cpd00010          coa                      CoA  C21H32N7O16P3S  764.0
# 10  cpd00011          co2                      CO2             CO2   44.0
# 11  cpd00012          ppi                      PPi           HO7P2  176.0
# 12  cpd00013          nh4                      NH3             H4N   18.0
# 13  cpd00014          udp                      UDP    C9H12N2O12P2  402.0
# 14  cpd00015          fad                      FAD   C27H31N9O15P2  783.0
# 15  cpd00016       pydx5p      Pyridoxal phosphate        C8H8NO6P  246.0
# 16  cpd00017         amet  S-Adenosyl-L-methionine     C15H23N6O5S  399.0
# 17  cpd00018          amp                      AMP     C10H12N5O7P  346.0
# 18  cpd00019        ahcys  S-Adenosyl-homocysteine     C14H20N6O5S  384.0
# 19  cpd00020          pyr                 Pyruvate          C3H3O3   87.0
# 20  cpd00021         Iron                       Fe              Fe   56.0
# 21  cpd00022        accoa               Acetyl-CoA  C23H34N7O17P3S  806.0
# 22  cpd00023        glu-L              L-Glutamate         C5H8NO4  146.0
# 23  cpd00024          akg           2-Oxoglutarate          C5H4O5  144.0
# 24  cpd00025         h2o2                     H2O2            H2O2   34.0
#
#               source                     inchikey  charge  is_core  \
# 0   Primary Database  XLYOFNOQVPJJNP-UHFFFAOYSA-N       0        1
# 1   Primary Database  ZKHQWZAMYRWXGA-KQYNXXCUSA-K      -3        1
# 2   Primary Database  BAWFJGJZGIEFAR-NNYOXOHSSA-M      -1        1
# 3   Primary Database  BOPGDPNILDQYTO-NNYOXOHSSA-L      -2        1
# 4   Primary Database  ACFIXJIJDZMPPO-NNYOXOHSSA-J      -4        1
# 5   Primary Database  XJLXINKUBYWONI-NNYOXOHSSA-K      -3        1
# 6   Primary Database  MYMOFIZGZYHOMD-UHFFFAOYSA-N       0        1
# 7   Primary Database  XTWYTFMLZFPYCI-KQYNXXCUSA-L      -2        1
# 8   Primary Database  NBIIXXVUZAFLBC-UHFFFAOYSA-L      -2        1
# 9   Primary Database  RGJOEKWQDUBAIZ-IBOSZNHHSA-J      -4        1
# 10  Primary Database  CURLTUGMZLYLDI-UHFFFAOYSA-N       0        1
# 11  Primary Database  XPPKVPWEQAFLFU-UHFFFAOYSA-K      -3        1
# 12  Primary Database  QGZKDVFQNNGYKY-UHFFFAOYSA-O       1        1
# 13  Primary Database  XCCTYIAWTASOJW-XVFCMESISA-L      -2        1
# 14  Primary Database  IMGVNJNCCGXBHD-UYBVJOGSSA-K      -2        1
# 15  Primary Database  NGVDGCNFYWLIFO-UHFFFAOYSA-L      -2        1
# 16  Primary Database  MEFKEPWMEQBLKI-AIRLBKTGSA-O       1        1
# 17  Primary Database  UDMBCSSLTHHNCD-KQYNXXCUSA-L      -2        1
# 18  Primary Database  ZJUKTBDSGOFHSH-WFMPWKQPSA-N       0        1
# 19  Primary Database  LCTONWCANYUPML-UHFFFAOYSA-M      -1        1
# 20  Primary Database  XEEYBQQBJWHFJM-UHFFFAOYSA-N       0        1
# 21  Primary Database  ZSLZBFCDCINBPY-ZSJPKINUSA-J      -4        1
# 22  Primary Database  WHUUTDBJXJRKMK-VKHMYHEASA-M      -1        1
# 23  Primary Database  KPGXRSRHYNQIFN-UHFFFAOYSA-L      -2        1
# 24  Primary Database  MHAJPDPJQMAIIY-UHFFFAOYSA-N       0        1
#
#     is_obsolete  ...                                                pka  \
# 0             0  ...                                          1:1:15.70
# 1             0  ...  1:14:12.60;1:22:3.29;1:26:0.90;1:29:7.42;1:30:...
# 2             0  ...  1:6:11.94;1:17:1.85;1:18:2.28;1:25:11.38;1:35:...
# 3             0  ...  1:14:12.28;1:18:14.00;1:22:-7.46;1:26:-1.05;1:...
# 4             0  ...  1:18:0.90;1:19:5.78;1:26:0.66;1:30:3.26;1:40:1...
# 5             0  ...  1:18:0.90;1:19:5.78;1:26:3.26;1:30:0.66;1:47:1...
# 6             0  ...                                                NaN
# 7             0  ...  1:14:12.46;1:18:13.98;1:22:2.22;1:25:7.42;1:26...
# 8             0  ...                        1:2:12.90;1:3:1.80;1:4:6.95
# 9             0  ...  1:22:0.92;1:23:5.94;1:26:0.83;1:30:3.27;1:48:1...
# 10            0  ...                                                NaN
# 11            0  ...                1:3:8.17;1:4:1.70;1:7:3.06;1:8:6.98
# 12            0  ...                                                NaN
# 13            0  ...  1:9:12.62;1:10:9.70;1:14:14.07;1:20:3.21;1:23:...
# 14            0  ...  1:1:6.01;1:31:2.28;1:35:1.85;1:42:13.98;1:43:1...
# 15            0  ...                      1:10:8.00;1:14:1.68;1:15:6.69
# 16            0  ...                    1:14:12.44;1:18:13.95;1:26:1.70
# 17            0  ...  1:14:12.46;1:16:18.54;1:18:13.98;1:21:1.23;1:2...
# 18            0  ...                      1:6:12.47;1:8:14.01;1:24:1.81
# 19            0  ...                                           1:4:2.93
# 20            0  ...                                                NaN
# 21            0  ...  1:24:3.27;1:31:12.61;1:34:0.92;1:35:5.94;1:49:...
# 22            0  ...                                  1:6:1.88;1:9:4.27
# 23            0  ...                                 1:6:2.66;1:10:3.87
# 24            0  ...                                1:1:11.52;1:2:14.40
#
#                                                   pkb  abstract_compound  \
# 0                                           1:1:-1.80                NaN
# 1            1:6:-7.46;1:9:-1.06;1:14:-3.85;1:15:4.93                NaN
# 2   1:6:-4.22;1:35:-3.85;1:37:-1.05;1:41:4.93;1:43...                NaN
# 3   1:6:2.28;1:9:1.85;1:14:-3.85;1:15:4.93;1:18:-3...                NaN
# 4          1:11:-7.46;1:12:-1.06;1:22:4.87;1:40:-3.78                NaN
# 5                     1:11:-7.46;1:12:-1.06;1:22:4.87                NaN
# 6                                                 NaN                NaN
# 7   1:6:-7.46;1:9:-1.05;1:14:-3.85;1:15:4.93;1:18:...                NaN
# 8                                                 NaN                NaN
# 9                       1:8:-7.46;1:9:-1.06;1:17:4.89                NaN
# 10                                                NaN                NaN
# 11                                                NaN                NaN
# 12                                           1:1:8.86                NaN
# 13          1:3:-4.29;1:9:-3.79;1:14:-3.66;1:17:-5.40                NaN
# 14  1:42:-3.67;1:43:-3.85;1:44:4.89;1:46:-7.46;1:5...                NaN
# 15                                1:7:4.11;1:10:-5.84                NaN
# 16  1:6:-7.46;1:9:-1.05;1:14:-3.85;1:15:3.94;1:18:...                NaN
# 17  1:6:-7.46;1:9:-1.05;1:14:-3.85;1:15:3.92;1:16:...                NaN
# 18  1:6:-3.85;1:8:-3.65;1:12:-1.05;1:14:-7.46;1:16...                NaN
# 19                                          1:5:-9.58                NaN
# 20                                                NaN                NaN
# 21         1:31:-3.87;1:41:-1.06;1:43:4.89;1:45:-7.46                NaN
# 22                                           1:4:9.54                NaN
# 23                                          1:4:-9.67                NaN
# 24                                1:1:-4.19;1:2:-4.19                NaN
#
#     comprised_of                                            aliases  \
# 0            NaN  Name: H20; H2O; H3O+; HO-; Hydroxide ion; OH; ...
# 1            NaN  Name: ATP; Adenosine 5'-triphosphate; adenosin...
# 2            NaN  Name: DPN; DPN+; DPN-ox; Diphosphopyridine nuc...
# 3            NaN  Name: DPNH; NAD-reduced; NADH; NADH+H+; NADH2;...
# 4            NaN  Name: NADP(H); NADP-red; NADP-reduced; NADPH; ...
# 5            NaN  Name: NADP; NADP(+); NADP+; NADP-ox; NADP-oxid...
# 6            NaN  Name: O2; Oxygen; dioxygen; oxygen; oxygen mol...
# 7            NaN  Name: ADP; Adenosine 5'-diphosphate; Adenosine...
# 8            NaN  Name: H2PO4-; HPO4-2; HPO42-; Orthophosphate; ...
# 9            NaN  Name: CoA; CoA-SH; Coenzyme A; CoenzymeA; Coen...
# 10           NaN  Name: CO2; Carbon dioxide; carbon dioxide; car...
# 11           NaN  Name: Diphosphate; Diphosphoric acid; PP; PPi;...
# 12           NaN  Name: Ammonia; Ammonia ion; Ammonium; Ammonium...
# 13           NaN  Name: UDP; Uridine 5'-diphosphate; uridine-5'-...
# 14           NaN  Name: FAD; Flavin adenine dinucleotide; Flavin...
# 15           NaN  Name: PLP; Pyridoxal 5'-phosphate; Pyridoxal 5...
# 16           NaN  Name: 2-S-adenosyl-L-methionine; Acylcarnitine...
# 17           NaN  Name: 5'-AMP; 5'-Adenosine monophosphate; 5'-A...
# 18           NaN  Name: 2-S-adenosyl-L-homocysteine; AdoHcy; S-A...
# 19           NaN  Name: 2-Oxopropanoate; 2-Oxopropanoic acid; 2-...
# 20           NaN          Name: Iron|KEGG: C00023|iMO1053-PAO1: fe2
# 21           NaN  Name: Acetyl coenzyme A; Acetyl-CoA; ac-CoA; a...
# 22           NaN  Name: 1-amino-propane-1,3-dicarboxylic acid; 2...
# 23           NaN  Name: 2-Ketoglutaric acid; 2-Oxoglutarate; 2-k...
# 24           NaN  Name: H2O2; Hydrogen peroxide; Hydrogenperoxid...
#
#                                                smiles      notes  \
# 0                                                   O  GC|EQ|EQU
# 1   Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O...  GC|EQ|EQU
# 2   NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(...  GC|EQ|EQU
# 3   NC(=O)C1=CN([C@@H]2O[C@H](COP(=O)([O-])OP(=O)(...  GC|EQ|EQU
# 4   NC(=O)C1=CN([C@@H]2O[C@H](COP(=O)([O-])OP(=O)(...  GC|EQ|EQU
# 5   NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(...  GC|EQ|EQU
# 6                                                 O=O  GC|EQ|EQU
# 7   Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O...  GC|EQ|EQU
# 8                                    O=P([O-])([O-])O  GC|EQ|EQU
# 9   CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H]...  GC|EQ|EQU
# 10                                              O=C=O  GC|EQ|EQU
# 11                       O=P([O-])([O-])OP(=O)([O-])O  GC|EQ|EQU
# 12                                             [NH4+]  GC|EQ|EQU
# 13  O=c1ccn([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-]...  GC|EQ|EQU
# 14  Cc1cc2nc3c(=O)[n-]c(=O)nc-3n(C[C@H](O)[C@H](O)...  GC|EQ|EQU
# 15                 Cc1ncc(COP(=O)([O-])[O-])c(C=O)c1O  GC|EQ|EQU
# 16  C[S+](CC[C@H]([NH3+])C(=O)[O-])C[C@H]1O[C@@H](...      GC|EQ
# 17  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])[O-])...  GC|EQ|EQU
# 18  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CSCC[C@H]([NH3+])C...  GC|EQ|EQU
# 19                                    CC(=O)C(=O)[O-]  GC|EQ|EQU
# 20                                               [Fe]  GC|EQ|EQU
# 21  CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(...  GC|EQ|EQU
# 22                 [NH3+][C@@H](CCC(=O)[O-])C(=O)[O-]  GC|EQ|EQU
# 23                          O=C([O-])CCC(=O)C(=O)[O-]  GC|EQ|EQU
# 24                                                 OO  GC|EQ|EQU
#
#     abbreviation_lower                                       aliases_dict  \
# 0                  h2o  {'Name': ' H20; H2O; H3O+; HO-; Hydroxide ion;...
# 1                  atp  {'Name': ' ATP; Adenosine 5'-triphosphate; ade...
# 2                  nad  {'Name': ' DPN; DPN+; DPN-ox; Diphosphopyridin...
# 3                 nadh  {'Name': ' DPNH; NAD-reduced; NADH; NADH+H+; N...
# 4                nadph  {'Name': ' NADP(H); NADP-red; NADP-reduced; NA...
# 5                 nadp  {'Name': ' NADP; NADP(+); NADP+; NADP-ox; NADP...
# 6                   o2  {'Name': ' O2; Oxygen; dioxygen; oxygen; oxyge...
# 7                  adp  {'Name': ' ADP; Adenosine 5'-diphosphate; Aden...
# 8                   pi  {'Name': ' H2PO4-; HPO4-2; HPO42-; Orthophosph...
# 9                  coa  {'Name': ' CoA; CoA-SH; Coenzyme A; CoenzymeA;...
# 10                 co2  {'Name': ' CO2; Carbon dioxide; carbon dioxide...
# 11                 ppi  {'Name': ' Diphosphate; Diphosphoric acid; PP;...
# 12                 nh4  {'Name': ' Ammonia; Ammonia ion; Ammonium; Amm...
# 13                 udp  {'Name': ' UDP; Uridine 5'-diphosphate; uridin...
# 14                 fad  {'Name': ' FAD; Flavin adenine dinucleotide; F...
# 15              pydx5p  {'Name': ' PLP; Pyridoxal 5'-phosphate; Pyrido...
# 16                amet  {'Name': ' 2-S-adenosyl-L-methionine; Acylcarn...
# 17                 amp  {'Name': ' 5'-AMP; 5'-Adenosine monophosphate;...
# 18               ahcys  {'Name': ' 2-S-adenosyl-L-homocysteine; AdoHcy...
# 19                 pyr  {'Name': ' 2-Oxopropanoate; 2-Oxopropanoic aci...
# 20                iron  {'Name': ' Iron', 'KEGG': ' C00023', 'iMO1053-...
# 21               accoa  {'Name': ' Acetyl coenzyme A; Acetyl-CoA; ac-C...
# 22               glu-l  {'Name': ' 1-amino-propane-1,3-dicarboxylic ac...
# 23                 akg  {'Name': ' 2-Ketoglutaric acid; 2-Oxoglutarate...
# 24                h2o2  {'Name': ' H2O2; Hydrogen peroxide; Hydrogenpe...
#
#                           aliases_dict_items_splitted
# 0   {'Name': ['H20', 'H2O', 'H3O+', 'HO-', 'Hydrox...
# 1   {'Name': ['ATP', 'Adenosine 5'-triphosphate', ...
# 2   {'Name': ['DPN', 'DPN+', 'DPN-ox', 'Diphosphop...
# 3   {'Name': ['DPNH', 'NAD-reduced', 'NADH', 'NADH...
# 4   {'Name': ['NADP(H)', 'NADP-red', 'NADP-reduced...
# 5   {'Name': ['NADP', 'NADP(+)', 'NADP+', 'NADP-ox...
# 6   {'Name': ['O2', 'Oxygen', 'dioxygen', 'oxygen'...
# 7   {'Name': ['ADP', 'Adenosine 5'-diphosphate', '...
# 8   {'Name': ['H2PO4-', 'HPO4-2', 'HPO42-', 'Ortho...
# 9   {'Name': ['CoA', 'CoA-SH', 'Coenzyme A', 'Coen...
# 10  {'Name': ['CO2', 'Carbon dioxide', 'carbon dio...
# 11  {'Name': ['Diphosphate', 'Diphosphoric acid', ...
# 12  {'Name': ['Ammonia', 'Ammonia ion', 'Ammonium'...
# 13  {'Name': ['UDP', 'Uridine 5'-diphosphate', 'ur...
# 14  {'Name': ['FAD', 'Flavin adenine dinucleotide'...
# 15  {'Name': ['PLP', 'Pyridoxal 5'-phosphate', 'Py...
# 16  {'Name': ['2-S-adenosyl-L-methionine', 'Acylca...
# 17  {'Name': ['5'-AMP', '5'-Adenosine monophosphat...
# 18  {'Name': ['2-S-adenosyl-L-homocysteine', 'AdoH...
# 19  {'Name': ['2-Oxopropanoate', '2-Oxopropanoic a...
# 20  {'Name': ['Iron'], 'KEGG': ['C00023'], 'iMO105...
# 21  {'Name': ['Acetyl coenzyme A', 'Acetyl-CoA', '...
# 22  {'Name': ['1-amino-propane-1,3-dicarboxylic ac...
# 23  {'Name': ['2-Ketoglutaric acid', '2-Oxoglutara...
# 24  {'Name': ['H2O2', 'Hydrogen peroxide', 'Hydrog...
#
# [25 rows x 24 columns]

# %%
#All database keys in aliases
np.unique(df_metabolites_seed['aliases_dict_items_splitted'].apply(lambda x: list(x.keys())).sum())
# Out:
# array(['AlgaGEM', 'AraCyc', 'AraGEM', 'BiGG', 'BrachyCyc', 'ChlamyCyc',
#        'CornCyc', 'DF_Athaliana', 'EcoCyc', 'JM_Creinhardtii',
#        'JP_Creinhardtii_MSB', 'JP_Creinhardtii_NMeth', 'KEGG', 'MaizeCyc',
#        'Maize_C4GEM', 'MetaCyc', 'Name', 'PlantCyc', 'PoplarCyc',
#        'RiceCyc', 'SorghumCyc', 'SoyCyc', 'TS_Athaliana', 'iAF1260',
#        'iAF692', 'iAG612', 'iAO358', 'iAbaylyiv4', 'iGT196', 'iIN800',
#        'iIT341', 'iJN746', 'iJR904', 'iMA945', 'iMEO21', 'iMM904',
#        'iMO1053-PAO1', 'iMO1056', 'iND750', 'iNJ661', 'iPS189', 'iRR1083',
#        'iRS1563', 'iRS1597', 'iSB619', 'iSO783', 'iYO844'], dtype='<U21')

# %% [markdown]
# ## 3) Get BiGG metabolite ids

# %%
#Get BiGG metabolite ids
def apply_bigg_metabolites_id(dict_aliases):
    if "BiGG" in dict_aliases.keys():
        dict_aliases = dict_aliases["BiGG"]
    else:
        dict_aliases = None
    return dict_aliases # WARNING !! Don't forget the return !! 
        
df_metabolites_seed['BiGG'] = df_metabolites_seed['aliases_dict_items_splitted'].apply(apply_bigg_metabolites_id)
        
df_metabolites_seed.head(25)
# Out:
#           id abbreviation                     name         formula   mass  \
# 0   cpd00001          h2o                      H2O             H2O   18.0
# 1   cpd00002          atp                      ATP   C10H13N5O13P3  504.0
# 2   cpd00003          nad                      NAD   C21H26N7O14P2  662.0
# 3   cpd00004         nadh                     NADH   C21H27N7O14P2  663.0
# 4   cpd00005        nadph                    NADPH   C21H26N7O17P3  742.0
# 5   cpd00006         nadp                     NADP   C21H25N7O17P3  741.0
# 6   cpd00007           o2                       O2              O2   32.0
# 7   cpd00008          adp                      ADP   C10H13N5O10P2  425.0
# 8   cpd00009           pi                Phosphate            HO4P   96.0
# 9   cpd00010          coa                      CoA  C21H32N7O16P3S  764.0
# 10  cpd00011          co2                      CO2             CO2   44.0
# 11  cpd00012          ppi                      PPi           HO7P2  176.0
# 12  cpd00013          nh4                      NH3             H4N   18.0
# 13  cpd00014          udp                      UDP    C9H12N2O12P2  402.0
# 14  cpd00015          fad                      FAD   C27H31N9O15P2  783.0
# 15  cpd00016       pydx5p      Pyridoxal phosphate        C8H8NO6P  246.0
# 16  cpd00017         amet  S-Adenosyl-L-methionine     C15H23N6O5S  399.0
# 17  cpd00018          amp                      AMP     C10H12N5O7P  346.0
# 18  cpd00019        ahcys  S-Adenosyl-homocysteine     C14H20N6O5S  384.0
# 19  cpd00020          pyr                 Pyruvate          C3H3O3   87.0
# 20  cpd00021         Iron                       Fe              Fe   56.0
# 21  cpd00022        accoa               Acetyl-CoA  C23H34N7O17P3S  806.0
# 22  cpd00023        glu-L              L-Glutamate         C5H8NO4  146.0
# 23  cpd00024          akg           2-Oxoglutarate          C5H4O5  144.0
# 24  cpd00025         h2o2                     H2O2            H2O2   34.0
#
#               source                     inchikey  charge  is_core  \
# 0   Primary Database  XLYOFNOQVPJJNP-UHFFFAOYSA-N       0        1
# 1   Primary Database  ZKHQWZAMYRWXGA-KQYNXXCUSA-K      -3        1
# 2   Primary Database  BAWFJGJZGIEFAR-NNYOXOHSSA-M      -1        1
# 3   Primary Database  BOPGDPNILDQYTO-NNYOXOHSSA-L      -2        1
# 4   Primary Database  ACFIXJIJDZMPPO-NNYOXOHSSA-J      -4        1
# 5   Primary Database  XJLXINKUBYWONI-NNYOXOHSSA-K      -3        1
# 6   Primary Database  MYMOFIZGZYHOMD-UHFFFAOYSA-N       0        1
# 7   Primary Database  XTWYTFMLZFPYCI-KQYNXXCUSA-L      -2        1
# 8   Primary Database  NBIIXXVUZAFLBC-UHFFFAOYSA-L      -2        1
# 9   Primary Database  RGJOEKWQDUBAIZ-IBOSZNHHSA-J      -4        1
# 10  Primary Database  CURLTUGMZLYLDI-UHFFFAOYSA-N       0        1
# 11  Primary Database  XPPKVPWEQAFLFU-UHFFFAOYSA-K      -3        1
# 12  Primary Database  QGZKDVFQNNGYKY-UHFFFAOYSA-O       1        1
# 13  Primary Database  XCCTYIAWTASOJW-XVFCMESISA-L      -2        1
# 14  Primary Database  IMGVNJNCCGXBHD-UYBVJOGSSA-K      -2        1
# 15  Primary Database  NGVDGCNFYWLIFO-UHFFFAOYSA-L      -2        1
# 16  Primary Database  MEFKEPWMEQBLKI-AIRLBKTGSA-O       1        1
# 17  Primary Database  UDMBCSSLTHHNCD-KQYNXXCUSA-L      -2        1
# 18  Primary Database  ZJUKTBDSGOFHSH-WFMPWKQPSA-N       0        1
# 19  Primary Database  LCTONWCANYUPML-UHFFFAOYSA-M      -1        1
# 20  Primary Database  XEEYBQQBJWHFJM-UHFFFAOYSA-N       0        1
# 21  Primary Database  ZSLZBFCDCINBPY-ZSJPKINUSA-J      -4        1
# 22  Primary Database  WHUUTDBJXJRKMK-VKHMYHEASA-M      -1        1
# 23  Primary Database  KPGXRSRHYNQIFN-UHFFFAOYSA-L      -2        1
# 24  Primary Database  MHAJPDPJQMAIIY-UHFFFAOYSA-N       0        1
#
#     is_obsolete  ...                                                pkb  \
# 0             0  ...                                          1:1:-1.80
# 1             0  ...           1:6:-7.46;1:9:-1.06;1:14:-3.85;1:15:4.93
# 2             0  ...  1:6:-4.22;1:35:-3.85;1:37:-1.05;1:41:4.93;1:43...
# 3             0  ...  1:6:2.28;1:9:1.85;1:14:-3.85;1:15:4.93;1:18:-3...
# 4             0  ...         1:11:-7.46;1:12:-1.06;1:22:4.87;1:40:-3.78
# 5             0  ...                    1:11:-7.46;1:12:-1.06;1:22:4.87
# 6             0  ...                                                NaN
# 7             0  ...  1:6:-7.46;1:9:-1.05;1:14:-3.85;1:15:4.93;1:18:...
# 8             0  ...                                                NaN
# 9             0  ...                      1:8:-7.46;1:9:-1.06;1:17:4.89
# 10            0  ...                                                NaN
# 11            0  ...                                                NaN
# 12            0  ...                                           1:1:8.86
# 13            0  ...          1:3:-4.29;1:9:-3.79;1:14:-3.66;1:17:-5.40
# 14            0  ...  1:42:-3.67;1:43:-3.85;1:44:4.89;1:46:-7.46;1:5...
# 15            0  ...                                1:7:4.11;1:10:-5.84
# 16            0  ...  1:6:-7.46;1:9:-1.05;1:14:-3.85;1:15:3.94;1:18:...
# 17            0  ...  1:6:-7.46;1:9:-1.05;1:14:-3.85;1:15:3.92;1:16:...
# 18            0  ...  1:6:-3.85;1:8:-3.65;1:12:-1.05;1:14:-7.46;1:16...
# 19            0  ...                                          1:5:-9.58
# 20            0  ...                                                NaN
# 21            0  ...         1:31:-3.87;1:41:-1.06;1:43:4.89;1:45:-7.46
# 22            0  ...                                           1:4:9.54
# 23            0  ...                                          1:4:-9.67
# 24            0  ...                                1:1:-4.19;1:2:-4.19
#
#     abstract_compound  comprised_of  \
# 0                 NaN           NaN
# 1                 NaN           NaN
# 2                 NaN           NaN
# 3                 NaN           NaN
# 4                 NaN           NaN
# 5                 NaN           NaN
# 6                 NaN           NaN
# 7                 NaN           NaN
# 8                 NaN           NaN
# 9                 NaN           NaN
# 10                NaN           NaN
# 11                NaN           NaN
# 12                NaN           NaN
# 13                NaN           NaN
# 14                NaN           NaN
# 15                NaN           NaN
# 16                NaN           NaN
# 17                NaN           NaN
# 18                NaN           NaN
# 19                NaN           NaN
# 20                NaN           NaN
# 21                NaN           NaN
# 22                NaN           NaN
# 23                NaN           NaN
# 24                NaN           NaN
#
#                                               aliases  \
# 0   Name: H20; H2O; H3O+; HO-; Hydroxide ion; OH; ...
# 1   Name: ATP; Adenosine 5'-triphosphate; adenosin...
# 2   Name: DPN; DPN+; DPN-ox; Diphosphopyridine nuc...
# 3   Name: DPNH; NAD-reduced; NADH; NADH+H+; NADH2;...
# 4   Name: NADP(H); NADP-red; NADP-reduced; NADPH; ...
# 5   Name: NADP; NADP(+); NADP+; NADP-ox; NADP-oxid...
# 6   Name: O2; Oxygen; dioxygen; oxygen; oxygen mol...
# 7   Name: ADP; Adenosine 5'-diphosphate; Adenosine...
# 8   Name: H2PO4-; HPO4-2; HPO42-; Orthophosphate; ...
# 9   Name: CoA; CoA-SH; Coenzyme A; CoenzymeA; Coen...
# 10  Name: CO2; Carbon dioxide; carbon dioxide; car...
# 11  Name: Diphosphate; Diphosphoric acid; PP; PPi;...
# 12  Name: Ammonia; Ammonia ion; Ammonium; Ammonium...
# 13  Name: UDP; Uridine 5'-diphosphate; uridine-5'-...
# 14  Name: FAD; Flavin adenine dinucleotide; Flavin...
# 15  Name: PLP; Pyridoxal 5'-phosphate; Pyridoxal 5...
# 16  Name: 2-S-adenosyl-L-methionine; Acylcarnitine...
# 17  Name: 5'-AMP; 5'-Adenosine monophosphate; 5'-A...
# 18  Name: 2-S-adenosyl-L-homocysteine; AdoHcy; S-A...
# 19  Name: 2-Oxopropanoate; 2-Oxopropanoic acid; 2-...
# 20          Name: Iron|KEGG: C00023|iMO1053-PAO1: fe2
# 21  Name: Acetyl coenzyme A; Acetyl-CoA; ac-CoA; a...
# 22  Name: 1-amino-propane-1,3-dicarboxylic acid; 2...
# 23  Name: 2-Ketoglutaric acid; 2-Oxoglutarate; 2-k...
# 24  Name: H2O2; Hydrogen peroxide; Hydrogenperoxid...
#
#                                                smiles      notes  \
# 0                                                   O  GC|EQ|EQU
# 1   Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O...  GC|EQ|EQU
# 2   NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(...  GC|EQ|EQU
# 3   NC(=O)C1=CN([C@@H]2O[C@H](COP(=O)([O-])OP(=O)(...  GC|EQ|EQU
# 4   NC(=O)C1=CN([C@@H]2O[C@H](COP(=O)([O-])OP(=O)(...  GC|EQ|EQU
# 5   NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(...  GC|EQ|EQU
# 6                                                 O=O  GC|EQ|EQU
# 7   Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O...  GC|EQ|EQU
# 8                                    O=P([O-])([O-])O  GC|EQ|EQU
# 9   CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H]...  GC|EQ|EQU
# 10                                              O=C=O  GC|EQ|EQU
# 11                       O=P([O-])([O-])OP(=O)([O-])O  GC|EQ|EQU
# 12                                             [NH4+]  GC|EQ|EQU
# 13  O=c1ccn([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-]...  GC|EQ|EQU
# 14  Cc1cc2nc3c(=O)[n-]c(=O)nc-3n(C[C@H](O)[C@H](O)...  GC|EQ|EQU
# 15                 Cc1ncc(COP(=O)([O-])[O-])c(C=O)c1O  GC|EQ|EQU
# 16  C[S+](CC[C@H]([NH3+])C(=O)[O-])C[C@H]1O[C@@H](...      GC|EQ
# 17  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])[O-])...  GC|EQ|EQU
# 18  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CSCC[C@H]([NH3+])C...  GC|EQ|EQU
# 19                                    CC(=O)C(=O)[O-]  GC|EQ|EQU
# 20                                               [Fe]  GC|EQ|EQU
# 21  CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(...  GC|EQ|EQU
# 22                 [NH3+][C@@H](CCC(=O)[O-])C(=O)[O-]  GC|EQ|EQU
# 23                          O=C([O-])CCC(=O)C(=O)[O-]  GC|EQ|EQU
# 24                                                 OO  GC|EQ|EQU
#
#     abbreviation_lower                                       aliases_dict  \
# 0                  h2o  {'Name': ' H20; H2O; H3O+; HO-; Hydroxide ion;...
# 1                  atp  {'Name': ' ATP; Adenosine 5'-triphosphate; ade...
# 2                  nad  {'Name': ' DPN; DPN+; DPN-ox; Diphosphopyridin...
# 3                 nadh  {'Name': ' DPNH; NAD-reduced; NADH; NADH+H+; N...
# 4                nadph  {'Name': ' NADP(H); NADP-red; NADP-reduced; NA...
# 5                 nadp  {'Name': ' NADP; NADP(+); NADP+; NADP-ox; NADP...
# 6                   o2  {'Name': ' O2; Oxygen; dioxygen; oxygen; oxyge...
# 7                  adp  {'Name': ' ADP; Adenosine 5'-diphosphate; Aden...
# 8                   pi  {'Name': ' H2PO4-; HPO4-2; HPO42-; Orthophosph...
# 9                  coa  {'Name': ' CoA; CoA-SH; Coenzyme A; CoenzymeA;...
# 10                 co2  {'Name': ' CO2; Carbon dioxide; carbon dioxide...
# 11                 ppi  {'Name': ' Diphosphate; Diphosphoric acid; PP;...
# 12                 nh4  {'Name': ' Ammonia; Ammonia ion; Ammonium; Amm...
# 13                 udp  {'Name': ' UDP; Uridine 5'-diphosphate; uridin...
# 14                 fad  {'Name': ' FAD; Flavin adenine dinucleotide; F...
# 15              pydx5p  {'Name': ' PLP; Pyridoxal 5'-phosphate; Pyrido...
# 16                amet  {'Name': ' 2-S-adenosyl-L-methionine; Acylcarn...
# 17                 amp  {'Name': ' 5'-AMP; 5'-Adenosine monophosphate;...
# 18               ahcys  {'Name': ' 2-S-adenosyl-L-homocysteine; AdoHcy...
# 19                 pyr  {'Name': ' 2-Oxopropanoate; 2-Oxopropanoic aci...
# 20                iron  {'Name': ' Iron', 'KEGG': ' C00023', 'iMO1053-...
# 21               accoa  {'Name': ' Acetyl coenzyme A; Acetyl-CoA; ac-C...
# 22               glu-l  {'Name': ' 1-amino-propane-1,3-dicarboxylic ac...
# 23                 akg  {'Name': ' 2-Ketoglutaric acid; 2-Oxoglutarate...
# 24                h2o2  {'Name': ' H2O2; Hydrogen peroxide; Hydrogenpe...
#
#                           aliases_dict_items_splitted        BiGG
# 0   {'Name': ['H20', 'H2O', 'H3O+', 'HO-', 'Hydrox...  [h2o, oh1]
# 1   {'Name': ['ATP', 'Adenosine 5'-triphosphate', ...       [atp]
# 2   {'Name': ['DPN', 'DPN+', 'DPN-ox', 'Diphosphop...       [nad]
# 3   {'Name': ['DPNH', 'NAD-reduced', 'NADH', 'NADH...      [nadh]
# 4   {'Name': ['NADP(H)', 'NADP-red', 'NADP-reduced...     [nadph]
# 5   {'Name': ['NADP', 'NADP(+)', 'NADP+', 'NADP-ox...      [nadp]
# 6   {'Name': ['O2', 'Oxygen', 'dioxygen', 'oxygen'...        [o2]
# 7   {'Name': ['ADP', 'Adenosine 5'-diphosphate', '...       [adp]
# 8   {'Name': ['H2PO4-', 'HPO4-2', 'HPO42-', 'Ortho...        [pi]
# 9   {'Name': ['CoA', 'CoA-SH', 'Coenzyme A', 'Coen...       [coa]
# 10  {'Name': ['CO2', 'Carbon dioxide', 'carbon dio...       [co2]
# 11  {'Name': ['Diphosphate', 'Diphosphoric acid', ...       [ppi]
# 12  {'Name': ['Ammonia', 'Ammonia ion', 'Ammonium'...  [nh3, nh4]
# 13  {'Name': ['UDP', 'Uridine 5'-diphosphate', 'ur...       [udp]
# 14  {'Name': ['FAD', 'Flavin adenine dinucleotide'...       [fad]
# 15  {'Name': ['PLP', 'Pyridoxal 5'-phosphate', 'Py...    [pydx5p]
# 16  {'Name': ['2-S-adenosyl-L-methionine', 'Acylca...      [amet]
# 17  {'Name': ['5'-AMP', '5'-Adenosine monophosphat...       [amp]
# 18  {'Name': ['2-S-adenosyl-L-homocysteine', 'AdoH...     [ahcys]
# 19  {'Name': ['2-Oxopropanoate', '2-Oxopropanoic a...       [pyr]
# 20  {'Name': ['Iron'], 'KEGG': ['C00023'], 'iMO105...        None
# 21  {'Name': ['Acetyl coenzyme A', 'Acetyl-CoA', '...     [accoa]
# 22  {'Name': ['1-amino-propane-1,3-dicarboxylic ac...    [glu__L]
# 23  {'Name': ['2-Ketoglutaric acid', '2-Oxoglutara...       [akg]
# 24  {'Name': ['H2O2', 'Hydrogen peroxide', 'Hydrog...      [h2o2]
#
# [25 rows x 25 columns]

# %%
df_metabolites_seed['BiGG'].notna().value_counts() # => ModelSeed seems to have only 2729 compounds mapped with BiGG Ids
# Out:
# False    31263
# True      2729
# Name: BiGG, dtype: int64

# %% [markdown]
# # V / Mapping AraCore

# %% [markdown]
# ## 1) Mapping AraCore - BiGG

# %% [markdown]
# ### Based on BiGG and AraCore Metabolite Ids

# %%
df_metabolites_aracore.head(25)
# Out:
#    aracore_ids                                       aracore_name  \
# 0        hnu_h                                             Photon
# 1         PQ_h                             Oxidized plastoquinone
# 2        H2O_h                                         H2O, water
# 3          H_h                                         H+, proton
# 4       PQH2_h                              Reduced plastoquinone
# 5         O2_h                                         O2, oxygen
# 6          H_l                                         H+, proton
# 7       PCox_h                              Oxidized plastocyanin
# 8       PCrd_h                               Reduced plastocyanin
# 9       Fdox_h                                Oxidized ferredoxin
# 10      Fdrd_h                                 Reduced ferredoxin
# 11      NADP_h        Nicotinamide adenine dinucleotide phosphate
# 12     NADPH_h  Nicotinamide adenine dinucleotide phosphate - ...
# 13       ADP_h                              Adenosine diphosphate
# 14        Pi_h                                     Orthophosphate
# 15       ATP_h                             Adenosine triphosphate
# 16      RuBP_h                          Ribulose 1,5-bisphosphate
# 17       CO2_h                                CO2, carbon dioxide
# 18       PGA_h                                 3-Phosphoglycerate
# 19      DPGA_h                    3-Phospho-D-glyceroyl phosphate
# 20       GAP_h                         Glyceraldehyde 3-phosphate
# 21      DHAP_h                         Dihydroxyacetone phosphate
# 22       FBP_h                          Fructose 1,6-bisphosphate
# 23       F6P_h                               Fructose 6-phosphate
# 24       E4P_h                              Erythrose 4-phosphate
#
#    aracore_formula aracore_annotations aracore_updated_ids  \
# 0                X                  {}               hnu_h
# 1         C13H16O2                  {}                PQ_h
# 2              H2O                  {}               H2O_h
# 3                H                  {}                 H_h
# 4         C13H18O2                  {}              PQH2_h
# 5               O2                  {}                O2_h
# 6                H                  {}                H_ul
# 7                X                  {}              PCox_h
# 8                X                  {}              PCrd_h
# 9            S8FeX                  {}              Fdox_h
# 10           S8FeX                  {}              Fdrd_h
# 11   C21H25N7O17P3                  {}              NADP_h
# 12   C21H26N7O17P3                  {}             NADPH_h
# 13   C10H12N5O10P2                  {}               ADP_h
# 14            HO4P                  {}                Pi_h
# 15   C10H12N5O13P3                  {}               ATP_h
# 16       C5H8O11P2                  {}              RuBP_h
# 17             CO2                  {}               CO2_h
# 18         C3H4O7P                  {}               PGA_h
# 19       C3H4O10P2                  {}              DPGA_h
# 20         C3H5O6P                  {}               GAP_h
# 21         C3H5O6P                  {}              DHAP_h
# 22      C6H10O12P2                  {}               FBP_h
# 23        C6H11O9P                  {}               F6P_h
# 24         C4H7O7P                  {}               E4P_h
#
#    aracore_updated_universal_ids aracore_updated_universal_ids_lower
# 0                            hnu                                 hnu
# 1                             PQ                                  pq
# 2                            H2O                                 h2o
# 3                              H                                   h
# 4                           PQH2                                pqh2
# 5                             O2                                  o2
# 6                              H                                   h
# 7                           PCox                                pcox
# 8                           PCrd                                pcrd
# 9                           Fdox                                fdox
# 10                          Fdrd                                fdrd
# 11                          NADP                                nadp
# 12                         NADPH                               nadph
# 13                           ADP                                 adp
# 14                            Pi                                  pi
# 15                           ATP                                 atp
# 16                          RuBP                                rubp
# 17                           CO2                                 co2
# 18                           PGA                                 pga
# 19                          DPGA                                dpga
# 20                           GAP                                 gap
# 21                          DHAP                                dhap
# 22                           FBP                                 fbp
# 23                           F6P                                 f6p
# 24                           E4P                                 e4p

# %%
#Check if universal metabolite ids of aracore model have an equivalent metabolite ids in BIGG based on same namimg
df_metabolites_aracore['is_bigg_id'] = df_metabolites_aracore['aracore_updated_universal_ids_lower'].apply(lambda met_id: ((df_metabolites_bigg['universal_bigg_id_lower'] == met_id).sum() > 0))

#Fill column for universal bigg ids for which above is the case
df_metabolites_aracore['universal_bigg_id'] = df_metabolites_aracore[['aracore_updated_universal_ids_lower','is_bigg_id']].apply(lambda x: x[0] if x[1] else None,axis=1)

#Add ModelSEED compound ids from BiGG metabolite table => df_metabolites_bigg['seed.compound']
df_metabolites_aracore['bigg_seed_id'] = df_metabolites_aracore[['aracore_updated_universal_ids_lower','is_bigg_id']].apply(lambda x: df_metabolites_bigg[df_metabolites_bigg['universal_bigg_id_lower'] == x[0]]['seed.compound'].unique()[0] if x[1] else None,axis=1)

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids                                       aracore_name  \
# 0        hnu_h                                             Photon
# 1         PQ_h                             Oxidized plastoquinone
# 2        H2O_h                                         H2O, water
# 3          H_h                                         H+, proton
# 4       PQH2_h                              Reduced plastoquinone
# 5         O2_h                                         O2, oxygen
# 6          H_l                                         H+, proton
# 7       PCox_h                              Oxidized plastocyanin
# 8       PCrd_h                               Reduced plastocyanin
# 9       Fdox_h                                Oxidized ferredoxin
# 10      Fdrd_h                                 Reduced ferredoxin
# 11      NADP_h        Nicotinamide adenine dinucleotide phosphate
# 12     NADPH_h  Nicotinamide adenine dinucleotide phosphate - ...
# 13       ADP_h                              Adenosine diphosphate
# 14        Pi_h                                     Orthophosphate
# 15       ATP_h                             Adenosine triphosphate
# 16      RuBP_h                          Ribulose 1,5-bisphosphate
# 17       CO2_h                                CO2, carbon dioxide
# 18       PGA_h                                 3-Phosphoglycerate
# 19      DPGA_h                    3-Phospho-D-glyceroyl phosphate
# 20       GAP_h                         Glyceraldehyde 3-phosphate
# 21      DHAP_h                         Dihydroxyacetone phosphate
# 22       FBP_h                          Fructose 1,6-bisphosphate
# 23       F6P_h                               Fructose 6-phosphate
# 24       E4P_h                              Erythrose 4-phosphate
#
#    aracore_formula aracore_annotations aracore_updated_ids  \
# 0                X                  {}               hnu_h
# 1         C13H16O2                  {}                PQ_h
# 2              H2O                  {}               H2O_h
# 3                H                  {}                 H_h
# 4         C13H18O2                  {}              PQH2_h
# 5               O2                  {}                O2_h
# 6                H                  {}                H_ul
# 7                X                  {}              PCox_h
# 8                X                  {}              PCrd_h
# 9            S8FeX                  {}              Fdox_h
# 10           S8FeX                  {}              Fdrd_h
# 11   C21H25N7O17P3                  {}              NADP_h
# 12   C21H26N7O17P3                  {}             NADPH_h
# 13   C10H12N5O10P2                  {}               ADP_h
# 14            HO4P                  {}                Pi_h
# 15   C10H12N5O13P3                  {}               ATP_h
# 16       C5H8O11P2                  {}              RuBP_h
# 17             CO2                  {}               CO2_h
# 18         C3H4O7P                  {}               PGA_h
# 19       C3H4O10P2                  {}              DPGA_h
# 20         C3H5O6P                  {}               GAP_h
# 21         C3H5O6P                  {}              DHAP_h
# 22      C6H10O12P2                  {}               FBP_h
# 23        C6H11O9P                  {}               F6P_h
# 24         C4H7O7P                  {}               E4P_h
#
#    aracore_updated_universal_ids aracore_updated_universal_ids_lower  \
# 0                            hnu                                 hnu
# 1                             PQ                                  pq
# 2                            H2O                                 h2o
# 3                              H                                   h
# 4                           PQH2                                pqh2
# 5                             O2                                  o2
# 6                              H                                   h
# 7                           PCox                                pcox
# 8                           PCrd                                pcrd
# 9                           Fdox                                fdox
# 10                          Fdrd                                fdrd
# 11                          NADP                                nadp
# 12                         NADPH                               nadph
# 13                           ADP                                 adp
# 14                            Pi                                  pi
# 15                           ATP                                 atp
# 16                          RuBP                                rubp
# 17                           CO2                                 co2
# 18                           PGA                                 pga
# 19                          DPGA                                dpga
# 20                           GAP                                 gap
# 21                          DHAP                                dhap
# 22                           FBP                                 fbp
# 23                           F6P                                 f6p
# 24                           E4P                                 e4p
#
#     is_bigg_id universal_bigg_id bigg_seed_id
# 0        False              None         None
# 1         True                pq         None
# 2         True               h2o     cpd27222
# 3         True                 h     cpd00067
# 4         True              pqh2         None
# 5         True                o2     cpd00007
# 6         True                 h     cpd00067
# 7         True              pcox     cpd30035
# 8         True              pcrd     cpd30034
# 9         True              fdox     cpd15876
# 10       False              None         None
# 11        True              nadp     cpd00006
# 12        True             nadph     cpd00005
# 13        True               adp     cpd00008
# 14        True                pi     cpd27787
# 15        True               atp     cpd00002
# 16       False              None         None
# 17        True               co2     cpd00011
# 18       False              None         None
# 19       False              None         None
# 20       False              None         None
# 21        True              dhap     cpd00095
# 22       False              None         None
# 23        True               f6p     cpd19035
# 24        True               e4p     cpd00236

# %%
#Count the number of mappings there are between between aracore_updated_universal_ids and universal_bigg_id_lower 
df_metabolites_aracore['is_bigg_id'].value_counts() # => 165 mapping between aracore_updated_universal_ids and universal_bigg_id_lower
#value_counts() function returns a Series containing counts of unique rows in the DataFrame.
# Out:
# False    248
# True     165
# Name: is_bigg_id, dtype: int64

# %%
#Count the number of ModelSEED compound ids found by mapped BiGG: these are noted as notna() in the dataframe
df_metabolites_aracore['bigg_seed_id'].isna().value_counts() # => 156 additional ModelSeed compound id found by mapped BiGG
# isna() function allows us to see the ids which as noted as NaN in the dataframe
# Out:
# True     257
# False    156
# Name: bigg_seed_id, dtype: int64

# %% [markdown]
# ## 2) Mapping AraCore - ModelSEED

# %%
#Check if universal metabolite ids of aracore model have an equivalent metabolite ids in BIGG based on same namimg
df_metabolites_aracore['is_seed_id'] = df_metabolites_aracore['aracore_updated_universal_ids_lower'].apply(lambda met_id: ((df_metabolites_seed['abbreviation_lower'] == met_id).sum() > 0))

#Fill column for universal bigg ids for which above is the case
df_metabolites_aracore['seed_id'] = df_metabolites_aracore[['aracore_updated_universal_ids_lower','is_seed_id']].apply(lambda x: df_metabolites_seed[df_metabolites_seed['abbreviation_lower'] == x[0]]['id'].tolist()[0] if x[1] else None,axis=1)

#Add BiGG ids (BiGG) from ModelSEED table => df_metabolites_seed['BiGG]
df_metabolites_aracore['seed_BiGG_id'] = df_metabolites_aracore[['seed_id','is_seed_id']].apply(lambda x: df_metabolites_seed[df_metabolites_seed['id'] == x[0]]['BiGG']  if x[1] else None,axis=1)
df_metabolites_aracore['seed_BiGG_id'] = df_metabolites_aracore['seed_BiGG_id'].apply(lambda x: x.values.tolist()[0] if isinstance(x, pd.core.series.Series) else None)

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids                                       aracore_name  \
# 0        hnu_h                                             Photon
# 1         PQ_h                             Oxidized plastoquinone
# 2        H2O_h                                         H2O, water
# 3          H_h                                         H+, proton
# 4       PQH2_h                              Reduced plastoquinone
# 5         O2_h                                         O2, oxygen
# 6          H_l                                         H+, proton
# 7       PCox_h                              Oxidized plastocyanin
# 8       PCrd_h                               Reduced plastocyanin
# 9       Fdox_h                                Oxidized ferredoxin
# 10      Fdrd_h                                 Reduced ferredoxin
# 11      NADP_h        Nicotinamide adenine dinucleotide phosphate
# 12     NADPH_h  Nicotinamide adenine dinucleotide phosphate - ...
# 13       ADP_h                              Adenosine diphosphate
# 14        Pi_h                                     Orthophosphate
# 15       ATP_h                             Adenosine triphosphate
# 16      RuBP_h                          Ribulose 1,5-bisphosphate
# 17       CO2_h                                CO2, carbon dioxide
# 18       PGA_h                                 3-Phosphoglycerate
# 19      DPGA_h                    3-Phospho-D-glyceroyl phosphate
# 20       GAP_h                         Glyceraldehyde 3-phosphate
# 21      DHAP_h                         Dihydroxyacetone phosphate
# 22       FBP_h                          Fructose 1,6-bisphosphate
# 23       F6P_h                               Fructose 6-phosphate
# 24       E4P_h                              Erythrose 4-phosphate
#
#    aracore_formula aracore_annotations aracore_updated_ids  \
# 0                X                  {}               hnu_h
# 1         C13H16O2                  {}                PQ_h
# 2              H2O                  {}               H2O_h
# 3                H                  {}                 H_h
# 4         C13H18O2                  {}              PQH2_h
# 5               O2                  {}                O2_h
# 6                H                  {}                H_ul
# 7                X                  {}              PCox_h
# 8                X                  {}              PCrd_h
# 9            S8FeX                  {}              Fdox_h
# 10           S8FeX                  {}              Fdrd_h
# 11   C21H25N7O17P3                  {}              NADP_h
# 12   C21H26N7O17P3                  {}             NADPH_h
# 13   C10H12N5O10P2                  {}               ADP_h
# 14            HO4P                  {}                Pi_h
# 15   C10H12N5O13P3                  {}               ATP_h
# 16       C5H8O11P2                  {}              RuBP_h
# 17             CO2                  {}               CO2_h
# 18         C3H4O7P                  {}               PGA_h
# 19       C3H4O10P2                  {}              DPGA_h
# 20         C3H5O6P                  {}               GAP_h
# 21         C3H5O6P                  {}              DHAP_h
# 22      C6H10O12P2                  {}               FBP_h
# 23        C6H11O9P                  {}               F6P_h
# 24         C4H7O7P                  {}               E4P_h
#
#    aracore_updated_universal_ids aracore_updated_universal_ids_lower  \
# 0                            hnu                                 hnu
# 1                             PQ                                  pq
# 2                            H2O                                 h2o
# 3                              H                                   h
# 4                           PQH2                                pqh2
# 5                             O2                                  o2
# 6                              H                                   h
# 7                           PCox                                pcox
# 8                           PCrd                                pcrd
# 9                           Fdox                                fdox
# 10                          Fdrd                                fdrd
# 11                          NADP                                nadp
# 12                         NADPH                               nadph
# 13                           ADP                                 adp
# 14                            Pi                                  pi
# 15                           ATP                                 atp
# 16                          RuBP                                rubp
# 17                           CO2                                 co2
# 18                           PGA                                 pga
# 19                          DPGA                                dpga
# 20                           GAP                                 gap
# 21                          DHAP                                dhap
# 22                           FBP                                 fbp
# 23                           F6P                                 f6p
# 24                           E4P                                 e4p
#
#     is_bigg_id universal_bigg_id bigg_seed_id  is_seed_id   seed_id  \
# 0        False              None         None       False      None
# 1         True                pq         None       False      None
# 2         True               h2o     cpd27222        True  cpd00001
# 3         True                 h     cpd00067        True  cpd00067
# 4         True              pqh2         None       False      None
# 5         True                o2     cpd00007        True  cpd00007
# 6         True                 h     cpd00067        True  cpd00067
# 7         True              pcox     cpd30035       False      None
# 8         True              pcrd     cpd30034       False      None
# 9         True              fdox     cpd15876        True  cpd15876
# 10       False              None         None       False      None
# 11        True              nadp     cpd00006        True  cpd00006
# 12        True             nadph     cpd00005        True  cpd00005
# 13        True               adp     cpd00008        True  cpd00008
# 14        True                pi     cpd27787        True  cpd00009
# 15        True               atp     cpd00002        True  cpd00002
# 16       False              None         None       False      None
# 17        True               co2     cpd00011        True  cpd00011
# 18       False              None         None        True  cpd29254
# 19       False              None         None       False      None
# 20       False              None         None       False      None
# 21        True              dhap     cpd00095        True  cpd00095
# 22       False              None         None       False      None
# 23        True               f6p     cpd19035        True  cpd00072
# 24        True               e4p     cpd00236        True  cpd00236
#
#     seed_BiGG_id
# 0           None
# 1           None
# 2     [h2o, oh1]
# 3            [h]
# 4           None
# 5           [o2]
# 6            [h]
# 7           None
# 8           None
# 9         [fdox]
# 10          None
# 11        [nadp]
# 12       [nadph]
# 13         [adp]
# 14          [pi]
# 15         [atp]
# 16          None
# 17         [co2]
# 18          None
# 19          None
# 20          None
# 21        [dhap]
# 22          None
# 23  [f6p, f6p_B]
# 24         [e4p]

# %%
#Count the number of correspondences there are between aracore_updated_universal_ids and ModelSeed abbreviation
df_metabolites_aracore['is_seed_id'].value_counts() # => 162 mapping between aracore_updated_universal_ids and ModelSeed abbreviation
# Out:
# False    251
# True     162
# Name: is_seed_id, dtype: int64

# %%
#Count the number of additional BiGG ids there are after mapping ModelSEED compound ids
df_metabolites_aracore['seed_BiGG_id'].notna().value_counts() # => 157 additional BiGG Ids found by mapped ModelSeed compound id
#notna() function returns a boolean same-sized object indicating if the values are not NA
# Out:
# False    256
# True     157
# Name: seed_BiGG_id, dtype: int64

# %% [markdown]
# # VI / Aggregation of compound ids

# %% [markdown]
# ## 1) Aggregate ModelSEED compound ids in column 'bigg_seed_id' and 'seed_id'

# %%
#Aggregate model seed compound ids from columns 'bigg_seed_id' and 'seed_id' into a list and extract unique values of this list
df_metabolites_aracore['seed_id_aggr'] = df_metabolites_aracore[['bigg_seed_id', 'seed_id']].apply(lambda x: list(np.unique(list(filter(None,[x[0],x[1]])))) , axis=1)
df_metabolites_aracore.head(25)
# Out:
#    aracore_ids                                       aracore_name  \
# 0        hnu_h                                             Photon
# 1         PQ_h                             Oxidized plastoquinone
# 2        H2O_h                                         H2O, water
# 3          H_h                                         H+, proton
# 4       PQH2_h                              Reduced plastoquinone
# 5         O2_h                                         O2, oxygen
# 6          H_l                                         H+, proton
# 7       PCox_h                              Oxidized plastocyanin
# 8       PCrd_h                               Reduced plastocyanin
# 9       Fdox_h                                Oxidized ferredoxin
# 10      Fdrd_h                                 Reduced ferredoxin
# 11      NADP_h        Nicotinamide adenine dinucleotide phosphate
# 12     NADPH_h  Nicotinamide adenine dinucleotide phosphate - ...
# 13       ADP_h                              Adenosine diphosphate
# 14        Pi_h                                     Orthophosphate
# 15       ATP_h                             Adenosine triphosphate
# 16      RuBP_h                          Ribulose 1,5-bisphosphate
# 17       CO2_h                                CO2, carbon dioxide
# 18       PGA_h                                 3-Phosphoglycerate
# 19      DPGA_h                    3-Phospho-D-glyceroyl phosphate
# 20       GAP_h                         Glyceraldehyde 3-phosphate
# 21      DHAP_h                         Dihydroxyacetone phosphate
# 22       FBP_h                          Fructose 1,6-bisphosphate
# 23       F6P_h                               Fructose 6-phosphate
# 24       E4P_h                              Erythrose 4-phosphate
#
#    aracore_formula aracore_annotations aracore_updated_ids  \
# 0                X                  {}               hnu_h
# 1         C13H16O2                  {}                PQ_h
# 2              H2O                  {}               H2O_h
# 3                H                  {}                 H_h
# 4         C13H18O2                  {}              PQH2_h
# 5               O2                  {}                O2_h
# 6                H                  {}                H_ul
# 7                X                  {}              PCox_h
# 8                X                  {}              PCrd_h
# 9            S8FeX                  {}              Fdox_h
# 10           S8FeX                  {}              Fdrd_h
# 11   C21H25N7O17P3                  {}              NADP_h
# 12   C21H26N7O17P3                  {}             NADPH_h
# 13   C10H12N5O10P2                  {}               ADP_h
# 14            HO4P                  {}                Pi_h
# 15   C10H12N5O13P3                  {}               ATP_h
# 16       C5H8O11P2                  {}              RuBP_h
# 17             CO2                  {}               CO2_h
# 18         C3H4O7P                  {}               PGA_h
# 19       C3H4O10P2                  {}              DPGA_h
# 20         C3H5O6P                  {}               GAP_h
# 21         C3H5O6P                  {}              DHAP_h
# 22      C6H10O12P2                  {}               FBP_h
# 23        C6H11O9P                  {}               F6P_h
# 24         C4H7O7P                  {}               E4P_h
#
#    aracore_updated_universal_ids aracore_updated_universal_ids_lower  \
# 0                            hnu                                 hnu
# 1                             PQ                                  pq
# 2                            H2O                                 h2o
# 3                              H                                   h
# 4                           PQH2                                pqh2
# 5                             O2                                  o2
# 6                              H                                   h
# 7                           PCox                                pcox
# 8                           PCrd                                pcrd
# 9                           Fdox                                fdox
# 10                          Fdrd                                fdrd
# 11                          NADP                                nadp
# 12                         NADPH                               nadph
# 13                           ADP                                 adp
# 14                            Pi                                  pi
# 15                           ATP                                 atp
# 16                          RuBP                                rubp
# 17                           CO2                                 co2
# 18                           PGA                                 pga
# 19                          DPGA                                dpga
# 20                           GAP                                 gap
# 21                          DHAP                                dhap
# 22                           FBP                                 fbp
# 23                           F6P                                 f6p
# 24                           E4P                                 e4p
#
#     is_bigg_id universal_bigg_id bigg_seed_id  is_seed_id   seed_id  \
# 0        False              None         None       False      None
# 1         True                pq         None       False      None
# 2         True               h2o     cpd27222        True  cpd00001
# 3         True                 h     cpd00067        True  cpd00067
# 4         True              pqh2         None       False      None
# 5         True                o2     cpd00007        True  cpd00007
# 6         True                 h     cpd00067        True  cpd00067
# 7         True              pcox     cpd30035       False      None
# 8         True              pcrd     cpd30034       False      None
# 9         True              fdox     cpd15876        True  cpd15876
# 10       False              None         None       False      None
# 11        True              nadp     cpd00006        True  cpd00006
# 12        True             nadph     cpd00005        True  cpd00005
# 13        True               adp     cpd00008        True  cpd00008
# 14        True                pi     cpd27787        True  cpd00009
# 15        True               atp     cpd00002        True  cpd00002
# 16       False              None         None       False      None
# 17        True               co2     cpd00011        True  cpd00011
# 18       False              None         None        True  cpd29254
# 19       False              None         None       False      None
# 20       False              None         None       False      None
# 21        True              dhap     cpd00095        True  cpd00095
# 22       False              None         None       False      None
# 23        True               f6p     cpd19035        True  cpd00072
# 24        True               e4p     cpd00236        True  cpd00236
#
#     seed_BiGG_id          seed_id_aggr
# 0           None                    []
# 1           None                    []
# 2     [h2o, oh1]  [cpd00001, cpd27222]
# 3            [h]            [cpd00067]
# 4           None                    []
# 5           [o2]            [cpd00007]
# 6            [h]            [cpd00067]
# 7           None            [cpd30035]
# 8           None            [cpd30034]
# 9         [fdox]            [cpd15876]
# 10          None                    []
# 11        [nadp]            [cpd00006]
# 12       [nadph]            [cpd00005]
# 13         [adp]            [cpd00008]
# 14          [pi]  [cpd00009, cpd27787]
# 15         [atp]            [cpd00002]
# 16          None                    []
# 17         [co2]            [cpd00011]
# 18          None            [cpd29254]
# 19          None                    []
# 20          None                    []
# 21        [dhap]            [cpd00095]
# 22          None                    []
# 23  [f6p, f6p_B]  [cpd00072, cpd19035]
# 24         [e4p]            [cpd00236]

# %%
df_metabolites_aracore['seed_id_aggr'].apply(len).value_counts() # => 127  + 37 = 164 metabolites have ModelSeed Ids -> 37 metabolites have 2 ModelSeed Ids -> potential conflicts !?!
# Out:
# 0    249
# 1    127
# 2     37
# Name: seed_id_aggr, dtype: int64

# %%
#Extract those metabolites that have more than one ModelSeed compound ids mmapped
df_metabolites_aracore_seed_conflicted = df_metabolites_aracore[df_metabolites_aracore['seed_id_aggr'].apply(len) > 1].copy()
df_metabolites_aracore_seed_conflicted
# Out:
#     aracore_ids                aracore_name aracore_formula  \
# 2         H2O_h                  H2O, water             H2O
# 14         Pi_h              Orthophosphate            HO4P
# 23        F6P_h        Fructose 6-phosphate        C6H11O9P
# 28        R5P_h          Ribose 5-phosphate         C5H9O8P
# 30        G6P_h         Glucose 6-phosphate        C6H11O9P
# 31        G1P_h         Glucose 1-phosphate        C6H11O9P
# 33        PPi_h  Diphosphate, Pyrophosphate            O7P2
# 45        G6P_c         Glucose 6-phosphate        C6H11O9P
# 50         Pi_c              Orthophosphate            HO4P
# 51        G1P_c         Glucose 1-phosphate        C6H11O9P
# 55        H2O_c                  H2O, water             H2O
# 56        F6P_c        Fructose 6-phosphate        C6H11O9P
# 59       UDPG_c                 UDP-Glucose   C15H22N2O17P2
# 60        PPi_c  Diphosphate, Pyrophosphate           HO7P2
# 95        CoA_m                  Coenzyme A  C21H32N7O16P3S
# 101       H2O_m                  H2O, water             H2O
# 109        Pi_m              Orthophosphate            HO4P
# 126       H2O_p                  H2O, water             H2O
# 133       THF_m    5,6,7,8-Tetrahydrofolate      C19H21N7O6
# 136       NH4_m                     Ammonia             H4N
# 157       AMP_h       Adenosine 5-phosphate     C10H12N5O7P
# 164       CoA_c                  Coenzyme A  C21H33N7O16P3S
# 167       CoA_h                  Coenzyme A  C21H32N7O16P3S
# 182       For_h                     Formate            CHO2
# 183       THF_h    5,6,7,8-Tetrahydrofolate      C19H21N7O6
# 186       THF_c    5,6,7,8-Tetrahydrofolate      C19H22N7O6
# 190       AMP_c       Adenosine 5-phosphate     C10H12N5O7P
# 198       NH4_h                     Ammonia             H4N
# 199       SO4_h                     Sulfate             O4S
# 200       SO4_m                     Sulfate             O4S
# 205       H2S_h            Hydrogen sulfide             H2S
# 216       Orn_h                   Ornithine       C5H13N2O2
# 231       NH4_c                     Ammonia             H4N
# 237       H2S_c            Hydrogen sulfide             H2S
# 241       H2S_m            Hydrogen sulfide             H2S
# 303       Orn_m                   Ornithine       C5H13N2O2
# 364       SO4_c                     Sulfate             O4S
#
#     aracore_annotations aracore_updated_ids aracore_updated_universal_ids  \
# 2                    {}               H2O_h                           H2O
# 14                   {}                Pi_h                            Pi
# 23                   {}               F6P_h                           F6P
# 28                   {}               R5P_h                           R5P
# 30                   {}               G6P_h                           G6P
# 31                   {}               G1P_h                           G1P
# 33                   {}               PPi_h                           PPi
# 45                   {}               G6P_c                           G6P
# 50                   {}                Pi_c                            Pi
# 51                   {}               G1P_c                           G1P
# 55                   {}               H2O_c                           H2O
# 56                   {}               F6P_c                           F6P
# 59                   {}              UDPG_c                          UDPG
# 60                   {}               PPi_c                           PPi
# 95                   {}               CoA_m                           CoA
# 101                  {}               H2O_m                           H2O
# 109                  {}                Pi_m                            Pi
# 126                  {}               H2O_x                           H2O
# 133                  {}               THF_m                           THF
# 136                  {}               NH4_m                           NH4
# 157                  {}               AMP_h                           AMP
# 164                  {}               CoA_c                           CoA
# 167                  {}               CoA_h                           CoA
# 182                  {}               For_h                           For
# 183                  {}               THF_h                           THF
# 186                  {}               THF_c                           THF
# 190                  {}               AMP_c                           AMP
# 198                  {}               NH4_h                           NH4
# 199                  {}               SO4_h                           SO4
# 200                  {}               SO4_m                           SO4
# 205                  {}               H2S_h                           H2S
# 216                  {}               Orn_h                           Orn
# 231                  {}               NH4_c                           NH4
# 237                  {}               H2S_c                           H2S
# 241                  {}               H2S_m                           H2S
# 303                  {}               Orn_m                           Orn
# 364                  {}               SO4_c                           SO4
#
#     aracore_updated_universal_ids_lower  is_bigg_id universal_bigg_id  \
# 2                                   h2o        True               h2o
# 14                                   pi        True                pi
# 23                                  f6p        True               f6p
# 28                                  r5p        True               r5p
# 30                                  g6p        True               g6p
# 31                                  g1p        True               g1p
# 33                                  ppi        True               ppi
# 45                                  g6p        True               g6p
# 50                                   pi        True                pi
# 51                                  g1p        True               g1p
# 55                                  h2o        True               h2o
# 56                                  f6p        True               f6p
# 59                                 udpg        True              udpg
# 60                                  ppi        True               ppi
# 95                                  coa        True               coa
# 101                                 h2o        True               h2o
# 109                                  pi        True                pi
# 126                                 h2o        True               h2o
# 133                                 thf        True               thf
# 136                                 nh4        True               nh4
# 157                                 amp        True               amp
# 164                                 coa        True               coa
# 167                                 coa        True               coa
# 182                                 for        True               for
# 183                                 thf        True               thf
# 186                                 thf        True               thf
# 190                                 amp        True               amp
# 198                                 nh4        True               nh4
# 199                                 so4        True               so4
# 200                                 so4        True               so4
# 205                                 h2s        True               h2s
# 216                                 orn        True               orn
# 231                                 nh4        True               nh4
# 237                                 h2s        True               h2s
# 241                                 h2s        True               h2s
# 303                                 orn        True               orn
# 364                                 so4        True               so4
#
#     bigg_seed_id  is_seed_id   seed_id   seed_BiGG_id          seed_id_aggr
# 2       cpd27222        True  cpd00001     [h2o, oh1]  [cpd00001, cpd27222]
# 14      cpd27787        True  cpd00009           [pi]  [cpd00009, cpd27787]
# 23      cpd19035        True  cpd00072   [f6p, f6p_B]  [cpd00072, cpd19035]
# 28      cpd19028        True  cpd00101          [r5p]  [cpd00101, cpd19028]
# 30      cpd26836        True  cpd00079          [g6p]  [cpd00079, cpd26836]
# 31      cpd28817        True  cpd00089          [g1p]  [cpd00089, cpd28817]
# 33      cpd27828        True  cpd00012          [ppi]  [cpd00012, cpd27828]
# 45      cpd26836        True  cpd00079          [g6p]  [cpd00079, cpd26836]
# 50      cpd27787        True  cpd00009           [pi]  [cpd00009, cpd27787]
# 51      cpd28817        True  cpd00089          [g1p]  [cpd00089, cpd28817]
# 55      cpd27222        True  cpd00001     [h2o, oh1]  [cpd00001, cpd27222]
# 56      cpd19035        True  cpd00072   [f6p, f6p_B]  [cpd00072, cpd19035]
# 59      cpd28293        True  cpd00026         [udpg]  [cpd00026, cpd28293]
# 60      cpd27828        True  cpd00012          [ppi]  [cpd00012, cpd27828]
# 95      cpd22528        True  cpd00010          [coa]  [cpd00010, cpd22528]
# 101     cpd27222        True  cpd00001     [h2o, oh1]  [cpd00001, cpd27222]
# 109     cpd27787        True  cpd00009           [pi]  [cpd00009, cpd27787]
# 126     cpd27222        True  cpd00001     [h2o, oh1]  [cpd00001, cpd27222]
# 133     cpd29254        True  cpd00087          [thf]  [cpd00087, cpd29254]
# 136     cpd19013        True  cpd00013     [nh3, nh4]  [cpd00013, cpd19013]
# 157     cpd22272        True  cpd00018          [amp]  [cpd00018, cpd22272]
# 164     cpd22528        True  cpd00010          [coa]  [cpd00010, cpd22528]
# 167     cpd22528        True  cpd00010          [coa]  [cpd00010, cpd22528]
# 182     cpd22511        True  cpd00047          [for]  [cpd00047, cpd22511]
# 183     cpd29254        True  cpd00087          [thf]  [cpd00087, cpd29254]
# 186     cpd29254        True  cpd00087          [thf]  [cpd00087, cpd29254]
# 190     cpd22272        True  cpd00018          [amp]  [cpd00018, cpd22272]
# 198     cpd19013        True  cpd00013     [nh3, nh4]  [cpd00013, cpd19013]
# 199     cpd29301        True  cpd00048          [so4]  [cpd00048, cpd29301]
# 200     cpd29301        True  cpd00048          [so4]  [cpd00048, cpd29301]
# 205     cpd24697        True  cpd00239          [h2s]  [cpd00239, cpd24697]
# 216     cpd19016        True  cpd00064  [orn, orn__L]  [cpd00064, cpd19016]
# 231     cpd19013        True  cpd00013     [nh3, nh4]  [cpd00013, cpd19013]
# 237     cpd24697        True  cpd00239          [h2s]  [cpd00239, cpd24697]
# 241     cpd24697        True  cpd00239          [h2s]  [cpd00239, cpd24697]
# 303     cpd19016        True  cpd00064  [orn, orn__L]  [cpd00064, cpd19016]
# 364     cpd29301        True  cpd00048          [so4]  [cpd00048, cpd29301]

# %%
#Add abbreviations and formulas of the df_metabolites_seed to compare by eye and make notes to solve potential conflicts for later
df_metabolites_aracore_seed_conflicted['seed_id_aggr_abbr'] = df_metabolites_aracore_seed_conflicted['seed_id_aggr'].apply(lambda x: [df_metabolites_seed[df_metabolites_seed['id'] == compound_id]['abbreviation'].tolist()[0] for compound_id in x])
df_metabolites_aracore_seed_conflicted['seed_id_aggr_formula'] = df_metabolites_aracore_seed_conflicted['seed_id_aggr'].apply(lambda x: [df_metabolites_seed[df_metabolites_seed['id'] == compound_id]['formula'].tolist()[0] for compound_id in x])
df_metabolites_aracore_seed_conflicted[['aracore_ids','aracore_name','aracore_formula','seed_id_aggr','seed_id_aggr_abbr','seed_id_aggr_formula']]
# Out:
#     aracore_ids                aracore_name aracore_formula  \
# 2         H2O_h                  H2O, water             H2O
# 14         Pi_h              Orthophosphate            HO4P
# 23        F6P_h        Fructose 6-phosphate        C6H11O9P
# 28        R5P_h          Ribose 5-phosphate         C5H9O8P
# 30        G6P_h         Glucose 6-phosphate        C6H11O9P
# 31        G1P_h         Glucose 1-phosphate        C6H11O9P
# 33        PPi_h  Diphosphate, Pyrophosphate            O7P2
# 45        G6P_c         Glucose 6-phosphate        C6H11O9P
# 50         Pi_c              Orthophosphate            HO4P
# 51        G1P_c         Glucose 1-phosphate        C6H11O9P
# 55        H2O_c                  H2O, water             H2O
# 56        F6P_c        Fructose 6-phosphate        C6H11O9P
# 59       UDPG_c                 UDP-Glucose   C15H22N2O17P2
# 60        PPi_c  Diphosphate, Pyrophosphate           HO7P2
# 95        CoA_m                  Coenzyme A  C21H32N7O16P3S
# 101       H2O_m                  H2O, water             H2O
# 109        Pi_m              Orthophosphate            HO4P
# 126       H2O_p                  H2O, water             H2O
# 133       THF_m    5,6,7,8-Tetrahydrofolate      C19H21N7O6
# 136       NH4_m                     Ammonia             H4N
# 157       AMP_h       Adenosine 5-phosphate     C10H12N5O7P
# 164       CoA_c                  Coenzyme A  C21H33N7O16P3S
# 167       CoA_h                  Coenzyme A  C21H32N7O16P3S
# 182       For_h                     Formate            CHO2
# 183       THF_h    5,6,7,8-Tetrahydrofolate      C19H21N7O6
# 186       THF_c    5,6,7,8-Tetrahydrofolate      C19H22N7O6
# 190       AMP_c       Adenosine 5-phosphate     C10H12N5O7P
# 198       NH4_h                     Ammonia             H4N
# 199       SO4_h                     Sulfate             O4S
# 200       SO4_m                     Sulfate             O4S
# 205       H2S_h            Hydrogen sulfide             H2S
# 216       Orn_h                   Ornithine       C5H13N2O2
# 231       NH4_c                     Ammonia             H4N
# 237       H2S_c            Hydrogen sulfide             H2S
# 241       H2S_m            Hydrogen sulfide             H2S
# 303       Orn_m                   Ornithine       C5H13N2O2
# 364       SO4_c                     Sulfate             O4S
#
#              seed_id_aggr                   seed_id_aggr_abbr  \
# 2    [cpd00001, cpd27222]               [h2o, hydroxyl-group]
# 14   [cpd00009, cpd27787]               [pi, phosphate-group]
# 23   [cpd00072, cpd19035]  [f6p, beta-D-Fructose 6-phosphate]
# 28   [cpd00101, cpd19028]   [r5p, alpha-D-Ribose 5-phosphate]
# 30   [cpd00079, cpd26836]        [g6p, D-glucose-6-phosphate]
# 31   [cpd00089, cpd28817]          [g1p, glucose-1-phosphate]
# 33   [cpd00012, cpd27828]          [ppi, pyrophosphate-group]
# 45   [cpd00079, cpd26836]        [g6p, D-glucose-6-phosphate]
# 50   [cpd00009, cpd27787]               [pi, phosphate-group]
# 51   [cpd00089, cpd28817]          [g1p, glucose-1-phosphate]
# 55   [cpd00001, cpd27222]               [h2o, hydroxyl-group]
# 56   [cpd00072, cpd19035]  [f6p, beta-D-Fructose 6-phosphate]
# 59   [cpd00026, cpd28293]                 [udpg, UDP-GLUCOSE]
# 60   [cpd00012, cpd27828]          [ppi, pyrophosphate-group]
# 95   [cpd00010, cpd22528]                          [coa, CoA]
# 101  [cpd00001, cpd27222]               [h2o, hydroxyl-group]
# 109  [cpd00009, cpd27787]               [pi, phosphate-group]
# 126  [cpd00001, cpd27222]               [h2o, hydroxyl-group]
# 133  [cpd00087, cpd29254]                          [thf, PGA]
# 136  [cpd00013, cpd19013]                         [nh4, NH4+]
# 157  [cpd00018, cpd22272]                    [amp, AMP group]
# 164  [cpd00010, cpd22528]                          [coa, CoA]
# 167  [cpd00010, cpd22528]                          [coa, CoA]
# 182  [cpd00047, cpd22511]             [for, a carboxyl group]
# 183  [cpd00087, cpd29254]                          [thf, PGA]
# 186  [cpd00087, cpd29254]                          [thf, PGA]
# 190  [cpd00018, cpd22272]                    [amp, AMP group]
# 198  [cpd00013, cpd19013]                         [nh4, NH4+]
# 199  [cpd00048, cpd29301]                        [so4, H2SO4]
# 200  [cpd00048, cpd29301]                        [so4, H2SO4]
# 205  [cpd00239, cpd24697]                          [h2s, S2-]
# 216  [cpd00064, cpd19016]                    [orn, Ornithine]
# 231  [cpd00013, cpd19013]                         [nh4, NH4+]
# 237  [cpd00239, cpd24697]                          [h2s, S2-]
# 241  [cpd00239, cpd24697]                          [h2s, S2-]
# 303  [cpd00064, cpd19016]                    [orn, Ornithine]
# 364  [cpd00048, cpd29301]                        [so4, H2SO4]
#
#                  seed_id_aggr_formula
# 2                           [H2O, HO]
# 14                       [HO4P, HO4P]
# 23               [C6H11O9P, C6H11O9P]
# 28                 [C5H9O8P, C5H9O8P]
# 30               [C6H11O9P, C6H11O9P]
# 31               [C6H11O9P, C6H11O9P]
# 33                     [HO7P2, HO7P2]
# 45               [C6H11O9P, C6H11O9P]
# 50                       [HO4P, HO4P]
# 51               [C6H11O9P, C6H11O9P]
# 55                          [H2O, HO]
# 56               [C6H11O9P, C6H11O9P]
# 59     [C15H22N2O17P2, C15H22N2O17P2]
# 60                     [HO7P2, HO7P2]
# 95   [C21H32N7O16P3S, C21H32N7O16P3S]
# 101                         [H2O, HO]
# 109                      [HO4P, HO4P]
# 126                         [H2O, HO]
# 133          [C19H21N7O6, C19H19N7O6]
# 136                        [H4N, H4N]
# 157        [C10H12N5O7P, C10H12N5O7P]
# 164  [C21H32N7O16P3S, C21H32N7O16P3S]
# 167  [C21H32N7O16P3S, C21H32N7O16P3S]
# 182                      [CHO2, CHO2]
# 183          [C19H21N7O6, C19H19N7O6]
# 186          [C19H21N7O6, C19H19N7O6]
# 190        [C10H12N5O7P, C10H12N5O7P]
# 198                        [H4N, H4N]
# 199                      [O4S, H2O4S]
# 200                      [O4S, H2O4S]
# 205                          [HS, HS]
# 216            [C5H13N2O2, C5H13N2O2]
# 231                        [H4N, H4N]
# 237                          [HS, HS]
# 241                          [HS, HS]
# 303            [C5H13N2O2, C5H13N2O2]
# 364                      [O4S, H2O4S]

# %%
#Resolve conflict in original table df_metabolites_aracore

df_metabolites_aracore.set_index("aracore_ids",inplace=True) #Set index to acacore_ids to make editing "easier"

#H2O_c, H2O_h, H2O_p, H2O_m == cpd00001
df_metabolites_aracore.loc['H2O_c','seed_id_aggr'] == ['cpd00001']
df_metabolites_aracore.loc['H2O_h','seed_id_aggr'] == ['cpd00001']
df_metabolites_aracore.loc['H2O_p','seed_id_aggr'] == ['cpd00001']
df_metabolites_aracore.loc['H2O_m','seed_id_aggr'] == ['cpd00001']

#THF_m, THF_c, THF_h	5,6,7,8-Tetrahydrofolate == cpd00087 -> 186 has one more H in sum formula
df_metabolites_aracore.loc['THF_m','seed_id_aggr'] == ['cpd00087']
df_metabolites_aracore.loc['THF_c','seed_id_aggr'] == ['cpd00087']
df_metabolites_aracore.loc['THF_h','seed_id_aggr'] == ['cpd00087']

#SO4_h, SO4_m, SO4_c Sulfate O4S == cpd00048
df_metabolites_aracore.loc['SO4_h','seed_id_aggr'] == ['cpd00048']
df_metabolites_aracore.loc['SO4_m','seed_id_aggr'] == ['cpd00048']
df_metabolites_aracore.loc['SO4_c','seed_id_aggr'] == ['cpd00048']

#ppi has different sum formulas in the Aracore model?
#Coenzyme A has different sum formulas in the Aracore model?
#5,6,7,8-Tetrahydrofolate has different sum formulas in the Aracore model?

df_metabolites_aracore.reset_index(inplace=True)

# %% [markdown]
# ## 2) Aggregate BiGG ids in column 'universal_bigg_id' and 'seed_BiGG_id'

# %%
#Aggregate model seed compound ids from columns 'bigg_seed_id' and 'seed_id' into a list and extract unique values of this list

df_metabolites_aracore['bigg_id_aggr'] = df_metabolites_aracore[['universal_bigg_id', 'seed_BiGG_id']].apply(lambda x: list(filter(None,[x[0]]+x[1])) if x[1] else  list(filter(None,[x[0]]+[x[1]])), axis=1) #.apply(len).value_counts()
df_metabolites_aracore['bigg_id_aggr'] = df_metabolites_aracore['bigg_id_aggr'].apply(lambda x: list(np.unique(x)))

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids                                       aracore_name  \
# 0        hnu_h                                             Photon
# 1         PQ_h                             Oxidized plastoquinone
# 2        H2O_h                                         H2O, water
# 3          H_h                                         H+, proton
# 4       PQH2_h                              Reduced plastoquinone
# 5         O2_h                                         O2, oxygen
# 6          H_l                                         H+, proton
# 7       PCox_h                              Oxidized plastocyanin
# 8       PCrd_h                               Reduced plastocyanin
# 9       Fdox_h                                Oxidized ferredoxin
# 10      Fdrd_h                                 Reduced ferredoxin
# 11      NADP_h        Nicotinamide adenine dinucleotide phosphate
# 12     NADPH_h  Nicotinamide adenine dinucleotide phosphate - ...
# 13       ADP_h                              Adenosine diphosphate
# 14        Pi_h                                     Orthophosphate
# 15       ATP_h                             Adenosine triphosphate
# 16      RuBP_h                          Ribulose 1,5-bisphosphate
# 17       CO2_h                                CO2, carbon dioxide
# 18       PGA_h                                 3-Phosphoglycerate
# 19      DPGA_h                    3-Phospho-D-glyceroyl phosphate
# 20       GAP_h                         Glyceraldehyde 3-phosphate
# 21      DHAP_h                         Dihydroxyacetone phosphate
# 22       FBP_h                          Fructose 1,6-bisphosphate
# 23       F6P_h                               Fructose 6-phosphate
# 24       E4P_h                              Erythrose 4-phosphate
#
#    aracore_formula aracore_annotations aracore_updated_ids  \
# 0                X                  {}               hnu_h
# 1         C13H16O2                  {}                PQ_h
# 2              H2O                  {}               H2O_h
# 3                H                  {}                 H_h
# 4         C13H18O2                  {}              PQH2_h
# 5               O2                  {}                O2_h
# 6                H                  {}                H_ul
# 7                X                  {}              PCox_h
# 8                X                  {}              PCrd_h
# 9            S8FeX                  {}              Fdox_h
# 10           S8FeX                  {}              Fdrd_h
# 11   C21H25N7O17P3                  {}              NADP_h
# 12   C21H26N7O17P3                  {}             NADPH_h
# 13   C10H12N5O10P2                  {}               ADP_h
# 14            HO4P                  {}                Pi_h
# 15   C10H12N5O13P3                  {}               ATP_h
# 16       C5H8O11P2                  {}              RuBP_h
# 17             CO2                  {}               CO2_h
# 18         C3H4O7P                  {}               PGA_h
# 19       C3H4O10P2                  {}              DPGA_h
# 20         C3H5O6P                  {}               GAP_h
# 21         C3H5O6P                  {}              DHAP_h
# 22      C6H10O12P2                  {}               FBP_h
# 23        C6H11O9P                  {}               F6P_h
# 24         C4H7O7P                  {}               E4P_h
#
#    aracore_updated_universal_ids aracore_updated_universal_ids_lower  \
# 0                            hnu                                 hnu
# 1                             PQ                                  pq
# 2                            H2O                                 h2o
# 3                              H                                   h
# 4                           PQH2                                pqh2
# 5                             O2                                  o2
# 6                              H                                   h
# 7                           PCox                                pcox
# 8                           PCrd                                pcrd
# 9                           Fdox                                fdox
# 10                          Fdrd                                fdrd
# 11                          NADP                                nadp
# 12                         NADPH                               nadph
# 13                           ADP                                 adp
# 14                            Pi                                  pi
# 15                           ATP                                 atp
# 16                          RuBP                                rubp
# 17                           CO2                                 co2
# 18                           PGA                                 pga
# 19                          DPGA                                dpga
# 20                           GAP                                 gap
# 21                          DHAP                                dhap
# 22                           FBP                                 fbp
# 23                           F6P                                 f6p
# 24                           E4P                                 e4p
#
#     is_bigg_id universal_bigg_id bigg_seed_id  is_seed_id   seed_id  \
# 0        False              None         None       False      None
# 1         True                pq         None       False      None
# 2         True               h2o     cpd27222        True  cpd00001
# 3         True                 h     cpd00067        True  cpd00067
# 4         True              pqh2         None       False      None
# 5         True                o2     cpd00007        True  cpd00007
# 6         True                 h     cpd00067        True  cpd00067
# 7         True              pcox     cpd30035       False      None
# 8         True              pcrd     cpd30034       False      None
# 9         True              fdox     cpd15876        True  cpd15876
# 10       False              None         None       False      None
# 11        True              nadp     cpd00006        True  cpd00006
# 12        True             nadph     cpd00005        True  cpd00005
# 13        True               adp     cpd00008        True  cpd00008
# 14        True                pi     cpd27787        True  cpd00009
# 15        True               atp     cpd00002        True  cpd00002
# 16       False              None         None       False      None
# 17        True               co2     cpd00011        True  cpd00011
# 18       False              None         None        True  cpd29254
# 19       False              None         None       False      None
# 20       False              None         None       False      None
# 21        True              dhap     cpd00095        True  cpd00095
# 22       False              None         None       False      None
# 23        True               f6p     cpd19035        True  cpd00072
# 24        True               e4p     cpd00236        True  cpd00236
#
#     seed_BiGG_id          seed_id_aggr  bigg_id_aggr
# 0           None                    []            []
# 1           None                    []          [pq]
# 2     [h2o, oh1]  [cpd00001, cpd27222]    [h2o, oh1]
# 3            [h]            [cpd00067]           [h]
# 4           None                    []        [pqh2]
# 5           [o2]            [cpd00007]          [o2]
# 6            [h]            [cpd00067]           [h]
# 7           None            [cpd30035]        [pcox]
# 8           None            [cpd30034]        [pcrd]
# 9         [fdox]            [cpd15876]        [fdox]
# 10          None                    []            []
# 11        [nadp]            [cpd00006]        [nadp]
# 12       [nadph]            [cpd00005]       [nadph]
# 13         [adp]            [cpd00008]         [adp]
# 14          [pi]  [cpd00009, cpd27787]          [pi]
# 15         [atp]            [cpd00002]         [atp]
# 16          None                    []            []
# 17         [co2]            [cpd00011]         [co2]
# 18          None            [cpd29254]            []
# 19          None                    []            []
# 20          None                    []            []
# 21        [dhap]            [cpd00095]        [dhap]
# 22          None                    []            []
# 23  [f6p, f6p_B]  [cpd00072, cpd19035]  [f6p, f6p_B]
# 24         [e4p]            [cpd00236]         [e4p]

# %%
#Extract those metabolites that have more than one ModelSeed compound ids mapped
df_metabolites_aracore_bigg_conflicted = df_metabolites_aracore[df_metabolites_aracore['bigg_id_aggr'].apply(len) > 1].copy()
df_metabolites_aracore_bigg_conflicted
# Out:
#     aracore_ids          aracore_name aracore_formula aracore_annotations  \
# 2         H2O_h            H2O, water             H2O                  {}
# 23        F6P_h  Fructose 6-phosphate        C6H11O9P                  {}
# 55        H2O_c            H2O, water             H2O                  {}
# 56        F6P_c  Fructose 6-phosphate        C6H11O9P                  {}
# 76       HCO3_c           Bicarbonate            CHO3                  {}
# 101       H2O_m            H2O, water             H2O                  {}
# 126       H2O_p            H2O, water             H2O                  {}
# 136       NH4_m               Ammonia             H4N                  {}
# 178      HCO3_h           Bicarbonate            CHO3                  {}
# 180       ACP_h  Acyl-carrier protein             HSR                  {}
# 198       NH4_h               Ammonia             H4N                  {}
# 216       Orn_h             Ornithine       C5H13N2O2                  {}
# 231       NH4_c               Ammonia             H4N                  {}
# 303       Orn_m             Ornithine       C5H13N2O2                  {}
#
#     aracore_updated_ids aracore_updated_universal_ids  \
# 2                 H2O_h                           H2O
# 23                F6P_h                           F6P
# 55                H2O_c                           H2O
# 56                F6P_c                           F6P
# 76               HCO3_c                          HCO3
# 101               H2O_m                           H2O
# 126               H2O_x                           H2O
# 136               NH4_m                           NH4
# 178              HCO3_h                          HCO3
# 180               ACP_h                           ACP
# 198               NH4_h                           NH4
# 216               Orn_h                           Orn
# 231               NH4_c                           NH4
# 303               Orn_m                           Orn
#
#     aracore_updated_universal_ids_lower  is_bigg_id universal_bigg_id  \
# 2                                   h2o        True               h2o
# 23                                  f6p        True               f6p
# 55                                  h2o        True               h2o
# 56                                  f6p        True               f6p
# 76                                 hco3        True              hco3
# 101                                 h2o        True               h2o
# 126                                 h2o        True               h2o
# 136                                 nh4        True               nh4
# 178                                hco3        True              hco3
# 180                                 acp        True               acp
# 198                                 nh4        True               nh4
# 216                                 orn        True               orn
# 231                                 nh4        True               nh4
# 303                                 orn        True               orn
#
#     bigg_seed_id  is_seed_id   seed_id   seed_BiGG_id          seed_id_aggr  \
# 2       cpd27222        True  cpd00001     [h2o, oh1]  [cpd00001, cpd27222]
# 23      cpd19035        True  cpd00072   [f6p, f6p_B]  [cpd00072, cpd19035]
# 55      cpd27222        True  cpd00001     [h2o, oh1]  [cpd00001, cpd27222]
# 56      cpd19035        True  cpd00072   [f6p, f6p_B]  [cpd00072, cpd19035]
# 76      cpd00242        True  cpd00242  [h2co3, hco3]            [cpd00242]
# 101     cpd27222        True  cpd00001     [h2o, oh1]  [cpd00001, cpd27222]
# 126     cpd27222        True  cpd00001     [h2o, oh1]  [cpd00001, cpd27222]
# 136     cpd19013        True  cpd00013     [nh3, nh4]  [cpd00013, cpd19013]
# 178     cpd00242        True  cpd00242  [h2co3, hco3]            [cpd00242]
# 180     cpd11493        True  cpd11493          [ACP]            [cpd11493]
# 198     cpd19013        True  cpd00013     [nh3, nh4]  [cpd00013, cpd19013]
# 216     cpd19016        True  cpd00064  [orn, orn__L]  [cpd00064, cpd19016]
# 231     cpd19013        True  cpd00013     [nh3, nh4]  [cpd00013, cpd19013]
# 303     cpd19016        True  cpd00064  [orn, orn__L]  [cpd00064, cpd19016]
#
#       bigg_id_aggr
# 2       [h2o, oh1]
# 23    [f6p, f6p_B]
# 55      [h2o, oh1]
# 56    [f6p, f6p_B]
# 76   [h2co3, hco3]
# 101     [h2o, oh1]
# 126     [h2o, oh1]
# 136     [nh3, nh4]
# 178  [h2co3, hco3]
# 180     [ACP, acp]
# 198     [nh3, nh4]
# 216  [orn, orn__L]
# 231     [nh3, nh4]
# 303  [orn, orn__L]

# %% [markdown]
# **Access above table and compare by eye and make notes to solve potential conflicts for later:**
# - H2O_h, H2O_m, H2O_p, H2O_c  => h2O
# - F6P_h, F6P_c => f6p
# - HCO3_c, HCO3_h => hco3
# - NH4_m, NH4_h, NH4_c => nh4
# - ACP_h => acp
# - Orn_h, Orn_m => orn

# %%
#Resolve conflict in original table df_metabolites_aracore

df_metabolites_aracore.set_index("aracore_ids",inplace=True) #Set index to acacore_ids to make editing easiers

# H2O_h, H2O_m, H2O_p, H2O_c  => h2O
df_metabolites_aracore.loc['H2O_c','bigg_id_aggr'] = [['h2o']]
df_metabolites_aracore.loc['H2O_h','bigg_id_aggr'] = [['h2o']]
df_metabolites_aracore.loc['H2O_p','bigg_id_aggr'] = [['h2o']]
df_metabolites_aracore.loc['H2O_m','bigg_id_aggr'] = [['h2o']]

# F6P_h, F6P_c => f6p
df_metabolites_aracore.loc['F6P_h','bigg_id_aggr'] = [['f6p']]
df_metabolites_aracore.loc['F6P_c','bigg_id_aggr'] = [['f6p']]

# HCO3_c, HCO3_h => hco3
df_metabolites_aracore.loc['HCO3_c','bigg_id_aggr'] = [['hco3']]
df_metabolites_aracore.loc['HCO3_h','bigg_id_aggr'] = [['hco3']]

# NH4_m, NH4_h, NH4_c => nh4
df_metabolites_aracore.loc['NH4_m','bigg_id_aggr'] = [['nh4']]
df_metabolites_aracore.loc['NH4_h','bigg_id_aggr'] =[ ['nh4']]
df_metabolites_aracore.loc['NH4_c','bigg_id_aggr'] = [['nh4']]

# ACP_h => acp
df_metabolites_aracore.loc['ACP_h','bigg_id_aggr'] = [['acp']]

# Orn_h, Orn_m => orn
df_metabolites_aracore.loc['Orn_h','bigg_id_aggr'] = [['orn']]
df_metabolites_aracore.loc['Orn_m','bigg_id_aggr'] = [['orn']]


#ppi has different sum formulas in the Aracore model?
#Coenzyme A has different sum formulas in the Aracore model?
#5,6,7,8-Tetrahydrofolate has different sum formulas in the Aracore model?

df_metabolites_aracore.reset_index(inplace=True)

# %%
#Check if all bigg conflicts resolved 
(df_metabolites_aracore['bigg_id_aggr'].apply(len) > 1).value_counts() #all conflicts resolved
# Out:
# False    413
# Name: bigg_id_aggr, dtype: int64

# %%
#Convert list of len 1 into string of BiGG id
df_metabolites_aracore['bigg_id_aggr'] = df_metabolites_aracore['bigg_id_aggr'].apply(lambda x: x[0] if x else None)

#Clean dataframe and drop cols
df_metabolites_aracore.drop(['is_seed_id','is_bigg_id','seed_BiGG_id','seed_id','bigg_seed_id','universal_bigg_id'], axis=1, inplace=True)

df_metabolites_aracore.head(25)
# Out:
#    aracore_ids                                       aracore_name  \
# 0        hnu_h                                             Photon
# 1         PQ_h                             Oxidized plastoquinone
# 2        H2O_h                                         H2O, water
# 3          H_h                                         H+, proton
# 4       PQH2_h                              Reduced plastoquinone
# 5         O2_h                                         O2, oxygen
# 6          H_l                                         H+, proton
# 7       PCox_h                              Oxidized plastocyanin
# 8       PCrd_h                               Reduced plastocyanin
# 9       Fdox_h                                Oxidized ferredoxin
# 10      Fdrd_h                                 Reduced ferredoxin
# 11      NADP_h        Nicotinamide adenine dinucleotide phosphate
# 12     NADPH_h  Nicotinamide adenine dinucleotide phosphate - ...
# 13       ADP_h                              Adenosine diphosphate
# 14        Pi_h                                     Orthophosphate
# 15       ATP_h                             Adenosine triphosphate
# 16      RuBP_h                          Ribulose 1,5-bisphosphate
# 17       CO2_h                                CO2, carbon dioxide
# 18       PGA_h                                 3-Phosphoglycerate
# 19      DPGA_h                    3-Phospho-D-glyceroyl phosphate
# 20       GAP_h                         Glyceraldehyde 3-phosphate
# 21      DHAP_h                         Dihydroxyacetone phosphate
# 22       FBP_h                          Fructose 1,6-bisphosphate
# 23       F6P_h                               Fructose 6-phosphate
# 24       E4P_h                              Erythrose 4-phosphate
#
#    aracore_formula aracore_annotations aracore_updated_ids  \
# 0                X                  {}               hnu_h
# 1         C13H16O2                  {}                PQ_h
# 2              H2O                  {}               H2O_h
# 3                H                  {}                 H_h
# 4         C13H18O2                  {}              PQH2_h
# 5               O2                  {}                O2_h
# 6                H                  {}                H_ul
# 7                X                  {}              PCox_h
# 8                X                  {}              PCrd_h
# 9            S8FeX                  {}              Fdox_h
# 10           S8FeX                  {}              Fdrd_h
# 11   C21H25N7O17P3                  {}              NADP_h
# 12   C21H26N7O17P3                  {}             NADPH_h
# 13   C10H12N5O10P2                  {}               ADP_h
# 14            HO4P                  {}                Pi_h
# 15   C10H12N5O13P3                  {}               ATP_h
# 16       C5H8O11P2                  {}              RuBP_h
# 17             CO2                  {}               CO2_h
# 18         C3H4O7P                  {}               PGA_h
# 19       C3H4O10P2                  {}              DPGA_h
# 20         C3H5O6P                  {}               GAP_h
# 21         C3H5O6P                  {}              DHAP_h
# 22      C6H10O12P2                  {}               FBP_h
# 23        C6H11O9P                  {}               F6P_h
# 24         C4H7O7P                  {}               E4P_h
#
#    aracore_updated_universal_ids aracore_updated_universal_ids_lower  \
# 0                            hnu                                 hnu
# 1                             PQ                                  pq
# 2                            H2O                                 h2o
# 3                              H                                   h
# 4                           PQH2                                pqh2
# 5                             O2                                  o2
# 6                              H                                   h
# 7                           PCox                                pcox
# 8                           PCrd                                pcrd
# 9                           Fdox                                fdox
# 10                          Fdrd                                fdrd
# 11                          NADP                                nadp
# 12                         NADPH                               nadph
# 13                           ADP                                 adp
# 14                            Pi                                  pi
# 15                           ATP                                 atp
# 16                          RuBP                                rubp
# 17                           CO2                                 co2
# 18                           PGA                                 pga
# 19                          DPGA                                dpga
# 20                           GAP                                 gap
# 21                          DHAP                                dhap
# 22                           FBP                                 fbp
# 23                           F6P                                 f6p
# 24                           E4P                                 e4p
#
#             seed_id_aggr bigg_id_aggr
# 0                     []         None
# 1                     []           pq
# 2   [cpd00001, cpd27222]          h2o
# 3             [cpd00067]            h
# 4                     []         pqh2
# 5             [cpd00007]           o2
# 6             [cpd00067]            h
# 7             [cpd30035]         pcox
# 8             [cpd30034]         pcrd
# 9             [cpd15876]         fdox
# 10                    []         None
# 11            [cpd00006]         nadp
# 12            [cpd00005]        nadph
# 13            [cpd00008]          adp
# 14  [cpd00009, cpd27787]           pi
# 15            [cpd00002]          atp
# 16                    []         None
# 17            [cpd00011]          co2
# 18            [cpd29254]         None
# 19                    []         None
# 20                    []         None
# 21            [cpd00095]         dhap
# 22                    []         None
# 23  [cpd00072, cpd19035]          f6p
# 24            [cpd00236]          e4p

# %%
df_metabolites_aracore['bigg_id_aggr'].notna().value_counts() #165 BiGG Ids mapped to aracore id
# => 248 - 165 = 83 conflicts to solve by hand
# Out:
# False    248
# True     165
# Name: bigg_id_aggr, dtype: int64

# %%
#Resolve conflict in original table df_metabolites_aracore
df_metabolites_aracore.set_index("aracore_ids",inplace=True) #Set index to acacore_ids to make editing easiers

#H2O_c, H2O_h, H2O_p, H2O_m == cpd00001
df_metabolites_aracore.loc['H2O_c','seed_id_aggr'] = [['cpd00001']]
df_metabolites_aracore.loc['H2O_h','seed_id_aggr'] = [['cpd00001']]
df_metabolites_aracore.loc['H2O_p','seed_id_aggr'] = [['cpd00001']]
df_metabolites_aracore.loc['H2O_m','seed_id_aggr'] = [['cpd00001']]

#Pi_h,_c,_m => cpd00009
df_metabolites_aracore.loc['Pi_c','seed_id_aggr'] = [['cpd00009']]
df_metabolites_aracore.loc['Pi_h','seed_id_aggr'] = [['cpd00009']]
df_metabolites_aracore.loc['Pi_m','seed_id_aggr'] = [['cpd00009']]

#F6P_c,h => cpd00072
df_metabolites_aracore.loc['F6P_c','seed_id_aggr'] = [['cpd00072']]
df_metabolites_aracore.loc['F6P_h','seed_id_aggr'] = [['cpd00072']]

#R5P_h => cpd00101
df_metabolites_aracore.loc['R5P_h','seed_id_aggr'] = [['cpd00101']]

#G6P_h,c => cpd00079
df_metabolites_aracore.loc['G6P_c','seed_id_aggr'] = [['cpd00079']]
df_metabolites_aracore.loc['G6P_h','seed_id_aggr'] = [['cpd00079']]

#G1P_h,c => cpd00089
df_metabolites_aracore.loc['G1P_c','seed_id_aggr'] = [['cpd00089']]
df_metabolites_aracore.loc['G1P_h','seed_id_aggr'] = [['cpd00089']]


#UDPG_c => cpd00026
df_metabolites_aracore.loc['UDPG_c','seed_id_aggr'] = [['cpd00026']]

#PPi_h,_c => cpd00012
df_metabolites_aracore.loc['PPi_c','seed_id_aggr'] = [['cpd00012']]
df_metabolites_aracore.loc['PPi_h','seed_id_aggr'] = [['cpd00012']]


#CoA_m,_c,_h => cpd00010
df_metabolites_aracore.loc['CoA_c','seed_id_aggr'] = [['cpd00010']]
df_metabolites_aracore.loc['CoA_h','seed_id_aggr'] = [['cpd00010']]
df_metabolites_aracore.loc['CoA_m','seed_id_aggr'] = [['cpd00010']]

#NH4_m,_h,_c => cpd00013
df_metabolites_aracore.loc['NH4_c','seed_id_aggr'] = [['cpd00013']]
df_metabolites_aracore.loc['NH4_h','seed_id_aggr'] = [['cpd00013']]
df_metabolites_aracore.loc['NH4_m','seed_id_aggr'] = [['cpd00013']]

#AMP_h,_c => cpd00018
df_metabolites_aracore.loc['AMP_c','seed_id_aggr'] = [['cpd00018']]
df_metabolites_aracore.loc['AMP_h','seed_id_aggr'] = [['cpd00018']]

#H2S_h,_c,_m => cpd00239
df_metabolites_aracore.loc['H2S_c','seed_id_aggr'] = [['cpd00239']]
df_metabolites_aracore.loc['H2S_h','seed_id_aggr'] = [['cpd00239']]
df_metabolites_aracore.loc['H2S_m','seed_id_aggr'] = [['cpd00239']]

#Orn_h,_m => cpd00064
df_metabolites_aracore.loc['Orn_h','seed_id_aggr'] = [['cpd00064']]
df_metabolites_aracore.loc['Orn_m','seed_id_aggr'] = [['cpd00064']]

#For_h => cpd00047
df_metabolites_aracore.loc['For_h','seed_id_aggr'] = [['cpd00047']]

#THF_m, THF_c, THF_h	5,6,7,8-Tetrahydrofolate == cpd00087 -> 186 has one more H in sum formula
df_metabolites_aracore.loc['THF_m','seed_id_aggr'] = [['cpd00087']]
df_metabolites_aracore.loc['THF_c','seed_id_aggr'] = [['cpd00087']]
df_metabolites_aracore.loc['THF_h','seed_id_aggr'] = [['cpd00087']]

#SO4_h, SO4_m, SO4_c Sulfate O4S == cpd00048
df_metabolites_aracore.loc['SO4_h','seed_id_aggr'] = [['cpd00048']]
df_metabolites_aracore.loc['SO4_m','seed_id_aggr'] = [['cpd00048']]
df_metabolites_aracore.loc['SO4_c','seed_id_aggr'] = [['cpd00048']]

#ppi has different sum formulas in the Aracore model?!?
#Coenzyme A has different sum formulas in the Aracore model?!?
#5,6,7,8-Tetrahydrofolate has different sum formulas in the Aracore model?!?

df_metabolites_aracore.reset_index(inplace=True)

# %%
#Export final mapping table for manual mapping
df_metabolites_aracore.to_csv('../data/processed/2021-06-22-ca-metabolite-mapping-table')

# %% [markdown]
# **After mapping the identifiers from the AraCore model and the two databases BiGG and ModelSEED, we will try to perform the mapping according to the chemical formulas.**

# %% [markdown]
# # VII / Mapping by chemical formulas

# %%
df_metabolites_seed["formula"].value_counts()
# Out:
# C15H24        150
# C6H12O6       100
# C12H22O11      66
# C6H11O9P       66
# C15H26O        54
#              ...
# C33H39N4O4      1
# C6H3Cl4N        1
# C24H29O4        1
# C8H11NO5P       1
# C38H46N2O8      1
# Name: formula, Length: 16762, dtype: int64

# %% [markdown]
# **From df_metabolites_seed, we create a new dataframe in which one raw corresponds to one chemical formula.**
#
# **Chemical formula = index of the dataframe.**
#
#
# 1. We use the groupby() function with a column name in parameter to group all the lines having the same value for the column of interest.
#
# 2. We are lucky, because we have a column with the corresponding id modelSEED generated by the group by
# => Aggregation of the id modelSEED (transformation of the group value to have only one value)
# ex : mean, sum, max, min
#
# **In this case, we pass the column named "formula" to the groupby() function.
# We group all the lines which have the same chemical formula to aggregate the lines.
# As we want all the ids modelSEED, we will recover them in a list.**
#
# 3. drop() function to delete the "X" (no value)
#
# 4. reset_index() function to include the index, and then, betting a dataframe
#
#
# First, we tried to use these following commands :
#
# df_metabolites_groupby_formula = df_metabolites_seed.groupby("formula")["id"].apply(list).drop(labels = 'X', axis=0) reset_index()
# df_metabolites_groupby_formula
#
# However, it didn't seem to be very efficient to solve both the groupby() part and the conflicts on model_seed_id. Thus, we performed an aggregation on model_seed_id after the groupby() function to list the model_seed_id.
#
# > After a groupby(), we need to perform an aggregation, with the following function : agg().
#
# > agg(dictionary) : this function defines the aggregation we want for each column.
#
# > dictionary as parameter : the keys are the names of the columns at which we want to perform the aggregation, and the values are the way we aggregate the values of the columns.
#
# Finally, we tried to use these following commands :
#
# df_metabolites_groupby_formula = df_metabolites_seed.groupby("formula").agg({"id":list, "abbreviation":list}).drop(labels = 'X', axis = 0).reset_index()
#
# df_metabolites_groupby_formula

# %%
df_metabolites_groupby_formula = df_metabolites_seed.groupby("formula").agg({"id":list, "abbreviation":list}).drop(labels = 'X', axis = 0).reset_index()
df_metabolites_groupby_formula
# Out:
#       formula                              id          abbreviation
# 0          Ag  [cpd04100, cpd24345, cpd37274]    [ag, Ag++, Silver]
# 1      Ag2O4S                      [cpd22247]          [Ag2SO4(aq)]
# 2       AgNO3                      [cpd28685]               [AgNO3]
# 3          Al                      [cpd24344]               [Al+++]
# 4        AlF3                      [cpd26028]  [aluminium fluoride]
# ...       ...                             ...                   ...
# 16756       V                      [cpd12858]                   [V]
# 16757       W            [cpd00560, cpd28334]       [Tungsten, W+6]
# 16758      Xe                      [cpd09418]               [Xenon]
# 16759       Z                      [cpd31000]              [photon]
# 16760      Zn                      [cpd00034]                 [zn2]
#
# [16761 rows x 3 columns]

# %%
df_metabolites_groupby_formula = df_metabolites_groupby_formula.rename(columns = {"formula":"model_seed_formula", "id":"model_seed_id", "abbreviation":"model_seed_abbreviation"})
df_metabolites_groupby_formula
# Out:
#       model_seed_formula                   model_seed_id  \
# 0                     Ag  [cpd04100, cpd24345, cpd37274]
# 1                 Ag2O4S                      [cpd22247]
# 2                  AgNO3                      [cpd28685]
# 3                     Al                      [cpd24344]
# 4                   AlF3                      [cpd26028]
# ...                  ...                             ...
# 16756                  V                      [cpd12858]
# 16757                  W            [cpd00560, cpd28334]
# 16758                 Xe                      [cpd09418]
# 16759                  Z                      [cpd31000]
# 16760                 Zn                      [cpd00034]
#
#       model_seed_abbreviation
# 0          [ag, Ag++, Silver]
# 1                [Ag2SO4(aq)]
# 2                     [AgNO3]
# 3                     [Al+++]
# 4        [aluminium fluoride]
# ...                       ...
# 16756                     [V]
# 16757         [Tungsten, W+6]
# 16758                 [Xenon]
# 16759                [photon]
# 16760                   [zn2]
#
# [16761 rows x 3 columns]

# %%
# Now, we merge with the dataframe according to the formula
df_metabolites_aracore_final = df_metabolites_aracore.merge(df_metabolites_groupby_formula, how = 'left', left_on = 'aracore_formula', right_on = 'model_seed_formula')
df_metabolites_aracore_final
# Out:
#         aracore_ids                                       aracore_name  \
# 0             hnu_h                                             Photon
# 1              PQ_h                             Oxidized plastoquinone
# 2             H2O_h                                         H2O, water
# 3               H_h                                         H+, proton
# 4            PQH2_h                              Reduced plastoquinone
# ..              ...                                                ...
# 408        PQstar_h                              Plastoquinone radical
# 409  PGR5_PGRL1ox_h  oxidised proton gradient regulation 5 (PGR5)/P...
# 410  PGR5_PGRL1rd_h  reduced proton gradient regulation 5 (PGR5)/PG...
# 411         NDHox_h     oxidised NADH dehydrogenase-like (NDH) complex
# 412         NDHrd_h      reduced NADH dehydrogenase-like (NDH) complex
#
#     aracore_formula aracore_annotations aracore_updated_ids  \
# 0                 X                  {}               hnu_h
# 1          C13H16O2                  {}                pq_h
# 2               H2O                  {}               h2o_h
# 3                 H                  {}                 h_h
# 4          C13H18O2                  {}              pqh2_h
# ..              ...                 ...                 ...
# 408        C13H16O2                  {}            pqstar_h
# 409               X                  {}      pgr5_pgrl1ox_h
# 410               X                  {}      pgr5_pgrl1rd_h
# 411               X                  {}             ndhox_h
# 412               X                  {}             ndhrd_h
#
#     aracore_updated_universal_ids  seed_id_aggr bigg_id_aggr  \
# 0                             hnu            []         None
# 1                              pq            []           pq
# 2                             h2o  [[cpd00001]]          h2o
# 3                               h    [cpd00067]            h
# 4                            pqh2            []         pqh2
# ..                            ...           ...          ...
# 408                        pqstar            []         None
# 409                  pgr5_pgrl1ox            []         None
# 410                  pgr5_pgrl1rd            []         None
# 411                         ndhox            []         None
# 412                         ndhrd            []         None
#
#     model_seed_formula                   model_seed_id  \
# 0                  NaN                             NaN
# 1             C13H16O2  [cpd07588, cpd12011, cpd16487]
# 2                  H2O            [cpd00001, cpd15275]
# 3                    H                      [cpd00067]
# 4             C13H18O2            [cpd01475, cpd16486]
# ..                 ...                             ...
# 408           C13H16O2  [cpd07588, cpd12011, cpd16487]
# 409                NaN                             NaN
# 410                NaN                             NaN
# 411                NaN                             NaN
# 412                NaN                             NaN
#
#                                model_seed_abbreviation
# 0                                                  NaN
# 1    [4'-Hydroxy-3'-prenylacetophenone, Plastoquino...
# 2                                           [h2o, oh1]
# 3                                                  [h]
# 4                       [Plastoquinol-1, Plastoquinol]
# ..                                                 ...
# 408  [4'-Hydroxy-3'-prenylacetophenone, Plastoquino...
# 409                                                NaN
# 410                                                NaN
# 411                                                NaN
# 412                                                NaN
#
# [413 rows x 11 columns]

# %%
df_metabolites_aracore_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 413 entries, 0 to 412
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   aracore_ids                    413 non-null    object
#  1   aracore_name                   413 non-null    object
#  2   aracore_formula                413 non-null    object
#  3   aracore_annotations            413 non-null    object
#  4   aracore_updated_ids            413 non-null    object
#  5   aracore_updated_universal_ids  413 non-null    object
#  6   seed_id_aggr                   413 non-null    object
#  7   bigg_id_aggr                   165 non-null    object
#  8   model_seed_formula             360 non-null    object
#  9   model_seed_id                  360 non-null    object
#  10  model_seed_abbreviation        360 non-null    object
# dtypes: object(11)
# memory usage: 38.7+ KB

# %%
#Export final mapping table for manual mapping
df_metabolites_aracore_final.to_csv('../data/processed/2021-06-22-metabolite-mapping-table2.csv')

# %% [markdown]
# # Conflicts solving

# %% [markdown]
# Now, we have a dataframe with a column including ModelSEED IDs from the ModelSEED database. However, conflicts could be present if we have more than one ID. Thus, we will apply the len() function to each line of the dataframe, and we count the number of line for each length value thanks to the value_counts() function.
# => Value_counts() function returns a Series containing counts for unique rows in the dataframe.

# %%
# replace the NaN values by empty lists
def apply_replace_Nan_by_list(line):
    if type(line) is not list:
        value = []
    else:
        value = line # WARNING !! Always put the else: condition to specify which value is taken in that case; here, we recover
        # the line if type(line) is list
    return value
df_metabolites_aracore_final["model_seed_id"] = df_metabolites_aracore_final["model_seed_id"].apply(apply_replace_Nan_by_list)
df_metabolites_aracore_final
# Out:
#         aracore_ids                                       aracore_name  \
# 0             hnu_h                                             Photon
# 1              PQ_h                             Oxidized plastoquinone
# 2             H2O_h                                         H2O, water
# 3               H_h                                         H+, proton
# 4            PQH2_h                              Reduced plastoquinone
# ..              ...                                                ...
# 408        PQstar_h                              Plastoquinone radical
# 409  PGR5_PGRL1ox_h  oxidised proton gradient regulation 5 (PGR5)/P...
# 410  PGR5_PGRL1rd_h  reduced proton gradient regulation 5 (PGR5)/PG...
# 411         NDHox_h     oxidised NADH dehydrogenase-like (NDH) complex
# 412         NDHrd_h      reduced NADH dehydrogenase-like (NDH) complex
#
#     aracore_formula aracore_annotations aracore_updated_ids  \
# 0                 X                  {}               hnu_h
# 1          C13H16O2                  {}                pq_h
# 2               H2O                  {}               h2o_h
# 3                 H                  {}                 h_h
# 4          C13H18O2                  {}              pqh2_h
# ..              ...                 ...                 ...
# 408        C13H16O2                  {}            pqstar_h
# 409               X                  {}      pgr5_pgrl1ox_h
# 410               X                  {}      pgr5_pgrl1rd_h
# 411               X                  {}             ndhox_h
# 412               X                  {}             ndhrd_h
#
#     aracore_updated_universal_ids  seed_id_aggr bigg_id_aggr  \
# 0                             hnu            []         None
# 1                              pq            []           pq
# 2                             h2o  [[cpd00001]]          h2o
# 3                               h    [cpd00067]            h
# 4                            pqh2            []         pqh2
# ..                            ...           ...          ...
# 408                        pqstar            []         None
# 409                  pgr5_pgrl1ox            []         None
# 410                  pgr5_pgrl1rd            []         None
# 411                         ndhox            []         None
# 412                         ndhrd            []         None
#
#     model_seed_formula                   model_seed_id  \
# 0                  NaN                              []
# 1             C13H16O2  [cpd07588, cpd12011, cpd16487]
# 2                  H2O            [cpd00001, cpd15275]
# 3                    H                      [cpd00067]
# 4             C13H18O2            [cpd01475, cpd16486]
# ..                 ...                             ...
# 408           C13H16O2  [cpd07588, cpd12011, cpd16487]
# 409                NaN                              []
# 410                NaN                              []
# 411                NaN                              []
# 412                NaN                              []
#
#                                model_seed_abbreviation
# 0                                                  NaN
# 1    [4'-Hydroxy-3'-prenylacetophenone, Plastoquino...
# 2                                           [h2o, oh1]
# 3                                                  [h]
# 4                       [Plastoquinol-1, Plastoquinol]
# ..                                                 ...
# 408  [4'-Hydroxy-3'-prenylacetophenone, Plastoquino...
# 409                                                NaN
# 410                                                NaN
# 411                                                NaN
# 412                                                NaN
#
# [413 rows x 11 columns]

# %%
df_metabolites_aracore_final["model_seed_id"].apply(len).value_counts() # on the left : the length of the lists at the level of
# the ModelSEED ID; on the right, the numbers of rows for this length value
# => 53 lines would have 0 IDs; 77 lines would have 1 ID 
# => 63 lines would have 2 IDs; the other lines would have more than 2 IDs => potential conflicts?
# Out:
# 1      77
# 2      63
# 0      53
# 3      51
# 4      27
# 5      22
# 7      20
# 66     13
# 11     12
# 9      11
# 16     11
# 6       8
# 10      7
# 12      6
# 100     6
# 14      5
# 19      5
# 13      4
# 8       3
# 15      3
# 20      2
# 39      2
# 52      2
# Name: model_seed_id, dtype: int64

# %%
# Extract those metabolites that have more than one ModelSEED compound ids mapped
df_metabolites_aracore_seed_conflicted = df_metabolites_aracore_final[df_metabolites_aracore_final['model_seed_id'].apply(len) > 1].copy()
df_metabolites_aracore_seed_conflicted
# Out:
#     aracore_ids                                 aracore_name aracore_formula  \
# 1          PQ_h                       Oxidized plastoquinone        C13H16O2
# 2         H2O_h                                   H2O, water             H2O
# 4        PQH2_h                        Reduced plastoquinone        C13H18O2
# 5          O2_h                                   O2, oxygen              O2
# 11       NADP_h  Nicotinamide adenine dinucleotide phosphate   C21H25N7O17P3
# ..          ...                                          ...             ...
# 404       Thr_m                                    Threonine         C4H9NO3
# 405       Trp_m                                   Tryptophan      C11H12N2O2
# 406       Tyr_m                                     Tyrosine        C9H11NO3
# 407       Val_m                                       Valine        C5H11NO2
# 408    PQstar_h                        Plastoquinone radical        C13H16O2
#
#     aracore_annotations aracore_updated_ids aracore_updated_universal_ids  \
# 1                    {}                pq_h                            pq
# 2                    {}               h2o_h                           h2o
# 4                    {}              pqh2_h                          pqh2
# 5                    {}                o2_h                            o2
# 11                   {}              nadp_h                          nadp
# ..                  ...                 ...                           ...
# 404                  {}               thr_m                           thr
# 405                  {}               trp_m                           trp
# 406                  {}               tyr_m                           tyr
# 407                  {}               val_m                           val
# 408                  {}            pqstar_h                        pqstar
#
#      seed_id_aggr bigg_id_aggr model_seed_formula  \
# 1              []           pq           C13H16O2
# 2    [[cpd00001]]          h2o                H2O
# 4              []         pqh2           C13H18O2
# 5      [cpd00007]           o2                 O2
# 11     [cpd00006]         nadp      C21H25N7O17P3
# ..            ...          ...                ...
# 404            []         None            C4H9NO3
# 405            []         None         C11H12N2O2
# 406            []         None           C9H11NO3
# 407            []         None           C5H11NO2
# 408            []         None           C13H16O2
#
#                                          model_seed_id  \
# 1                       [cpd07588, cpd12011, cpd16487]
# 2                                 [cpd00001, cpd15275]
# 4                                 [cpd01475, cpd16486]
# 5                                 [cpd00007, cpd00532]
# 11                                [cpd00006, cpd33786]
# ..                                                 ...
# 404  [cpd00161, cpd00227, cpd00611, cpd01432, cpd02...
# 405  [cpd00065, cpd00411, cpd04921, cpd07629, cpd10...
# 406  [cpd00069, cpd02099, cpd02674, cpd03843, cpd23...
# 407  [cpd00156, cpd00339, cpd00540, cpd01241, cpd01...
# 408                     [cpd07588, cpd12011, cpd16487]
#
#                                model_seed_abbreviation
# 1    [4'-Hydroxy-3'-prenylacetophenone, Plastoquino...
# 2                                           [h2o, oh1]
# 4                       [Plastoquinol-1, Plastoquinol]
# 5                                            [o2, o2s]
# 11                                 [nadp, alpha-NADP+]
# ..                                                 ...
# 404  [thr-L, hom-L, D-Threonine, 2-Methylserine, GA...
# 405  [trp-L, D-Tryptophan, Ethotoin, Vasicinol, Nir...
# 406  [tyr-L, L-threo-3-Phenylserine, beta-Tyrosine,...
# 407  [val-L, 5aptn, glyb, D-Norvaline, L-Norvaline,...
# 408  [4'-Hydroxy-3'-prenylacetophenone, Plastoquino...
#
# [283 rows x 11 columns]

# %%
df_metabolites_aracore_seed_conflicted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 283 entries, 1 to 408
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   aracore_ids                    283 non-null    object
#  1   aracore_name                   283 non-null    object
#  2   aracore_formula                283 non-null    object
#  3   aracore_annotations            283 non-null    object
#  4   aracore_updated_ids            283 non-null    object
#  5   aracore_updated_universal_ids  283 non-null    object
#  6   seed_id_aggr                   283 non-null    object
#  7   bigg_id_aggr                   95 non-null     object
#  8   model_seed_formula             283 non-null    object
#  9   model_seed_id                  283 non-null    object
#  10  model_seed_abbreviation        283 non-null    object
# dtypes: object(11)
# memory usage: 26.5+ KB

# %% [markdown]
# > According to the results obtained below, we would have 283 conflicts to solve by hand.
#
# > We will look for the conflicts we couldn't solve before, e.g. the seed_id_aggr which are empty

# %%
# We would like to look at the conflicts we want to solve
df_metabolites_aracore_seed_no_match = df_metabolites_aracore_seed_conflicted[df_metabolites_aracore_seed_conflicted['seed_id_aggr'].apply(len) == 0].copy()
df_metabolites_aracore_seed_no_match
# Out:
#     aracore_ids                aracore_name aracore_formula  \
# 1          PQ_h      Oxidized plastoquinone        C13H16O2
# 4        PQH2_h       Reduced plastoquinone        C13H18O2
# 16       RuBP_h   Ribulose 1,5-bisphosphate       C5H8O11P2
# 20        GAP_h  Glyceraldehyde 3-phosphate         C3H5O6P
# 22        FBP_h   Fructose 1,6-bisphosphate      C6H10O12P2
# ..          ...                         ...             ...
# 404       Thr_m                   Threonine         C4H9NO3
# 405       Trp_m                  Tryptophan      C11H12N2O2
# 406       Tyr_m                    Tyrosine        C9H11NO3
# 407       Val_m                      Valine        C5H11NO2
# 408    PQstar_h       Plastoquinone radical        C13H16O2
#
#     aracore_annotations aracore_updated_ids aracore_updated_universal_ids  \
# 1                    {}                pq_h                            pq
# 4                    {}              pqh2_h                          pqh2
# 16                   {}              rubp_h                          rubp
# 20                   {}               gap_h                           gap
# 22                   {}               fbp_h                           fbp
# ..                  ...                 ...                           ...
# 404                  {}               thr_m                           thr
# 405                  {}               trp_m                           trp
# 406                  {}               tyr_m                           tyr
# 407                  {}               val_m                           val
# 408                  {}            pqstar_h                        pqstar
#
#     seed_id_aggr bigg_id_aggr model_seed_formula  \
# 1             []           pq           C13H16O2
# 4             []         pqh2           C13H18O2
# 16            []         None          C5H8O11P2
# 20            []         None            C3H5O6P
# 22            []         None         C6H10O12P2
# ..           ...          ...                ...
# 404           []         None            C4H9NO3
# 405           []         None         C11H12N2O2
# 406           []         None           C9H11NO3
# 407           []         None           C5H11NO2
# 408           []         None           C13H16O2
#
#                                          model_seed_id  \
# 1                       [cpd07588, cpd12011, cpd16487]
# 4                                 [cpd01475, cpd16486]
# 16                      [cpd00847, cpd00871, cpd34070]
# 20            [cpd00095, cpd00102, cpd19005, cpd27362]
# 22   [cpd00290, cpd00499, cpd00503, cpd00898, cpd02...
# ..                                                 ...
# 404  [cpd00161, cpd00227, cpd00611, cpd01432, cpd02...
# 405  [cpd00065, cpd00411, cpd04921, cpd07629, cpd10...
# 406  [cpd00069, cpd02099, cpd02674, cpd03843, cpd23...
# 407  [cpd00156, cpd00339, cpd00540, cpd01241, cpd01...
# 408                     [cpd07588, cpd12011, cpd16487]
#
#                                model_seed_abbreviation
# 1    [4'-Hydroxy-3'-prenylacetophenone, Plastoquino...
# 4                       [Plastoquinol-1, Plastoquinol]
# 16    [r15bp, rb15bp, D-ribofuranose 2,5-bisphosphate]
# 20   [dhap, g3p, DL-Glyceraldehyde 3-phosphate, L-GAP]
# 22   [fdp, g16bp, f26bp, Inositol 1,4-bisphosphate,...
# ..                                                 ...
# 404  [thr-L, hom-L, D-Threonine, 2-Methylserine, GA...
# 405  [trp-L, D-Tryptophan, Ethotoin, Vasicinol, Nir...
# 406  [tyr-L, L-threo-3-Phenylserine, beta-Tyrosine,...
# 407  [val-L, 5aptn, glyb, D-Norvaline, L-Norvaline,...
# 408  [4'-Hydroxy-3'-prenylacetophenone, Plastoquino...
#
# [189 rows x 11 columns]

# %%
df_metabolites_aracore_seed_no_match.to_csv('../data/processed/2021-06-01-metabolite-aracore-seed-no-match.csv')

# %% [markdown]
# > **After executing the commands, we would have 189 conflicts to solve by hand.**

# %%
#Resolve conflict in original table df_metabolites_aracore
df_metabolites_aracore.set_index("aracore_ids",inplace=True) #Set index to acacore_ids to make editing easiers

# %% [markdown]
# > **Due to the important number of conflicts to solve by hand and the lack of time, we have decided to skip this step and keep the mapping table presenting less conflicts to solve by hand.**
