# %% [markdown]
# # Creating genes mapping table

# %% [markdown]
# ## I / Import the resources : AraCore model and ModelSEED and BiGG tables

# %% [markdown]
# ### 1) Install missing modules and load modules

# %%
import pandas as pd
import numpy as np
import cobra
import requests

# %% [markdown]
# ### 2) Load AraCore Model

# %%
#Get file from github
fileName = 'https://raw.githubusercontent.com/ma-blaetke/CBM_C3_C4_Metabolism/master/data/2018-23-05-mb-genC3.sbml'
r = requests.get(fileName)

# %%
#Create model
model = cobra.io.read_sbml_model(r.text)
model
# Out:
# <Model c3_model at 0x7fbe597fb4c0>

# %% [markdown]
# ### 3) Correct gene naming in AraCore Model according to BiGG naming conventions

# %% [markdown]
# ###  4) Correct gene naming in AraCore Model according to ModelSEED naming conventions

# %% [markdown]
# ### 5) Create Gene Table for AraCore Model

# %%
df_genes_aracore = pd.DataFrame(
    {
        "aracore_ids":[x.id for x in model.genes],
        "aracore_name":[x.name for x in model.genes],
        "aracore_annotations":[x.annotation for x in model.genes]
    })
df_genes_aracore
# Out:
#     aracore_ids aracore_name aracore_annotations
# 0     AT4G05180    AT4G05180                  {}
# 1     AT2G30570    AT2G30570                  {}
# 2     ATCG00560    ATCG00560                  {}
# 3     AT4G21280    AT4G21280                  {}
# 4     ATCG00300    ATCG00300                  {}
# ..          ...          ...                 ...
# 799   AT3G27620    AT3G27620                  {}
# 800   AT5G64210    AT5G64210                  {}
# 801   AT1G32350    AT1G32350                  {}
# 802   AT3G22360    AT3G22360                  {}
# 803   AT4G22260    AT4G22260                  {}
#
# [804 rows x 3 columns]

# %%
df_genes_aracore["aracore_ids"].shape[0] # indicates the number of genes
# Out:
# 804

# %%
df_genes_aracore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   aracore_ids          804 non-null    object
#  1   aracore_name         804 non-null    object
#  2   aracore_annotations  804 non-null    object
# dtypes: object(3)
# memory usage: 19.0+ KB

# %% [markdown]
# When we look at the metabolites or the reactions in the BiGG database, for example, we can notice that there are the correspondong genes, as well as their ID in the NCBI database.
# => Check in the NCBI database :
# We have :
# - the gene ID
# - summary
# - the genomic context
# - the genomic regions, transcripts, and products
# - bibliography
# - the general protein information
# - NCBI preferenced sequence
# - related sequence
# - additional links
# =>

# %%
#EXAMPLE REQUEST:

#Retrieve Information on gene symbol, location (chromosome, start and end), uniprot id/descriptive name using the ENSEMBL REST API
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/lookup

gene_id = 'AT4G05180'

#ENSEMBL Server Url
server = "https://rest.ensembl.org"

#URL specification to get meta-information of a gene by its id
ext = f"/lookup/id/{gene_id}?expand=1"
  
#Request information from URL in json format
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})

#Check if request was successful
if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

else:

    json_anno = None

json_anno
# Out:
# {'end': 2673243,
#  'logic_name': 'araport11',
#  'start': 2671523,
#  'db_type': 'core',
#  'assembly_name': 'TAIR10',
#  'id': 'AT4G05180',
#  'seq_region_name': '4',
#  'biotype': 'protein_coding',
#  'Transcript': [{'biotype': 'protein_coding',
#    'Exon': [{'id': 'AT4G05180.1.exon1',
#      'assembly_name': 'TAIR10',
#      'db_type': 'core',
#      'seq_region_name': '4',
#      'end': 2673243,
#      'start': 2672873,
#      'species': 'arabidopsis_thaliana',
#      'object_type': 'Exon',
#      'strand': -1},
#     {'strand': -1,
#      'object_type': 'Exon',
#      'species': 'arabidopsis_thaliana',
#      'start': 2672340,
#      'end': 2672635,
#      'seq_region_name': '4',
#      'assembly_name': 'TAIR10',
#      'id': 'AT4G05180.1.exon2',
#      'db_type': 'core'},
#     {'object_type': 'Exon',
#      'strand': -1,
#      'species': 'arabidopsis_thaliana',
#      'end': 2672191,
#      'start': 2671900,
#      'assembly_name': 'TAIR10',
#      'id': 'AT4G05180.1.exon3',
#      'db_type': 'core',
#      'seq_region_name': '4'},
#     {'strand': -1,
#      'object_type': 'Exon',
#      'species': 'arabidopsis_thaliana',
#      'start': 2671523,
#      'end': 2671718,
#      'seq_region_name': '4',
#      'db_type': 'core',
#      'assembly_name': 'TAIR10',
#      'id': 'AT4G05180.1.exon4'}],
#    'id': 'AT4G05180.1',
#    'db_type': 'core',
#    'start': 2671523,
#    'logic_name': 'araport11',
#    'strand': -1,
#    'is_canonical': 1,
#    'source': 'araport11',
#    'Parent': 'AT4G05180',
#    'Translation': {'species': 'arabidopsis_thaliana',
#     'length': 230,
#     'Parent': 'AT4G05180.1',
#     'object_type': 'Translation',
#     'id': 'AT4G05180.1',
#     'db_type': 'core',
#     'start': 2672093,
#     'end': 2673170},
#    'seq_region_name': '4',
#    'assembly_name': 'TAIR10',
#    'end': 2673243,
#    'species': 'arabidopsis_thaliana',
#    'object_type': 'Transcript'},
#   {'species': 'arabidopsis_thaliana',
#    'object_type': 'Transcript',
#    'seq_region_name': '4',
#    'assembly_name': 'TAIR10',
#    'end': 2673243,
#    'is_canonical': 0,
#    'source': 'araport11',
#    'strand': -1,
#    'Translation': {'end': 2673170,
#     'start': 2672093,
#     'id': 'AT4G05180.2',
#     'db_type': 'core',
#     'Parent': 'AT4G05180.2',
#     'object_type': 'Translation',
#     'length': 230,
#     'species': 'arabidopsis_thaliana'},
#    'Parent': 'AT4G05180',
#    'Exon': [{'end': 2673243,
#      'start': 2672873,
#      'id': 'AT4G05180.1.exon1',
#      'assembly_name': 'TAIR10',
#      'db_type': 'core',
#      'seq_region_name': '4',
#      'object_type': 'Exon',
#      'strand': -1,
#      'species': 'arabidopsis_thaliana'},
#     {'end': 2672635,
#      'start': 2672340,
#      'assembly_name': 'TAIR10',
#      'id': 'AT4G05180.1.exon2',
#      'db_type': 'core',
#      'seq_region_name': '4',
#      'object_type': 'Exon',
#      'strand': -1,
#      'species': 'arabidopsis_thaliana'},
#     {'end': 2672191,
#      'start': 2671784,
#      'db_type': 'core',
#      'id': 'AT4G05180.2.exon3',
#      'assembly_name': 'TAIR10',
#      'seq_region_name': '4',
#      'object_type': 'Exon',
#      'strand': -1,
#      'species': 'arabidopsis_thaliana'}],
#    'biotype': 'protein_coding',
#    'db_type': 'core',
#    'id': 'AT4G05180.2',
#    'start': 2671784,
#    'logic_name': 'araport11'}],
#  'object_type': 'Gene',
#  'display_name': 'PSBQ2',
#  'source': 'araport11',
#  'strand': -1,
#  'species': 'arabidopsis_thaliana',
#  'description': 'Oxygen-evolving enhancer protein 3-2, chloroplastic [Source:UniProtKB/Swiss-Prot;Acc:Q41932]'}

# %%
#Retrieve Information on gene symbol, location (chromosome, start and end), uniprot id/descriptive name using the ENSEMBL REST API
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/lookup

def lookup_ensembl_id(gene_id):

  #pandas series to hold information
  ds_anno = pd.Series(index=['symbol','chr','start', 'end', 'description'])
  
  #ENSEMBL Server Url
  server = "https://rest.ensembl.org"
  
  #URL specification to get meta-information of a gene by its id
  ext = f"/lookup/id/{gene_id}?expand=1"
  
  #Request information from URL in json format
  r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
  
  #Check if request wad successful
if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

    #Save relevant information in pandas series
    ds_anno['symbol'] = json_anno.get('display_name', None)
    ds_anno['chr'] = json_anno.get('seq_region_name', None)
    ds_anno['start'] = json_anno.get('start', None)
    ds_anno['end'] = json_anno.get('end', None)
    ds_anno['description'] = json_anno.get('description', None)
else:
    #Save set pandas series to None if request was not successfull
    ds_anno['symbol'] = None
    ds_anno['chr'] = None
    ds_anno['start'] = None
    ds_anno['end'] = None
    ds_anno['description'] = None

  #return pandas series
  return ds_anno

# %%
#EXAMPLE REQUEST

#Retrieve Information on cross references for each gene symbol (NCBI gene id)
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/xref_id

gene_id = 'AT4G05180'

#ENSEMBL Server Url
server = "https://rest.ensembl.org"

#URL specification to get meta-information of a gene by its id
ext = f"/xrefs/id/{gene_id}?"
  
#Request information from URL in json format
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})

#Check if request wad successful
if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

    #Convert json to pandas dataframe format to easily retrieve information
    df_anno = pd.DataFrame(json_anno)
    df_anno.set_index('dbname', inplace=True)
  
else:
     df_anno = None

df_anno
# Out:
#                                db_display_name primary_id  \
# dbname
# NASC_GENE_ID                      NASC Gene ID  AT4G05180
# ArrayExpress                  Expression Atlas  AT4G05180
# TAIR_LOCUS                                TAIR  AT4G05180
# TAIR_SYMBOL                     TAIR Gene Name       PSBQ
# UniGene                                UniGene   At.21853
# EntrezGene     NCBI gene (formerly Entrezgene)     825866
# KNETMINER_ARA                    KNETMINER_ARA  AT4G05180
#
#                                         description        display_id  \
# dbname
# NASC_GENE_ID             photosystem II subunit Q-2  AT4G05180-TAIR-G
# ArrayExpress                                                AT4G05180
# TAIR_LOCUS               photosystem II subunit Q-2         AT4G05180
# TAIR_SYMBOL                                                      PSBQ
# UniGene        Oxygen-evolving enhancer protein 3-2          At.21853
# EntrezGene                                     None            825866
# KNETMINER_ARA                                  None         AT4G05180
#
#                                       synonyms version info_text  \
# dbname
# NASC_GENE_ID                                []       0
# ArrayExpress                                []       0
# TAIR_LOCUS                                  []       0
# TAIR_SYMBOL    [PSBQ-1, PSBQ-2, PSBQA, PSII-Q]       0
# UniGene                                     []       0
# EntrezGene                                  []       0
# KNETMINER_ARA                               []       0
#
#                     info_type  ensembl_end  xref_start  ensembl_start  \
# dbname
# NASC_GENE_ID           DIRECT          NaN         NaN            NaN
# ArrayExpress           DIRECT          NaN         NaN            NaN
# TAIR_LOCUS             DIRECT          NaN         NaN            NaN
# TAIR_SYMBOL            DIRECT          NaN         NaN            NaN
# UniGene        SEQUENCE_MATCH       1037.0         1.0            1.0
# EntrezGene          DEPENDENT          NaN         NaN            NaN
# KNETMINER_ARA       DEPENDENT          NaN         NaN            NaN
#
#                ensembl_identity   score  xref_identity cigar_line  evalue  \
# dbname
# NASC_GENE_ID                NaN     NaN            NaN        NaN     NaN
# ArrayExpress                NaN     NaN            NaN        NaN     NaN
# TAIR_LOCUS                  NaN     NaN            NaN        NaN     NaN
# TAIR_SYMBOL                 NaN     NaN            NaN        NaN     NaN
# UniGene                    96.0  5185.0          100.0      1037M     NaN
# EntrezGene                  NaN     NaN            NaN        NaN     NaN
# KNETMINER_ARA               NaN     NaN            NaN        NaN     NaN
#
#                xref_end
# dbname
# NASC_GENE_ID        NaN
# ArrayExpress        NaN
# TAIR_LOCUS          NaN
# TAIR_SYMBOL         NaN
# UniGene          1037.0
# EntrezGene          NaN
# KNETMINER_ARA       NaN

# %%
#Retrieve Information on cross references for each gene symbol (NCBI gene id)
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/xref_id

def xrefs_ensembl_id(gene_id):
  
  #pandas series to hold information
  ds_anno = pd.Series(index=['ncbigene'])
  
  #ENSEMBL Server Url
  server = "https://rest.ensembl.org"
  #URL specification to get meta-information of a gene by its id
  ext = f"/xrefs/id/{gene_id}?"
  
  #Request information from URL in json format
  r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
  
  #Check if request wad successful
  if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

    #Convert json to pandas dataframe format
    df_anno = pd.DataFrame(json_anno)
    df_anno.set_index('dbname', inplace=True)
    
    #Save relevant information in pandas series
    if 'EntrezGene' in df_anno.index:
      if 'primary_id' in df_anno.columns:
        ds_anno['ncbigene'] = str(df_anno.loc['EntrezGene','primary_id'])
  
  else:
     ds_anno['ncbigene'] = None
 
  return ds_anno

# %%
#Request information for each gene using xrefs_ensembl_id() function
df_genes_xref = df_genes_aracore['aracore_ids'].parallel_apply(lambda x: xrefs_ensembl_id(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-a3f59e75c06b> in <module>
#       1 #Request information for each gene using xrefs_ensembl_id() function
# ----> 2 df_genes_xref = df_genes_aracore['aracore_ids'].parallel_apply(lambda x: xrefs_ensembl_id(x))
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'parallel_apply'

# %% [markdown]
# ### 6) Import BiGG genes file

# %% [markdown]
# ### 7) Import ModelSEED genes file

# %% [markdown]
# ## II / Extract the annotations from the AraCore model

# %% [markdown]
# ## III / Extract the id from the annotations we extracted previously (2nd step)

# %% [markdown]
# ## IV / Merge AraCore table with BiGG one
