# %% [markdown]
# # Install missing modules & load modules

# %%
# !pip install cobra #install cobra - only required for google colab
# Out:
# Requirement already satisfied: cobra in /usr/local/lib/python3.7/dist-packages (0.22.0)
# Requirement already satisfied: httpx~=0.14 in /usr/local/lib/python3.7/dist-packages (from cobra) (0.18.1)
# Requirement already satisfied: pandas~=1.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.1.5)
# Requirement already satisfied: depinfo in /usr/local/lib/python3.7/dist-packages (from cobra) (1.7.0)
# Requirement already satisfied: diskcache~=5.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (5.2.1)
# Requirement already satisfied: optlang~=1.5 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.5.2)
# Requirement already satisfied: pydantic~=1.6 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.8.2)
# Requirement already satisfied: python-libsbml==5.19.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (5.19.0)
# Requirement already satisfied: rich>=8.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (10.2.2)
# Requirement already satisfied: ruamel.yaml~=0.16 in /usr/local/lib/python3.7/dist-packages (from cobra) (0.17.7)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from cobra) (0.16.0)
# Requirement already satisfied: swiglpk in /usr/local/lib/python3.7/dist-packages (from cobra) (5.0.3)
# Requirement already satisfied: numpy~=1.13 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.19.5)
# Requirement already satisfied: appdirs~=1.4 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.4.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from cobra) (5.1.3)
# Requirement already satisfied: httpcore<0.14.0,>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (0.13.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (1.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (2020.12.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (1.2.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.0->cobra) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.0->cobra) (2.8.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from depinfo->cobra) (4.0.1)
# Requirement already satisfied: sympy>=1.0 in /usr/local/lib/python3.7/dist-packages (from optlang~=1.5->cobra) (1.7.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from optlang~=1.5->cobra) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pydantic~=1.6->cobra) (3.7.4.3)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (2.6.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (0.9.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (0.4.4)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml~=0.16->cobra) (0.2.2)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-resources->cobra) (3.4.1)
# Requirement already satisfied: h11<0.13,>=0.11 in /usr/local/lib/python3.7/dist-packages (from httpcore<0.14.0,>=0.13.0->httpx~=0.14->cobra) (0.12.0)
# Requirement already satisfied: idna; extra == "idna2008" in /usr/local/lib/python3.7/dist-packages (from rfc3986[idna2008]<2,>=1.3->httpx~=0.14->cobra) (2.10)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.0->optlang~=1.5->cobra) (1.2.1)

# %%
# !pip install pandarallel #install panadarallel - only required for google colab
# Out:
# Requirement already satisfied: pandarallel in /usr/local/lib/python3.7/dist-packages (1.5.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from pandarallel) (0.3.3)

# %%
import pandas as pd
import numpy as np
import cobra
import requests
import sys

# %%
from urllib.error import HTTPError

# %%
#If this doesn't run install pandarallel in your conda enviroment using conda or pip
#https://github.com/nalepae/pandarallel 

from pandarallel import pandarallel 

pandarallel.initialize(progress_bar=True)

from pandarallel.utils import progress_bars
progress_bars.is_notebook_lab = lambda : True
# Out:
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# # Load AraCore Model

# %%
#Get file from github
fileName = 'https://raw.githubusercontent.com/ma-blaetke/CBM_C3_C4_Metabolism/master/data/2018-23-05-mb-genC3.sbml'
r = requests.get(fileName)

# %%
#Create model
model = cobra.io.read_sbml_model(r.text)

# %%
model
# Out:
# <Model c3_model at 0x7faf67589fd0>

# %% [markdown]
# # Create Gene Table for AraCore Model

# %%
#Create mapping table
df_genes_aracore = pd.DataFrame(
    {
        "aracore_ids" : [gene_id.id for gene_id in model.genes],
        "aracore_name" : [gene_id.name for gene_id in model.genes],
        "aracore_annotations" : [gene_id.annotation for gene_id in model.genes]
    })

df_genes_aracore.head(25)
# Out:
#    aracore_ids aracore_name aracore_annotations
# 0    AT4G05180    AT4G05180                  {}
# 1    AT2G30570    AT2G30570                  {}
# 2    ATCG00560    ATCG00560                  {}
# 3    AT4G21280    AT4G21280                  {}
# 4    ATCG00300    ATCG00300                  {}
# 5    AT1G06680    AT1G06680                  {}
# 6    ATCG00080    ATCG00080                  {}
# 7    AT2G06520    AT2G06520                  {}
# 8    AT1G79040    AT1G79040                  {}
# 9    AT5G66570    AT5G66570                  {}
# 10   AT3G21055    AT3G21055                  {}
# 11   ATCG00020    ATCG00020                  {}
# 12   ATCG00270    ATCG00270                  {}
# 13   ATCG00690    ATCG00690                  {}
# 14   ATCG00710    ATCG00710                  {}
# 15   ATCG00550    ATCG00550                  {}
# 16   ATCG00570    ATCG00570                  {}
# 17   AT1G67740    AT1G67740                  {}
# 18   ATCG00580    ATCG00580                  {}
# 19   AT3G50820    AT3G50820                  {}
# 20   ATCG00680    ATCG00680                  {}
# 21   ATCG00280    ATCG00280                  {}
# 22   AT1G44575    AT1G44575                  {}
# 23   ATCG00220    ATCG00220                  {}
# 24   ATCG00700    ATCG00700                  {}

# %%
df_genes_aracore['aracore_ids'].shape[0] #804 genes
# Out:
# 804

# %% [markdown]
# # Retrieve additional information on genes using the ENSEMBL API

# %%
#EXAMPLE REQUEST:

#Retrieve Information on gene symbol, location (chromosome, start and end), uniprot id/descriptive name using the ENSEMBL REST API
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/lookup

gene_id = 'AT4G05180'

#ENSEMBL Server Url
server = "https://rest.ensembl.org"

#URL specification to get meta-information of a gene by its id
ext = f"/lookup/id/{gene_id}?expand=1"
  
#Request information from URL in json format
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})

#Check if request wad successful
if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

else:

    json_anno = None

json_anno
# Out:
# {'Transcript': [{'Exon': [{'assembly_name': 'TAIR10',
#      'db_type': 'core',
#      'end': 2673243,
#      'id': 'AT4G05180.1.exon1',
#      'object_type': 'Exon',
#      'seq_region_name': '4',
#      'species': 'arabidopsis_thaliana',
#      'start': 2672873,
#      'strand': -1},
#     {'assembly_name': 'TAIR10',
#      'db_type': 'core',
#      'end': 2672635,
#      'id': 'AT4G05180.1.exon2',
#      'object_type': 'Exon',
#      'seq_region_name': '4',
#      'species': 'arabidopsis_thaliana',
#      'start': 2672340,
#      'strand': -1},
#     {'assembly_name': 'TAIR10',
#      'db_type': 'core',
#      'end': 2672191,
#      'id': 'AT4G05180.1.exon3',
#      'object_type': 'Exon',
#      'seq_region_name': '4',
#      'species': 'arabidopsis_thaliana',
#      'start': 2671900,
#      'strand': -1},
#     {'assembly_name': 'TAIR10',
#      'db_type': 'core',
#      'end': 2671718,
#      'id': 'AT4G05180.1.exon4',
#      'object_type': 'Exon',
#      'seq_region_name': '4',
#      'species': 'arabidopsis_thaliana',
#      'start': 2671523,
#      'strand': -1}],
#    'Parent': 'AT4G05180',
#    'Translation': {'Parent': 'AT4G05180.1',
#     'db_type': 'core',
#     'end': 2673170,
#     'id': 'AT4G05180.1',
#     'length': 230,
#     'object_type': 'Translation',
#     'species': 'arabidopsis_thaliana',
#     'start': 2672093},
#    'assembly_name': 'TAIR10',
#    'biotype': 'protein_coding',
#    'db_type': 'core',
#    'end': 2673243,
#    'id': 'AT4G05180.1',
#    'is_canonical': 1,
#    'logic_name': 'araport11',
#    'object_type': 'Transcript',
#    'seq_region_name': '4',
#    'source': 'araport11',
#    'species': 'arabidopsis_thaliana',
#    'start': 2671523,
#    'strand': -1},
#   {'Exon': [{'assembly_name': 'TAIR10',
#      'db_type': 'core',
#      'end': 2673243,
#      'id': 'AT4G05180.1.exon1',
#      'object_type': 'Exon',
#      'seq_region_name': '4',
#      'species': 'arabidopsis_thaliana',
#      'start': 2672873,
#      'strand': -1},
#     {'assembly_name': 'TAIR10',
#      'db_type': 'core',
#      'end': 2672635,
#      'id': 'AT4G05180.1.exon2',
#      'object_type': 'Exon',
#      'seq_region_name': '4',
#      'species': 'arabidopsis_thaliana',
#      'start': 2672340,
#      'strand': -1},
#     {'assembly_name': 'TAIR10',
#      'db_type': 'core',
#      'end': 2672191,
#      'id': 'AT4G05180.2.exon3',
#      'object_type': 'Exon',
#      'seq_region_name': '4',
#      'species': 'arabidopsis_thaliana',
#      'start': 2671784,
#      'strand': -1}],
#    'Parent': 'AT4G05180',
#    'Translation': {'Parent': 'AT4G05180.2',
#     'db_type': 'core',
#     'end': 2673170,
#     'id': 'AT4G05180.2',
#     'length': 230,
#     'object_type': 'Translation',
#     'species': 'arabidopsis_thaliana',
#     'start': 2672093},
#    'assembly_name': 'TAIR10',
#    'biotype': 'protein_coding',
#    'db_type': 'core',
#    'end': 2673243,
#    'id': 'AT4G05180.2',
#    'is_canonical': 0,
#    'logic_name': 'araport11',
#    'object_type': 'Transcript',
#    'seq_region_name': '4',
#    'source': 'araport11',
#    'species': 'arabidopsis_thaliana',
#    'start': 2671784,
#    'strand': -1}],
#  'assembly_name': 'TAIR10',
#  'biotype': 'protein_coding',
#  'db_type': 'core',
#  'description': 'Oxygen-evolving enhancer protein 3-2, chloroplastic [Source:UniProtKB/Swiss-Prot;Acc:Q41932]',
#  'display_name': 'PSBQ2',
#  'end': 2673243,
#  'id': 'AT4G05180',
#  'logic_name': 'araport11',
#  'object_type': 'Gene',
#  'seq_region_name': '4',
#  'source': 'araport11',
#  'species': 'arabidopsis_thaliana',
#  'start': 2671523,
#  'strand': -1}

# %%
#Retrieve Information on gene symbol, location (chromosome, start and end), uniprot id/descriptive name using the ENSEMBL REST API
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/lookup

def lookup_ensembl_id(gene_id):

  #pandas series to hold information
  ds_anno = pd.Series(index=['symbol','chr','start', 'end', 'description'])
  
  #ENSEMBL Server Url
  server = "https://rest.ensembl.org"
  
  #URL specification to get meta-information of a gene by its id
  ext = f"/lookup/id/{gene_id}?expand=1"
  
  #Request information from URL in json format
  r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
  
  #Check if request wad successful
  if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

    #Save relevant information in pandas series
    ds_anno['symbol'] = json_anno.get('display_name', None)
    ds_anno['chr'] = json_anno.get('seq_region_name', None)
    ds_anno['start'] = json_anno.get('start', None)
    ds_anno['end'] = json_anno.get('end', None)
    ds_anno['description'] = json_anno.get('description', None)
  else:
    #Save set pandas series to None if request was not successfull
    ds_anno['symbol'] = None
    ds_anno['chr'] = None
    ds_anno['start'] = None
    ds_anno['end'] = None
    ds_anno['description'] = None

  #return pandas series
  return ds_anno

# %%
#EXAMPLE REQUEST

#Retrieve Information on cross references for each gene symbol (NCBI gene id)
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/xref_id

gene_id = 'AT4G05180'

#ENSEMBL Server Url
server = "https://rest.ensembl.org"

#URL specification to get meta-information of a gene by its id
ext = f"/xrefs/id/{gene_id}?"
  
#Request information from URL in json format
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})

#Check if request wad successful
if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

    #Convert json to pandas dataframe format to easily retrieve information
    df_anno = pd.DataFrame(json_anno)
    df_anno.set_index('dbname', inplace=True)
  
else:
     df_anno = None

df_anno
# Out:
#                     info_type version info_text  ... xref_end cigar_line evalue
# dbname                                           ...
# NASC_GENE_ID           DIRECT       0            ...      NaN        NaN    NaN
# ArrayExpress           DIRECT       0            ...      NaN        NaN    NaN
# TAIR_LOCUS             DIRECT       0            ...      NaN        NaN    NaN
# TAIR_SYMBOL            DIRECT       0            ...      NaN        NaN    NaN
# UniGene        SEQUENCE_MATCH       0            ...   1037.0      1037M    NaN
# EntrezGene          DEPENDENT       0            ...      NaN        NaN    NaN
# KNETMINER_ARA       DEPENDENT       0            ...      NaN        NaN    NaN
#
# [7 rows x 17 columns]

# %%
#Retrieve Information on cross references for each gene symbol (NCBI gene id)
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/xref_id

def xrefs_ensembl_id(gene_id):
  
  #pandas series to hold information
  ds_anno = pd.Series(index=['ncbigene'])
  
  #ENSEMBL Server Url
  server = "https://rest.ensembl.org"
  #URL specification to get meta-information of a gene by its id
  ext = f"/xrefs/id/{gene_id}?"
  
  #Request information from URL in json format
  r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
  
  #Check if request wad successful
  if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

    #Convert json to pandas dataframe format
    df_anno = pd.DataFrame(json_anno)
    df_anno.set_index('dbname', inplace=True)
    
    #Save relevant information in pandas series
    if 'EntrezGene' in df_anno.index:
      if 'primary_id' in df_anno.columns:
        ds_anno['ncbigene'] = str(df_anno.loc['EntrezGene','primary_id'])
  
  else:
     ds_anno['ncbigene'] = None
 
  return ds_anno

# %%
#Request information for each gene using xrefs_ensembl_id() function
df_genes_xref = df_genes_aracore['aracore_ids'].parallel_apply(lambda x: xrefs_ensembl_id(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=402), Label(value='0 / 402'))), HB…

# %%
#Request information for each gene using lookup_ensembl_id() function
df_genes_lookup = df_genes_aracore['aracore_ids'].parallel_apply(lambda x: lookup_ensembl_id(x)) #This may take a few minutes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=402), Label(value='0 / 402'))), HB…

# %% [markdown]
# # Merge information into a single mapping table

# %%
#Concat dataframe df_genes_aracore, df_genes_lookup, df_genes_xref
df_genes_aracore = pd.concat([df_genes_aracore, df_genes_lookup, df_genes_xref], axis=1) 
df_genes_aracore
# Out:
#     aracore_ids  ... ncbigene
# 0     AT4G05180  ...   825866
# 1     AT2G30570  ...   817606
# 2     ATCG00560  ...   844751
# 3     AT4G21280  ...   827877
# 4     ATCG00300  ...   844774
# ..          ...  ...      ...
# 799   AT3G27620  ...   822384
# 800   AT5G64210  ...   836542
# 801   AT1G32350  ...   840127
# 802   AT3G22360  ...   821805
# 803   AT4G22260  ...   828321
#
# [804 rows x 9 columns]

# %%
#Seperate descriptive name from uniprot symbol by first appearance of "[", expand in to two columns
#e.g. "Oxygen-evolving enhancer protein 3-2, chloroplastic [Source:UniProtKB/Swiss-Prot;Acc:Q41932]" -> "Oxygen-evolving enhancer protein 3-2, chloroplastic" & Source:UniProtKB/Swiss-Prot;Acc:Q41932]

df_name_uniprot = df_genes_aracore['description'].str.split('[', 1, expand=True,) 
df_name_uniprot
# Out:
#                                                      0                                        1
# 0    Oxygen-evolving enhancer protein 3-2, chloropl...  Source:UniProtKB/Swiss-Prot;Acc:Q41932]
# 1                                                PSBW   Source:UniProtKB/TrEMBL;Acc:A0A178VQ32]
# 2            Photosystem II reaction center protein L   Source:UniProtKB/Swiss-Prot;Acc:P60129]
# 3    Oxygen-evolving enhancer protein 3-1, chloropl...  Source:UniProtKB/Swiss-Prot;Acc:Q9XFT3]
# 4            Photosystem II reaction center protein Z   Source:UniProtKB/TrEMBL;Acc:A0A1B1W4U3]
# ..                                                 ...                                      ...
# 799               Ubiquinol oxidase 1c, mitochondrial   Source:UniProtKB/Swiss-Prot;Acc:O22048]
# 800                Ubiquinol oxidase 2, mitochondrial   Source:UniProtKB/Swiss-Prot;Acc:O22049]
# 801                                             AOX1D   Source:UniProtKB/TrEMBL;Acc:A0A384LFI3]
# 802               Ubiquinol oxidase 1b, mitochondrial   Source:UniProtKB/Swiss-Prot;Acc:O23913]
# 803  Ubiquinol oxidase 4, chloroplastic/chromoplastic   Source:UniProtKB/Swiss-Prot;Acc:Q56X52]
#
# [804 rows x 2 columns]

# %%
#Merge with df_genes_aracore
df_genes_aracore = pd.concat([df_genes_aracore, df_name_uniprot], axis=1) 

#rename columns
df_genes_aracore.rename(columns={0: 'gene_name', 1: 'uniprot_id'}, inplace=True)
df_genes_aracore
# Out:
#     aracore_ids  ...                                        1
# 0     AT4G05180  ...  Source:UniProtKB/Swiss-Prot;Acc:Q41932]
# 1     AT2G30570  ...  Source:UniProtKB/TrEMBL;Acc:A0A178VQ32]
# 2     ATCG00560  ...  Source:UniProtKB/Swiss-Prot;Acc:P60129]
# 3     AT4G21280  ...  Source:UniProtKB/Swiss-Prot;Acc:Q9XFT3]
# 4     ATCG00300  ...  Source:UniProtKB/TrEMBL;Acc:A0A1B1W4U3]
# ..          ...  ...                                      ...
# 799   AT3G27620  ...  Source:UniProtKB/Swiss-Prot;Acc:O22048]
# 800   AT5G64210  ...  Source:UniProtKB/Swiss-Prot;Acc:O22049]
# 801   AT1G32350  ...  Source:UniProtKB/TrEMBL;Acc:A0A384LFI3]
# 802   AT3G22360  ...  Source:UniProtKB/Swiss-Prot;Acc:O23913]
# 803   AT4G22260  ...  Source:UniProtKB/Swiss-Prot;Acc:Q56X52]
#
# [804 rows x 11 columns]

# %%
#Extract Uniprot id by splitting on last appearance of ':', expand columns, but only keep the last column for the uniprot id, the rest is trash
#e.g. Source:UniProtKB/Swiss-Prot;Acc:Q41932] -> "Source:UniProtKB/Swiss-Prot;Acc" & "Q41932]"
df_genes_aracore['uniprot_id'] = df_genes_aracore['uniprot_id'].str.rsplit(':',1,expand=True).iloc[:,-1]

#Remove closing "]" from uniprot id 
#e.g. "Q41932]" -> "Q41932"
df_genes_aracore['uniprot_id'] = df_genes_aracore['uniprot_id'].apply(lambda x: x[:-1] if isinstance(x,str) else None)
df_genes_aracore

# %%
df_genes_aracore
# Out:
#     aracore_ids  ...  uniprot_id
# 0     AT4G05180  ...      Q41932
# 1     AT2G30570  ...  A0A178VQ32
# 2     ATCG00560  ...      P60129
# 3     AT4G21280  ...      Q9XFT3
# 4     ATCG00300  ...  A0A1B1W4U3
# ..          ...  ...         ...
# 799   AT3G27620  ...      O22048
# 800   AT5G64210  ...      O22049
# 801   AT1G32350  ...  A0A384LFI3
# 802   AT3G22360  ...      O23913
# 803   AT4G22260  ...      Q56X52
#
# [804 rows x 11 columns]

# %%
df_genes_aracore[df_genes_aracore.isna().sum(axis=1) == 8] #2 Genes have no annotations at all -> Look-up those genes, maybe the Gene ids are wrong!?!
# Out:
#     aracore_ids aracore_name aracore_annotations  ... ncbigene gene_name  uniprot_id
# 683   AT5G34920    AT5G34920                  {}  ...      NaN       NaN        None
# 721  AT3G600180   AT3G600180                  {}  ...      NaN       NaN        None
#
# [2 rows x 11 columns]

# %%
df_genes_aracore[df_genes_aracore['ncbigene'].isna()] # ~28 genes without NCBI Symbol
# Out:
#     aracore_ids  ... uniprot_id
# 43    ATCG00890  ...  ATCG00890
# 58    ATCG01050  ...  ATCG01050
# 181   AT1G17000  ...  AT1G17000
# 306   ATMG00510  ...     G1C2X4
# 307   ATMG00580  ...     G1C2U9
# 308   ATMG00060  ...  ATMG00060
# 309   ATMG00070  ...  ATMG00070
# 310   ATMG01275  ...  ATMG01275
# 311   ATMG00285  ...  ATMG00285
# 314   ATMG00270  ...     G1C2Y0
# 315   ATMG00665  ...  ATMG00665
# 318   ATMG01120  ...  ATMG01120
# 319   ATMG00513  ...  ATMG00513
# 320   ATMG01320  ...  ATMG01320
# 322   ATMG00516  ...  ATMG00516
# 323   ATMG00650  ...     G1C2W6
# 324   ATMG00990  ...     G1C2Y6
# 343   ATMG00730  ...  ATMG00730
# 346   ATMG00160  ...     G1C2Q7
# 347   ATMG01360  ...     P60620
# 355   AT5G08670  ...  AT5G08670
# 356   ATMG01170  ...     G1C2S8
# 364   ATMG01190  ...     G1C2Z0
# 367   ATMG00640  ...  ATMG00640
# 426   AT1G32480  ...  AT1G32480
# 683   AT5G34920  ...       None
# 721  AT3G600180  ...       None
# 794   AT5G08740  ...  AT5G08740
#
# [28 rows x 11 columns]

# %%
df_genes_aracore[df_genes_aracore['symbol'].isna()].head(100) # 97 genes have no official gene #symbol
# Out:
#     aracore_ids  ...  uniprot_id
# 30    AT2G26500  ...      O48717
# 94    AT5G38410  ...      B3H5S2
# 98    AT1G56190  ...  A0A178W4Q1
# 116   AT5G44520  ...   AT5G44520
# 143   AT4G26520  ...   AT4G26520
# ..          ...  ...         ...
# 721  AT3G600180  ...        None
# 732   AT4G13720  ...   AT4G13720
# 735   AT4G23895  ...      F4JPD8
# 774   AT4G05590  ...   AT4G05590
# 784   AT2G32040  ...      Q9SKZ5
#
# [97 rows x 11 columns]

# %%
df_genes_aracore[df_genes_aracore['uniprot_id'].isna()] #2 genes have no uniprot id (same as above)
# Out:
#     aracore_ids aracore_name aracore_annotations  ... ncbigene gene_name  uniprot_id
# 683   AT5G34920    AT5G34920                  {}  ...      NaN       NaN        None
# 721  AT3G600180   AT3G600180                  {}  ...      NaN       NaN        None
#
# [2 rows x 11 columns]

# %%
#Export final mapping table for manual mapping
df_genes_aracore.to_csv('drive/MyDrive/2021-05-27-genes-mapping-table.csv')
