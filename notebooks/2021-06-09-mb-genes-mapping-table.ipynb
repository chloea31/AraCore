# %% [markdown]
# # Creating genes mapping table

# %% [markdown]
# # I / Install missing modules & load modules

# %%
import pandas as pd
import numpy as np
import cobra
import requests
import sys

# %%
from urllib.error import HTTPError

# %%
#If this doesn't run install pandarallel in your conda enviroment using conda or pip
#https://github.com/nalepae/pandarallel 

# => Problem to install pandarallel => seems to work with Python version 3.{5, 6, 7, 8}, not 3.9
# => Create a new environment containing the same packages, but changing the version of Python : Python 3.8
# Then, try to install pandarallel

# => For this gene mapping, use the environment named env_aracore_update_gene_mapping => same problem
# same problem for all the versions of python...

from pandarallel import pandarallel 

pandarallel.initialize(progress_bar=True)

from pandarallel.utils import progress_bars
progress_bars.is_notebook_lab = lambda : True
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# # II / Load AraCore model

# %%
#Get file from github
fileName = 'https://raw.githubusercontent.com/ma-blaetke/CBM_C3_C4_Metabolism/master/data/2018-23-05-mb-genC3.sbml'
r = requests.get(fileName)

# %%
#Create model
model = cobra.io.read_sbml_model(r.text)

# %%
model
# Out:
# <Model c3_model at 0x7f427cd6d550>

# %% [markdown]
# # III / Create Gene Table for AraCore Model

# %%
#Create mapping table
df_genes_aracore = pd.DataFrame(
    {
        "aracore_ids" : [gene_id.id for gene_id in model.genes],
        "aracore_name" : [gene_id.name for gene_id in model.genes],
        "aracore_annotations" : [gene_id.annotation for gene_id in model.genes]
    })

df_genes_aracore.head(25)
# Out:
#    aracore_ids aracore_name aracore_annotations
# 0    AT4G05180    AT4G05180                  {}
# 1    AT2G30570    AT2G30570                  {}
# 2    ATCG00560    ATCG00560                  {}
# 3    AT4G21280    AT4G21280                  {}
# 4    ATCG00300    ATCG00300                  {}
# 5    AT1G06680    AT1G06680                  {}
# 6    ATCG00080    ATCG00080                  {}
# 7    AT2G06520    AT2G06520                  {}
# 8    AT1G79040    AT1G79040                  {}
# 9    AT5G66570    AT5G66570                  {}
# 10   AT3G21055    AT3G21055                  {}
# 11   ATCG00020    ATCG00020                  {}
# 12   ATCG00270    ATCG00270                  {}
# 13   ATCG00690    ATCG00690                  {}
# 14   ATCG00710    ATCG00710                  {}
# 15   ATCG00550    ATCG00550                  {}
# 16   ATCG00570    ATCG00570                  {}
# 17   AT1G67740    AT1G67740                  {}
# 18   ATCG00580    ATCG00580                  {}
# 19   AT3G50820    AT3G50820                  {}
# 20   ATCG00680    ATCG00680                  {}
# 21   ATCG00280    ATCG00280                  {}
# 22   AT1G44575    AT1G44575                  {}
# 23   ATCG00220    ATCG00220                  {}
# 24   ATCG00700    ATCG00700                  {}

# %%
df_genes_aracore['aracore_ids'].shape[0] #804 genes
# Out:
# 804

# %% [markdown]
# # IV / Retrieve additional information on genes using the ENSEMBL API

# %% [markdown]
# **ENSEMBL** is a database that provides information about **genomic features**. It contains the IDs and the symbol of the genes, as well as the species.

# %%
#EXAMPLE REQUEST:

#Retrieve Information on gene symbol, location (chromosome, start and end), uniprot id/descriptive name using the ENSEMBL REST API
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/lookup

gene_id = 'AT4G05180'

#ENSEMBL Server Url
server = "https://rest.ensembl.org"

#URL specification to get meta-information of a gene by its id
ext = f"/lookup/id/{gene_id}?expand=1"
  
#Request information from URL in json format
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})

#Check if request wad successful
if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json()

else:

    json_anno = None

json_anno
# Out:
# {'strand': -1,
#  'start': 2671523,
#  'species': 'arabidopsis_thaliana',
#  'description': 'Oxygen-evolving enhancer protein 3-2, chloroplastic [Source:UniProtKB/Swiss-Prot;Acc:Q41932]',
#  'object_type': 'Gene',
#  'display_name': 'PSBQ2',
#  'Transcript': [{'assembly_name': 'TAIR10',
#    'biotype': 'protein_coding',
#    'end': 2673243,
#    'source': 'araport11',
#    'is_canonical': 1,
#    'db_type': 'core',
#    'Parent': 'AT4G05180',
#    'Translation': {'end': 2673170,
#     'id': 'AT4G05180.1',
#     'length': 230,
#     'db_type': 'core',
#     'Parent': 'AT4G05180.1',
#     'object_type': 'Translation',
#     'start': 2672093,
#     'species': 'arabidopsis_thaliana'},
#    'species': 'arabidopsis_thaliana',
#    'start': 2671523,
#    'strand': -1,
#    'seq_region_name': '4',
#    'Exon': [{'end': 2673243,
#      'id': 'AT4G05180.1.exon1',
#      'assembly_name': 'TAIR10',
#      'seq_region_name': '4',
#      'db_type': 'core',
#      'strand': -1,
#      'start': 2672873,
#      'species': 'arabidopsis_thaliana',
#      'object_type': 'Exon'},
#     {'assembly_name': 'TAIR10',
#      'seq_region_name': '4',
#      'end': 2672635,
#      'id': 'AT4G05180.1.exon2',
#      'db_type': 'core',
#      'object_type': 'Exon',
#      'start': 2672340,
#      'strand': -1,
#      'species': 'arabidopsis_thaliana'},
#     {'object_type': 'Exon',
#      'strand': -1,
#      'start': 2671900,
#      'species': 'arabidopsis_thaliana',
#      'db_type': 'core',
#      'end': 2672191,
#      'id': 'AT4G05180.1.exon3',
#      'assembly_name': 'TAIR10',
#      'seq_region_name': '4'},
#     {'start': 2671523,
#      'strand': -1,
#      'species': 'arabidopsis_thaliana',
#      'object_type': 'Exon',
#      'db_type': 'core',
#      'end': 2671718,
#      'id': 'AT4G05180.1.exon4',
#      'assembly_name': 'TAIR10',
#      'seq_region_name': '4'}],
#    'id': 'AT4G05180.1',
#    'logic_name': 'araport11',
#    'object_type': 'Transcript'},
#   {'Exon': [{'species': 'arabidopsis_thaliana',
#      'strand': -1,
#      'start': 2672873,
#      'object_type': 'Exon',
#      'assembly_name': 'TAIR10',
#      'seq_region_name': '4',
#      'id': 'AT4G05180.1.exon1',
#      'end': 2673243,
#      'db_type': 'core'},
#     {'end': 2672635,
#      'id': 'AT4G05180.1.exon2',
#      'assembly_name': 'TAIR10',
#      'seq_region_name': '4',
#      'db_type': 'core',
#      'start': 2672340,
#      'strand': -1,
#      'species': 'arabidopsis_thaliana',
#      'object_type': 'Exon'},
#     {'seq_region_name': '4',
#      'assembly_name': 'TAIR10',
#      'id': 'AT4G05180.2.exon3',
#      'end': 2672191,
#      'db_type': 'core',
#      'object_type': 'Exon',
#      'strand': -1,
#      'start': 2671784,
#      'species': 'arabidopsis_thaliana'}],
#    'id': 'AT4G05180.2',
#    'seq_region_name': '4',
#    'logic_name': 'araport11',
#    'object_type': 'Transcript',
#    'is_canonical': 0,
#    'source': 'araport11',
#    'end': 2673243,
#    'assembly_name': 'TAIR10',
#    'biotype': 'protein_coding',
#    'Parent': 'AT4G05180',
#    'db_type': 'core',
#    'start': 2671784,
#    'species': 'arabidopsis_thaliana',
#    'strand': -1,
#    'Translation': {'length': 230,
#     'id': 'AT4G05180.2',
#     'end': 2673170,
#     'Parent': 'AT4G05180.2',
#     'db_type': 'core',
#     'start': 2672093,
#     'species': 'arabidopsis_thaliana',
#     'object_type': 'Translation'}}],
#  'assembly_name': 'TAIR10',
#  'biotype': 'protein_coding',
#  'seq_region_name': '4',
#  'id': 'AT4G05180',
#  'source': 'araport11',
#  'end': 2673243,
#  'logic_name': 'araport11',
#  'db_type': 'core'}

# %%
#Retrieve Information on gene symbol, location (chromosome, start and end), uniprot id/descriptive name using the ENSEMBL REST API
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/lookup

def lookup_ensembl_id(gene_id):

    #pandas series to hold information
    ds_anno = pd.Series(index=['symbol','chr','start', 'end', 'description'])
  
    #ENSEMBL Server Url
    server = "https://rest.ensembl.org"
  
    #URL specification to get meta-information of a gene by its id
    ext = f"/lookup/id/{gene_id}?expand=1"
  
  #Request information from URL in json format
    r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
  
  #Check if request wad successful
    if r.ok:
    
        #Get json (dictionary-like structure) from request
        json_anno = r.json()

        #Save relevant information in pandas series
        ds_anno['symbol'] = json_anno.get('display_name', None)
        ds_anno['chr'] = json_anno.get('seq_region_name', None)
        ds_anno['start'] = json_anno.get('start', None)
        ds_anno['end'] = json_anno.get('end', None)
        ds_anno['description'] = json_anno.get('description', None)
    else:
        #Save set pandas series to None if request was not successfull
        ds_anno['symbol'] = None
        ds_anno['chr'] = None
        ds_anno['start'] = None
        ds_anno['end'] = None
        ds_anno['description'] = None

    #return pandas series
    return ds_anno

# %%
#EXAMPLE REQUEST

#Retrieve Information on cross references for each gene symbol (NCBI gene id)
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/xref_id

gene_id = 'AT4G05180'

#ENSEMBL Server Url
server = "https://rest.ensembl.org"

#URL specification to get meta-information of a gene by its id
ext = f"/xrefs/id/{gene_id}?"
  
#Request information from URL in json format
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})

#Check if request was successful
if r.ok:
    
    #Get json (dictionary-like structure) from request
    json_anno = r.json() # json format file for annotations containing r variable content

    #Convert json to pandas dataframe format to easily retrieve information
    df_anno = pd.DataFrame(json_anno) # dataframe containing annotations
    df_anno.set_index('dbname', inplace=True) # delete the index on the left of the dataframe
else:
     df_anno = None

df_anno
# Out:
#                                db_display_name  \
# dbname
# NASC_GENE_ID                      NASC Gene ID
# ArrayExpress                  Expression Atlas
# TAIR_LOCUS                                TAIR
# TAIR_SYMBOL                     TAIR Gene Name
# UniGene                                UniGene
# EntrezGene     NCBI gene (formerly Entrezgene)
# KNETMINER_ARA                    KNETMINER_ARA
#
#                                       synonyms version info_text primary_id  \
# dbname
# NASC_GENE_ID                                []       0            AT4G05180
# ArrayExpress                                []       0            AT4G05180
# TAIR_LOCUS                                  []       0            AT4G05180
# TAIR_SYMBOL    [PSBQ-1, PSBQ-2, PSBQA, PSII-Q]       0                 PSBQ
# UniGene                                     []       0             At.21853
# EntrezGene                                  []       0               825866
# KNETMINER_ARA                               []       0            AT4G05180
#
#                      display_id       info_type  \
# dbname
# NASC_GENE_ID   AT4G05180-TAIR-G          DIRECT
# ArrayExpress          AT4G05180          DIRECT
# TAIR_LOCUS            AT4G05180          DIRECT
# TAIR_SYMBOL                PSBQ          DIRECT
# UniGene                At.21853  SEQUENCE_MATCH
# EntrezGene               825866       DEPENDENT
# KNETMINER_ARA         AT4G05180       DEPENDENT
#
#                                         description  xref_end  xref_identity  \
# dbname
# NASC_GENE_ID             photosystem II subunit Q-2       NaN            NaN
# ArrayExpress                                              NaN            NaN
# TAIR_LOCUS               photosystem II subunit Q-2       NaN            NaN
# TAIR_SYMBOL                                               NaN            NaN
# UniGene        Oxygen-evolving enhancer protein 3-2    1037.0          100.0
# EntrezGene                                     None       NaN            NaN
# KNETMINER_ARA                                  None       NaN            NaN
#
#                ensembl_end  ensembl_identity   score  xref_start  evalue  \
# dbname
# NASC_GENE_ID           NaN               NaN     NaN         NaN     NaN
# ArrayExpress           NaN               NaN     NaN         NaN     NaN
# TAIR_LOCUS             NaN               NaN     NaN         NaN     NaN
# TAIR_SYMBOL            NaN               NaN     NaN         NaN     NaN
# UniGene             1037.0              96.0  5185.0         1.0     NaN
# EntrezGene             NaN               NaN     NaN         NaN     NaN
# KNETMINER_ARA          NaN               NaN     NaN         NaN     NaN
#
#               cigar_line  ensembl_start
# dbname
# NASC_GENE_ID         NaN            NaN
# ArrayExpress         NaN            NaN
# TAIR_LOCUS           NaN            NaN
# TAIR_SYMBOL          NaN            NaN
# UniGene            1037M            1.0
# EntrezGene           NaN            NaN
# KNETMINER_ARA        NaN            NaN

# %%
#Retrieve Information on cross references for each gene symbol (NCBI gene id)
#https://rest.ensembl.org/
#https://rest.ensembl.org/documentation/info/xref_id

def xrefs_ensembl_id(gene_id):
  
  #pandas series to hold information
    ds_anno = pd.Series(index=['ncbigene'])
  
  #ENSEMBL Server Url
    server = "https://rest.ensembl.org"
  #URL specification to get meta-information of a gene by its id
    ext = f"/xrefs/id/{gene_id}?"
  
  #Request information from URL in json format
    r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
  
  #Check if request wad successful
    if r.ok:
    
    #Get json (dictionary-like structure) from request
        json_anno = r.json()

        #Convert json to pandas dataframe format
        df_anno = pd.DataFrame(json_anno)
        df_anno.set_index('dbname', inplace=True)

        #Save relevant information in pandas series
        if 'EntrezGene' in df_anno.index:
              if 'primary_id' in df_anno.columns:
                    ds_anno['ncbigene'] = str(df_anno.loc['EntrezGene','primary_id'])

    else:
        ds_anno['ncbigene'] = None
 
    return ds_anno

# %%
#Request information for each gene using xrefs_ensembl_id() function
df_genes_xref = df_genes_aracore['aracore_ids'].parallel_apply(lambda x: xrefs_ensembl_id(x))
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-13-a3f59e75c06b> in <module>
#       1 #Request information for each gene using xrefs_ensembl_id() function
# ----> 2 df_genes_xref = df_genes_aracore['aracore_ids'].parallel_apply(lambda x: xrefs_ensembl_id(x))
#
# ~/miniconda3/envs/env_aracore_update_gene_mapping/lib/python3.8/site-packages/pandarallel/pandarallel.py in closure(data, func, *args, **kwargs)
#     424         queue = manager.Queue()
#     425
# --> 426         workers_args, chunk_lengths, input_files, output_files = get_workers_args(
#     427             use_memory_fs,
#     428             nb_requested_workers,
#
# ~/miniconda3/envs/env_aracore_update_gene_mapping/lib/python3.8/site-packages/pandarallel/pandarallel.py in get_workers_args(use_memory_fs, nb_workers, progress_bar, chunks, worker_meta_args, queue, func, args, kwargs)
#     279             raise OSError(msg)
#     280
# --> 281         workers_args = [
#     282             (
#     283                 input_file.name,
#
# ~/miniconda3/envs/env_aracore_update_gene_mapping/lib/python3.8/site-packages/pandarallel/pandarallel.py in <listcomp>(.0)
#     288                 progress_bar == PROGRESS_IN_WORKER,
#     289                 dill.dumps(
# --> 290                     progress_wrapper(
#     291                         progress_bar >= PROGRESS_IN_FUNC, queue, index, chunk_length
#     292                     )(func)
#
# ~/miniconda3/envs/env_aracore_update_gene_mapping/lib/python3.8/site-packages/pandarallel/pandarallel.py in wrapper(func)
#     198     def wrapper(func):
#     199         if progress_bar:
# --> 200             wrapped_func = inline(
#     201                 progress_pre_func,
#     202                 func,
#
# ~/miniconda3/envs/env_aracore_update_gene_mapping/lib/python3.8/site-packages/pandarallel/utils/inliner.py in wrapper(*args, **kwargs)
#      30         python_version = sys.version_info
#      31         if not (python_version.major == 3 and python_version.minor in (5, 6, 7)):
# ---> 32             raise SystemError("Python version should be 3.{5, 6, 7}")
#      33
#      34         return function(*args, **kwargs)
#
# SystemError: Python version should be 3.{5, 6, 7}

# %% [markdown]
# **Concerning the cell below**:
#
# We write a REQUEST, which contains the URL of the ENSEMBL gene ID, and the Output format, under the following form :
# REQUEST(URL, Output format)
#
# This URL is constituted into 2 parts:
# - the base of the URL, which refers to the database ENSEMBL
# - the keywords, which will be translated into MySQL
#
# These 2 parts of the REQUEST are together converted into the Output format.
#
# This Output format is JSON, similar to a dictionary in Python.

# %%
#Request information for each gene using lookup_ensembl_id() function
df_genes_lookup = df_genes_aracore['aracore_ids'].parallel_apply(lambda x: lookup_ensembl_id(x)) #This may take a few minutes

# %% [markdown]
# # V / Merge information into a single mapping table

# %%
#Concat dataframe df_genes_aracore, df_genes_lookup, df_genes_xref
df_genes_aracore = pd.concat([df_genes_aracore, df_genes_lookup, df_genes_xref], axis=1) 
df_genes_aracore
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-60aae18e7ced> in <module>
#       1 #Concat dataframe df_genes_aracore, df_genes_lookup, df_genes_xref
# ----> 2 df_genes_aracore = pd.concat([df_genes_aracore, df_genes_lookup, df_genes_xref], axis=1)
#       3 df_genes_aracore
#
# NameError: name 'df_genes_lookup' is not defined

# %%
#Seperate descriptive name from uniprot symbol by first appearance of "[", expand in to two columns
#e.g. "Oxygen-evolving enhancer protein 3-2, chloroplastic [Source:UniProtKB/Swiss-Prot;Acc:Q41932]" -> "Oxygen-evolving enhancer protein 3-2, chloroplastic" & Source:UniProtKB/Swiss-Prot;Acc:Q41932]

df_name_uniprot = df_genes_aracore['description'].str.split('[', 1, expand=True,) 
df_name_uniprot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'description'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-0df3ce687e44> in <module>
#       2 #e.g. "Oxygen-evolving enhancer protein 3-2, chloroplastic [Source:UniProtKB/Swiss-Prot;Acc:Q41932]" -> "Oxygen-evolving enhancer protein 3-2, chloroplastic" & Source:UniProtKB/Swiss-Prot;Acc:Q41932]
#       3
# ----> 4 df_name_uniprot = df_genes_aracore['description'].str.split('[', 1, expand=True,)
#       5 df_name_uniprot
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'description'

# %%
#Merge with df_genes_aracore
df_genes_aracore = pd.concat([df_genes_aracore, df_name_uniprot], axis=1) 

#rename columns
df_genes_aracore.rename(columns={0: 'gene_name', 1: 'uniprot_id'}, inplace=True)
df_genes_aracore
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b3b832ebccf2> in <module>
#       1 #Merge with df_genes_aracore
# ----> 2 df_genes_aracore = pd.concat([df_genes_aracore, df_name_uniprot], axis=1)
#       3
#       4 #rename columns
#       5 df_genes_aracore.rename(columns={0: 'gene_name', 1: 'uniprot_id'}, inplace=True)
#
# NameError: name 'df_name_uniprot' is not defined

# %%
#Extract Uniprot id by splitting on last appearance of ':', expand columns, but only keep the last column for the uniprot id, the rest is trash
#e.g. Source:UniProtKB/Swiss-Prot;Acc:Q41932] -> "Source:UniProtKB/Swiss-Prot;Acc" & "Q41932]"
df_genes_aracore['uniprot_id'] = df_genes_aracore['uniprot_id'].str.rsplit(':',1,expand=True).iloc[:,-1]

#Remove closing "]" from uniprot id 
#e.g. "Q41932]" -> "Q41932"
df_genes_aracore['uniprot_id'] = df_genes_aracore['uniprot_id'].apply(lambda x: x[:-1] if isinstance(x,str) else None)
df_genes_aracore
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'uniprot_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-287046fb7e76> in <module>
#       1 #Extract Uniprot id by splitting on last appearance of ':', expand columns, but only keep the last column for the uniprot id, the rest is trash
#       2 #e.g. Source:UniProtKB/Swiss-Prot;Acc:Q41932] -> "Source:UniProtKB/Swiss-Prot;Acc" & "Q41932]"
# ----> 3 df_genes_aracore['uniprot_id'] = df_genes_aracore['uniprot_id'].str.rsplit(':',1,expand=True).iloc[:,-1]
#       4
#       5 #Remove closing "]" from uniprot id
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'uniprot_id'

# %%
df_genes_aracore[df_genes_aracore.isna().sum(axis=1) == 8] #2 Genes have no annotations at all -> Look-up those genes, maybe the Gene ids are wrong!?!
# Out:
# Empty DataFrame
# Columns: [aracore_ids, aracore_name, aracore_annotations]
# Index: []

# %%
df_genes_aracore[df_genes_aracore['ncbigene'].isna()] # ~28 genes without NCBI Symbol
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ncbigene'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-cdce47eae23d> in <module>
# ----> 1 df_genes_aracore[df_genes_aracore['ncbigene'].isna()] # ~28 genes without NCBI Symbol
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ncbigene'

# %%
df_genes_aracore[df_genes_aracore['symbol'].isna()].head(100) # 97 genes have no official gene #symbol
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'symbol'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-740a4a5d167b> in <module>
# ----> 1 df_genes_aracore[df_genes_aracore['symbol'].isna()].head(100) # 97 genes have no official gene #symbol
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'symbol'

# %%
df_genes_aracore[df_genes_aracore['uniprot_id'].isna()] #2 genes have no uniprot id (same as above)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'uniprot_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-fa606cf230bd> in <module>
# ----> 1 df_genes_aracore[df_genes_aracore['uniprot_id'].isna()] #2 genes have no uniprot id (same as above)
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/miniconda3/envs/photosynthesis_bis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'uniprot_id'

# %%
#Export final mapping table for manual mapping
df_genes_aracore.to_csv('../data/processed/2021-05-27-genes-mapping-table.csv')
