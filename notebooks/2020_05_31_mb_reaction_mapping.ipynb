# %% [markdown]
# # Install missing modules & load modules

# %%
# !pip install cobra #install cobra only required for google colab
# Out:
# Requirement already satisfied: cobra in /usr/local/lib/python3.7/dist-packages (0.22.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from cobra) (0.16.0)
# Requirement already satisfied: pandas~=1.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.1.5)
# Requirement already satisfied: depinfo in /usr/local/lib/python3.7/dist-packages (from cobra) (1.7.0)
# Requirement already satisfied: appdirs~=1.4 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.4.4)
# Requirement already satisfied: ruamel.yaml~=0.16 in /usr/local/lib/python3.7/dist-packages (from cobra) (0.17.7)
# Requirement already satisfied: rich>=8.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (10.2.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from cobra) (5.1.3)
# Requirement already satisfied: diskcache~=5.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (5.2.1)
# Requirement already satisfied: pydantic~=1.6 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.8.2)
# Requirement already satisfied: numpy~=1.13 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.19.5)
# Requirement already satisfied: python-libsbml==5.19.0 in /usr/local/lib/python3.7/dist-packages (from cobra) (5.19.0)
# Requirement already satisfied: httpx~=0.14 in /usr/local/lib/python3.7/dist-packages (from cobra) (0.18.1)
# Requirement already satisfied: optlang~=1.5 in /usr/local/lib/python3.7/dist-packages (from cobra) (1.5.2)
# Requirement already satisfied: swiglpk in /usr/local/lib/python3.7/dist-packages (from cobra) (5.0.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.0->cobra) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas~=1.0->cobra) (2.8.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from depinfo->cobra) (4.0.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml~=0.16->cobra) (0.2.2)
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (3.7.4.3)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (2.6.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (0.4.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich>=8.0->cobra) (0.9.1)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-resources->cobra) (3.4.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (2020.12.5)
# Requirement already satisfied: httpcore<0.14.0,>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (0.13.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (1.2.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx~=0.14->cobra) (1.5.0)
# Requirement already satisfied: sympy>=1.0 in /usr/local/lib/python3.7/dist-packages (from optlang~=1.5->cobra) (1.7.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from optlang~=1.5->cobra) (1.15.0)
# Requirement already satisfied: h11<0.13,>=0.11 in /usr/local/lib/python3.7/dist-packages (from httpcore<0.14.0,>=0.13.0->httpx~=0.14->cobra) (0.12.0)
# Requirement already satisfied: idna; extra == "idna2008" in /usr/local/lib/python3.7/dist-packages (from rfc3986[idna2008]<2,>=1.3->httpx~=0.14->cobra) (2.10)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.0->optlang~=1.5->cobra) (1.2.1)

# %%
import pandas as pd
import numpy as np
import cobra
import requests

# %% [markdown]
# # Load AraCore Model

# %%
#Get file from github
fileName = 'https://raw.githubusercontent.com/ma-blaetke/CBM_C3_C4_Metabolism/master/data/2018-23-05-mb-genC3.sbml'
r = requests.get(fileName)

# %%
#Create model
model = cobra.io.read_sbml_model(r.text)

# %% [markdown]
# # Correct Compartment Naming in AraCore Model according to BiGG naming conventions

# %%
model.compartments
# Out:
# {'c': 'Cytosol',
#  'h': 'Chloroplast',
#  'i': 'IntermembraneSpace',
#  'l': 'Lumen',
#  'm': 'Mitochondrion',
#  'p': 'Peroxisome'}

# %%
bigg_compartments = {'c':	'cytosol',
'e':	'extracellular space',
'p':	'periplasm',
'm':	'mitochondria',
'x':	'peroxisome/glyoxysome',
'r':	'endoplasmic reticulum',
'v':	'vacuole',
'n':	'nucleus',
'g':	'golgi apparatus',
'u':	'thylakoid',
'l':	'lysosome',
'h':	'chloroplast',
'f':	'flagellum',
's':	'eyespot',
'im':	'intermembrane space of mitochondria',
'cx':	'carboxyzome',
'um':	'thylakoid membrane',
'cm':	'cytosolic membrane',
'i':	'inner mitochondrial compartment',
'mm':	'mitochondrial intermembrane',
'w':	'wildtype staph aureus',
'y':	'cytochrome complex'}

# %%
#http://bigg.ucsd.edu/compartments

#c	cytosol
#h	chloroplast
#m	mitochondria
#x	peroxisome/glyoxysome
#im	intermembrane space of mitochondria
#h	chloroplast
#ul thylakoid lumen <<< NEW


df_compartment_mapping = pd.Series(
  { 'c': 'c', #cytosol
  'h': 'h', #chloroplast
  'm': 'm', #mitochondria
  'p': 'x', #peroxisome/glyoxysome
  'i': 'im', #intermembrane space of mitochondria
  'l': 'ul', #thylakoid lumen <<< NEW, not in BiGG compartment list
   'e':'e', #extracellular space << NEW, not yet in model
  }
 )

# %% [markdown]
# # Create Reaction Table for AraCore Model

# %%
#Create mapping table
df_reactions_aracore = pd.DataFrame(
    {
        "aracore_ids" : [r_obj.id for r_obj in model.reactions],
        "aracore_name" : [r_obj.name for r_obj in model.reactions],
        "aracore_annotations" : [r_obj.annotation for r_obj in model.reactions]
    })
 
df_reactions_aracore.set_index("aracore_ids",inplace=True) #Set index to acacore_ids to make the renaming of certain labels easiers

df_reactions_aracore.head(25)
# Out:
#                                                       aracore_name                                aracore_annotations
# aracore_ids
# PSII_h                                              photosystem II  {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Cytb6f1_h                                    cytochrom b6f complex  {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Cytb6f2_h                                    cytochrom b6f complex  {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# PGR5PGRL11_h     proton gradient regulation 5 (PGR5)/PGR5-like ...  {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# PGR5PGRL12_h     proton gradient regulation 5 (PGR5)/PGR5-like ...  {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# NDH1_h                       NADH dehydrogenase-like (NDH) complex  {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# NDH2_h                       NADH dehydrogenase-like (NDH) complex  {'doi': '10.1016/j.tplants.2011.10.004', 'go':...
# PSI_h                                                photosystem I  {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# Fd_DASH_NADPR_h                          ferredoxin-NADP reductase  {'ec-code': '1.18.1.2', 'go': 'GO:0019684', 'k...
# ATPase_h                                                    ATPase  {'doi': '10.1016/j.tplants.2011.10.004', 'ec-c...
# RBC_h                                                      RuBisCO  {'doi': '10.1146/annurev.arplant.53.100301.135...
# PGAK_h                                                  PGA kinase  {'ec-code': '2.7.2.3', 'go': ['GO:0019253', 'G...
# GAPDH1_h                                         GAP dehydrogenase  {'doi': ['10.1107/S1744309110013527', ' 10.107...
# TPI_h                                                 TP isomerase  {'ec-code': '5.3.1.1', 'go': ['GO:0019253', 'G...
# FBPA_h                                                FBP aldolase  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# FBPase_h                                                    FBPase  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....
# FTK_h                                            F6P transketolase  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# SBPA_h                                                SBP aldolase  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# SBPase_h                                                    SBPase  {'doi': '10.1093/jxb/50.330.1', 'ec-code': '3....
# STK_h                                            S7P transketolase  {'doi': '10.1074/mcp.M500180-MCP200', 'ec-code...
# Ru5PE_h                                             Ru5P epimerase  {'doi': '10.1104/pp.118.1.199', 'ec-code': '5....
# R5PI_h                                               R5P isomerase  {'ec-code': '5.3.1.6', 'go': ['GO:0019253', 'G...
# Ru5PK_h                                                Ru5P kinase  {'doi': '10.1104/pp.105.068445', 'ec-code': '2...
# PGI_h                                                G6P isomerase  {'doi': '10.1104/pp.105.068445', 'ec-code': '5...
# PGM_h                                           Phosphoglucomutase  {'ec-code': '5.4.2.2', 'go': 'GO:0019252', 'ke...

# %%
#BiGG naming convention https://github.com/SBRG/bigg_models/wiki/BiGG-Models-ID-Specification-and-Guidelines
# - Reaction symbols all neeed to be uppercase
# - Only contain upper and lowercase letters, numbers, and underscores

#df.rename(index= {'name': 'new_name'})
#Rename reaction ids StS_h1, StS_h3, StS_h2
df_reactions_aracore.rename(index={'StS_h1':'StS1_h'}, inplace=True)
df_reactions_aracore.rename(index={'StS_h2':'StS2_h'}, inplace=True)
df_reactions_aracore.rename(index={'StS_h3':'StS3_h'}, inplace=True)

#Rename reaction ids CeS_c1, CeS_c2, CeS_c3
df_reactions_aracore.rename(index={'CeS_c1':'CeS1_c'}, inplace=True)
df_reactions_aracore.rename(index={'CeS_c2':'CeS2_c'}, inplace=True)
df_reactions_aracore.rename(index={'CeS_c3':'CeS3_c'}, inplace=True)

#Rename reaction id AGluK
df_reactions_aracore.rename(index={'AGluK':'AGluK_h'}, inplace=True)

#Rename all import reaction ids, add "_e" for extracellular space
for r_obj in model.reactions.query(lambda rxn: (rxn.id.startswith('Im_'))):
  df_reactions_aracore.rename(index={r_obj.id: f"{r_obj.id}_e"}, inplace=True)


#Rename all export reaction ids, add "_e" for extracellular space
for r_obj in model.reactions.query(lambda rxn: (rxn.id.startswith('Ex_'))):
    df_reactions_aracore.rename(index={r_obj.id: f"{r_obj.id}_e"}, inplace=True)

#Rename all transport reaction ids, add compartment symbol of first metabolite
for r_obj in model.reactions.query(lambda rxn: (rxn.id.startswith('Tr_'))):
  met_first_comp = list(r_obj.metabolites.keys())[0].compartment
  if r_obj.id.rsplit('_',1)[-1] in ['mc','hc']:
    r_id_new = f"{r_obj.id.rsplit('_',1)[0]}_{met_first_comp}"
  else:
    r_id_new = f"{r_obj.id}_{met_first_comp}"
  df_reactions_aracore.rename(index={r_obj.id: r_id_new}, inplace=True)


df_reactions_aracore.reset_index(inplace=True) #Reset index to numeric labels, to be able to use the apply function on 'aracore_updated_ids' which is not possible as index

#Update compartment symbols in metabolite ids and make metabolite ids lower case
df_reactions_aracore['aracore_updated_ids'] = df_reactions_aracore['aracore_ids'].apply(lambda r_id: f"{r_id.rsplit('_',1)[0].upper()}_{df_compartment_mapping[r_id.rsplit('_',1)[-1]]}")

#Create universal metabolite ids by removing compartment symbols
df_reactions_aracore['aracore_updated_universal_ids'] = df_reactions_aracore['aracore_updated_ids'].apply(lambda r_id: r_id.rsplit('_',1)[0])

df_reactions_aracore.head(25)
# Out:
#         aracore_ids  ... aracore_updated_universal_ids
# 0            PSII_h  ...                          PSII
# 1         Cytb6f1_h  ...                       CYTB6F1
# 2         Cytb6f2_h  ...                       CYTB6F2
# 3      PGR5PGRL11_h  ...                    PGR5PGRL11
# 4      PGR5PGRL12_h  ...                    PGR5PGRL12
# 5            NDH1_h  ...                          NDH1
# 6            NDH2_h  ...                          NDH2
# 7             PSI_h  ...                           PSI
# 8   Fd_DASH_NADPR_h  ...                 FD_DASH_NADPR
# 9          ATPase_h  ...                        ATPASE
# 10            RBC_h  ...                           RBC
# 11           PGAK_h  ...                          PGAK
# 12         GAPDH1_h  ...                        GAPDH1
# 13            TPI_h  ...                           TPI
# 14           FBPA_h  ...                          FBPA
# 15         FBPase_h  ...                        FBPASE
# 16            FTK_h  ...                           FTK
# 17           SBPA_h  ...                          SBPA
# 18         SBPase_h  ...                        SBPASE
# 19            STK_h  ...                           STK
# 20          Ru5PE_h  ...                         RU5PE
# 21           R5PI_h  ...                          R5PI
# 22          Ru5PK_h  ...                         RU5PK
# 23            PGI_h  ...                           PGI
# 24            PGM_h  ...                           PGM
#
# [25 rows x 5 columns]

# %%
df_reactions_aracore[df_reactions_aracore['aracore_ids'].str.contains('DASH')]
# Out:
#           aracore_ids  ... aracore_updated_universal_ids
# 8     Fd_DASH_NADPR_h  ...                 FD_DASH_NADPR
# 227  Asp_DASH_SeADH_h  ...                ASP_DASH_SEADH
# 239   5M_DASH_THFOR_c  ...                 5M_DASH_THFOR
#
# [3 rows x 5 columns]

# %%
# Extract Kegg Id from 'aracore_annotations' column (annotations are already provided as dictionaries => key "kegg.reactions")
df_reactions_aracore['kegg_id'] = df_reactions_aracore['aracore_annotations'].apply(lambda anno_dict: anno_dict['kegg.reaction'] if 'kegg.reaction' in anno_dict.keys() else None)

df_reactions_aracore.head(25)
# Out:
#         aracore_ids  ... kegg_id
# 0            PSII_h  ...  R09503
# 1         Cytb6f1_h  ...  R03817
# 2         Cytb6f2_h  ...  R03817
# 3      PGR5PGRL11_h  ...  R03817
# 4      PGR5PGRL12_h  ...  R03817
# 5            NDH1_h  ...  R03817
# 6            NDH2_h  ...  R03817
# 7             PSI_h  ...  R09542
# 8   Fd_DASH_NADPR_h  ...  R01195
# 9          ATPase_h  ...  R00086
# 10            RBC_h  ...  R00024
# 11           PGAK_h  ...  R01512
# 12         GAPDH1_h  ...  R01063
# 13            TPI_h  ...  R01015
# 14           FBPA_h  ...  R01068
# 15         FBPase_h  ...  R00762
# 16            FTK_h  ...  R01067
# 17           SBPA_h  ...  R01829
# 18         SBPase_h  ...  R01845
# 19            STK_h  ...  R01641
# 20          Ru5PE_h  ...  R01529
# 21           R5PI_h  ...  R01056
# 22          Ru5PK_h  ...  R01523
# 23            PGI_h  ...  R00771
# 24            PGM_h  ...  R08639
#
# [25 rows x 6 columns]

# %%
# Extract Ec code from 'aracore_annotations' column (annotations are already provided as dictionaries => key "ec-code")
df_reactions_aracore['ec-code'] = df_reactions_aracore['aracore_annotations'].apply(lambda anno_dict: anno_dict['ec-code'] if 'ec-code' in anno_dict.keys() else None)

df_reactions_aracore.head(25)
# Out:
#         aracore_ids  ...    ec-code
# 0            PSII_h  ...   1.10.3.9
# 1         Cytb6f1_h  ...   1.10.9.1
# 2         Cytb6f2_h  ...   1.10.9.1
# 3      PGR5PGRL11_h  ...       None
# 4      PGR5PGRL12_h  ...       None
# 5            NDH1_h  ...       None
# 6            NDH2_h  ...       None
# 7             PSI_h  ...  1.97.1.12
# 8   Fd_DASH_NADPR_h  ...   1.18.1.2
# 9          ATPase_h  ...   3.6.3.14
# 10            RBC_h  ...   4.1.1.39
# 11           PGAK_h  ...    2.7.2.3
# 12         GAPDH1_h  ...   1.2.1.13
# 13            TPI_h  ...    5.3.1.1
# 14           FBPA_h  ...   4.1.2.13
# 15         FBPase_h  ...   3.1.3.11
# 16            FTK_h  ...    2.2.1.1
# 17           SBPA_h  ...   4.1.2.13
# 18         SBPase_h  ...   3.1.3.37
# 19            STK_h  ...    2.2.1.1
# 20          Ru5PE_h  ...    5.1.3.1
# 21           R5PI_h  ...    5.3.1.6
# 22          Ru5PK_h  ...   2.7.1.19
# 23            PGI_h  ...    5.3.1.9
# 24            PGM_h  ...    5.4.2.2
#
# [25 rows x 7 columns]

# %% [markdown]
# # BiGG Reactions
# ---

# %%
# Loag BIGG Reaction Table
bigg_reactions_url = 'http://bigg.ucsd.edu/static/namespace/bigg_models_reactions.txt'
df_reactions_bigg = pd.read_csv(bigg_reactions_url, sep='\t')
df_reactions_bigg.loc[170:200,:] # I just selected a range of reactions that will have a kegg identifier for sure, its only for demo
# Out:
#            bigg_id  ...             old_bigg_ids
# 170   12DGR181tipp  ...             12DGR181tipp
# 171      12PPDStex  ...                12PPDStex
# 172  14GLUCANabcpp  ...            14GLUCANabcpp
# 173      23CCMPtex  ...                23CCMPtex
# 174      23CGMPtex  ...                23CGMPtex
# 175       23PDE2pp  ...                 23PDE2pp
# 176       23PDE9pp  ...                 23PDE9pp
# 177   2AGPA120tipp  ...             2AGPA120tipp
# 178   2AGPA140tipp  ...             2AGPA140tipp
# 179   2AGPA180tipp  ...             2AGPA180tipp
# 180   2AGPA181tipp  ...             2AGPA181tipp
# 181   2AGPE140tipp  ...             2AGPE140tipp
# 182   2AGPE141tipp  ...             2AGPE141tipp
# 183     2AGPEAT141  ...  2AGPEAT141; _2AGPEAT141
# 184   2AGPG160tipp  ...             2AGPG160tipp
# 185   2AGPG161tipp  ...             2AGPG161tipp
# 186   2AGPG180tipp  ...             2AGPG180tipp
# 187   2AGPG181tipp  ...             2AGPG181tipp
# 188     2AGPGAT120  ...  2AGPGAT120; _2AGPGAT120
# 189     2AGPGAT141  ...  2AGPGAT141; _2AGPGAT141
# 190     2AGPGAT160  ...  2AGPGAT160; _2AGPGAT160
# 191     2AGPGAT180  ...  2AGPGAT180; _2AGPGAT180
# 192       2DGULRGx  ...                 2DGULRGx
# 193        2DGULRx  ...                  2DGULRx
# 194         2MAHMP  ...                   2MAHMP
# 195        3AMPtex  ...                  3AMPtex
# 196        3GMPtex  ...                  3GMPtex
# 197        3HAD121  ...        3HAD121; _3HAD121
# 198        3HAD160  ...        3HAD160; _3HAD160
# 199        3HAD161  ...        3HAD161; _3HAD161
# 200        3HAD180  ...        3HAD180; _3HAD180
#
# [31 rows x 6 columns]

# %%
#Convert string of database links into dictionaries of database identifier/symbol (key) and database-specific metabolite/annotation id (value)
df_reactions_bigg['database_links'] = df_reactions_bigg['database_links'].apply(lambda str_links: {db_link.split(':',1)[-1].split('/')[-2]: db_link.split(':',1)[-1].split('/')[-1] for db_link in str_links.split(';')} if isinstance(str_links,str) else {})

# %%
#All database keys in database_links
np.unique(df_reactions_bigg['database_links'].apply(lambda x: list(x.keys())).sum())
# Out:
# array(['biocyc', 'ec-code', 'kegg.reaction', 'metanetx.reaction',
#        'reactome', 'rhea', 'seed.reaction'], dtype='<U17')

# %%
#Extract kegg id from 'database_links' column (dictionary => key "kegg.reaction")
df_reactions_bigg['kegg.reaction'] = df_reactions_bigg['database_links'].apply(lambda dict_db_link:  dict_db_link['kegg.reaction'] if 'kegg.reaction' in dict_db_link.keys() else None)
df_reactions_bigg.loc[170:200]
# Out:
#            bigg_id  ... kegg.reaction
# 170   12DGR181tipp  ...          None
# 171      12PPDStex  ...          None
# 172  14GLUCANabcpp  ...          None
# 173      23CCMPtex  ...          None
# 174      23CGMPtex  ...          None
# 175       23PDE2pp  ...        R03538
# 176       23PDE9pp  ...        R05135
# 177   2AGPA120tipp  ...          None
# 178   2AGPA140tipp  ...          None
# 179   2AGPA180tipp  ...          None
# 180   2AGPA181tipp  ...          None
# 181   2AGPE140tipp  ...          None
# 182   2AGPE141tipp  ...          None
# 183     2AGPEAT141  ...          None
# 184   2AGPG160tipp  ...          None
# 185   2AGPG161tipp  ...          None
# 186   2AGPG180tipp  ...          None
# 187   2AGPG181tipp  ...          None
# 188     2AGPGAT120  ...          None
# 189     2AGPGAT141  ...          None
# 190     2AGPGAT160  ...          None
# 191     2AGPGAT180  ...          None
# 192       2DGULRGx  ...          None
# 193        2DGULRx  ...          None
# 194         2MAHMP  ...          None
# 195        3AMPtex  ...          None
# 196        3GMPtex  ...          None
# 197        3HAD121  ...          None
# 198        3HAD160  ...        R04544
# 199        3HAD161  ...          None
# 200        3HAD180  ...        R07764
#
# [31 rows x 7 columns]

# %%
#Extract ec-code from 'database_links' column (dictionary => key "ec-code")
df_reactions_bigg['ec-code'] = df_reactions_bigg['database_links'].apply(lambda dict_db_link:  dict_db_link['ec-code'] if 'ec-code' in dict_db_link.keys() else None)
df_reactions_bigg.loc[170:200]
# Out:
#            bigg_id  ...   ec-code
# 170   12DGR181tipp  ...      None
# 171      12PPDStex  ...      None
# 172  14GLUCANabcpp  ...      None
# 173      23CCMPtex  ...      None
# 174      23CGMPtex  ...      None
# 175       23PDE2pp  ...  3.1.4.16
# 176       23PDE9pp  ...  3.1.4.16
# 177   2AGPA120tipp  ...      None
# 178   2AGPA140tipp  ...      None
# 179   2AGPA180tipp  ...      None
# 180   2AGPA181tipp  ...      None
# 181   2AGPE140tipp  ...      None
# 182   2AGPE141tipp  ...      None
# 183     2AGPEAT141  ...      None
# 184   2AGPG160tipp  ...      None
# 185   2AGPG161tipp  ...      None
# 186   2AGPG180tipp  ...      None
# 187   2AGPG181tipp  ...      None
# 188     2AGPGAT120  ...      None
# 189     2AGPGAT141  ...      None
# 190     2AGPGAT160  ...      None
# 191     2AGPGAT180  ...      None
# 192       2DGULRGx  ...      None
# 193        2DGULRx  ...      None
# 194         2MAHMP  ...      None
# 195        3AMPtex  ...      None
# 196        3GMPtex  ...      None
# 197        3HAD121  ...  4.2.1.61
# 198        3HAD160  ...  4.2.1.61
# 199        3HAD161  ...  4.2.1.61
# 200        3HAD180  ...  4.2.1.61
#
# [31 rows x 8 columns]

# %%
#Extract seed.reaction from 'database_links' column (dictionary => key "seed.reaction")
df_reactions_bigg['seed.reaction'] = df_reactions_bigg['database_links'].apply(lambda dict_db_link:  dict_db_link['seed.reaction'] if 'seed.reaction' in dict_db_link.keys() else None)
df_reactions_bigg.loc[170:200]
# Out:
#            bigg_id  ... seed.reaction
# 170   12DGR181tipp  ...          None
# 171      12PPDStex  ...          None
# 172  14GLUCANabcpp  ...          None
# 173      23CCMPtex  ...      rxn07926
# 174      23CGMPtex  ...      rxn07927
# 175       23PDE2pp  ...      rxn02522
# 176       23PDE9pp  ...      rxn03483
# 177   2AGPA120tipp  ...      rxn07932
# 178   2AGPA140tipp  ...      rxn07933
# 179   2AGPA180tipp  ...      rxn07937
# 180   2AGPA181tipp  ...      rxn07938
# 181   2AGPE140tipp  ...          None
# 182   2AGPE141tipp  ...          None
# 183     2AGPEAT141  ...          None
# 184   2AGPG160tipp  ...          None
# 185   2AGPG161tipp  ...          None
# 186   2AGPG180tipp  ...          None
# 187   2AGPG181tipp  ...          None
# 188     2AGPGAT120  ...          None
# 189     2AGPGAT141  ...          None
# 190     2AGPGAT160  ...          None
# 191     2AGPGAT180  ...          None
# 192       2DGULRGx  ...          None
# 193        2DGULRx  ...      rxn07969
# 194         2MAHMP  ...      rxn07971
# 195        3AMPtex  ...      rxn07973
# 196        3GMPtex  ...      rxn07975
# 197        3HAD121  ...      rxn07976
# 198        3HAD160  ...      rxn05332
# 199        3HAD161  ...      rxn07978
# 200        3HAD180  ...      rxn07979
#
# [31 rows x 9 columns]

# %% [markdown]
# # ModelSeed Reactions

# %%
# Load ModelSeed Reaction Table

seed_reactions_url = 'https://raw.githubusercontent.com/ModelSEED/ModelSEEDDatabase/master/Biochemistry/reactions.tsv'
df_reactions_seed = pd.read_csv(seed_reactions_url, sep='\t')

df_reactions_seed.head(25)
# Out:
#           id abbreviation  ...           notes            source
# 0   rxn00001       R00004  ...  GCC|HB|EQC|EQU  Primary Database
# 1   rxn00002       R00005  ...     GCC|EQC|EQU  Primary Database
# 2   rxn00003       R00006  ...     GCC|EQC|EQU  Primary Database
# 3   rxn00004       R00008  ...     GCC|EQC|EQU  Primary Database
# 4   rxn00006       R00009  ...     GCC|EQC|EQU  Primary Database
# 5   rxn00007       R00010  ...     GCC|EQC|EQU  Primary Database
# 6   rxn00008       R00011  ...     GCC|EQC|EQU  Primary Database
# 7   rxn00009       R00012  ...  GCC|HB|EQC|EQU  Primary Database
# 8   rxn00010       R00013  ...     GCC|EQC|EQU  Primary Database
# 9   rxn00011       R00014  ...     GCC|EQC|EQU  Primary Database
# 10  rxn00012       R00015  ...     GCC|EQC|EQU  Primary Database
# 11  rxn00013       G1PPDM  ...  GCC|HB|EQC|EQU  Primary Database
# 12  rxn00014       R00017  ...         GCP|EQP  Primary Database
# 13  rxn00015       R00018  ...     GCC|EQC|EQU  Primary Database
# 14  rxn00016       R00022  ...     GCC|EQC|EQU  Primary Database
# 15  rxn00017       R00023  ...         GCC|EQP  Primary Database
# 16  rxn00018       R00024  ...     GCC|EQC|EQU  Primary Database
# 17  rxn00019        2NPDO  ...      HB|GCP|EQP   Published Model
# 18  rxn00020       R00026  ...     GCC|EQC|EQU  Primary Database
# 19  rxn00021       R00027  ...     GCC|EQC|EQU  Primary Database
# 20  rxn00022       R00028  ...     GCC|EQC|EQU  Primary Database
# 21  rxn00023       R00029  ...      HB|GCP|EQP  Primary Database
# 22  rxn00024       R00031  ...     GCC|EQC|EQU  Primary Database
# 23  rxn00025       R00032  ...     GCC|EQC|EQU  Primary Database
# 24  rxn00026       R00033  ...     GCC|EQC|EQU  Primary Database
#
# [25 rows x 22 columns]

# %%
#Convert string of alias pairs into dictionaries of keys and value - 
# 1) split by "|" to sepertae the different key - value pairs
# 2) split by ":" to seperate keys and values
df_reactions_seed['aliases'] = df_reactions_seed['aliases'].apply(lambda aliases_str: 
                                                                      {alias.split(':',1)[0]: alias.split(':',1)[-1] 
                                                                       for alias in aliases_str.split('|')} if isinstance(aliases_str, str) else {} )

# Some of the keys have values that are again a strings with multiple items that need to be splitted
# 3) split those  string by ';' and also remove leading and tailing white spaces 
df_reactions_seed['aliases'] = df_reactions_seed['aliases'].apply(lambda aliases_dict: 
                                                                      {alias_key:
                                                                       [alias_value.strip() for alias_value in alias_values.split(';')]
                                                                       for alias_key, alias_values in aliases_dict.items()}
                                                                      )

df_reactions_seed.head(25)
# Out:
#           id abbreviation  ...           notes            source
# 0   rxn00001       R00004  ...  GCC|HB|EQC|EQU  Primary Database
# 1   rxn00002       R00005  ...     GCC|EQC|EQU  Primary Database
# 2   rxn00003       R00006  ...     GCC|EQC|EQU  Primary Database
# 3   rxn00004       R00008  ...     GCC|EQC|EQU  Primary Database
# 4   rxn00006       R00009  ...     GCC|EQC|EQU  Primary Database
# 5   rxn00007       R00010  ...     GCC|EQC|EQU  Primary Database
# 6   rxn00008       R00011  ...     GCC|EQC|EQU  Primary Database
# 7   rxn00009       R00012  ...  GCC|HB|EQC|EQU  Primary Database
# 8   rxn00010       R00013  ...     GCC|EQC|EQU  Primary Database
# 9   rxn00011       R00014  ...     GCC|EQC|EQU  Primary Database
# 10  rxn00012       R00015  ...     GCC|EQC|EQU  Primary Database
# 11  rxn00013       G1PPDM  ...  GCC|HB|EQC|EQU  Primary Database
# 12  rxn00014       R00017  ...         GCP|EQP  Primary Database
# 13  rxn00015       R00018  ...     GCC|EQC|EQU  Primary Database
# 14  rxn00016       R00022  ...     GCC|EQC|EQU  Primary Database
# 15  rxn00017       R00023  ...         GCC|EQP  Primary Database
# 16  rxn00018       R00024  ...     GCC|EQC|EQU  Primary Database
# 17  rxn00019        2NPDO  ...      HB|GCP|EQP   Published Model
# 18  rxn00020       R00026  ...     GCC|EQC|EQU  Primary Database
# 19  rxn00021       R00027  ...     GCC|EQC|EQU  Primary Database
# 20  rxn00022       R00028  ...     GCC|EQC|EQU  Primary Database
# 21  rxn00023       R00029  ...      HB|GCP|EQP  Primary Database
# 22  rxn00024       R00031  ...     GCC|EQC|EQU  Primary Database
# 23  rxn00025       R00032  ...     GCC|EQC|EQU  Primary Database
# 24  rxn00026       R00033  ...     GCC|EQC|EQU  Primary Database
#
# [25 rows x 22 columns]

# %%
#All possible keys in ModelSEED aliases => seems like only KEGG, BiGG and AraCyc would make sense
#array(['AlgaGEM', 'AraCyc', 'AraGEM', 'BiGG', 'BrachyCyc', 'ChlamyCyc',
#       'CornCyc', 'DF_Athaliana', 'EcoCyc', 'JM_Creinhardtii',
#       'JP_Creinhardtii_MSB', 'JP_Creinhardtii_NMeth', 'KEGG', 'MaizeCyc',
#       'Maize_C4GEM', 'MetaCyc', 'Name', 'PlantCyc', 'PoplarCyc',
#       'RiceCyc', 'SorghumCyc', 'SoyCyc', 'TS_Athaliana', 'iAF1260',
#       'iAF692', 'iAG612', 'iAO358', 'iAbaylyiv4', 'iGT196', 'iIN800',
#       'iIT341', 'iJN746', 'iJR904', 'iMA945', 'iMEO21', 'iMM904',
#       'iMO1053-PAO1', 'iMO1056', 'iND750', 'iNJ661', 'iPS189', 'iRR1083',
#       'iRS1563', 'iRS1597', 'iSB619', 'iSO783', 'iYO844'], dtype='<U21')

# %%
#Get BiGG reaction ids
df_reactions_seed['BiGG'] = df_reactions_seed['aliases'].apply(lambda dict_aliases:  dict_aliases['BiGG'] if 'BiGG' in dict_aliases.keys() else None)
df_reactions_seed.head(25)
# Out:
#           id  ...                                               BiGG
# 0   rxn00001  ...                           [IPP1, PPA, PPA_1, PPAm]
# 1   rxn00002  ...                                   [ALPHNH, DUR1_2]
# 2   rxn00003  ...                                           [ILV2_2]
# 3   rxn00004  ...                                               None
# 4   rxn00006  ...                            [CAT, CATp, CTA1, CTT1]
# 5   rxn00007  ...     [ATH1, NTH1, NTH2, TREH, TREHe, TREHpp, TREHv]
# 6   rxn00008  ...                                               None
# 7   rxn00009  ...                                               None
# 8   rxn00010  ...                                    [GLXCBL, GLXCL]
# 9   rxn00011  ...                                               None
# 10  rxn00012  ...                                               None
# 11  rxn00013  ...                                               None
# 12  rxn00014  ...                                [CCP, CCP2m, CYCPO]
# 13  rxn00015  ...                                            [HSPMS]
# 14  rxn00016  ...                                             [HXAD]
# 15  rxn00017  ...                                               None
# 16  rxn00018  ...                                             [RBPC]
# 17  rxn00019  ...                                               None
# 18  rxn00020  ...                                               None
# 19  rxn00021  ...                                               None
# 20  rxn00022  ...  [FSP2_1, MAL12, MAL32, MALT, YGR287C, YIL172C,...
# 21  rxn00023  ...                                               None
# 22  rxn00024  ...                                               None
# 23  rxn00025  ...                                               None
# 24  rxn00026  ...                                               None
#
# [25 rows x 23 columns]

# %%
#Get BiGG reaction ids
df_reactions_seed['KEGG'] = df_reactions_seed['aliases'].apply(lambda dict_aliases:  dict_aliases['KEGG'] if 'KEGG' in dict_aliases.keys() else None)
df_reactions_seed.head(25)
# Out:
#           id  ...              KEGG
# 0   rxn00001  ...          [R00004]
# 1   rxn00002  ...          [R00005]
# 2   rxn00003  ...          [R00006]
# 3   rxn00004  ...          [R00008]
# 4   rxn00006  ...          [R00009]
# 5   rxn00007  ...  [R00010, R06103]
# 6   rxn00008  ...          [R00011]
# 7   rxn00009  ...          [R00012]
# 8   rxn00010  ...          [R00013]
# 9   rxn00011  ...          [R00014]
# 10  rxn00012  ...          [R00015]
# 11  rxn00013  ...          [R00016]
# 12  rxn00014  ...          [R00017]
# 13  rxn00015  ...          [R00018]
# 14  rxn00016  ...          [R00022]
# 15  rxn00017  ...          [R00023]
# 16  rxn00018  ...          [R00024]
# 17  rxn00019  ...              None
# 18  rxn00020  ...  [R00026, R06092]
# 19  rxn00021  ...          [R00027]
# 20  rxn00022  ...  [R00028, R06084]
# 21  rxn00023  ...          [R00029]
# 22  rxn00024  ...          [R00031]
# 23  rxn00025  ...          [R00032]
# 24  rxn00026  ...          [R00033]
#
# [25 rows x 24 columns]

# %%
#Get AraCyc reaction ids
df_reactions_seed['AraCyc'] = df_reactions_seed['aliases'].apply(lambda dict_aliases:  dict_aliases['AraCyc'] if 'AraCyc' in dict_aliases.keys() else None)
df_reactions_seed.head(25)
# Out:
#           id  ...                                             AraCyc
# 0   rxn00001  ...                            [INORGPYROPHOSPHAT-RXN]
# 1   rxn00002  ...                        [ALLOPHANATE-HYDROLASE-RXN]
# 2   rxn00003  ...                                               None
# 3   rxn00004  ...                                               None
# 4   rxn00006  ...                                        [CATAL-RXN]
# 5   rxn00007  ...                                               None
# 6   rxn00008  ...                                               None
# 7   rxn00009  ...                                               None
# 8   rxn00010  ...                                               None
# 9   rxn00011  ...                                        [RXN-12583]
# 10  rxn00012  ...                                               None
# 11  rxn00013  ...                                               None
# 12  rxn00014  ...                                               None
# 13  rxn00015  ...                                               None
# 14  rxn00016  ...                                        [RXN-12625]
# 15  rxn00017  ...                                               None
# 16  rxn00018  ...            [RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN]
# 17  rxn00019  ...                                               None
# 18  rxn00020  ...                                               None
# 19  rxn00021  ...                                               None
# 20  rxn00022  ...                                               None
# 21  rxn00023  ...                                               None
# 22  rxn00024  ...                                               None
# 23  rxn00025  ...  [1.14.99.36-RXN, BETA-CAROTENE-1515-DIOXYGENAS...
# 24  rxn00026  ...                                               None
#
# [25 rows x 25 columns]

# %%
# 'ec_numbers' should also be convert into a list 
df_reactions_seed['ec_numbers'] = df_reactions_seed['ec_numbers'].astype(str)
df_reactions_seed['ec_numbers'] = df_reactions_seed['ec_numbers'].apply(lambda x: x.split('|') if x else None)
df_reactions_seed.head(25)
# Out:
#           id  ...                                             AraCyc
# 0   rxn00001  ...                            [INORGPYROPHOSPHAT-RXN]
# 1   rxn00002  ...                        [ALLOPHANATE-HYDROLASE-RXN]
# 2   rxn00003  ...                                               None
# 3   rxn00004  ...                                               None
# 4   rxn00006  ...                                        [CATAL-RXN]
# 5   rxn00007  ...                                               None
# 6   rxn00008  ...                                               None
# 7   rxn00009  ...                                               None
# 8   rxn00010  ...                                               None
# 9   rxn00011  ...                                        [RXN-12583]
# 10  rxn00012  ...                                               None
# 11  rxn00013  ...                                               None
# 12  rxn00014  ...                                               None
# 13  rxn00015  ...                                               None
# 14  rxn00016  ...                                        [RXN-12625]
# 15  rxn00017  ...                                               None
# 16  rxn00018  ...            [RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN]
# 17  rxn00019  ...                                               None
# 18  rxn00020  ...                                               None
# 19  rxn00021  ...                                               None
# 20  rxn00022  ...                                               None
# 21  rxn00023  ...                                               None
# 22  rxn00024  ...                                               None
# 23  rxn00025  ...  [1.14.99.36-RXN, BETA-CAROTENE-1515-DIOXYGENAS...
# 24  rxn00026  ...                                               None
#
# [25 rows x 25 columns]

# %% [markdown]
# # Mapping AraCore and BiGG

# %% [markdown]
# ## Using KEGG Ids

# %%
#Check if kegg_id of the aracore reactions is in any of the list of kegg ids mapped in the BiGG table
df_reactions_aracore['is_bigg_kegg_id'] = df_reactions_aracore['kegg_id'].apply(lambda kegg_id: ((df_reactions_bigg['kegg.reaction'] == kegg_id).sum() > 0) if isinstance(kegg_id, str) else False)

#get the BiGG ids where kegg ids are matching
df_reactions_aracore['kegg_bigg_ids'] = df_reactions_aracore[['kegg_id','is_bigg_kegg_id']].apply(lambda x: 
                                                                                            df_reactions_bigg[df_reactions_bigg['kegg.reaction'] == x[0]]['bigg_id'].tolist() 
                                                                                            if x[1] 
                                                                                            else [None], axis=1)
df_reactions_aracore.head(25)
# Out:
#         aracore_ids  ...                kegg_bigg_ids
# 0            PSII_h  ...                       [None]
# 1         Cytb6f1_h  ...                       [None]
# 2         Cytb6f2_h  ...                       [None]
# 3      PGR5PGRL11_h  ...                       [None]
# 4      PGR5PGRL12_h  ...                       [None]
# 5            NDH1_h  ...                       [None]
# 6            NDH2_h  ...                       [None]
# 7             PSI_h  ...                       [None]
# 8   Fd_DASH_NADPR_h  ...                       [FNOR]
# 9          ATPase_h  ...   [ATPM, NTP1, ATPPHm, ATPS]
# 10            RBC_h  ...                [RBPCh, RBPC]
# 11           PGAK_h  ...      [PGKm, PGK, PGKf, PGKh]
# 12         GAPDH1_h  ...  [GAPDi_nadp, GAPDH_nadp_hi]
# 13            TPI_h  ...                  [TPI, TPIh]
# 14           FBPA_h  ...                        [FBA]
# 15         FBPase_h  ...                       [None]
# 16            FTK_h  ...                       [None]
# 17           SBPA_h  ...               [FBA3hi, FBA3]
# 18         SBPase_h  ...                 [SBP, SBP_1]
# 19            STK_h  ...                       [None]
# 20          Ru5PE_h  ...                  [RPEh, RPE]
# 21           R5PI_h  ...                       [None]
# 22          Ru5PK_h  ...               [PRUK, PRUK_1]
# 23            PGI_h  ...                       [None]
# 24            PGM_h  ...                       [PGMT]
#
# [25 rows x 9 columns]

# %%
df_reactions_aracore['is_bigg_kegg_id'].value_counts() #=> 249 reactions mapped
# Out:
# False    323
# True     249
# Name: is_bigg_kegg_id, dtype: int64

# %% [markdown]
# ## Using Ec-code

# %%
#Check if ec-code of the aracore reactions is in any of the list of ec-code mapped in the BiGG table
df_reactions_aracore['is_bigg_ec_code'] = df_reactions_aracore['ec-code'].apply(lambda kegg_id: ((df_reactions_bigg['ec-code'] == kegg_id).sum() > 0) if isinstance(kegg_id, str) else False)

#get the ec-code ids where kegg ids are matching
df_reactions_aracore['ec_bigg_ids'] = df_reactions_aracore[['ec-code','is_bigg_ec_code']].apply(lambda x: 
                                                                                            df_reactions_bigg[df_reactions_bigg['ec-code'] == x[0]]['bigg_id'].tolist() 
                                                                                            if x[1] 
                                                                                            else [None], axis=1)
df_reactions_aracore.head(50)
# Out:
#         aracore_ids  ...                                        ec_bigg_ids
# 0            PSII_h  ...                                             [None]
# 1         Cytb6f1_h  ...                                             [None]
# 2         Cytb6f2_h  ...                                             [None]
# 3      PGR5PGRL11_h  ...                                             [None]
# 4      PGR5PGRL12_h  ...                                             [None]
# 5            NDH1_h  ...                                             [None]
# 6            NDH2_h  ...                                             [None]
# 7             PSI_h  ...                                             [None]
# 8   Fd_DASH_NADPR_h  ...                                       [FRDO, FNOR]
# 9          ATPase_h  ...  [ATPS4rpp, ATPS3m, ATPasel, ATPS3g, ATPS3v, AT...
# 10            RBC_h  ...                        [RBPCh, RBCh_1, RBCh, RBPC]
# 11           PGAK_h  ...                            [PGKm, PGK, PGKf, PGKh]
# 12         GAPDH1_h  ...                                             [None]
# 13            TPI_h  ...                                        [TPI, TPIh]
# 14           FBPA_h  ...  [FBA, FBA2, FBA3hi, FPGPL, FBAf, FBAm, FBA3, F...
# 15         FBPase_h  ...                                 [FBP, BFBP, BFBPh]
# 16            FTK_h  ...                         [TKT2, TKT1h, TKT2h, TKT1]
# 17           SBPA_h  ...  [FBA, FBA2, FBA3hi, FPGPL, FBAf, FBAm, FBA3, F...
# 18         SBPase_h  ...                                       [SBP, SBP_1]
# 19            STK_h  ...                         [TKT2, TKT1h, TKT2h, TKT1]
# 20          Ru5PE_h  ...                                        [RPEh, RPE]
# 21           R5PI_h  ...                          [RPI, RPIh, ALLPI, r0249]
# 22          Ru5PK_h  ...                                     [PRUK, PRUK_1]
# 23            PGI_h  ...  [PGI, G6PI, G6PI3, G6PIh, PGIA, PGIBh, G6PI2, ...
# 24            PGM_h  ...                                             [None]
# 25         AGPase_h  ...                                     [GLGC, GLPThi]
# 26           StS1_h  ...                                            [GLCS1]
# 27           StS2_h  ...                                            [GLCS1]
# 28           StS3_h  ...                                            [GLCS1]
# 29          bAMY1_h  ...                                             [None]
# 30          bAMY2_h  ...                                             [None]
# 31          DPE11_h  ...                   [AMALT3, AMALT1, AMALT2, AMALT4]
# 32          DPE12_h  ...                   [AMALT3, AMALT1, AMALT2, AMALT4]
# 33          DPE13_h  ...                   [AMALT3, AMALT1, AMALT2, AMALT4]
# 34           DPE2_c  ...                   [AMALT3, AMALT1, AMALT2, AMALT4]
# 35           HEXK_c  ...                [r0354, r0360, r0361, r0363, r0364]
# 36           StP1_h  ...                       [GLCP2, MLTP1, MLTP2, MLTP3]
# 37          StP21_c  ...                       [GLCP2, MLTP1, MLTP2, MLTP3]
# 38            TPI_c  ...                                        [TPI, TPIh]
# 39           FBPA_c  ...  [FBA, FBA2, FBA3hi, FPGPL, FBAf, FBAm, FBA3, F...
# 40         FBPase_c  ...                                 [FBP, BFBP, BFBPh]
# 41          F6PK2_c  ...                                   [PFK26_1, PFK26]
# 42        F26BPPh_c  ...                                     [FBP26, FBPPH]
# 43            PGI_c  ...  [PGI, G6PI, G6PI3, G6PIh, PGIA, PGIBh, G6PI2, ...
# 44            PGM_c  ...                                      [PGMTh, PGCM]
# 45         UGPase_c  ...                                            [GALUi]
# 46           S6PS_c  ...                                       [SPS, UFAGT]
# 47          S6PPh_c  ...                                              [SPP]
# 48           SucS_c  ...                                             [None]
# 49          FrcFD_c  ...  [RAFH, GALS4, FFSD, STACHGALACT, RAFHpp, SYGH,...
#
# [50 rows x 11 columns]

# %%
df_reactions_aracore['is_bigg_ec_code'].value_counts() #=> 249 reactions mapped
# Out:
# False    309
# True     263
# Name: is_bigg_ec_code, dtype: int64

# %% [markdown]
# ## Aggregate all BiGG ids from mapping of KEGG ids and Ec-codes

# %%
#Fuse list of mapped BiGG ids by kegg and ec code 
df_reactions_aracore['kegg_ec_bigg_id'] = df_reactions_aracore[['ec_bigg_ids','kegg_bigg_ids']].apply(lambda x: list(filter(None, x[0]+x[1])), axis=1)

#Create list of unique BiGG ids
df_reactions_aracore['kegg_ec_bigg_id'].apply(lambda x: list(np.unique(x)))

#Clean dataframe and remove cols
df_reactions_aracore.drop(['is_bigg_ec_code','is_bigg_kegg_id','ec_bigg_ids','kegg_bigg_ids'], axis=1, inplace=True)

df_reactions_aracore.head(50)
# Out:
#         aracore_ids  ...                                    kegg_ec_bigg_id
# 0            PSII_h  ...                                                 []
# 1         Cytb6f1_h  ...                                                 []
# 2         Cytb6f2_h  ...                                                 []
# 3      PGR5PGRL11_h  ...                                                 []
# 4      PGR5PGRL12_h  ...                                                 []
# 5            NDH1_h  ...                                                 []
# 6            NDH2_h  ...                                                 []
# 7             PSI_h  ...                                                 []
# 8   Fd_DASH_NADPR_h  ...                                 [FRDO, FNOR, FNOR]
# 9          ATPase_h  ...  [ATPS4rpp, ATPS3m, ATPasel, ATPS3g, ATPS3v, AT...
# 10            RBC_h  ...           [RBPCh, RBCh_1, RBCh, RBPC, RBPCh, RBPC]
# 11           PGAK_h  ...     [PGKm, PGK, PGKf, PGKh, PGKm, PGK, PGKf, PGKh]
# 12         GAPDH1_h  ...                        [GAPDi_nadp, GAPDH_nadp_hi]
# 13            TPI_h  ...                             [TPI, TPIh, TPI, TPIh]
# 14           FBPA_h  ...  [FBA, FBA2, FBA3hi, FPGPL, FBAf, FBAm, FBA3, F...
# 15         FBPase_h  ...                                 [FBP, BFBP, BFBPh]
# 16            FTK_h  ...                         [TKT2, TKT1h, TKT2h, TKT1]
# 17           SBPA_h  ...  [FBA, FBA2, FBA3hi, FPGPL, FBAf, FBAm, FBA3, F...
# 18         SBPase_h  ...                           [SBP, SBP_1, SBP, SBP_1]
# 19            STK_h  ...                         [TKT2, TKT1h, TKT2h, TKT1]
# 20          Ru5PE_h  ...                             [RPEh, RPE, RPEh, RPE]
# 21           R5PI_h  ...                          [RPI, RPIh, ALLPI, r0249]
# 22          Ru5PK_h  ...                       [PRUK, PRUK_1, PRUK, PRUK_1]
# 23            PGI_h  ...  [PGI, G6PI, G6PI3, G6PIh, PGIA, PGIBh, G6PI2, ...
# 24            PGM_h  ...                                             [PGMT]
# 25         AGPase_h  ...                       [GLGC, GLPThi, GLGC, GLPThi]
# 26           StS1_h  ...                                            [GLCS1]
# 27           StS2_h  ...                                            [GLCS1]
# 28           StS3_h  ...                                            [GLCS1]
# 29          bAMY1_h  ...                                                 []
# 30          bAMY2_h  ...                                                 []
# 31          DPE11_h  ...                   [AMALT3, AMALT1, AMALT2, AMALT4]
# 32          DPE12_h  ...                   [AMALT3, AMALT1, AMALT2, AMALT4]
# 33          DPE13_h  ...                   [AMALT3, AMALT1, AMALT2, AMALT4]
# 34           DPE2_c  ...                   [AMALT3, AMALT1, AMALT2, AMALT4]
# 35           HEXK_c  ...          [r0354, r0360, r0361, r0363, r0364, HEX1]
# 36           StP1_h  ...                       [GLCP2, MLTP1, MLTP2, MLTP3]
# 37          StP21_c  ...                       [GLCP2, MLTP1, MLTP2, MLTP3]
# 38            TPI_c  ...                             [TPI, TPIh, TPI, TPIh]
# 39           FBPA_c  ...  [FBA, FBA2, FBA3hi, FPGPL, FBAf, FBAm, FBA3, F...
# 40         FBPase_c  ...                                 [FBP, BFBP, BFBPh]
# 41          F6PK2_c  ...                   [PFK26_1, PFK26, PFK26_1, PFK26]
# 42        F26BPPh_c  ...                                     [FBP26, FBPPH]
# 43            PGI_c  ...  [PGI, G6PI, G6PI3, G6PIh, PGIA, PGIBh, G6PI2, ...
# 44            PGM_c  ...                                [PGMTh, PGCM, PGMT]
# 45         UGPase_c  ...                                     [GALUi, GALUi]
# 46           S6PS_c  ...                                       [SPS, UFAGT]
# 47          S6PPh_c  ...                                              [SPP]
# 48           SucS_c  ...                                                 []
# 49          FrcFD_c  ...  [RAFH, GALS4, FFSD, STACHGALACT, RAFHpp, SYGH,...
#
# [50 rows x 8 columns]

# %%
(df_reactions_aracore['kegg_ec_bigg_id'].apply(len) > 1).value_counts() #284 have mapped BiGG ids
# Out:
# False    288
# True     284
# Name: kegg_ec_bigg_id, dtype: int64

# %% [markdown]
# ## Add SEED Reaction ids that are known from the BiGG Table
#
# > Indented block

# %%
#Add all ModelSeed ids that have already been mapped to BiGG ids in the Bigg Table
df_reactions_aracore['bigg_seed_id'] = df_reactions_aracore['kegg_ec_bigg_id'].apply(lambda bigg_id_list: 
                                      [df_reactions_bigg[df_reactions_bigg['bigg_id'] == bigg_id]['seed.reaction'] for bigg_id in bigg_id_list] if bigg_id_list else [[None]] )
#Process packed lists of ModelSEED Ids
df_reactions_aracore['bigg_seed_id'] = df_reactions_aracore['bigg_seed_id'].apply(lambda x: [item_x  for sub_x in x for item_x in sub_x] )

#Create list of unique ModelSEED ids
df_reactions_aracore['bigg_seed_id'] = df_reactions_aracore['bigg_seed_id'].apply(lambda x: list(np.unique(list(filter(None,x)))))

# %%
df_reactions_aracore.head(50)
# Out:
#         aracore_ids  ...                                       bigg_seed_id
# 0            PSII_h  ...                                                 []
# 1         Cytb6f1_h  ...                                                 []
# 2         Cytb6f2_h  ...                                                 []
# 3      PGR5PGRL11_h  ...                                                 []
# 4      PGR5PGRL12_h  ...                                                 []
# 5            NDH1_h  ...                                                 []
# 6            NDH2_h  ...                                                 []
# 7             PSI_h  ...                                                 []
# 8   Fd_DASH_NADPR_h  ...                               [rxn05937, rxn14159]
# 9          ATPase_h  ...                     [rxn10042, rxn11300, rxn13766]
# 10            RBC_h  ...                               [rxn00018, rxn02251]
# 11           PGAK_h  ...                                         [rxn01100]
# 12         GAPDH1_h  ...                                         [rxn00782]
# 13            TPI_h  ...                                         [rxn00747]
# 14           FBPA_h  ...                     [rxn00786, rxn01334, rxn01870]
# 15         FBPase_h  ...                                                 []
# 16            FTK_h  ...                                                 []
# 17           SBPA_h  ...                     [rxn00786, rxn01334, rxn01870]
# 18         SBPase_h  ...                                         [rxn01345]
# 19            STK_h  ...                                                 []
# 20          Ru5PE_h  ...                                         [rxn01116]
# 21           R5PI_h  ...                                         [rxn08113]
# 22          Ru5PK_h  ...                                         [rxn01111]
# 23            PGI_h  ...                                         [rxn01977]
# 24            PGM_h  ...                                         [rxn00704]
# 25         AGPase_h  ...                                         [rxn00695]
# 26           StS1_h  ...                                         [rxn13643]
# 27           StS2_h  ...                                         [rxn13643]
# 28           StS3_h  ...                                         [rxn13643]
# 29          bAMY1_h  ...                                                 []
# 30          bAMY2_h  ...                                                 []
# 31          DPE11_h  ...           [rxn08126, rxn08127, rxn08128, rxn08129]
# 32          DPE12_h  ...           [rxn08126, rxn08127, rxn08128, rxn08129]
# 33          DPE13_h  ...           [rxn08126, rxn08127, rxn08128, rxn08129]
# 34           DPE2_c  ...           [rxn08126, rxn08127, rxn08128, rxn08129]
# 35           HEXK_c  ...  [rxn00216, rxn00518, rxn00976, rxn00978, rxn01...
# 36           StP1_h  ...           [rxn08611, rxn08941, rxn08942, rxn08943]
# 37          StP21_c  ...           [rxn08611, rxn08941, rxn08942, rxn08943]
# 38            TPI_c  ...                                         [rxn00747]
# 39           FBPA_c  ...                     [rxn00786, rxn01334, rxn01870]
# 40         FBPase_c  ...                                                 []
# 41          F6PK2_c  ...                                                 []
# 42        F26BPPh_c  ...                                                 []
# 43            PGI_c  ...                                         [rxn01977]
# 44            PGM_c  ...                                         [rxn00704]
# 45         UGPase_c  ...                                         [rxn00213]
# 46           S6PS_c  ...                                                 []
# 47          S6PPh_c  ...                                         [rxn00578]
# 48           SucS_c  ...                                                 []
# 49          FrcFD_c  ...                               [rxn02596, rxn02760]
#
# [50 rows x 9 columns]

# %% [markdown]
# # Mapping AraCore and ModelSeed

# %% [markdown]
# ## Using KEGG ids

# %%
def check_for_kegg_modelseed(kegg_id):
  return df_reactions_seed[df_reactions_seed['KEGG'].apply(lambda x: kegg_id in x if x else False)]['id'].tolist() 

#Map KEGG ids in the aracore table and the ModelSEED table to get additional Seed ids
df_reactions_aracore['kegg_seed_ids'] = df_reactions_aracore['kegg_id'].apply(lambda kegg_id: check_for_kegg_modelseed(kegg_id) if isinstance(kegg_id, str) else [None])

df_reactions_aracore.head(25)
# Out:
#         aracore_ids  ...                                      kegg_seed_ids
# 0            PSII_h  ...                               [rxn16345, rxn34264]
# 1         Cytb6f1_h  ...                               [rxn11995, rxn39426]
# 2         Cytb6f2_h  ...                               [rxn11995, rxn39426]
# 3      PGR5PGRL11_h  ...                               [rxn11995, rxn39426]
# 4      PGR5PGRL12_h  ...                               [rxn11995, rxn39426]
# 5            NDH1_h  ...                               [rxn11995, rxn39426]
# 6            NDH2_h  ...                               [rxn11995, rxn39426]
# 7             PSI_h  ...                                         [rxn16384]
# 8   Fd_DASH_NADPR_h  ...                                         [rxn14159]
# 9          ATPase_h  ...  [rxn00062, rxn11300, rxn27586, rxn27587, rxn27...
# 10            RBC_h  ...                     [rxn00018, rxn20788, rxn38286]
# 11           PGAK_h  ...  [rxn01100, rxn20544, rxn35241, rxn38256, rxn38...
# 12         GAPDH1_h  ...                     [rxn00782, rxn17199, rxn37888]
# 13            TPI_h  ...                     [rxn00747, rxn27386, rxn33035]
# 14           FBPA_h  ...                               [rxn00786, rxn31335]
# 15         FBPase_h  ...                               [rxn00549, rxn31218]
# 16            FTK_h  ...                               [rxn00785, rxn31366]
# 17           SBPA_h  ...                     [rxn01334, rxn28981, rxn31868]
# 18         SBPase_h  ...           [rxn01345, rxn28982, rxn31076, rxn33873]
# 19            STK_h  ...           [rxn01200, rxn15228, rxn27495, rxn34273]
# 20          Ru5PE_h  ...                               [rxn01116, rxn28146]
# 21           R5PI_h  ...  [rxn00777, rxn15114, rxn28141, rxn34267, rxn38...
# 22          Ru5PK_h  ...                     [rxn01111, rxn28078, rxn38263]
# 23            PGI_h  ...                               [rxn00558, rxn34259]
# 24            PGM_h  ...           [rxn00704, rxn12204, rxn15773, rxn33867]
#
# [25 rows x 10 columns]

# %%
df_reactions_aracore['kegg_seed_ids'].apply(lambda x: isinstance(x,list)).value_counts() #319 reactions with ModelSeed Id
# Out:
# True    572
# Name: kegg_seed_ids, dtype: int64

# %% [markdown]
# ## Add BiGG Reaction ids that are known from the ModelSeed Table

# %%
#Add all BiGG ids that have already been mapped to ModelSEED ids in the ModelSEED Table
df_reactions_aracore['seed_bigg_id'] = df_reactions_aracore['kegg_seed_ids'].apply(lambda kegg_seed_ids: 
                                            [df_reactions_seed[df_reactions_seed['id'] == seed_id]['BiGG'].tolist() 
                                            for seed_id in kegg_seed_ids ]
                                            if isinstance(kegg_seed_ids, list) else None ) 

#Process packed lists of BiGG Ids
df_reactions_aracore['seed_bigg_id'] = df_reactions_aracore['seed_bigg_id'].apply(lambda x: [item_x  for sub_x in x for item_x in sub_x] if x else None )

#Create list of unique BiGG Ids
df_reactions_aracore['seed_bigg_id'] = df_reactions_aracore['seed_bigg_id'].apply(lambda x: list(np.unique(list(filter(None,x)))) if x else [None])

# %%
df_reactions_aracore.head(50)
# Out:
#         aracore_ids  ...                      seed_bigg_id
# 0            PSII_h  ...                                []
# 1         Cytb6f1_h  ...                                []
# 2         Cytb6f2_h  ...                                []
# 3      PGR5PGRL11_h  ...                                []
# 4      PGR5PGRL12_h  ...                                []
# 5            NDH1_h  ...                                []
# 6            NDH2_h  ...                                []
# 7             PSI_h  ...                                []
# 8   Fd_DASH_NADPR_h  ...                                []
# 9          ATPase_h  ...  [ATPM, ATPOBJ, FATP, NTP1, U214]
# 10            RBC_h  ...                            [RBPC]
# 11           PGAK_h  ...                       [PGK, PGK1]
# 12         GAPDH1_h  ...           [GAPD(nadp), GAPD_NADP]
# 13            TPI_h  ...                             [TPI]
# 14           FBPA_h  ...                             [FBA]
# 15         FBPase_h  ...                       [FBP, FBP1]
# 16            FTK_h  ...                            [TKT2]
# 17           SBPA_h  ...                            [FBA3]
# 18         SBPase_h  ...                                []
# 19            STK_h  ...                            [TKT1]
# 20          Ru5PE_h  ...                       [RPE, RPE1]
# 21           R5PI_h  ...                       [RKI1, RPI]
# 22          Ru5PK_h  ...                           [PRKIN]
# 23            PGI_h  ...                     [PGI, PGI1_1]
# 24            PGM_h  ...            [PGM1_2, PGM2_2, PGMT]
# 25         AGPase_h  ...                     [GLGC, GLGCr]
# 26           StS1_h  ...                                []
# 27           StS2_h  ...                                []
# 28           StS3_h  ...                                []
# 29          bAMY1_h  ...                                []
# 30          bAMY2_h  ...                                []
# 31          DPE11_h  ...                                []
# 32          DPE12_h  ...                                []
# 33          DPE13_h  ...                                []
# 34           DPE2_c  ...                                []
# 35           HEXK_c  ...    [GLK1_1, HEX1, HXK1_2, HXK2_2]
# 36           StP1_h  ...                                []
# 37          StP21_c  ...                                []
# 38            TPI_c  ...                             [TPI]
# 39           FBPA_c  ...                             [FBA]
# 40         FBPase_c  ...                       [FBP, FBP1]
# 41          F6PK2_c  ...                    [PFK26, PFK27]
# 42        F26BPPh_c  ...                           [FBP26]
# 43            PGI_c  ...                     [PGI, PGI1_1]
# 44            PGM_c  ...            [PGM1_2, PGM2_2, PGMT]
# 45         UGPase_c  ...      [GALU, GALUi, UGP1, YHL012W]
# 46           S6PS_c  ...                                []
# 47          S6PPh_c  ...                                []
# 48           SucS_c  ...                                []
# 49          FrcFD_c  ...                                []
#
# [50 rows x 11 columns]

# %% [markdown]
# # Aggregate Seed and BiGG Ids

# %%
#Fuse list of mapped BiGG ids and create list of unique ids
df_reactions_aracore['bigg_id_aggr'] = df_reactions_aracore[['seed_bigg_id','kegg_ec_bigg_id']].apply(lambda x: list(filter(None, x[0]+x[1])), axis=1)
df_reactions_aracore['bigg_id_aggr'] = df_reactions_aracore['bigg_id_aggr'].apply(lambda x: list(np.unique(x)))

#Fuse list of mapped Seeds ids and create list of unique ids
df_reactions_aracore['seed_id_aggr'] = df_reactions_aracore[['kegg_seed_ids','bigg_seed_id']].apply(lambda x: list(filter(None, x[0]+x[1])), axis=1)
df_reactions_aracore['seed_id_aggr'] = df_reactions_aracore['seed_id_aggr'].apply(lambda x: list(np.unique(x)))

#Clean dataframe and drop cols
df_reactions_aracore.drop(['kegg_ec_bigg_id', 'bigg_seed_id', 'kegg_seed_ids', 'seed_bigg_id'], axis=1, inplace=True)

df_reactions_aracore.head(50)
# Out:
#         aracore_ids  ...                                       seed_id_aggr
# 0            PSII_h  ...                               [rxn16345, rxn34264]
# 1         Cytb6f1_h  ...                               [rxn11995, rxn39426]
# 2         Cytb6f2_h  ...                               [rxn11995, rxn39426]
# 3      PGR5PGRL11_h  ...                               [rxn11995, rxn39426]
# 4      PGR5PGRL12_h  ...                               [rxn11995, rxn39426]
# 5            NDH1_h  ...                               [rxn11995, rxn39426]
# 6            NDH2_h  ...                               [rxn11995, rxn39426]
# 7             PSI_h  ...                                         [rxn16384]
# 8   Fd_DASH_NADPR_h  ...                               [rxn05937, rxn14159]
# 9          ATPase_h  ...  [rxn00062, rxn10042, rxn11300, rxn13766, rxn27...
# 10            RBC_h  ...           [rxn00018, rxn02251, rxn20788, rxn38286]
# 11           PGAK_h  ...  [rxn01100, rxn20544, rxn35241, rxn38256, rxn38...
# 12         GAPDH1_h  ...                     [rxn00782, rxn17199, rxn37888]
# 13            TPI_h  ...                     [rxn00747, rxn27386, rxn33035]
# 14           FBPA_h  ...           [rxn00786, rxn01334, rxn01870, rxn31335]
# 15         FBPase_h  ...                               [rxn00549, rxn31218]
# 16            FTK_h  ...                               [rxn00785, rxn31366]
# 17           SBPA_h  ...  [rxn00786, rxn01334, rxn01870, rxn28981, rxn31...
# 18         SBPase_h  ...           [rxn01345, rxn28982, rxn31076, rxn33873]
# 19            STK_h  ...           [rxn01200, rxn15228, rxn27495, rxn34273]
# 20          Ru5PE_h  ...                               [rxn01116, rxn28146]
# 21           R5PI_h  ...  [rxn00777, rxn08113, rxn15114, rxn28141, rxn34...
# 22          Ru5PK_h  ...                     [rxn01111, rxn28078, rxn38263]
# 23            PGI_h  ...                     [rxn00558, rxn01977, rxn34259]
# 24            PGM_h  ...           [rxn00704, rxn12204, rxn15773, rxn33867]
# 25         AGPase_h  ...                               [rxn00695, rxn19776]
# 26           StS1_h  ...                     [rxn13643, rxn15562, rxn31314]
# 27           StS2_h  ...                     [rxn13643, rxn15562, rxn31314]
# 28           StS3_h  ...                     [rxn13643, rxn15562, rxn31314]
# 29          bAMY1_h  ...                                         [rxn15591]
# 30          bAMY2_h  ...                                         [rxn15591]
# 31          DPE11_h  ...  [rxn08126, rxn08127, rxn08128, rxn08129, rxn15...
# 32          DPE12_h  ...  [rxn08126, rxn08127, rxn08128, rxn08129, rxn15...
# 33          DPE13_h  ...  [rxn08126, rxn08127, rxn08128, rxn08129, rxn15...
# 34           DPE2_c  ...  [rxn08126, rxn08127, rxn08128, rxn08129, rxn15...
# 35           HEXK_c  ...  [rxn00216, rxn00518, rxn00976, rxn00978, rxn01...
# 36           StP1_h  ...  [rxn08611, rxn08941, rxn08942, rxn08943, rxn15...
# 37          StP21_c  ...  [rxn08611, rxn08941, rxn08942, rxn08943, rxn15...
# 38            TPI_c  ...                     [rxn00747, rxn27386, rxn33035]
# 39           FBPA_c  ...           [rxn00786, rxn01334, rxn01870, rxn31335]
# 40         FBPase_c  ...                               [rxn00549, rxn31218]
# 41          F6PK2_c  ...                     [rxn01971, rxn30180, rxn39359]
# 42        F26BPPh_c  ...                                         [rxn00550]
# 43            PGI_c  ...                     [rxn00558, rxn01977, rxn34259]
# 44            PGM_c  ...           [rxn00704, rxn12204, rxn15773, rxn33867]
# 45         UGPase_c  ...                               [rxn00213, rxn38117]
# 46           S6PS_c  ...                               [rxn00553, rxn15062]
# 47          S6PPh_c  ...                     [rxn00578, rxn31083, rxn31919]
# 48           SucS_c  ...                               [rxn00579, rxn33446]
# 49          FrcFD_c  ...  [rxn02596, rxn02760, rxn15069, rxn28252, rxn28...
#
# [50 rows x 9 columns]

# %%
(df_reactions_aracore['bigg_id_aggr'].apply(len) != 0).value_counts() #298 reactions have at least one bigg id
# Out:
# True     298
# False    274
# Name: bigg_id_aggr, dtype: int64

# %%
(df_reactions_aracore['seed_id_aggr'].apply(len) != 0).value_counts() #320 reactions have at least one seed id
# Out:
# True     320
# False    252
# Name: seed_id_aggr, dtype: int64

# %%
#Export final mapping table for manual mapping
df_reactions_aracore.to_csv('drive/MyDrive/2021-05-31-reactions-mapping-table.csv')
